# %% [markdown]
# # CPE Format Converter (POC) example Jupyter Notebook
#
# This is a proof of concept for a CPE Format Converter.
#
# ## Description
#
# Due to time constraints, the construction logic and thought process of this Proof of Concept (PoC) will be initially presented in this Jupyter Notebook. Further development and maintenance will continue to implement more comprehensive functionalities, such as automation and a Web User Interface.
#
# > 由於時間限制，此概念驗證（PoC）的建構邏輯與思路將以本 Jupyter Notebook 的形式初步呈現。後續將持續進行開發與維護，以實現自動化、Web 使用者介面等更完善的功能。
#
# ## Design
#
# This Proof of Concept (PoC) aims to provide users with a tool to search for vulnerabilities associated with specific products by inputting Vendor, Product, and Version information. The tool will interact with the National Vulnerability Database (NVD) Common Vulnerabilities and Exposures (CVE) database to retrieve relevant CVE vulnerability data. Since the NVD Vulnerability API (CVE API) uses Common Platform Enumeration (CPE) for searching, user input needs to be converted into CPE format. However, while the CPE format has a standardized specification, there is no standard conversion process, and it cannot be guaranteed that the converted CPE is included in the NVD. To address this issue, we will use the NVD's CPE Directory List as a foundation to convert user input and obtain or generate the correct CPE, subsequently using the NVD Vulnerability API to retrieve further vulnerability data.
#
# > 本概念驗證（PoC）旨在提供使用者一個工具，透過輸入廠商（Vendor）、產品（Product）和版本（Version）資訊，搜尋相關產品的漏洞（Vulnerability）。此工具將與美國國家漏洞資料庫（NVD）的通用漏洞披露（CVE）資料庫互動，取得相關的 CVE 漏洞資訊。由於 NVD 的漏洞應用程式介面（CVE API）使用通用平台列舉（CPE）進行搜尋，因此需要將使用者輸入轉換為 CPE 格式。然而，儘管 CPE 格式具有標準化的規範，卻缺乏標準的轉換流程，且無法確定轉換後的 CPE 是否已被 NVD 收錄。為解決此問題，我們將利用 NVD 提供的 CPE 目錄列表（CPE Directory List）作為基礎，進行使用者輸入的轉換，並取得或產生正確的 CPE，進而使用 NVD 的漏洞應用程式介面取得後續的漏洞資料。
#
# ## Usage
#
# We will leverage the interactive features of Jupyter Notebook to provide detailed explanations of the operational process through segmented code, allowing users to reproduce the same operational results by executing this notebook. Please follow the subsequent operational instructions and code comments for adjustments and execution.
#
# > 我們將利用 Jupyter Notebook 的互動式特性，以分段程式碼的方式詳細說明操作流程，並允許使用者透過執行本 Notebook 複現相同的操作結果。請依照後續的操作說明與程式碼註解進行調整與執行。

# %% [markdown]
# ## Step 1: Get Offical CPE Directory List
#
# Please manually download the CPE Directory List from the official National Vulnerability Database (NVD) website and place the file in the `data` directory of the project repository (Repo). If you have any questions about the operation, please refer to the README file in the `data` directory.
#
# > 請手動自美國國家漏洞資料庫（NVD）官方網站下載 CPE 目錄列表（CPE Directory List），並將檔案放置於專案儲存庫（Repo）的 `data` 目錄中。若對操作方式有疑問，請參閱 `data` 目錄中的 README 檔案。

# %% [markdown]
# ## Step 2: Decompression and Data Pre-processing
#
# The Common Platform Enumeration (CPE) list provided by the National Vulnerability Database (NVD) is in XML format. While detailed and comprehensive, its structure is not ideal for direct import into Chromadb for subsequent operations. Therefore, we will filter and organize the XML content of the CPE list and output it in Comma-Separated Values (CSV) format.
#
# (Converting to CSV format is a non-essential transitional step, primarily to facilitate the review of the organized XML data and accelerate data utilization and analysis.)
#
# The resulting structured CSV data (or Dataframe) will be processed and imported into Chromadb in the subsequent steps.
#
#
# > 由於美國國家漏洞資料庫（NVD）提供的通用平台列舉（CPE）列表為 XML 格式，其結構雖詳盡完整，但不利於直接匯入 Chromadb 進行後續操作。因此，我們將對 CPE 列表的 XML 內容進行篩選與整理，並轉換為逗號分隔值（CSV）格式輸出。
# >
# > （轉換為 CSV 格式為一非必要的過渡步驟，主要目的是為了方便檢視整理後的 XML 資料，以加速資料的使用與分析。）
# >
# > 轉換後的 CSV 結構化資料（或 Dataframe）將於後續步驟中進行計算並匯入 Chromadb。

# %%
from lxml import etree
import json
import csv
from typing import Dict, List, Iterator, Optional, Tuple
import logging
from pathlib import Path
import re
from dataclasses import dataclass, asdict
from contextlib import contextmanager


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class CPEParser:
    """CPE XML 字典的解析器，用於將 CPE 項目轉換為結構化資料"""

    # CPE 命名空間定義
    NAMESPACES = {
        'cpe-23': 'http://scap.nist.gov/schema/cpe-extension/2.3',
        'def': 'http://cpe.mitre.org/dictionary/2.0',
        'xml': 'http://www.w3.org/XML/1998/namespace'
    }

    def __init__(self, xml_file_path: str):
        """初始化 CPE 解析器

        Args:
            xml_file_path (str): XML 檔案路徑
        """
        self.xml_file_path = Path(xml_file_path)
        self.logger = logging.getLogger(__name__)

        if not self.xml_file_path.exists():
            raise FileNotFoundError(f"找不到 XML 檔案: {xml_file_path}")

    @staticmethod
    def parse_cpe23_uri(cpe23uri: str) -> Dict[str, str]:
        """解析 CPE 2.3 URI 並提取各個組件

        Args:
            cpe23uri (str): CPE 2.3 URI 字串 (例如: cpe:2.3:a:vendor:product:version:...)

        Returns:
            Dict[str, str]: 包含廠商、產品和版本資訊的字典
        """
        # CPE 2.3 格式: cpe:2.3:part:vendor:product:version:update:edition:language:sw_edition:target_sw:target_hw:other
        components = cpe23uri.split(':')

        if len(components) < 6:
            return {"vendor": "", "product": "", "version": ""}

        return {
            'vendor': components[3],
            'product': components[4],
            'version': components[5]
        }

    @contextmanager
    def _open_xml_context(self) -> Iterator:
        """創建用於迭代 XML 檔案中 CPE 項目的上下文管理器

        Yields:
            Iterator: 用於迭代 XML 檔案中 CPE 項目的迭代器
        """
        try:
            context = etree.iterparse(
                str(self.xml_file_path),
                events=('end',),
                tag=f'{{{self.NAMESPACES["def"]}}}cpe-item'
            )
            yield context
        except etree.ParseError as e:
            self.logger.error(f"XML 解析錯誤: {e}")
            raise
        except Exception as e:
            self.logger.error(f"處理 XML 時發生未預期的錯誤: {e}")
            raise

    def _extract_item_data(self, item: etree._Element) -> Optional[CPEItem]:
        """從 XML 元素中提取 CPE 項目資料

        Args:
            item (etree._Element): 包含 CPE 項目資料的 XML 元素

        Returns:
            Optional[CPEItem]: 如果成功提取則返回 CPEItem 物件，否則返回 None
        """
        try:
            # 取得 CPE 2.3 URI
            cpe23_item = item.find('.//cpe-23:cpe23-item', self.NAMESPACES)
            if cpe23_item is None:
                return None

            cpe23uri = cpe23_item.get('name', '')
            if not cpe23uri:
                return None

            # 解析 CPE 組件
            cpe_components = self.parse_cpe23_uri(cpe23uri)

            # 取得標題
            title_elem = item.find(
                './/def:title[@xml:lang="en-US"]', self.NAMESPACES)
            title = title_elem.text if title_elem is not None else ""

            # 取得參考資料
            references = self._extract_references(item)

            # 建立 CPE 項目物件
            return CPEItem(
                cpe22Uri=item.get('name', ''),
                cpe23Uri=cpe23uri,
                vendor=cpe_components['vendor'],
                product=cpe_components['product'],
                version=cpe_components['version'],
                title=title,
                references=references
            )
        except Exception as e:
            self.logger.warning(f"提取 CPE 項目時發生錯誤: {e}")
            return None

    def _extract_references(self, item: etree._Element) -> str:
        """從 XML 元素中提取參考資料

        Args:
            item (etree._Element): 包含參考資料的 XML 元素

        Returns:
            str: 格式化的參考資料字串
        """
        refs = item.findall('.//def:reference', self.NAMESPACES)
        ref_texts = []

        for ref in refs:
            href = ref.get('href', '')
            ref_text = ref.text or ''

            if href and ref_text:
                ref_texts.append(f"{ref_text} ({href})")
            elif href:
                ref_texts.append(href)
            elif ref_text:
                ref_texts.append(ref_text)

        return ' '.join(ref_texts)

    def _clear_element_memory(self, item: etree._Element) -> None:
        """清理 XML 元素佔用的記憶體

        Args:
            item (etree._Element): 要清理的 XML 元素
        """
        item.clear()
        # 清理前面的同層級元素以釋放記憶體
        while item.getprevious() is not None:
            del item.getparent()[0]

    def parse_xml(self) -> List[Dict]:
        """解析整個 CPE XML 檔案

        Returns:
            List[Dict]: 解析後的 CPE 資料列表
        """
        self.logger.info(f"開始解析 XML 檔案: {self.xml_file_path}")
        cpe_items = []

        with self._open_xml_context() as context:
            for event, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    cpe_items.append(asdict(cpe_item))

                self._clear_element_memory(item)

        self.logger.info(f"解析完成，共提取 {len(cpe_items)} 個 CPE 項目")
        return cpe_items

    def process_by_chunk(self, chunk_size: int = 1000) -> Iterator[List[Dict]]:
        """使用分批處理方式處理大型 XML 檔案

        Args:
            chunk_size (int, optional): 每批處理的項目數量. 預設為 1000.

        Yields:
            List[Dict]: 每批處理的 CPE 項目列表
        """
        self.logger.info(f"開始分批處理 XML 檔案 (每批 {chunk_size} 個項目)")
        items = []
        total_processed = 0

        with self._open_xml_context() as context:
            for event, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    items.append(asdict(cpe_item))

                self._clear_element_memory(item)

                if len(items) >= chunk_size:
                    total_processed += len(items)
                    self.logger.debug(f"已處理 {total_processed} 個項目")
                    yield items
                    items = []

            if items:
                total_processed += len(items)
                self.logger.debug(f"已處理 {total_processed} 個項目")
                yield items

        self.logger.info(f"分批處理完成，總共處理 {total_processed} 個項目")

    def save_to_json(self, output_file: str, items: Optional[List[Dict]] = None) -> None:
        """將解析結果儲存為 JSON 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict]], optional): 要儲存的項目列表，如果為 None 則會解析 XML 檔案. 預設為 None.
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            cpe_items = items if items is not None else self.parse_xml()

            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(cpe_items, f, ensure_ascii=False, indent=2)

            self.logger.info(
                f"已成功儲存 {len(cpe_items)} 個項目至 JSON 檔案: {output_path}")

        except Exception as e:
            self.logger.error(f"儲存 JSON 檔案時發生錯誤: {e}")
            raise

    def save_to_csv(self, output_file: str, items: Optional[List[Dict]] = None) -> None:
        """將解析結果儲存為 CSV 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict]], optional): 要儲存的項目列表，如果為 None 則會解析 XML 檔案. 預設為 None.
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            cpe_items = items if items is not None else self.parse_xml()
            fieldnames = ['cpe22Uri', 'cpe23Uri', 'vendor', 'product',
                          'version', 'title', 'references']

            with open(output_path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(cpe_items)

            self.logger.info(
                f"已成功儲存 {len(cpe_items)} 個項目至 CSV 檔案: {output_path}")

        except Exception as e:
            self.logger.error(f"儲存 CSV 檔案時發生錯誤: {e}")
            raise


def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


def main():
    """主程式進入點"""
    # 設定日誌
    log_file = "../logs/cpe_parser.log"
    setup_logging(log_level=logging.INFO, log_file=log_file)
    logger = logging.getLogger(__name__)

    # 設定檔案路徑
    input_file = "../data/official-cpe-dictionary_v2.3.xml"
    output_dir = Path("../data/convert")
    output_dir.mkdir(parents=True, exist_ok=True)

    output_json = output_dir / "official-cpe-dictionary_v2.3_v2.json"
    output_csv = output_dir / "official-cpe-dictionary_v2.3_v2.csv"

    try:
        logger.info(f"開始處理 CPE 字典檔案: {input_file}")
        parser = CPEParser(input_file)

        # 使用分批處理解析 XML 檔案並儲存結果
        all_items = []
        total_processed = 0

        for chunk in parser.process_by_chunk(chunk_size=1000):
            all_items.extend(chunk)
            total_processed += len(chunk)
            logger.info(f"已處理 {total_processed} 個項目")

        # 儲存為 JSON 和 CSV
        parser.save_to_json(str(output_json), all_items)
        parser.save_to_csv(str(output_csv), all_items)

        logger.info("程式執行完成")

    except FileNotFoundError as e:
        logger.error(f"找不到檔案: {e}")
    except Exception as e:
        logger.error(f"程式執行失敗: {e}", exc_info=True)


if __name__ == "__main__":
    main()
# Out:
# 2025-03-12 08:35:41,999 - __main__ - INFO - 開始處理 CPE 字典檔案: ../data/official-cpe-dictionary_v2.3.xml
# 2025-03-12 08:35:42,000 - __main__ - INFO - 開始分批處理 XML 檔案 (每批 1000 個項目)
# 2025-03-12 08:35:42,030 - __main__ - INFO - 已處理 1000 個項目
# 2025-03-12 08:35:42,058 - __main__ - INFO - 已處理 2000 個項目
# 2025-03-12 08:35:42,087 - __main__ - INFO - 已處理 3000 個項目
# 2025-03-12 08:35:42,116 - __main__ - INFO - 已處理 4000 個項目
# 2025-03-12 08:35:42,145 - __main__ - INFO - 已處理 5000 個項目
# 2025-03-12 08:35:42,174 - __main__ - INFO - 已處理 6000 個項目
# 2025-03-12 08:35:42,203 - __main__ - INFO - 已處理 7000 個項目
# 2025-03-12 08:35:42,233 - __main__ - INFO - 已處理 8000 個項目
# 2025-03-12 08:35:42,262 - __main__ - INFO - 已處理 9000 個項目
# 2025-03-12 08:35:42,291 - __main__ - INFO - 已處理 10000 個項目
# 2025-03-12 08:35:42,320 - __main__ - INFO - 已處理 11000 個項目
# 2025-03-12 08:35:42,349 - __main__ - INFO - 已處理 12000 個項目
# 2025-03-12 08:35:42,378 - __main__ - INFO - 已處理 13000 個項目
# 2025-03-12 08:35:42,408 - __main__ - INFO - 已處理 14000 個項目
# 2025-03-12 08:35:42,437 - __main__ - INFO - 已處理 15000 個項目
# 2025-03-12 08:35:42,466 - __main__ - INFO - 已處理 16000 個項目
# 2025-03-12 08:35:42,494 - __main__ - INFO - 已處理 17000 個項目
# 2025-03-12 08:35:42,522 - __main__ - INFO - 已處理 18000 個項目
# 2025-03-12 08:35:42,554 - __main__ - INFO - 已處理 19000 個項目
# 2025-03-12 08:35:42,582 - __main__ - INFO - 已處理 20000 個項目
# 2025-03-12 08:35:42,610 - __main__ - INFO - 已處理 21000 個項目
# 2025-03-12 08:35:42,641 - __main__ - INFO - 已處理 22000 個項目
# 2025-03-12 08:35:42,671 - __main__ - INFO - 已處理 23000 個項目
# 2025-03-12 08:35:42,701 - __main__ - INFO - 已處理 24000 個項目
# 2025-03-12 08:35:42,730 - __main__ - INFO - 已處理 25000 個項目
# 2025-03-12 08:35:42,759 - __main__ - INFO - 已處理 26000 個項目
# 2025-03-12 08:35:42,789 - __main__ - INFO - 已處理 27000 個項目
# 2025-03-12 08:35:42,819 - __main__ - INFO - 已處理 28000 個項目
# 2025-03-12 08:35:42,869 - __main__ - INFO - 已處理 29000 個項目
# 2025-03-12 08:35:42,898 - __main__ - INFO - 已處理 30000 個項目
# 2025-03-12 08:35:42,928 - __main__ - INFO - 已處理 31000 個項目
# 2025-03-12 08:35:42,958 - __main__ - INFO - 已處理 32000 個項目
# 2025-03-12 08:35:42,987 - __main__ - INFO - 已處理 33000 個項目
# 2025-03-12 08:35:43,017 - __main__ - INFO - 已處理 34000 個項目
# 2025-03-12 08:35:43,046 - __main__ - INFO - 已處理 35000 個項目
# 2025-03-12 08:35:43,076 - __main__ - INFO - 已處理 36000 個項目
# 2025-03-12 08:35:43,104 - __main__ - INFO - 已處理 37000 個項目
# 2025-03-12 08:35:43,134 - __main__ - INFO - 已處理 38000 個項目
# 2025-03-12 08:35:43,164 - __main__ - INFO - 已處理 39000 個項目
# 2025-03-12 08:35:43,193 - __main__ - INFO - 已處理 40000 個項目
# 2025-03-12 08:35:43,222 - __main__ - INFO - 已處理 41000 個項目
# 2025-03-12 08:35:43,250 - __main__ - INFO - 已處理 42000 個項目
# 2025-03-12 08:35:43,281 - __main__ - INFO - 已處理 43000 個項目
# 2025-03-12 08:35:43,310 - __main__ - INFO - 已處理 44000 個項目
# 2025-03-12 08:35:43,340 - __main__ - INFO - 已處理 45000 個項目
# 2025-03-12 08:35:43,369 - __main__ - INFO - 已處理 46000 個項目
# 2025-03-12 08:35:43,398 - __main__ - INFO - 已處理 47000 個項目
# 2025-03-12 08:35:43,427 - __main__ - INFO - 已處理 48000 個項目
# 2025-03-12 08:35:43,456 - __main__ - INFO - 已處理 49000 個項目
# 2025-03-12 08:35:43,486 - __main__ - INFO - 已處理 50000 個項目
# 2025-03-12 08:35:43,516 - __main__ - INFO - 已處理 51000 個項目
# 2025-03-12 08:35:43,544 - __main__ - INFO - 已處理 52000 個項目
# 2025-03-12 08:35:43,573 - __main__ - INFO - 已處理 53000 個項目
# 2025-03-12 08:35:43,603 - __main__ - INFO - 已處理 54000 個項目
# 2025-03-12 08:35:43,630 - __main__ - INFO - 已處理 55000 個項目
# 2025-03-12 08:35:43,658 - __main__ - INFO - 已處理 56000 個項目
# 2025-03-12 08:35:43,687 - __main__ - INFO - 已處理 57000 個項目
# 2025-03-12 08:35:43,715 - __main__ - INFO - 已處理 58000 個項目
# 2025-03-12 08:35:43,744 - __main__ - INFO - 已處理 59000 個項目
# 2025-03-12 08:35:43,772 - __main__ - INFO - 已處理 60000 個項目
# 2025-03-12 08:35:43,800 - __main__ - INFO - 已處理 61000 個項目
# 2025-03-12 08:35:43,828 - __main__ - INFO - 已處理 62000 個項目
# 2025-03-12 08:35:43,857 - __main__ - INFO - 已處理 63000 個項目
# 2025-03-12 08:35:43,885 - __main__ - INFO - 已處理 64000 個項目
# 2025-03-12 08:35:43,913 - __main__ - INFO - 已處理 65000 個項目
# 2025-03-12 08:35:43,941 - __main__ - INFO - 已處理 66000 個項目
# 2025-03-12 08:35:43,969 - __main__ - INFO - 已處理 67000 個項目
# 2025-03-12 08:35:43,997 - __main__ - INFO - 已處理 68000 個項目
# 2025-03-12 08:35:44,024 - __main__ - INFO - 已處理 69000 個項目
# 2025-03-12 08:35:44,052 - __main__ - INFO - 已處理 70000 個項目
# 2025-03-12 08:35:44,081 - __main__ - INFO - 已處理 71000 個項目
# 2025-03-12 08:35:44,110 - __main__ - INFO - 已處理 72000 個項目
# 2025-03-12 08:35:44,141 - __main__ - INFO - 已處理 73000 個項目
# 2025-03-12 08:35:44,171 - __main__ - INFO - 已處理 74000 個項目
# 2025-03-12 08:35:44,199 - __main__ - INFO - 已處理 75000 個項目
# 2025-03-12 08:35:44,225 - __main__ - INFO - 已處理 76000 個項目
# 2025-03-12 08:35:44,252 - __main__ - INFO - 已處理 77000 個項目
# 2025-03-12 08:35:44,280 - __main__ - INFO - 已處理 78000 個項目
# 2025-03-12 08:35:44,308 - __main__ - INFO - 已處理 79000 個項目
# 2025-03-12 08:35:44,336 - __main__ - INFO - 已處理 80000 個項目
# 2025-03-12 08:35:44,366 - __main__ - INFO - 已處理 81000 個項目
# 2025-03-12 08:35:44,394 - __main__ - INFO - 已處理 82000 個項目
# 2025-03-12 08:35:44,423 - __main__ - INFO - 已處理 83000 個項目
# 2025-03-12 08:35:44,453 - __main__ - INFO - 已處理 84000 個項目
# 2025-03-12 08:35:44,482 - __main__ - INFO - 已處理 85000 個項目
# 2025-03-12 08:35:44,510 - __main__ - INFO - 已處理 86000 個項目
# 2025-03-12 08:35:44,538 - __main__ - INFO - 已處理 87000 個項目
# 2025-03-12 08:35:44,567 - __main__ - INFO - 已處理 88000 個項目
# 2025-03-12 08:35:44,595 - __main__ - INFO - 已處理 89000 個項目
# 2025-03-12 08:35:44,624 - __main__ - INFO - 已處理 90000 個項目
# 2025-03-12 08:35:44,650 - __main__ - INFO - 已處理 91000 個項目
# 2025-03-12 08:35:44,679 - __main__ - INFO - 已處理 92000 個項目
# 2025-03-12 08:35:44,708 - __main__ - INFO - 已處理 93000 個項目
# 2025-03-12 08:35:44,736 - __main__ - INFO - 已處理 94000 個項目
# 2025-03-12 08:35:44,765 - __main__ - INFO - 已處理 95000 個項目
# 2025-03-12 08:35:44,794 - __main__ - INFO - 已處理 96000 個項目
# 2025-03-12 08:35:44,822 - __main__ - INFO - 已處理 97000 個項目
# 2025-03-12 08:35:44,850 - __main__ - INFO - 已處理 98000 個項目
# 2025-03-12 08:35:44,880 - __main__ - INFO - 已處理 99000 個項目
# 2025-03-12 08:35:44,909 - __main__ - INFO - 已處理 100000 個項目
# 2025-03-12 08:35:44,937 - __main__ - INFO - 已處理 101000 個項目
# 2025-03-12 08:35:44,966 - __main__ - INFO - 已處理 102000 個項目
# 2025-03-12 08:35:44,995 - __main__ - INFO - 已處理 103000 個項目
# 2025-03-12 08:35:45,025 - __main__ - INFO - 已處理 104000 個項目
# 2025-03-12 08:35:45,054 - __main__ - INFO - 已處理 105000 個項目
# 2025-03-12 08:35:45,083 - __main__ - INFO - 已處理 106000 個項目
# 2025-03-12 08:35:45,113 - __main__ - INFO - 已處理 107000 個項目
# 2025-03-12 08:35:45,143 - __main__ - INFO - 已處理 108000 個項目
# 2025-03-12 08:35:45,171 - __main__ - INFO - 已處理 109000 個項目
# 2025-03-12 08:35:45,200 - __main__ - INFO - 已處理 110000 個項目
# 2025-03-12 08:35:45,232 - __main__ - INFO - 已處理 111000 個項目
# 2025-03-12 08:35:45,263 - __main__ - INFO - 已處理 112000 個項目
# 2025-03-12 08:35:45,292 - __main__ - INFO - 已處理 113000 個項目
# 2025-03-12 08:35:45,323 - __main__ - INFO - 已處理 114000 個項目
# 2025-03-12 08:35:45,354 - __main__ - INFO - 已處理 115000 個項目
# 2025-03-12 08:35:45,383 - __main__ - INFO - 已處理 116000 個項目
# 2025-03-12 08:35:45,412 - __main__ - INFO - 已處理 117000 個項目
# 2025-03-12 08:35:45,442 - __main__ - INFO - 已處理 118000 個項目
# 2025-03-12 08:35:45,471 - __main__ - INFO - 已處理 119000 個項目
# 2025-03-12 08:35:45,499 - __main__ - INFO - 已處理 120000 個項目
# 2025-03-12 08:35:45,528 - __main__ - INFO - 已處理 121000 個項目
# 2025-03-12 08:35:45,557 - __main__ - INFO - 已處理 122000 個項目
# 2025-03-12 08:35:45,588 - __main__ - INFO - 已處理 123000 個項目
# 2025-03-12 08:35:45,618 - __main__ - INFO - 已處理 124000 個項目
# 2025-03-12 08:35:45,647 - __main__ - INFO - 已處理 125000 個項目
# 2025-03-12 08:35:45,676 - __main__ - INFO - 已處理 126000 個項目
# 2025-03-12 08:35:45,703 - __main__ - INFO - 已處理 127000 個項目
# 2025-03-12 08:35:45,732 - __main__ - INFO - 已處理 128000 個項目
# 2025-03-12 08:35:45,760 - __main__ - INFO - 已處理 129000 個項目
# 2025-03-12 08:35:45,790 - __main__ - INFO - 已處理 130000 個項目
# 2025-03-12 08:35:45,818 - __main__ - INFO - 已處理 131000 個項目
# 2025-03-12 08:35:45,848 - __main__ - INFO - 已處理 132000 個項目
# 2025-03-12 08:35:45,876 - __main__ - INFO - 已處理 133000 個項目
# 2025-03-12 08:35:45,904 - __main__ - INFO - 已處理 134000 個項目
# 2025-03-12 08:35:45,933 - __main__ - INFO - 已處理 135000 個項目
# 2025-03-12 08:35:45,962 - __main__ - INFO - 已處理 136000 個項目
# 2025-03-12 08:35:45,992 - __main__ - INFO - 已處理 137000 個項目
# 2025-03-12 08:35:46,020 - __main__ - INFO - 已處理 138000 個項目
# 2025-03-12 08:35:46,049 - __main__ - INFO - 已處理 139000 個項目
# 2025-03-12 08:35:46,077 - __main__ - INFO - 已處理 140000 個項目
# 2025-03-12 08:35:46,107 - __main__ - INFO - 已處理 141000 個項目
# 2025-03-12 08:35:46,136 - __main__ - INFO - 已處理 142000 個項目
# 2025-03-12 08:35:46,165 - __main__ - INFO - 已處理 143000 個項目
# 2025-03-12 08:35:46,194 - __main__ - INFO - 已處理 144000 個項目
# 2025-03-12 08:35:46,222 - __main__ - INFO - 已處理 145000 個項目
# 2025-03-12 08:35:46,252 - __main__ - INFO - 已處理 146000 個項目
# 2025-03-12 08:35:46,282 - __main__ - INFO - 已處理 147000 個項目
# 2025-03-12 08:35:46,311 - __main__ - INFO - 已處理 148000 個項目
# 2025-03-12 08:35:46,339 - __main__ - INFO - 已處理 149000 個項目
# 2025-03-12 08:35:46,367 - __main__ - INFO - 已處理 150000 個項目
# 2025-03-12 08:35:46,395 - __main__ - INFO - 已處理 151000 個項目
# 2025-03-12 08:35:46,425 - __main__ - INFO - 已處理 152000 個項目
# 2025-03-12 08:35:46,456 - __main__ - INFO - 已處理 153000 個項目
# 2025-03-12 08:35:46,486 - __main__ - INFO - 已處理 154000 個項目
# 2025-03-12 08:35:46,515 - __main__ - INFO - 已處理 155000 個項目
# 2025-03-12 08:35:46,542 - __main__ - INFO - 已處理 156000 個項目
# 2025-03-12 08:35:46,571 - __main__ - INFO - 已處理 157000 個項目
# 2025-03-12 08:35:46,601 - __main__ - INFO - 已處理 158000 個項目
# 2025-03-12 08:35:46,630 - __main__ - INFO - 已處理 159000 個項目
# 2025-03-12 08:35:46,659 - __main__ - INFO - 已處理 160000 個項目
# 2025-03-12 08:35:46,686 - __main__ - INFO - 已處理 161000 個項目
# 2025-03-12 08:35:46,716 - __main__ - INFO - 已處理 162000 個項目
# 2025-03-12 08:35:46,744 - __main__ - INFO - 已處理 163000 個項目
# 2025-03-12 08:35:46,774 - __main__ - INFO - 已處理 164000 個項目
# 2025-03-12 08:35:46,802 - __main__ - INFO - 已處理 165000 個項目
# 2025-03-12 08:35:46,832 - __main__ - INFO - 已處理 166000 個項目
# 2025-03-12 08:35:46,862 - __main__ - INFO - 已處理 167000 個項目
# 2025-03-12 08:35:46,890 - __main__ - INFO - 已處理 168000 個項目
# 2025-03-12 08:35:46,920 - __main__ - INFO - 已處理 169000 個項目
# 2025-03-12 08:35:46,949 - __main__ - INFO - 已處理 170000 個項目
# 2025-03-12 08:35:46,978 - __main__ - INFO - 已處理 171000 個項目
# 2025-03-12 08:35:47,006 - __main__ - INFO - 已處理 172000 個項目
# 2025-03-12 08:35:47,035 - __main__ - INFO - 已處理 173000 個項目
# 2025-03-12 08:35:47,065 - __main__ - INFO - 已處理 174000 個項目
# 2025-03-12 08:35:47,094 - __main__ - INFO - 已處理 175000 個項目
# 2025-03-12 08:35:47,123 - __main__ - INFO - 已處理 176000 個項目
# 2025-03-12 08:35:47,153 - __main__ - INFO - 已處理 177000 個項目
# 2025-03-12 08:35:47,182 - __main__ - INFO - 已處理 178000 個項目
# 2025-03-12 08:35:47,212 - __main__ - INFO - 已處理 179000 個項目
# 2025-03-12 08:35:47,240 - __main__ - INFO - 已處理 180000 個項目
# 2025-03-12 08:35:47,269 - __main__ - INFO - 已處理 181000 個項目
# 2025-03-12 08:35:47,298 - __main__ - INFO - 已處理 182000 個項目
# 2025-03-12 08:35:47,326 - __main__ - INFO - 已處理 183000 個項目
# 2025-03-12 08:35:47,355 - __main__ - INFO - 已處理 184000 個項目
# 2025-03-12 08:35:47,384 - __main__ - INFO - 已處理 185000 個項目
# 2025-03-12 08:35:47,410 - __main__ - INFO - 已處理 186000 個項目
# 2025-03-12 08:35:47,437 - __main__ - INFO - 已處理 187000 個項目
# 2025-03-12 08:35:47,466 - __main__ - INFO - 已處理 188000 個項目
# 2025-03-12 08:35:47,493 - __main__ - INFO - 已處理 189000 個項目
# 2025-03-12 08:35:47,523 - __main__ - INFO - 已處理 190000 個項目
# 2025-03-12 08:35:47,552 - __main__ - INFO - 已處理 191000 個項目
# 2025-03-12 08:35:47,582 - __main__ - INFO - 已處理 192000 個項目
# 2025-03-12 08:35:47,612 - __main__ - INFO - 已處理 193000 個項目
# 2025-03-12 08:35:47,641 - __main__ - INFO - 已處理 194000 個項目
# 2025-03-12 08:35:47,670 - __main__ - INFO - 已處理 195000 個項目
# 2025-03-12 08:35:47,697 - __main__ - INFO - 已處理 196000 個項目
# 2025-03-12 08:35:47,726 - __main__ - INFO - 已處理 197000 個項目
# 2025-03-12 08:35:47,753 - __main__ - INFO - 已處理 198000 個項目
# 2025-03-12 08:35:47,782 - __main__ - INFO - 已處理 199000 個項目
# 2025-03-12 08:35:47,811 - __main__ - INFO - 已處理 200000 個項目
# 2025-03-12 08:35:47,839 - __main__ - INFO - 已處理 201000 個項目
# 2025-03-12 08:35:47,866 - __main__ - INFO - 已處理 202000 個項目
# 2025-03-12 08:35:47,893 - __main__ - INFO - 已處理 203000 個項目
# 2025-03-12 08:35:47,919 - __main__ - INFO - 已處理 204000 個項目
# 2025-03-12 08:35:47,946 - __main__ - INFO - 已處理 205000 個項目
# 2025-03-12 08:35:47,972 - __main__ - INFO - 已處理 206000 個項目
# 2025-03-12 08:35:48,000 - __main__ - INFO - 已處理 207000 個項目
# 2025-03-12 08:35:48,029 - __main__ - INFO - 已處理 208000 個項目
# 2025-03-12 08:35:48,057 - __main__ - INFO - 已處理 209000 個項目
# 2025-03-12 08:35:48,086 - __main__ - INFO - 已處理 210000 個項目
# 2025-03-12 08:35:48,116 - __main__ - INFO - 已處理 211000 個項目
# 2025-03-12 08:35:48,145 - __main__ - INFO - 已處理 212000 個項目
# 2025-03-12 08:35:48,173 - __main__ - INFO - 已處理 213000 個項目
# 2025-03-12 08:35:48,203 - __main__ - INFO - 已處理 214000 個項目
# 2025-03-12 08:35:48,232 - __main__ - INFO - 已處理 215000 個項目
# 2025-03-12 08:35:48,261 - __main__ - INFO - 已處理 216000 個項目
# 2025-03-12 08:35:48,290 - __main__ - INFO - 已處理 217000 個項目
# 2025-03-12 08:35:48,319 - __main__ - INFO - 已處理 218000 個項目
# 2025-03-12 08:35:48,347 - __main__ - INFO - 已處理 219000 個項目
# 2025-03-12 08:35:48,375 - __main__ - INFO - 已處理 220000 個項目
# 2025-03-12 08:35:48,404 - __main__ - INFO - 已處理 221000 個項目
# 2025-03-12 08:35:48,432 - __main__ - INFO - 已處理 222000 個項目
# 2025-03-12 08:35:48,459 - __main__ - INFO - 已處理 223000 個項目
# 2025-03-12 08:35:48,487 - __main__ - INFO - 已處理 224000 個項目
# 2025-03-12 08:35:48,516 - __main__ - INFO - 已處理 225000 個項目
# 2025-03-12 08:35:48,544 - __main__ - INFO - 已處理 226000 個項目
# 2025-03-12 08:35:48,572 - __main__ - INFO - 已處理 227000 個項目
# 2025-03-12 08:35:48,600 - __main__ - INFO - 已處理 228000 個項目
# 2025-03-12 08:35:48,629 - __main__ - INFO - 已處理 229000 個項目
# 2025-03-12 08:35:48,660 - __main__ - INFO - 已處理 230000 個項目
# 2025-03-12 08:35:48,690 - __main__ - INFO - 已處理 231000 個項目
# 2025-03-12 08:35:48,719 - __main__ - INFO - 已處理 232000 個項目
# 2025-03-12 08:35:48,748 - __main__ - INFO - 已處理 233000 個項目
# 2025-03-12 08:35:48,777 - __main__ - INFO - 已處理 234000 個項目
# 2025-03-12 08:35:48,806 - __main__ - INFO - 已處理 235000 個項目
# 2025-03-12 08:35:48,835 - __main__ - INFO - 已處理 236000 個項目
# 2025-03-12 08:35:48,864 - __main__ - INFO - 已處理 237000 個項目
# 2025-03-12 08:35:48,893 - __main__ - INFO - 已處理 238000 個項目
# 2025-03-12 08:35:48,921 - __main__ - INFO - 已處理 239000 個項目
# 2025-03-12 08:35:48,951 - __main__ - INFO - 已處理 240000 個項目
# 2025-03-12 08:35:48,981 - __main__ - INFO - 已處理 241000 個項目
# 2025-03-12 08:35:49,011 - __main__ - INFO - 已處理 242000 個項目
# 2025-03-12 08:35:49,043 - __main__ - INFO - 已處理 243000 個項目
# 2025-03-12 08:35:49,072 - __main__ - INFO - 已處理 244000 個項目
# 2025-03-12 08:35:49,101 - __main__ - INFO - 已處理 245000 個項目
# 2025-03-12 08:35:49,131 - __main__ - INFO - 已處理 246000 個項目
# 2025-03-12 08:35:49,162 - __main__ - INFO - 已處理 247000 個項目
# 2025-03-12 08:35:49,190 - __main__ - INFO - 已處理 248000 個項目
# 2025-03-12 08:35:49,219 - __main__ - INFO - 已處理 249000 個項目
# 2025-03-12 08:35:49,249 - __main__ - INFO - 已處理 250000 個項目
# 2025-03-12 08:35:49,278 - __main__ - INFO - 已處理 251000 個項目
# 2025-03-12 08:35:49,306 - __main__ - INFO - 已處理 252000 個項目
# 2025-03-12 08:35:49,334 - __main__ - INFO - 已處理 253000 個項目
# 2025-03-12 08:35:49,364 - __main__ - INFO - 已處理 254000 個項目
# 2025-03-12 08:35:49,392 - __main__ - INFO - 已處理 255000 個項目
# 2025-03-12 08:35:49,421 - __main__ - INFO - 已處理 256000 個項目
# 2025-03-12 08:35:49,450 - __main__ - INFO - 已處理 257000 個項目
# 2025-03-12 08:35:49,480 - __main__ - INFO - 已處理 258000 個項目
# 2025-03-12 08:35:49,509 - __main__ - INFO - 已處理 259000 個項目
# 2025-03-12 08:35:49,539 - __main__ - INFO - 已處理 260000 個項目
# 2025-03-12 08:35:49,569 - __main__ - INFO - 已處理 261000 個項目
# 2025-03-12 08:35:49,596 - __main__ - INFO - 已處理 262000 個項目
# 2025-03-12 08:35:49,624 - __main__ - INFO - 已處理 263000 個項目
# 2025-03-12 08:35:49,653 - __main__ - INFO - 已處理 264000 個項目
# 2025-03-12 08:35:49,683 - __main__ - INFO - 已處理 265000 個項目
# 2025-03-12 08:35:49,713 - __main__ - INFO - 已處理 266000 個項目
# 2025-03-12 08:35:49,743 - __main__ - INFO - 已處理 267000 個項目
# 2025-03-12 08:35:49,773 - __main__ - INFO - 已處理 268000 個項目
# 2025-03-12 08:35:49,803 - __main__ - INFO - 已處理 269000 個項目
# 2025-03-12 08:35:49,833 - __main__ - INFO - 已處理 270000 個項目
# 2025-03-12 08:35:49,862 - __main__ - INFO - 已處理 271000 個項目
# 2025-03-12 08:35:49,892 - __main__ - INFO - 已處理 272000 個項目
# 2025-03-12 08:35:49,922 - __main__ - INFO - 已處理 273000 個項目
# 2025-03-12 08:35:49,951 - __main__ - INFO - 已處理 274000 個項目
# 2025-03-12 08:35:49,980 - __main__ - INFO - 已處理 275000 個項目
# 2025-03-12 08:35:50,009 - __main__ - INFO - 已處理 276000 個項目
# 2025-03-12 08:35:50,036 - __main__ - INFO - 已處理 277000 個項目
# 2025-03-12 08:35:50,065 - __main__ - INFO - 已處理 278000 個項目
# 2025-03-12 08:35:50,095 - __main__ - INFO - 已處理 279000 個項目
# 2025-03-12 08:35:50,124 - __main__ - INFO - 已處理 280000 個項目
# 2025-03-12 08:35:50,153 - __main__ - INFO - 已處理 281000 個項目
# 2025-03-12 08:35:50,182 - __main__ - INFO - 已處理 282000 個項目
# 2025-03-12 08:35:50,211 - __main__ - INFO - 已處理 283000 個項目
# 2025-03-12 08:35:50,239 - __main__ - INFO - 已處理 284000 個項目
# 2025-03-12 08:35:50,268 - __main__ - INFO - 已處理 285000 個項目
# 2025-03-12 08:35:50,297 - __main__ - INFO - 已處理 286000 個項目
# 2025-03-12 08:35:50,326 - __main__ - INFO - 已處理 287000 個項目
# 2025-03-12 08:35:50,354 - __main__ - INFO - 已處理 288000 個項目
# 2025-03-12 08:35:50,382 - __main__ - INFO - 已處理 289000 個項目
# 2025-03-12 08:35:50,410 - __main__ - INFO - 已處理 290000 個項目
# 2025-03-12 08:35:50,438 - __main__ - INFO - 已處理 291000 個項目
# 2025-03-12 08:35:50,467 - __main__ - INFO - 已處理 292000 個項目
# 2025-03-12 08:35:50,495 - __main__ - INFO - 已處理 293000 個項目
# 2025-03-12 08:35:50,524 - __main__ - INFO - 已處理 294000 個項目
# 2025-03-12 08:35:50,554 - __main__ - INFO - 已處理 295000 個項目
# 2025-03-12 08:35:50,582 - __main__ - INFO - 已處理 296000 個項目
# 2025-03-12 08:35:50,612 - __main__ - INFO - 已處理 297000 個項目
# 2025-03-12 08:35:50,641 - __main__ - INFO - 已處理 298000 個項目
# 2025-03-12 08:35:50,670 - __main__ - INFO - 已處理 299000 個項目
# 2025-03-12 08:35:50,700 - __main__ - INFO - 已處理 300000 個項目
# 2025-03-12 08:35:50,727 - __main__ - INFO - 已處理 301000 個項目
# 2025-03-12 08:35:50,756 - __main__ - INFO - 已處理 302000 個項目
# 2025-03-12 08:35:50,786 - __main__ - INFO - 已處理 303000 個項目
# 2025-03-12 08:35:50,818 - __main__ - INFO - 已處理 304000 個項目
# 2025-03-12 08:35:50,847 - __main__ - INFO - 已處理 305000 個項目
# 2025-03-12 08:35:50,876 - __main__ - INFO - 已處理 306000 個項目
# 2025-03-12 08:35:50,904 - __main__ - INFO - 已處理 307000 個項目
# 2025-03-12 08:35:50,933 - __main__ - INFO - 已處理 308000 個項目
# 2025-03-12 08:35:50,963 - __main__ - INFO - 已處理 309000 個項目
# 2025-03-12 08:35:50,991 - __main__ - INFO - 已處理 310000 個項目
# 2025-03-12 08:35:51,020 - __main__ - INFO - 已處理 311000 個項目
# 2025-03-12 08:35:51,050 - __main__ - INFO - 已處理 312000 個項目
# 2025-03-12 08:35:51,079 - __main__ - INFO - 已處理 313000 個項目
# 2025-03-12 08:35:51,108 - __main__ - INFO - 已處理 314000 個項目
# 2025-03-12 08:35:51,136 - __main__ - INFO - 已處理 315000 個項目
# 2025-03-12 08:35:51,166 - __main__ - INFO - 已處理 316000 個項目
# 2025-03-12 08:35:51,195 - __main__ - INFO - 已處理 317000 個項目
# 2025-03-12 08:35:51,225 - __main__ - INFO - 已處理 318000 個項目
# 2025-03-12 08:35:51,254 - __main__ - INFO - 已處理 319000 個項目
# 2025-03-12 08:35:51,282 - __main__ - INFO - 已處理 320000 個項目
# 2025-03-12 08:35:51,312 - __main__ - INFO - 已處理 321000 個項目
# 2025-03-12 08:35:51,341 - __main__ - INFO - 已處理 322000 個項目
# 2025-03-12 08:35:51,371 - __main__ - INFO - 已處理 323000 個項目
# 2025-03-12 08:35:51,400 - __main__ - INFO - 已處理 324000 個項目
# 2025-03-12 08:35:51,430 - __main__ - INFO - 已處理 325000 個項目
# 2025-03-12 08:35:51,459 - __main__ - INFO - 已處理 326000 個項目
# 2025-03-12 08:35:51,489 - __main__ - INFO - 已處理 327000 個項目
# 2025-03-12 08:35:51,518 - __main__ - INFO - 已處理 328000 個項目
# 2025-03-12 08:35:51,548 - __main__ - INFO - 已處理 329000 個項目
# 2025-03-12 08:35:51,577 - __main__ - INFO - 已處理 330000 個項目
# 2025-03-12 08:35:51,607 - __main__ - INFO - 已處理 331000 個項目
# 2025-03-12 08:35:51,637 - __main__ - INFO - 已處理 332000 個項目
# 2025-03-12 08:35:51,665 - __main__ - INFO - 已處理 333000 個項目
# 2025-03-12 08:35:51,696 - __main__ - INFO - 已處理 334000 個項目
# 2025-03-12 08:35:51,725 - __main__ - INFO - 已處理 335000 個項目
# 2025-03-12 08:35:51,755 - __main__ - INFO - 已處理 336000 個項目
# 2025-03-12 08:35:51,785 - __main__ - INFO - 已處理 337000 個項目
# 2025-03-12 08:35:51,821 - __main__ - INFO - 已處理 338000 個項目
# 2025-03-12 08:35:51,854 - __main__ - INFO - 已處理 339000 個項目
# 2025-03-12 08:35:51,884 - __main__ - INFO - 已處理 340000 個項目
# 2025-03-12 08:35:51,912 - __main__ - INFO - 已處理 341000 個項目
# 2025-03-12 08:35:51,941 - __main__ - INFO - 已處理 342000 個項目
# 2025-03-12 08:35:51,970 - __main__ - INFO - 已處理 343000 個項目
# 2025-03-12 08:35:52,000 - __main__ - INFO - 已處理 344000 個項目
# 2025-03-12 08:35:52,029 - __main__ - INFO - 已處理 345000 個項目
# 2025-03-12 08:35:52,059 - __main__ - INFO - 已處理 346000 個項目
# 2025-03-12 08:35:52,089 - __main__ - INFO - 已處理 347000 個項目
# 2025-03-12 08:35:52,118 - __main__ - INFO - 已處理 348000 個項目
# 2025-03-12 08:35:52,147 - __main__ - INFO - 已處理 349000 個項目
# 2025-03-12 08:35:52,176 - __main__ - INFO - 已處理 350000 個項目
# 2025-03-12 08:35:52,207 - __main__ - INFO - 已處理 351000 個項目
# 2025-03-12 08:35:52,237 - __main__ - INFO - 已處理 352000 個項目
# 2025-03-12 08:35:52,265 - __main__ - INFO - 已處理 353000 個項目
# 2025-03-12 08:35:52,295 - __main__ - INFO - 已處理 354000 個項目
# 2025-03-12 08:35:52,324 - __main__ - INFO - 已處理 355000 個項目
# 2025-03-12 08:35:52,354 - __main__ - INFO - 已處理 356000 個項目
# 2025-03-12 08:35:52,383 - __main__ - INFO - 已處理 357000 個項目
# 2025-03-12 08:35:52,413 - __main__ - INFO - 已處理 358000 個項目
# 2025-03-12 08:35:52,442 - __main__ - INFO - 已處理 359000 個項目
# 2025-03-12 08:35:52,470 - __main__ - INFO - 已處理 360000 個項目
# 2025-03-12 08:35:52,499 - __main__ - INFO - 已處理 361000 個項目
# 2025-03-12 08:35:52,529 - __main__ - INFO - 已處理 362000 個項目
# 2025-03-12 08:35:52,558 - __main__ - INFO - 已處理 363000 個項目
# 2025-03-12 08:35:52,587 - __main__ - INFO - 已處理 364000 個項目
# 2025-03-12 08:35:52,615 - __main__ - INFO - 已處理 365000 個項目
# 2025-03-12 08:35:52,644 - __main__ - INFO - 已處理 366000 個項目
# 2025-03-12 08:35:52,673 - __main__ - INFO - 已處理 367000 個項目
# 2025-03-12 08:35:52,702 - __main__ - INFO - 已處理 368000 個項目
# 2025-03-12 08:35:52,731 - __main__ - INFO - 已處理 369000 個項目
# 2025-03-12 08:35:52,758 - __main__ - INFO - 已處理 370000 個項目
# 2025-03-12 08:35:52,786 - __main__ - INFO - 已處理 371000 個項目
# 2025-03-12 08:35:52,816 - __main__ - INFO - 已處理 372000 個項目
# 2025-03-12 08:35:52,844 - __main__ - INFO - 已處理 373000 個項目
# 2025-03-12 08:35:52,874 - __main__ - INFO - 已處理 374000 個項目
# 2025-03-12 08:35:52,903 - __main__ - INFO - 已處理 375000 個項目
# 2025-03-12 08:35:52,934 - __main__ - INFO - 已處理 376000 個項目
# 2025-03-12 08:35:52,963 - __main__ - INFO - 已處理 377000 個項目
# 2025-03-12 08:35:52,990 - __main__ - INFO - 已處理 378000 個項目
# 2025-03-12 08:35:53,019 - __main__ - INFO - 已處理 379000 個項目
# 2025-03-12 08:35:53,048 - __main__ - INFO - 已處理 380000 個項目
# 2025-03-12 08:35:53,078 - __main__ - INFO - 已處理 381000 個項目
# 2025-03-12 08:35:53,107 - __main__ - INFO - 已處理 382000 個項目
# 2025-03-12 08:35:53,137 - __main__ - INFO - 已處理 383000 個項目
# 2025-03-12 08:35:53,166 - __main__ - INFO - 已處理 384000 個項目
# 2025-03-12 08:35:53,196 - __main__ - INFO - 已處理 385000 個項目
# 2025-03-12 08:35:53,224 - __main__ - INFO - 已處理 386000 個項目
# 2025-03-12 08:35:53,255 - __main__ - INFO - 已處理 387000 個項目
# 2025-03-12 08:35:53,284 - __main__ - INFO - 已處理 388000 個項目
# 2025-03-12 08:35:53,314 - __main__ - INFO - 已處理 389000 個項目
# 2025-03-12 08:35:53,344 - __main__ - INFO - 已處理 390000 個項目
# 2025-03-12 08:35:53,375 - __main__ - INFO - 已處理 391000 個項目
# 2025-03-12 08:35:53,405 - __main__ - INFO - 已處理 392000 個項目
# 2025-03-12 08:35:53,435 - __main__ - INFO - 已處理 393000 個項目
# 2025-03-12 08:35:53,463 - __main__ - INFO - 已處理 394000 個項目
# 2025-03-12 08:35:53,491 - __main__ - INFO - 已處理 395000 個項目
# 2025-03-12 08:35:53,519 - __main__ - INFO - 已處理 396000 個項目
# 2025-03-12 08:35:53,549 - __main__ - INFO - 已處理 397000 個項目
# 2025-03-12 08:35:53,577 - __main__ - INFO - 已處理 398000 個項目
# 2025-03-12 08:35:53,606 - __main__ - INFO - 已處理 399000 個項目
# 2025-03-12 08:35:53,634 - __main__ - INFO - 已處理 400000 個項目
# 2025-03-12 08:35:53,663 - __main__ - INFO - 已處理 401000 個項目
# 2025-03-12 08:35:53,693 - __main__ - INFO - 已處理 402000 個項目
# 2025-03-12 08:35:53,721 - __main__ - INFO - 已處理 403000 個項目
# 2025-03-12 08:35:53,751 - __main__ - INFO - 已處理 404000 個項目
# 2025-03-12 08:35:53,780 - __main__ - INFO - 已處理 405000 個項目
# 2025-03-12 08:35:53,810 - __main__ - INFO - 已處理 406000 個項目
# 2025-03-12 08:35:53,839 - __main__ - INFO - 已處理 407000 個項目
# 2025-03-12 08:35:53,870 - __main__ - INFO - 已處理 408000 個項目
# 2025-03-12 08:35:53,899 - __main__ - INFO - 已處理 409000 個項目
# 2025-03-12 08:35:53,927 - __main__ - INFO - 已處理 410000 個項目
# 2025-03-12 08:35:53,957 - __main__ - INFO - 已處理 411000 個項目
# 2025-03-12 08:35:53,986 - __main__ - INFO - 已處理 412000 個項目
# 2025-03-12 08:35:54,015 - __main__ - INFO - 已處理 413000 個項目
# 2025-03-12 08:35:54,044 - __main__ - INFO - 已處理 414000 個項目
# 2025-03-12 08:35:54,074 - __main__ - INFO - 已處理 415000 個項目
# 2025-03-12 08:35:54,102 - __main__ - INFO - 已處理 416000 個項目
# 2025-03-12 08:35:54,131 - __main__ - INFO - 已處理 417000 個項目
# 2025-03-12 08:35:54,160 - __main__ - INFO - 已處理 418000 個項目
# 2025-03-12 08:35:54,189 - __main__ - INFO - 已處理 419000 個項目
# 2025-03-12 08:35:54,218 - __main__ - INFO - 已處理 420000 個項目
# 2025-03-12 08:35:54,247 - __main__ - INFO - 已處理 421000 個項目
# 2025-03-12 08:35:54,276 - __main__ - INFO - 已處理 422000 個項目
# 2025-03-12 08:35:54,306 - __main__ - INFO - 已處理 423000 個項目
# 2025-03-12 08:35:54,336 - __main__ - INFO - 已處理 424000 個項目
# 2025-03-12 08:35:54,368 - __main__ - INFO - 已處理 425000 個項目
# 2025-03-12 08:35:54,399 - __main__ - INFO - 已處理 426000 個項目
# 2025-03-12 08:35:54,428 - __main__ - INFO - 已處理 427000 個項目
# 2025-03-12 08:35:54,456 - __main__ - INFO - 已處理 428000 個項目
# 2025-03-12 08:35:54,484 - __main__ - INFO - 已處理 429000 個項目
# 2025-03-12 08:35:54,513 - __main__ - INFO - 已處理 430000 個項目
# 2025-03-12 08:35:54,542 - __main__ - INFO - 已處理 431000 個項目
# 2025-03-12 08:35:54,571 - __main__ - INFO - 已處理 432000 個項目
# 2025-03-12 08:35:54,600 - __main__ - INFO - 已處理 433000 個項目
# 2025-03-12 08:35:54,628 - __main__ - INFO - 已處理 434000 個項目
# 2025-03-12 08:35:54,657 - __main__ - INFO - 已處理 435000 個項目
# 2025-03-12 08:35:54,687 - __main__ - INFO - 已處理 436000 個項目
# 2025-03-12 08:35:54,717 - __main__ - INFO - 已處理 437000 個項目
# 2025-03-12 08:35:54,746 - __main__ - INFO - 已處理 438000 個項目
# 2025-03-12 08:35:54,774 - __main__ - INFO - 已處理 439000 個項目
# 2025-03-12 08:35:54,801 - __main__ - INFO - 已處理 440000 個項目
# 2025-03-12 08:35:54,829 - __main__ - INFO - 已處理 441000 個項目
# 2025-03-12 08:35:54,856 - __main__ - INFO - 已處理 442000 個項目
# 2025-03-12 08:35:54,884 - __main__ - INFO - 已處理 443000 個項目
# 2025-03-12 08:35:54,911 - __main__ - INFO - 已處理 444000 個項目
# 2025-03-12 08:35:54,939 - __main__ - INFO - 已處理 445000 個項目
# 2025-03-12 08:35:54,967 - __main__ - INFO - 已處理 446000 個項目
# 2025-03-12 08:35:54,996 - __main__ - INFO - 已處理 447000 個項目
# 2025-03-12 08:35:55,024 - __main__ - INFO - 已處理 448000 個項目
# 2025-03-12 08:35:55,052 - __main__ - INFO - 已處理 449000 個項目
# 2025-03-12 08:35:55,080 - __main__ - INFO - 已處理 450000 個項目
# 2025-03-12 08:35:55,108 - __main__ - INFO - 已處理 451000 個項目
# 2025-03-12 08:35:55,138 - __main__ - INFO - 已處理 452000 個項目
# 2025-03-12 08:35:55,168 - __main__ - INFO - 已處理 453000 個項目
# 2025-03-12 08:35:55,198 - __main__ - INFO - 已處理 454000 個項目
# 2025-03-12 08:35:55,227 - __main__ - INFO - 已處理 455000 個項目
# 2025-03-12 08:35:55,255 - __main__ - INFO - 已處理 456000 個項目
# 2025-03-12 08:35:55,281 - __main__ - INFO - 已處理 457000 個項目
# 2025-03-12 08:35:55,307 - __main__ - INFO - 已處理 458000 個項目
# 2025-03-12 08:35:55,332 - __main__ - INFO - 已處理 459000 個項目
# 2025-03-12 08:35:55,360 - __main__ - INFO - 已處理 460000 個項目
# 2025-03-12 08:35:55,387 - __main__ - INFO - 已處理 461000 個項目
# 2025-03-12 08:35:55,414 - __main__ - INFO - 已處理 462000 個項目
# 2025-03-12 08:35:55,441 - __main__ - INFO - 已處理 463000 個項目
# 2025-03-12 08:35:55,469 - __main__ - INFO - 已處理 464000 個項目
# 2025-03-12 08:35:55,495 - __main__ - INFO - 已處理 465000 個項目
# 2025-03-12 08:35:55,524 - __main__ - INFO - 已處理 466000 個項目
# 2025-03-12 08:35:55,553 - __main__ - INFO - 已處理 467000 個項目
# 2025-03-12 08:35:55,584 - __main__ - INFO - 已處理 468000 個項目
# 2025-03-12 08:35:55,613 - __main__ - INFO - 已處理 469000 個項目
# 2025-03-12 08:35:55,643 - __main__ - INFO - 已處理 470000 個項目
# 2025-03-12 08:35:55,673 - __main__ - INFO - 已處理 471000 個項目
# 2025-03-12 08:35:55,701 - __main__ - INFO - 已處理 472000 個項目
# 2025-03-12 08:35:55,731 - __main__ - INFO - 已處理 473000 個項目
# 2025-03-12 08:35:55,760 - __main__ - INFO - 已處理 474000 個項目
# 2025-03-12 08:35:55,789 - __main__ - INFO - 已處理 475000 個項目
# 2025-03-12 08:35:55,819 - __main__ - INFO - 已處理 476000 個項目
# 2025-03-12 08:35:55,848 - __main__ - INFO - 已處理 477000 個項目
# 2025-03-12 08:35:55,877 - __main__ - INFO - 已處理 478000 個項目
# 2025-03-12 08:35:55,907 - __main__ - INFO - 已處理 479000 個項目
# 2025-03-12 08:35:55,936 - __main__ - INFO - 已處理 480000 個項目
# 2025-03-12 08:35:55,965 - __main__ - INFO - 已處理 481000 個項目
# 2025-03-12 08:35:55,994 - __main__ - INFO - 已處理 482000 個項目
# 2025-03-12 08:35:56,024 - __main__ - INFO - 已處理 483000 個項目
# 2025-03-12 08:35:56,052 - __main__ - INFO - 已處理 484000 個項目
# 2025-03-12 08:35:56,082 - __main__ - INFO - 已處理 485000 個項目
# 2025-03-12 08:35:56,111 - __main__ - INFO - 已處理 486000 個項目
# 2025-03-12 08:35:56,141 - __main__ - INFO - 已處理 487000 個項目
# 2025-03-12 08:35:56,169 - __main__ - INFO - 已處理 488000 個項目
# 2025-03-12 08:35:56,197 - __main__ - INFO - 已處理 489000 個項目
# 2025-03-12 08:35:56,226 - __main__ - INFO - 已處理 490000 個項目
# 2025-03-12 08:35:56,255 - __main__ - INFO - 已處理 491000 個項目
# 2025-03-12 08:35:56,285 - __main__ - INFO - 已處理 492000 個項目
# 2025-03-12 08:35:56,314 - __main__ - INFO - 已處理 493000 個項目
# 2025-03-12 08:35:56,342 - __main__ - INFO - 已處理 494000 個項目
# 2025-03-12 08:35:56,372 - __main__ - INFO - 已處理 495000 個項目
# 2025-03-12 08:35:56,402 - __main__ - INFO - 已處理 496000 個項目
# 2025-03-12 08:35:56,432 - __main__ - INFO - 已處理 497000 個項目
# 2025-03-12 08:35:56,460 - __main__ - INFO - 已處理 498000 個項目
# 2025-03-12 08:35:56,490 - __main__ - INFO - 已處理 499000 個項目
# 2025-03-12 08:35:56,520 - __main__ - INFO - 已處理 500000 個項目
# 2025-03-12 08:35:56,548 - __main__ - INFO - 已處理 501000 個項目
# 2025-03-12 08:35:56,576 - __main__ - INFO - 已處理 502000 個項目
# 2025-03-12 08:35:56,605 - __main__ - INFO - 已處理 503000 個項目
# 2025-03-12 08:35:56,634 - __main__ - INFO - 已處理 504000 個項目
# 2025-03-12 08:35:56,664 - __main__ - INFO - 已處理 505000 個項目
# 2025-03-12 08:35:56,692 - __main__ - INFO - 已處理 506000 個項目
# 2025-03-12 08:35:56,720 - __main__ - INFO - 已處理 507000 個項目
# 2025-03-12 08:35:56,749 - __main__ - INFO - 已處理 508000 個項目
# 2025-03-12 08:35:56,777 - __main__ - INFO - 已處理 509000 個項目
# 2025-03-12 08:35:56,806 - __main__ - INFO - 已處理 510000 個項目
# 2025-03-12 08:35:56,833 - __main__ - INFO - 已處理 511000 個項目
# 2025-03-12 08:35:56,861 - __main__ - INFO - 已處理 512000 個項目
# 2025-03-12 08:35:56,890 - __main__ - INFO - 已處理 513000 個項目
# 2025-03-12 08:35:56,918 - __main__ - INFO - 已處理 514000 個項目
# 2025-03-12 08:35:56,946 - __main__ - INFO - 已處理 515000 個項目
# 2025-03-12 08:35:56,974 - __main__ - INFO - 已處理 516000 個項目
# 2025-03-12 08:35:57,002 - __main__ - INFO - 已處理 517000 個項目
# 2025-03-12 08:35:57,028 - __main__ - INFO - 已處理 518000 個項目
# 2025-03-12 08:35:57,056 - __main__ - INFO - 已處理 519000 個項目
# 2025-03-12 08:35:57,084 - __main__ - INFO - 已處理 520000 個項目
# 2025-03-12 08:35:57,112 - __main__ - INFO - 已處理 521000 個項目
# 2025-03-12 08:35:57,140 - __main__ - INFO - 已處理 522000 個項目
# 2025-03-12 08:35:57,168 - __main__ - INFO - 已處理 523000 個項目
# 2025-03-12 08:35:57,195 - __main__ - INFO - 已處理 524000 個項目
# 2025-03-12 08:35:57,223 - __main__ - INFO - 已處理 525000 個項目
# 2025-03-12 08:35:57,250 - __main__ - INFO - 已處理 526000 個項目
# 2025-03-12 08:35:57,277 - __main__ - INFO - 已處理 527000 個項目
# 2025-03-12 08:35:57,304 - __main__ - INFO - 已處理 528000 個項目
# 2025-03-12 08:35:57,332 - __main__ - INFO - 已處理 529000 個項目
# 2025-03-12 08:35:57,360 - __main__ - INFO - 已處理 530000 個項目
# 2025-03-12 08:35:57,389 - __main__ - INFO - 已處理 531000 個項目
# 2025-03-12 08:35:57,418 - __main__ - INFO - 已處理 532000 個項目
# 2025-03-12 08:35:57,447 - __main__ - INFO - 已處理 533000 個項目
# 2025-03-12 08:35:57,476 - __main__ - INFO - 已處理 534000 個項目
# 2025-03-12 08:35:57,505 - __main__ - INFO - 已處理 535000 個項目
# 2025-03-12 08:35:57,533 - __main__ - INFO - 已處理 536000 個項目
# 2025-03-12 08:35:57,562 - __main__ - INFO - 已處理 537000 個項目
# 2025-03-12 08:35:57,590 - __main__ - INFO - 已處理 538000 個項目
# 2025-03-12 08:35:57,619 - __main__ - INFO - 已處理 539000 個項目
# 2025-03-12 08:35:57,649 - __main__ - INFO - 已處理 540000 個項目
# 2025-03-12 08:35:57,677 - __main__ - INFO - 已處理 541000 個項目
# 2025-03-12 08:35:57,707 - __main__ - INFO - 已處理 542000 個項目
# 2025-03-12 08:35:57,737 - __main__ - INFO - 已處理 543000 個項目
# 2025-03-12 08:35:57,766 - __main__ - INFO - 已處理 544000 個項目
# 2025-03-12 08:35:57,795 - __main__ - INFO - 已處理 545000 個項目
# 2025-03-12 08:35:57,823 - __main__ - INFO - 已處理 546000 個項目
# 2025-03-12 08:35:57,852 - __main__ - INFO - 已處理 547000 個項目
# 2025-03-12 08:35:57,881 - __main__ - INFO - 已處理 548000 個項目
# 2025-03-12 08:35:57,908 - __main__ - INFO - 已處理 549000 個項目
# 2025-03-12 08:35:57,935 - __main__ - INFO - 已處理 550000 個項目
# 2025-03-12 08:35:57,963 - __main__ - INFO - 已處理 551000 個項目
# 2025-03-12 08:35:57,992 - __main__ - INFO - 已處理 552000 個項目
# 2025-03-12 08:35:58,021 - __main__ - INFO - 已處理 553000 個項目
# 2025-03-12 08:35:58,050 - __main__ - INFO - 已處理 554000 個項目
# 2025-03-12 08:35:58,078 - __main__ - INFO - 已處理 555000 個項目
# 2025-03-12 08:35:58,107 - __main__ - INFO - 已處理 556000 個項目
# 2025-03-12 08:35:58,136 - __main__ - INFO - 已處理 557000 個項目
# 2025-03-12 08:35:58,164 - __main__ - INFO - 已處理 558000 個項目
# 2025-03-12 08:35:58,192 - __main__ - INFO - 已處理 559000 個項目
# 2025-03-12 08:35:58,222 - __main__ - INFO - 已處理 560000 個項目
# 2025-03-12 08:35:58,251 - __main__ - INFO - 已處理 561000 個項目
# 2025-03-12 08:35:58,281 - __main__ - INFO - 已處理 562000 個項目
# 2025-03-12 08:35:58,310 - __main__ - INFO - 已處理 563000 個項目
# 2025-03-12 08:35:58,339 - __main__ - INFO - 已處理 564000 個項目
# 2025-03-12 08:35:58,366 - __main__ - INFO - 已處理 565000 個項目
# 2025-03-12 08:35:58,395 - __main__ - INFO - 已處理 566000 個項目
# 2025-03-12 08:35:58,423 - __main__ - INFO - 已處理 567000 個項目
# 2025-03-12 08:35:58,451 - __main__ - INFO - 已處理 568000 個項目
# 2025-03-12 08:35:58,480 - __main__ - INFO - 已處理 569000 個項目
# 2025-03-12 08:35:58,512 - __main__ - INFO - 已處理 570000 個項目
# 2025-03-12 08:35:58,541 - __main__ - INFO - 已處理 571000 個項目
# 2025-03-12 08:35:58,572 - __main__ - INFO - 已處理 572000 個項目
# 2025-03-12 08:35:58,601 - __main__ - INFO - 已處理 573000 個項目
# 2025-03-12 08:35:58,631 - __main__ - INFO - 已處理 574000 個項目
# 2025-03-12 08:35:58,659 - __main__ - INFO - 已處理 575000 個項目
# 2025-03-12 08:35:58,688 - __main__ - INFO - 已處理 576000 個項目
# 2025-03-12 08:35:58,717 - __main__ - INFO - 已處理 577000 個項目
# 2025-03-12 08:35:58,747 - __main__ - INFO - 已處理 578000 個項目
# 2025-03-12 08:35:58,776 - __main__ - INFO - 已處理 579000 個項目
# 2025-03-12 08:35:58,804 - __main__ - INFO - 已處理 580000 個項目
# 2025-03-12 08:35:58,832 - __main__ - INFO - 已處理 581000 個項目
# 2025-03-12 08:35:58,861 - __main__ - INFO - 已處理 582000 個項目
# 2025-03-12 08:35:58,891 - __main__ - INFO - 已處理 583000 個項目
# 2025-03-12 08:35:58,919 - __main__ - INFO - 已處理 584000 個項目
# 2025-03-12 08:35:58,947 - __main__ - INFO - 已處理 585000 個項目
# 2025-03-12 08:35:58,976 - __main__ - INFO - 已處理 586000 個項目
# 2025-03-12 08:35:59,006 - __main__ - INFO - 已處理 587000 個項目
# 2025-03-12 08:35:59,035 - __main__ - INFO - 已處理 588000 個項目
# 2025-03-12 08:35:59,078 - __main__ - INFO - 已處理 589000 個項目
# 2025-03-12 08:35:59,107 - __main__ - INFO - 已處理 590000 個項目
# 2025-03-12 08:35:59,136 - __main__ - INFO - 已處理 591000 個項目
# 2025-03-12 08:35:59,164 - __main__ - INFO - 已處理 592000 個項目
# 2025-03-12 08:35:59,194 - __main__ - INFO - 已處理 593000 個項目
# 2025-03-12 08:35:59,223 - __main__ - INFO - 已處理 594000 個項目
# 2025-03-12 08:35:59,252 - __main__ - INFO - 已處理 595000 個項目
# 2025-03-12 08:35:59,282 - __main__ - INFO - 已處理 596000 個項目
# 2025-03-12 08:35:59,310 - __main__ - INFO - 已處理 597000 個項目
# 2025-03-12 08:35:59,338 - __main__ - INFO - 已處理 598000 個項目
# 2025-03-12 08:35:59,369 - __main__ - INFO - 已處理 599000 個項目
# 2025-03-12 08:35:59,397 - __main__ - INFO - 已處理 600000 個項目
# 2025-03-12 08:35:59,425 - __main__ - INFO - 已處理 601000 個項目
# 2025-03-12 08:35:59,454 - __main__ - INFO - 已處理 602000 個項目
# 2025-03-12 08:35:59,483 - __main__ - INFO - 已處理 603000 個項目
# 2025-03-12 08:35:59,511 - __main__ - INFO - 已處理 604000 個項目
# 2025-03-12 08:35:59,540 - __main__ - INFO - 已處理 605000 個項目
# 2025-03-12 08:35:59,569 - __main__ - INFO - 已處理 606000 個項目
# 2025-03-12 08:35:59,597 - __main__ - INFO - 已處理 607000 個項目
# 2025-03-12 08:35:59,625 - __main__ - INFO - 已處理 608000 個項目
# 2025-03-12 08:35:59,654 - __main__ - INFO - 已處理 609000 個項目
# 2025-03-12 08:35:59,682 - __main__ - INFO - 已處理 610000 個項目
# 2025-03-12 08:35:59,711 - __main__ - INFO - 已處理 611000 個項目
# 2025-03-12 08:35:59,743 - __main__ - INFO - 已處理 612000 個項目
# 2025-03-12 08:35:59,776 - __main__ - INFO - 已處理 613000 個項目
# 2025-03-12 08:35:59,805 - __main__ - INFO - 已處理 614000 個項目
# 2025-03-12 08:35:59,834 - __main__ - INFO - 已處理 615000 個項目
# 2025-03-12 08:35:59,862 - __main__ - INFO - 已處理 616000 個項目
# 2025-03-12 08:35:59,891 - __main__ - INFO - 已處理 617000 個項目
# 2025-03-12 08:35:59,920 - __main__ - INFO - 已處理 618000 個項目
# 2025-03-12 08:35:59,948 - __main__ - INFO - 已處理 619000 個項目
# 2025-03-12 08:35:59,977 - __main__ - INFO - 已處理 620000 個項目
# 2025-03-12 08:36:00,005 - __main__ - INFO - 已處理 621000 個項目
# 2025-03-12 08:36:00,034 - __main__ - INFO - 已處理 622000 個項目
# 2025-03-12 08:36:00,065 - __main__ - INFO - 已處理 623000 個項目
# 2025-03-12 08:36:00,094 - __main__ - INFO - 已處理 624000 個項目
# 2025-03-12 08:36:00,123 - __main__ - INFO - 已處理 625000 個項目
# 2025-03-12 08:36:00,154 - __main__ - INFO - 已處理 626000 個項目
# 2025-03-12 08:36:00,183 - __main__ - INFO - 已處理 627000 個項目
# 2025-03-12 08:36:00,212 - __main__ - INFO - 已處理 628000 個項目
# 2025-03-12 08:36:00,241 - __main__ - INFO - 已處理 629000 個項目
# 2025-03-12 08:36:00,269 - __main__ - INFO - 已處理 630000 個項目
# 2025-03-12 08:36:00,300 - __main__ - INFO - 已處理 631000 個項目
# 2025-03-12 08:36:00,329 - __main__ - INFO - 已處理 632000 個項目
# 2025-03-12 08:36:00,360 - __main__ - INFO - 已處理 633000 個項目
# 2025-03-12 08:36:00,388 - __main__ - INFO - 已處理 634000 個項目
# 2025-03-12 08:36:00,417 - __main__ - INFO - 已處理 635000 個項目
# 2025-03-12 08:36:00,446 - __main__ - INFO - 已處理 636000 個項目
# 2025-03-12 08:36:00,475 - __main__ - INFO - 已處理 637000 個項目
# 2025-03-12 08:36:00,503 - __main__ - INFO - 已處理 638000 個項目
# 2025-03-12 08:36:00,532 - __main__ - INFO - 已處理 639000 個項目
# 2025-03-12 08:36:00,560 - __main__ - INFO - 已處理 640000 個項目
# 2025-03-12 08:36:00,590 - __main__ - INFO - 已處理 641000 個項目
# 2025-03-12 08:36:00,620 - __main__ - INFO - 已處理 642000 個項目
# 2025-03-12 08:36:00,648 - __main__ - INFO - 已處理 643000 個項目
# 2025-03-12 08:36:00,678 - __main__ - INFO - 已處理 644000 個項目
# 2025-03-12 08:36:00,707 - __main__ - INFO - 已處理 645000 個項目
# 2025-03-12 08:36:00,736 - __main__ - INFO - 已處理 646000 個項目
# 2025-03-12 08:36:00,765 - __main__ - INFO - 已處理 647000 個項目
# 2025-03-12 08:36:00,794 - __main__ - INFO - 已處理 648000 個項目
# 2025-03-12 08:36:00,822 - __main__ - INFO - 已處理 649000 個項目
# 2025-03-12 08:36:00,851 - __main__ - INFO - 已處理 650000 個項目
# 2025-03-12 08:36:00,880 - __main__ - INFO - 已處理 651000 個項目
# 2025-03-12 08:36:00,909 - __main__ - INFO - 已處理 652000 個項目
# 2025-03-12 08:36:00,938 - __main__ - INFO - 已處理 653000 個項目
# 2025-03-12 08:36:00,967 - __main__ - INFO - 已處理 654000 個項目
# 2025-03-12 08:36:00,996 - __main__ - INFO - 已處理 655000 個項目
# 2025-03-12 08:36:01,025 - __main__ - INFO - 已處理 656000 個項目
# 2025-03-12 08:36:01,054 - __main__ - INFO - 已處理 657000 個項目
# 2025-03-12 08:36:01,084 - __main__ - INFO - 已處理 658000 個項目
# 2025-03-12 08:36:01,112 - __main__ - INFO - 已處理 659000 個項目
# 2025-03-12 08:36:01,141 - __main__ - INFO - 已處理 660000 個項目
# 2025-03-12 08:36:01,170 - __main__ - INFO - 已處理 661000 個項目
# 2025-03-12 08:36:01,200 - __main__ - INFO - 已處理 662000 個項目
# 2025-03-12 08:36:01,229 - __main__ - INFO - 已處理 663000 個項目
# 2025-03-12 08:36:01,258 - __main__ - INFO - 已處理 664000 個項目
# 2025-03-12 08:36:01,286 - __main__ - INFO - 已處理 665000 個項目
# 2025-03-12 08:36:01,315 - __main__ - INFO - 已處理 666000 個項目
# 2025-03-12 08:36:01,345 - __main__ - INFO - 已處理 667000 個項目
# 2025-03-12 08:36:01,375 - __main__ - INFO - 已處理 668000 個項目
# 2025-03-12 08:36:01,406 - __main__ - INFO - 已處理 669000 個項目
# 2025-03-12 08:36:01,435 - __main__ - INFO - 已處理 670000 個項目
# 2025-03-12 08:36:01,464 - __main__ - INFO - 已處理 671000 個項目
# 2025-03-12 08:36:01,492 - __main__ - INFO - 已處理 672000 個項目
# 2025-03-12 08:36:01,519 - __main__ - INFO - 已處理 673000 個項目
# 2025-03-12 08:36:01,547 - __main__ - INFO - 已處理 674000 個項目
# 2025-03-12 08:36:01,575 - __main__ - INFO - 已處理 675000 個項目
# 2025-03-12 08:36:01,603 - __main__ - INFO - 已處理 676000 個項目
# 2025-03-12 08:36:01,631 - __main__ - INFO - 已處理 677000 個項目
# 2025-03-12 08:36:01,660 - __main__ - INFO - 已處理 678000 個項目
# 2025-03-12 08:36:01,690 - __main__ - INFO - 已處理 679000 個項目
# 2025-03-12 08:36:01,719 - __main__ - INFO - 已處理 680000 個項目
# 2025-03-12 08:36:01,750 - __main__ - INFO - 已處理 681000 個項目
# 2025-03-12 08:36:01,779 - __main__ - INFO - 已處理 682000 個項目
# 2025-03-12 08:36:01,806 - __main__ - INFO - 已處理 683000 個項目
# 2025-03-12 08:36:01,835 - __main__ - INFO - 已處理 684000 個項目
# 2025-03-12 08:36:01,863 - __main__ - INFO - 已處理 685000 個項目
# 2025-03-12 08:36:01,892 - __main__ - INFO - 已處理 686000 個項目
# 2025-03-12 08:36:01,921 - __main__ - INFO - 已處理 687000 個項目
# 2025-03-12 08:36:01,948 - __main__ - INFO - 已處理 688000 個項目
# 2025-03-12 08:36:01,978 - __main__ - INFO - 已處理 689000 個項目
# 2025-03-12 08:36:02,007 - __main__ - INFO - 已處理 690000 個項目
# 2025-03-12 08:36:02,036 - __main__ - INFO - 已處理 691000 個項目
# 2025-03-12 08:36:02,066 - __main__ - INFO - 已處理 692000 個項目
# 2025-03-12 08:36:02,094 - __main__ - INFO - 已處理 693000 個項目
# 2025-03-12 08:36:02,123 - __main__ - INFO - 已處理 694000 個項目
# 2025-03-12 08:36:02,153 - __main__ - INFO - 已處理 695000 個項目
# 2025-03-12 08:36:02,181 - __main__ - INFO - 已處理 696000 個項目
# 2025-03-12 08:36:02,206 - __main__ - INFO - 已處理 697000 個項目
# 2025-03-12 08:36:02,233 - __main__ - INFO - 已處理 698000 個項目
# 2025-03-12 08:36:02,260 - __main__ - INFO - 已處理 699000 個項目
# 2025-03-12 08:36:02,288 - __main__ - INFO - 已處理 700000 個項目
# 2025-03-12 08:36:02,317 - __main__ - INFO - 已處理 701000 個項目
# 2025-03-12 08:36:02,345 - __main__ - INFO - 已處理 702000 個項目
# 2025-03-12 08:36:02,377 - __main__ - INFO - 已處理 703000 個項目
# 2025-03-12 08:36:02,407 - __main__ - INFO - 已處理 704000 個項目
# 2025-03-12 08:36:02,438 - __main__ - INFO - 已處理 705000 個項目
# 2025-03-12 08:36:02,468 - __main__ - INFO - 已處理 706000 個項目
# 2025-03-12 08:36:02,498 - __main__ - INFO - 已處理 707000 個項目
# 2025-03-12 08:36:02,528 - __main__ - INFO - 已處理 708000 個項目
# 2025-03-12 08:36:02,558 - __main__ - INFO - 已處理 709000 個項目
# 2025-03-12 08:36:02,589 - __main__ - INFO - 已處理 710000 個項目
# 2025-03-12 08:36:02,621 - __main__ - INFO - 已處理 711000 個項目
# 2025-03-12 08:36:02,651 - __main__ - INFO - 已處理 712000 個項目
# 2025-03-12 08:36:02,680 - __main__ - INFO - 已處理 713000 個項目
# 2025-03-12 08:36:02,709 - __main__ - INFO - 已處理 714000 個項目
# 2025-03-12 08:36:02,738 - __main__ - INFO - 已處理 715000 個項目
# 2025-03-12 08:36:02,768 - __main__ - INFO - 已處理 716000 個項目
# 2025-03-12 08:36:02,797 - __main__ - INFO - 已處理 717000 個項目
# 2025-03-12 08:36:02,826 - __main__ - INFO - 已處理 718000 個項目
# 2025-03-12 08:36:02,855 - __main__ - INFO - 已處理 719000 個項目
# 2025-03-12 08:36:02,884 - __main__ - INFO - 已處理 720000 個項目
# 2025-03-12 08:36:02,914 - __main__ - INFO - 已處理 721000 個項目
# 2025-03-12 08:36:02,944 - __main__ - INFO - 已處理 722000 個項目
# 2025-03-12 08:36:02,974 - __main__ - INFO - 已處理 723000 個項目
# 2025-03-12 08:36:03,002 - __main__ - INFO - 已處理 724000 個項目
# 2025-03-12 08:36:03,031 - __main__ - INFO - 已處理 725000 個項目
# 2025-03-12 08:36:03,060 - __main__ - INFO - 已處理 726000 個項目
# 2025-03-12 08:36:03,089 - __main__ - INFO - 已處理 727000 個項目
# 2025-03-12 08:36:03,119 - __main__ - INFO - 已處理 728000 個項目
# 2025-03-12 08:36:03,148 - __main__ - INFO - 已處理 729000 個項目
# 2025-03-12 08:36:03,180 - __main__ - INFO - 已處理 730000 個項目
# 2025-03-12 08:36:03,209 - __main__ - INFO - 已處理 731000 個項目
# 2025-03-12 08:36:03,238 - __main__ - INFO - 已處理 732000 個項目
# 2025-03-12 08:36:03,268 - __main__ - INFO - 已處理 733000 個項目
# 2025-03-12 08:36:03,298 - __main__ - INFO - 已處理 734000 個項目
# 2025-03-12 08:36:03,328 - __main__ - INFO - 已處理 735000 個項目
# 2025-03-12 08:36:03,358 - __main__ - INFO - 已處理 736000 個項目
# 2025-03-12 08:36:03,388 - __main__ - INFO - 已處理 737000 個項目
# 2025-03-12 08:36:03,418 - __main__ - INFO - 已處理 738000 個項目
# 2025-03-12 08:36:03,447 - __main__ - INFO - 已處理 739000 個項目
# 2025-03-12 08:36:03,476 - __main__ - INFO - 已處理 740000 個項目
# 2025-03-12 08:36:03,505 - __main__ - INFO - 已處理 741000 個項目
# 2025-03-12 08:36:03,534 - __main__ - INFO - 已處理 742000 個項目
# 2025-03-12 08:36:03,563 - __main__ - INFO - 已處理 743000 個項目
# 2025-03-12 08:36:03,592 - __main__ - INFO - 已處理 744000 個項目
# 2025-03-12 08:36:03,621 - __main__ - INFO - 已處理 745000 個項目
# 2025-03-12 08:36:03,650 - __main__ - INFO - 已處理 746000 個項目
# 2025-03-12 08:36:03,679 - __main__ - INFO - 已處理 747000 個項目
# 2025-03-12 08:36:03,709 - __main__ - INFO - 已處理 748000 個項目
# 2025-03-12 08:36:03,739 - __main__ - INFO - 已處理 749000 個項目
# 2025-03-12 08:36:03,768 - __main__ - INFO - 已處理 750000 個項目
# 2025-03-12 08:36:03,798 - __main__ - INFO - 已處理 751000 個項目
# 2025-03-12 08:36:03,829 - __main__ - INFO - 已處理 752000 個項目
# 2025-03-12 08:36:03,857 - __main__ - INFO - 已處理 753000 個項目
# 2025-03-12 08:36:03,887 - __main__ - INFO - 已處理 754000 個項目
# 2025-03-12 08:36:03,917 - __main__ - INFO - 已處理 755000 個項目
# 2025-03-12 08:36:03,947 - __main__ - INFO - 已處理 756000 個項目
# 2025-03-12 08:36:03,976 - __main__ - INFO - 已處理 757000 個項目
# 2025-03-12 08:36:04,006 - __main__ - INFO - 已處理 758000 個項目
# 2025-03-12 08:36:04,036 - __main__ - INFO - 已處理 759000 個項目
# 2025-03-12 08:36:04,065 - __main__ - INFO - 已處理 760000 個項目
# 2025-03-12 08:36:04,094 - __main__ - INFO - 已處理 761000 個項目
# 2025-03-12 08:36:04,124 - __main__ - INFO - 已處理 762000 個項目
# 2025-03-12 08:36:04,153 - __main__ - INFO - 已處理 763000 個項目
# 2025-03-12 08:36:04,181 - __main__ - INFO - 已處理 764000 個項目
# 2025-03-12 08:36:04,209 - __main__ - INFO - 已處理 765000 個項目
# 2025-03-12 08:36:04,238 - __main__ - INFO - 已處理 766000 個項目
# 2025-03-12 08:36:04,267 - __main__ - INFO - 已處理 767000 個項目
# 2025-03-12 08:36:04,295 - __main__ - INFO - 已處理 768000 個項目
# 2025-03-12 08:36:04,322 - __main__ - INFO - 已處理 769000 個項目
# 2025-03-12 08:36:04,350 - __main__ - INFO - 已處理 770000 個項目
# 2025-03-12 08:36:04,379 - __main__ - INFO - 已處理 771000 個項目
# 2025-03-12 08:36:04,408 - __main__ - INFO - 已處理 772000 個項目
# 2025-03-12 08:36:04,438 - __main__ - INFO - 已處理 773000 個項目
# 2025-03-12 08:36:04,467 - __main__ - INFO - 已處理 774000 個項目
# 2025-03-12 08:36:04,497 - __main__ - INFO - 已處理 775000 個項目
# 2025-03-12 08:36:04,525 - __main__ - INFO - 已處理 776000 個項目
# 2025-03-12 08:36:04,555 - __main__ - INFO - 已處理 777000 個項目
# 2025-03-12 08:36:04,584 - __main__ - INFO - 已處理 778000 個項目
# 2025-03-12 08:36:04,612 - __main__ - INFO - 已處理 779000 個項目
# 2025-03-12 08:36:04,643 - __main__ - INFO - 已處理 780000 個項目
# 2025-03-12 08:36:04,672 - __main__ - INFO - 已處理 781000 個項目
# 2025-03-12 08:36:04,700 - __main__ - INFO - 已處理 782000 個項目
# 2025-03-12 08:36:04,729 - __main__ - INFO - 已處理 783000 個項目
# 2025-03-12 08:36:04,758 - __main__ - INFO - 已處理 784000 個項目
# 2025-03-12 08:36:04,788 - __main__ - INFO - 已處理 785000 個項目
# 2025-03-12 08:36:04,815 - __main__ - INFO - 已處理 786000 個項目
# 2025-03-12 08:36:04,844 - __main__ - INFO - 已處理 787000 個項目
# 2025-03-12 08:36:04,873 - __main__ - INFO - 已處理 788000 個項目
# 2025-03-12 08:36:04,902 - __main__ - INFO - 已處理 789000 個項目
# 2025-03-12 08:36:04,932 - __main__ - INFO - 已處理 790000 個項目
# 2025-03-12 08:36:04,961 - __main__ - INFO - 已處理 791000 個項目
# 2025-03-12 08:36:04,991 - __main__ - INFO - 已處理 792000 個項目
# 2025-03-12 08:36:05,019 - __main__ - INFO - 已處理 793000 個項目
# 2025-03-12 08:36:05,046 - __main__ - INFO - 已處理 794000 個項目
# 2025-03-12 08:36:05,076 - __main__ - INFO - 已處理 795000 個項目
# 2025-03-12 08:36:05,106 - __main__ - INFO - 已處理 796000 個項目
# 2025-03-12 08:36:05,132 - __main__ - INFO - 已處理 797000 個項目
# 2025-03-12 08:36:05,161 - __main__ - INFO - 已處理 798000 個項目
# 2025-03-12 08:36:05,188 - __main__ - INFO - 已處理 799000 個項目
# 2025-03-12 08:36:05,217 - __main__ - INFO - 已處理 800000 個項目
# 2025-03-12 08:36:05,247 - __main__ - INFO - 已處理 801000 個項目
# 2025-03-12 08:36:05,277 - __main__ - INFO - 已處理 802000 個項目
# 2025-03-12 08:36:05,306 - __main__ - INFO - 已處理 803000 個項目
# 2025-03-12 08:36:05,336 - __main__ - INFO - 已處理 804000 個項目
# 2025-03-12 08:36:05,366 - __main__ - INFO - 已處理 805000 個項目
# 2025-03-12 08:36:05,394 - __main__ - INFO - 已處理 806000 個項目
# 2025-03-12 08:36:05,423 - __main__ - INFO - 已處理 807000 個項目
# 2025-03-12 08:36:05,451 - __main__ - INFO - 已處理 808000 個項目
# 2025-03-12 08:36:05,479 - __main__ - INFO - 已處理 809000 個項目
# 2025-03-12 08:36:05,509 - __main__ - INFO - 已處理 810000 個項目
# 2025-03-12 08:36:05,538 - __main__ - INFO - 已處理 811000 個項目
# 2025-03-12 08:36:05,567 - __main__ - INFO - 已處理 812000 個項目
# ...
# 2025-03-12 08:36:14,284 - __main__ - INFO - 已處理 1111000 個項目
# 2025-03-12 08:36:14,314 - __main__ - INFO - 已處理 1112000 個項目
# 2025-03-12 08:36:14,344 - __main__ - INFO - 已處理 1113000 個項目
# 2025-03-12 08:36:14,374 - __main__ - INFO - 已處理 1114000 個項目
# 2025-03-12 08:36:14,404 - __main__ - INFO - 已處理 1115000 個項目
# 2025-03-12 08:36:14,435 - __main__ - INFO - 已處理 1116000 個項目
# 2025-03-12 08:36:14,465 - __main__ - INFO - 已處理 1117000 個項目
# 2025-03-12 08:36:14,496 - __main__ - INFO - 已處理 1118000 個項目
# 2025-03-12 08:36:14,525 - __main__ - INFO - 已處理 1119000 個項目
# 2025-03-12 08:36:14,555 - __main__ - INFO - 已處理 1120000 個項目
# 2025-03-12 08:36:14,583 - __main__ - INFO - 已處理 1121000 個項目
# 2025-03-12 08:36:14,611 - __main__ - INFO - 已處理 1122000 個項目
# 2025-03-12 08:36:14,639 - __main__ - INFO - 已處理 1123000 個項目
# 2025-03-12 08:36:14,668 - __main__ - INFO - 已處理 1124000 個項目
# 2025-03-12 08:36:14,698 - __main__ - INFO - 已處理 1125000 個項目
# 2025-03-12 08:36:14,726 - __main__ - INFO - 已處理 1126000 個項目
# 2025-03-12 08:36:14,755 - __main__ - INFO - 已處理 1127000 個項目
# 2025-03-12 08:36:14,783 - __main__ - INFO - 已處理 1128000 個項目
# 2025-03-12 08:36:14,811 - __main__ - INFO - 已處理 1129000 個項目
# 2025-03-12 08:36:14,841 - __main__ - INFO - 已處理 1130000 個項目
# 2025-03-12 08:36:14,870 - __main__ - INFO - 已處理 1131000 個項目
# 2025-03-12 08:36:14,899 - __main__ - INFO - 已處理 1132000 個項目
# 2025-03-12 08:36:14,927 - __main__ - INFO - 已處理 1133000 個項目
# 2025-03-12 08:36:14,958 - __main__ - INFO - 已處理 1134000 個項目
# 2025-03-12 08:36:14,987 - __main__ - INFO - 已處理 1135000 個項目
# 2025-03-12 08:36:15,015 - __main__ - INFO - 已處理 1136000 個項目
# 2025-03-12 08:36:15,044 - __main__ - INFO - 已處理 1137000 個項目
# 2025-03-12 08:36:15,073 - __main__ - INFO - 已處理 1138000 個項目
# 2025-03-12 08:36:15,103 - __main__ - INFO - 已處理 1139000 個項目
# 2025-03-12 08:36:15,134 - __main__ - INFO - 已處理 1140000 個項目
# 2025-03-12 08:36:15,165 - __main__ - INFO - 已處理 1141000 個項目
# 2025-03-12 08:36:15,197 - __main__ - INFO - 已處理 1142000 個項目
# 2025-03-12 08:36:15,227 - __main__ - INFO - 已處理 1143000 個項目
# 2025-03-12 08:36:15,257 - __main__ - INFO - 已處理 1144000 個項目
# 2025-03-12 08:36:15,287 - __main__ - INFO - 已處理 1145000 個項目
# 2025-03-12 08:36:15,316 - __main__ - INFO - 已處理 1146000 個項目
# 2025-03-12 08:36:15,343 - __main__ - INFO - 已處理 1147000 個項目
# 2025-03-12 08:36:15,370 - __main__ - INFO - 已處理 1148000 個項目
# 2025-03-12 08:36:15,399 - __main__ - INFO - 已處理 1149000 個項目
# 2025-03-12 08:36:15,428 - __main__ - INFO - 已處理 1150000 個項目
# 2025-03-12 08:36:15,459 - __main__ - INFO - 已處理 1151000 個項目
# 2025-03-12 08:36:15,487 - __main__ - INFO - 已處理 1152000 個項目
# 2025-03-12 08:36:15,517 - __main__ - INFO - 已處理 1153000 個項目
# 2025-03-12 08:36:15,547 - __main__ - INFO - 已處理 1154000 個項目
# 2025-03-12 08:36:15,577 - __main__ - INFO - 已處理 1155000 個項目
# 2025-03-12 08:36:15,606 - __main__ - INFO - 已處理 1156000 個項目
# 2025-03-12 08:36:15,636 - __main__ - INFO - 已處理 1157000 個項目
# 2025-03-12 08:36:15,664 - __main__ - INFO - 已處理 1158000 個項目
# 2025-03-12 08:36:15,692 - __main__ - INFO - 已處理 1159000 個項目
# 2025-03-12 08:36:15,720 - __main__ - INFO - 已處理 1160000 個項目
# 2025-03-12 08:36:15,747 - __main__ - INFO - 已處理 1161000 個項目
# 2025-03-12 08:36:15,821 - __main__ - INFO - 已處理 1162000 個項目
# 2025-03-12 08:36:15,850 - __main__ - INFO - 已處理 1163000 個項目
# 2025-03-12 08:36:15,880 - __main__ - INFO - 已處理 1164000 個項目
# 2025-03-12 08:36:15,909 - __main__ - INFO - 已處理 1165000 個項目
# 2025-03-12 08:36:15,937 - __main__ - INFO - 已處理 1166000 個項目
# 2025-03-12 08:36:15,966 - __main__ - INFO - 已處理 1167000 個項目
# 2025-03-12 08:36:15,994 - __main__ - INFO - 已處理 1168000 個項目
# 2025-03-12 08:36:16,023 - __main__ - INFO - 已處理 1169000 個項目
# 2025-03-12 08:36:16,052 - __main__ - INFO - 已處理 1170000 個項目
# 2025-03-12 08:36:16,082 - __main__ - INFO - 已處理 1171000 個項目
# 2025-03-12 08:36:16,113 - __main__ - INFO - 已處理 1172000 個項目
# 2025-03-12 08:36:16,142 - __main__ - INFO - 已處理 1173000 個項目
# 2025-03-12 08:36:16,172 - __main__ - INFO - 已處理 1174000 個項目
# 2025-03-12 08:36:16,201 - __main__ - INFO - 已處理 1175000 個項目
# 2025-03-12 08:36:16,229 - __main__ - INFO - 已處理 1176000 個項目
# 2025-03-12 08:36:16,257 - __main__ - INFO - 已處理 1177000 個項目
# 2025-03-12 08:36:16,286 - __main__ - INFO - 已處理 1178000 個項目
# 2025-03-12 08:36:16,315 - __main__ - INFO - 已處理 1179000 個項目
# 2025-03-12 08:36:16,344 - __main__ - INFO - 已處理 1180000 個項目
# 2025-03-12 08:36:16,373 - __main__ - INFO - 已處理 1181000 個項目
# 2025-03-12 08:36:16,403 - __main__ - INFO - 已處理 1182000 個項目
# 2025-03-12 08:36:16,431 - __main__ - INFO - 已處理 1183000 個項目
# 2025-03-12 08:36:16,461 - __main__ - INFO - 已處理 1184000 個項目
# 2025-03-12 08:36:16,490 - __main__ - INFO - 已處理 1185000 個項目
# 2025-03-12 08:36:16,520 - __main__ - INFO - 已處理 1186000 個項目
# 2025-03-12 08:36:16,551 - __main__ - INFO - 已處理 1187000 個項目
# 2025-03-12 08:36:16,581 - __main__ - INFO - 已處理 1188000 個項目
# 2025-03-12 08:36:16,613 - __main__ - INFO - 已處理 1189000 個項目
# 2025-03-12 08:36:16,642 - __main__ - INFO - 已處理 1190000 個項目
# 2025-03-12 08:36:16,672 - __main__ - INFO - 已處理 1191000 個項目
# 2025-03-12 08:36:16,702 - __main__ - INFO - 已處理 1192000 個項目
# 2025-03-12 08:36:16,731 - __main__ - INFO - 已處理 1193000 個項目
# 2025-03-12 08:36:16,760 - __main__ - INFO - 已處理 1194000 個項目
# 2025-03-12 08:36:16,788 - __main__ - INFO - 已處理 1195000 個項目
# 2025-03-12 08:36:16,818 - __main__ - INFO - 已處理 1196000 個項目
# 2025-03-12 08:36:16,846 - __main__ - INFO - 已處理 1197000 個項目
# 2025-03-12 08:36:16,875 - __main__ - INFO - 已處理 1198000 個項目
# 2025-03-12 08:36:16,904 - __main__ - INFO - 已處理 1199000 個項目
# 2025-03-12 08:36:16,934 - __main__ - INFO - 已處理 1200000 個項目
# 2025-03-12 08:36:16,963 - __main__ - INFO - 已處理 1201000 個項目
# 2025-03-12 08:36:16,992 - __main__ - INFO - 已處理 1202000 個項目
# 2025-03-12 08:36:17,021 - __main__ - INFO - 已處理 1203000 個項目
# 2025-03-12 08:36:17,049 - __main__ - INFO - 已處理 1204000 個項目
# 2025-03-12 08:36:17,079 - __main__ - INFO - 已處理 1205000 個項目
# 2025-03-12 08:36:17,108 - __main__ - INFO - 已處理 1206000 個項目
# 2025-03-12 08:36:17,137 - __main__ - INFO - 已處理 1207000 個項目
# 2025-03-12 08:36:17,165 - __main__ - INFO - 已處理 1208000 個項目
# 2025-03-12 08:36:17,195 - __main__ - INFO - 已處理 1209000 個項目
# 2025-03-12 08:36:17,226 - __main__ - INFO - 已處理 1210000 個項目
# 2025-03-12 08:36:17,254 - __main__ - INFO - 已處理 1211000 個項目
# 2025-03-12 08:36:17,283 - __main__ - INFO - 已處理 1212000 個項目
# 2025-03-12 08:36:17,312 - __main__ - INFO - 已處理 1213000 個項目
# 2025-03-12 08:36:17,340 - __main__ - INFO - 已處理 1214000 個項目
# 2025-03-12 08:36:17,370 - __main__ - INFO - 已處理 1215000 個項目
# 2025-03-12 08:36:17,398 - __main__ - INFO - 已處理 1216000 個項目
# 2025-03-12 08:36:17,428 - __main__ - INFO - 已處理 1217000 個項目
# 2025-03-12 08:36:17,456 - __main__ - INFO - 已處理 1218000 個項目
# 2025-03-12 08:36:17,485 - __main__ - INFO - 已處理 1219000 個項目
# 2025-03-12 08:36:17,514 - __main__ - INFO - 已處理 1220000 個項目
# 2025-03-12 08:36:17,542 - __main__ - INFO - 已處理 1221000 個項目
# 2025-03-12 08:36:17,572 - __main__ - INFO - 已處理 1222000 個項目
# 2025-03-12 08:36:17,600 - __main__ - INFO - 已處理 1223000 個項目
# 2025-03-12 08:36:17,629 - __main__ - INFO - 已處理 1224000 個項目
# 2025-03-12 08:36:17,658 - __main__ - INFO - 已處理 1225000 個項目
# 2025-03-12 08:36:17,688 - __main__ - INFO - 已處理 1226000 個項目
# 2025-03-12 08:36:17,719 - __main__ - INFO - 已處理 1227000 個項目
# 2025-03-12 08:36:17,748 - __main__ - INFO - 已處理 1228000 個項目
# 2025-03-12 08:36:17,778 - __main__ - INFO - 已處理 1229000 個項目
# 2025-03-12 08:36:17,807 - __main__ - INFO - 已處理 1230000 個項目
# 2025-03-12 08:36:17,836 - __main__ - INFO - 已處理 1231000 個項目
# 2025-03-12 08:36:17,864 - __main__ - INFO - 已處理 1232000 個項目
# 2025-03-12 08:36:17,893 - __main__ - INFO - 已處理 1233000 個項目
# 2025-03-12 08:36:17,922 - __main__ - INFO - 已處理 1234000 個項目
# 2025-03-12 08:36:17,952 - __main__ - INFO - 已處理 1235000 個項目
# 2025-03-12 08:36:17,982 - __main__ - INFO - 已處理 1236000 個項目
# 2025-03-12 08:36:18,011 - __main__ - INFO - 已處理 1237000 個項目
# 2025-03-12 08:36:18,042 - __main__ - INFO - 已處理 1238000 個項目
# 2025-03-12 08:36:18,072 - __main__ - INFO - 已處理 1239000 個項目
# 2025-03-12 08:36:18,102 - __main__ - INFO - 已處理 1240000 個項目
# 2025-03-12 08:36:18,131 - __main__ - INFO - 已處理 1241000 個項目
# 2025-03-12 08:36:18,162 - __main__ - INFO - 已處理 1242000 個項目
# 2025-03-12 08:36:18,191 - __main__ - INFO - 已處理 1243000 個項目
# 2025-03-12 08:36:18,220 - __main__ - INFO - 已處理 1244000 個項目
# 2025-03-12 08:36:18,249 - __main__ - INFO - 已處理 1245000 個項目
# 2025-03-12 08:36:18,277 - __main__ - INFO - 已處理 1246000 個項目
# 2025-03-12 08:36:18,305 - __main__ - INFO - 已處理 1247000 個項目
# 2025-03-12 08:36:18,334 - __main__ - INFO - 已處理 1248000 個項目
# 2025-03-12 08:36:18,362 - __main__ - INFO - 已處理 1249000 個項目
# 2025-03-12 08:36:18,390 - __main__ - INFO - 已處理 1250000 個項目
# 2025-03-12 08:36:18,418 - __main__ - INFO - 已處理 1251000 個項目
# 2025-03-12 08:36:18,446 - __main__ - INFO - 已處理 1252000 個項目
# 2025-03-12 08:36:18,474 - __main__ - INFO - 已處理 1253000 個項目
# 2025-03-12 08:36:18,502 - __main__ - INFO - 已處理 1254000 個項目
# 2025-03-12 08:36:18,531 - __main__ - INFO - 已處理 1255000 個項目
# 2025-03-12 08:36:18,559 - __main__ - INFO - 已處理 1256000 個項目
# 2025-03-12 08:36:18,587 - __main__ - INFO - 已處理 1257000 個項目
# 2025-03-12 08:36:18,615 - __main__ - INFO - 已處理 1258000 個項目
# 2025-03-12 08:36:18,643 - __main__ - INFO - 已處理 1259000 個項目
# 2025-03-12 08:36:18,673 - __main__ - INFO - 已處理 1260000 個項目
# 2025-03-12 08:36:18,702 - __main__ - INFO - 已處理 1261000 個項目
# 2025-03-12 08:36:18,730 - __main__ - INFO - 已處理 1262000 個項目
# 2025-03-12 08:36:18,758 - __main__ - INFO - 已處理 1263000 個項目
# 2025-03-12 08:36:18,789 - __main__ - INFO - 已處理 1264000 個項目
# 2025-03-12 08:36:18,818 - __main__ - INFO - 已處理 1265000 個項目
# 2025-03-12 08:36:18,849 - __main__ - INFO - 已處理 1266000 個項目
# 2025-03-12 08:36:18,877 - __main__ - INFO - 已處理 1267000 個項目
# 2025-03-12 08:36:18,906 - __main__ - INFO - 已處理 1268000 個項目
# 2025-03-12 08:36:18,935 - __main__ - INFO - 已處理 1269000 個項目
# 2025-03-12 08:36:18,965 - __main__ - INFO - 已處理 1270000 個項目
# 2025-03-12 08:36:18,994 - __main__ - INFO - 已處理 1271000 個項目
# 2025-03-12 08:36:19,023 - __main__ - INFO - 已處理 1272000 個項目
# 2025-03-12 08:36:19,052 - __main__ - INFO - 已處理 1273000 個項目
# 2025-03-12 08:36:19,083 - __main__ - INFO - 已處理 1274000 個項目
# 2025-03-12 08:36:19,112 - __main__ - INFO - 已處理 1275000 個項目
# 2025-03-12 08:36:19,141 - __main__ - INFO - 已處理 1276000 個項目
# 2025-03-12 08:36:19,171 - __main__ - INFO - 已處理 1277000 個項目
# 2025-03-12 08:36:19,201 - __main__ - INFO - 已處理 1278000 個項目
# 2025-03-12 08:36:19,231 - __main__ - INFO - 已處理 1279000 個項目
# 2025-03-12 08:36:19,259 - __main__ - INFO - 已處理 1280000 個項目
# 2025-03-12 08:36:19,289 - __main__ - INFO - 已處理 1281000 個項目
# 2025-03-12 08:36:19,318 - __main__ - INFO - 已處理 1282000 個項目
# 2025-03-12 08:36:19,347 - __main__ - INFO - 已處理 1283000 個項目
# 2025-03-12 08:36:19,377 - __main__ - INFO - 已處理 1284000 個項目
# 2025-03-12 08:36:19,405 - __main__ - INFO - 已處理 1285000 個項目
# 2025-03-12 08:36:19,435 - __main__ - INFO - 已處理 1286000 個項目
# 2025-03-12 08:36:19,463 - __main__ - INFO - 已處理 1287000 個項目
# 2025-03-12 08:36:19,493 - __main__ - INFO - 已處理 1288000 個項目
# 2025-03-12 08:36:19,523 - __main__ - INFO - 已處理 1289000 個項目
# 2025-03-12 08:36:19,552 - __main__ - INFO - 已處理 1290000 個項目
# 2025-03-12 08:36:19,581 - __main__ - INFO - 已處理 1291000 個項目
# 2025-03-12 08:36:19,608 - __main__ - INFO - 已處理 1292000 個項目
# 2025-03-12 08:36:19,638 - __main__ - INFO - 已處理 1293000 個項目
# 2025-03-12 08:36:19,667 - __main__ - INFO - 已處理 1294000 個項目
# 2025-03-12 08:36:19,696 - __main__ - INFO - 已處理 1295000 個項目
# 2025-03-12 08:36:19,726 - __main__ - INFO - 已處理 1296000 個項目
# 2025-03-12 08:36:19,755 - __main__ - INFO - 已處理 1297000 個項目
# 2025-03-12 08:36:19,797 - __main__ - INFO - 已處理 1298000 個項目
# 2025-03-12 08:36:19,829 - __main__ - INFO - 已處理 1299000 個項目
# 2025-03-12 08:36:19,860 - __main__ - INFO - 已處理 1300000 個項目
# 2025-03-12 08:36:19,888 - __main__ - INFO - 已處理 1301000 個項目
# 2025-03-12 08:36:19,918 - __main__ - INFO - 已處理 1302000 個項目
# 2025-03-12 08:36:19,947 - __main__ - INFO - 已處理 1303000 個項目
# 2025-03-12 08:36:19,977 - __main__ - INFO - 已處理 1304000 個項目
# 2025-03-12 08:36:20,008 - __main__ - INFO - 已處理 1305000 個項目
# 2025-03-12 08:36:20,038 - __main__ - INFO - 已處理 1306000 個項目
# 2025-03-12 08:36:20,068 - __main__ - INFO - 已處理 1307000 個項目
# 2025-03-12 08:36:20,098 - __main__ - INFO - 已處理 1308000 個項目
# 2025-03-12 08:36:20,128 - __main__ - INFO - 已處理 1309000 個項目
# 2025-03-12 08:36:20,160 - __main__ - INFO - 已處理 1310000 個項目
# 2025-03-12 08:36:20,189 - __main__ - INFO - 已處理 1311000 個項目
# 2025-03-12 08:36:20,219 - __main__ - INFO - 已處理 1312000 個項目
# 2025-03-12 08:36:20,250 - __main__ - INFO - 已處理 1313000 個項目
# 2025-03-12 08:36:20,281 - __main__ - INFO - 已處理 1314000 個項目
# 2025-03-12 08:36:20,311 - __main__ - INFO - 已處理 1315000 個項目
# 2025-03-12 08:36:20,341 - __main__ - INFO - 已處理 1316000 個項目
# 2025-03-12 08:36:20,373 - __main__ - INFO - 已處理 1317000 個項目
# 2025-03-12 08:36:20,402 - __main__ - INFO - 已處理 1318000 個項目
# 2025-03-12 08:36:20,432 - __main__ - INFO - 已處理 1319000 個項目
# 2025-03-12 08:36:20,462 - __main__ - INFO - 已處理 1320000 個項目
# 2025-03-12 08:36:20,492 - __main__ - INFO - 已處理 1321000 個項目
# 2025-03-12 08:36:20,523 - __main__ - INFO - 已處理 1322000 個項目
# 2025-03-12 08:36:20,552 - __main__ - INFO - 已處理 1323000 個項目
# 2025-03-12 08:36:20,582 - __main__ - INFO - 已處理 1324000 個項目
# 2025-03-12 08:36:20,612 - __main__ - INFO - 已處理 1325000 個項目
# 2025-03-12 08:36:20,643 - __main__ - INFO - 已處理 1326000 個項目
# 2025-03-12 08:36:20,671 - __main__ - INFO - 已處理 1327000 個項目
# 2025-03-12 08:36:20,699 - __main__ - INFO - 已處理 1328000 個項目
# 2025-03-12 08:36:20,727 - __main__ - INFO - 已處理 1329000 個項目
# 2025-03-12 08:36:20,757 - __main__ - INFO - 已處理 1330000 個項目
# 2025-03-12 08:36:20,786 - __main__ - INFO - 已處理 1331000 個項目
# 2025-03-12 08:36:20,815 - __main__ - INFO - 已處理 1332000 個項目
# 2025-03-12 08:36:20,844 - __main__ - INFO - 已處理 1333000 個項目
# 2025-03-12 08:36:20,872 - __main__ - INFO - 已處理 1334000 個項目
# 2025-03-12 08:36:20,902 - __main__ - INFO - 已處理 1335000 個項目
# 2025-03-12 08:36:20,932 - __main__ - INFO - 已處理 1336000 個項目
# 2025-03-12 08:36:20,960 - __main__ - INFO - 已處理 1337000 個項目
# 2025-03-12 08:36:20,987 - __main__ - INFO - 已處理 1338000 個項目
# 2025-03-12 08:36:21,015 - __main__ - INFO - 已處理 1339000 個項目
# 2025-03-12 08:36:21,044 - __main__ - INFO - 已處理 1340000 個項目
# 2025-03-12 08:36:21,073 - __main__ - INFO - 已處理 1341000 個項目
# 2025-03-12 08:36:21,103 - __main__ - INFO - 已處理 1342000 個項目
# 2025-03-12 08:36:21,131 - __main__ - INFO - 已處理 1343000 個項目
# 2025-03-12 08:36:21,159 - __main__ - INFO - 已處理 1344000 個項目
# 2025-03-12 08:36:21,188 - __main__ - INFO - 已處理 1345000 個項目
# 2025-03-12 08:36:21,217 - __main__ - INFO - 已處理 1346000 個項目
# 2025-03-12 08:36:21,247 - __main__ - INFO - 已處理 1347000 個項目
# 2025-03-12 08:36:21,276 - __main__ - INFO - 已處理 1348000 個項目
# 2025-03-12 08:36:21,305 - __main__ - INFO - 已處理 1349000 個項目
# 2025-03-12 08:36:21,335 - __main__ - INFO - 已處理 1350000 個項目
# 2025-03-12 08:36:21,364 - __main__ - INFO - 已處理 1351000 個項目
# 2025-03-12 08:36:21,393 - __main__ - INFO - 已處理 1352000 個項目
# 2025-03-12 08:36:21,420 - __main__ - INFO - 已處理 1353000 個項目
# 2025-03-12 08:36:21,449 - __main__ - INFO - 已處理 1354000 個項目
# 2025-03-12 08:36:21,478 - __main__ - INFO - 已處理 1355000 個項目
# 2025-03-12 08:36:21,507 - __main__ - INFO - 已處理 1356000 個項目
# 2025-03-12 08:36:21,537 - __main__ - INFO - 已處理 1357000 個項目
# 2025-03-12 08:36:21,565 - __main__ - INFO - 已處理 1358000 個項目
# 2025-03-12 08:36:21,594 - __main__ - INFO - 已處理 1359000 個項目
# 2025-03-12 08:36:21,624 - __main__ - INFO - 已處理 1360000 個項目
# 2025-03-12 08:36:21,654 - __main__ - INFO - 已處理 1361000 個項目
# 2025-03-12 08:36:21,682 - __main__ - INFO - 已處理 1362000 個項目
# 2025-03-12 08:36:21,711 - __main__ - INFO - 已處理 1363000 個項目
# 2025-03-12 08:36:21,741 - __main__ - INFO - 已處理 1364000 個項目
# 2025-03-12 08:36:21,771 - __main__ - INFO - 已處理 1365000 個項目
# 2025-03-12 08:36:21,800 - __main__ - INFO - 已處理 1366000 個項目
# 2025-03-12 08:36:21,829 - __main__ - INFO - 已處理 1367000 個項目
# 2025-03-12 08:36:21,858 - __main__ - INFO - 已處理 1368000 個項目
# 2025-03-12 08:36:21,887 - __main__ - INFO - 已處理 1369000 個項目
# 2025-03-12 08:36:21,907 - __main__ - INFO - 已處理 1369696 個項目
# 2025-03-12 08:36:21,907 - __main__ - INFO - 分批處理完成，總共處理 1369696 個項目
# 2025-03-12 08:36:30,216 - __main__ - INFO - 已成功儲存 1369696 個項目至 JSON 檔案: ../data/convert/official-cpe-dictionary_v2.3_v2.json
# 2025-03-12 08:36:37,315 - __main__ - INFO - 已成功儲存 1369696 個項目至 CSV 檔案: ../data/convert/official-cpe-dictionary_v2.3_v2.csv
# 2025-03-12 08:36:37,317 - __main__ - INFO - 程式執行完成
