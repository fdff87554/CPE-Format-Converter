# %% [markdown]
# # CPE Format Converter (POC) example Jupyter Notebook
#
# This is a proof of concept for a CPE Format Converter.
#
# ## Description
#
# Due to time constraints, the construction logic and thought process of this Proof of Concept (PoC) will be initially presented in this Jupyter Notebook. Further development and maintenance will continue to implement more comprehensive functionalities, such as automation and a Web User Interface.
#
# > 由於時間限制，此概念驗證（PoC）的建構邏輯與思路將以本 Jupyter Notebook 的形式初步呈現。後續將持續進行開發與維護，以實現自動化、Web 使用者介面等更完善的功能。
#
# ## Design
#
# This Proof of Concept (PoC) aims to provide users with a tool to search for vulnerabilities associated with specific products by inputting Vendor, Product, and Version information. The tool will interact with the National Vulnerability Database (NVD) Common Vulnerabilities and Exposures (CVE) database to retrieve relevant CVE vulnerability data. Since the NVD Vulnerability API (CVE API) uses Common Platform Enumeration (CPE) for searching, user input needs to be converted into CPE format. However, while the CPE format has a standardized specification, there is no standard conversion process, and it cannot be guaranteed that the converted CPE is included in the NVD. To address this issue, we will use the NVD's CPE Directory List as a foundation to convert user input and obtain or generate the correct CPE, subsequently using the NVD Vulnerability API to retrieve further vulnerability data.
#
# > 本概念驗證（PoC）旨在提供使用者一個工具，透過輸入廠商（Vendor）、產品（Product）和版本（Version）資訊，搜尋相關產品的漏洞（Vulnerability）。此工具將與美國國家漏洞資料庫（NVD）的通用漏洞披露（CVE）資料庫互動，取得相關的 CVE 漏洞資訊。由於 NVD 的漏洞應用程式介面（CVE API）使用通用平台列舉（CPE）進行搜尋，因此需要將使用者輸入轉換為 CPE 格式。然而，儘管 CPE 格式具有標準化的規範，卻缺乏標準的轉換流程，且無法確定轉換後的 CPE 是否已被 NVD 收錄。為解決此問題，我們將利用 NVD 提供的 CPE 目錄列表（CPE Directory List）作為基礎，進行使用者輸入的轉換，並取得或產生正確的 CPE，進而使用 NVD 的漏洞應用程式介面取得後續的漏洞資料。
#
# ## Usage
#
# We will leverage the interactive features of Jupyter Notebook to provide detailed explanations of the operational process through segmented code, allowing users to reproduce the same operational results by executing this notebook. Please follow the subsequent operational instructions and code comments for adjustments and execution.
#
# > 我們將利用 Jupyter Notebook 的互動式特性，以分段程式碼的方式詳細說明操作流程，並允許使用者透過執行本 Notebook 複現相同的操作結果。請依照後續的操作說明與程式碼註解進行調整與執行。

# %% [markdown]
# ## Step 1: Get Offical CPE Directory List
#
# Please manually download the CPE Directory List from the official National Vulnerability Database (NVD) website and place the file in the `data` directory of the project repository (Repo). If you have any questions about the operation, please refer to the README file in the `data` directory.
#
# > 請手動自美國國家漏洞資料庫（NVD）官方網站下載 CPE 目錄列表（CPE Directory List），並將檔案放置於專案儲存庫（Repo）的 `data` 目錄中。若對操作方式有疑問，請參閱 `data` 目錄中的 README 檔案。

# %% [markdown]
# ## Step 2: Decompression and Data Pre-processing
#
# The Common Platform Enumeration (CPE) list provided by the National Vulnerability Database (NVD) is in XML format. While detailed and comprehensive, its structure is not ideal for direct import into Chromadb for subsequent operations. Therefore, we will filter and organize the XML content of the CPE list and output it in Comma-Separated Values (CSV) format.
#
# (Converting to CSV format is a non-essential transitional step, primarily to facilitate the review of the organized XML data and accelerate data utilization and analysis.)
#
# The resulting structured CSV data (or Dataframe) will be processed and imported into Chromadb in the subsequent steps.
#
#
# > 由於美國國家漏洞資料庫（NVD）提供的通用平台列舉（CPE）列表為 XML 格式，其結構雖詳盡完整，但不利於直接匯入 Chromadb 進行後續操作。因此，我們將對 CPE 列表的 XML 內容進行篩選與整理，並轉換為逗號分隔值（CSV）格式輸出。
# >
# > （轉換為 CSV 格式為一非必要的過渡步驟，主要目的是為了方便檢視整理後的 XML 資料，以加速資料的使用與分析。）
# >
# > 轉換後的 CSV 結構化資料（或 Dataframe）將於後續步驟中進行計算並匯入 Chromadb。

# %%
from lxml import etree
import json
import csv
from typing import Dict, List, Iterator, Optional, Tuple
import logging
from pathlib import Path
import re
from dataclasses import dataclass, asdict
from contextlib import contextmanager


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class CPEParser:
    """CPE XML 字典的分析器，用於將 CPE 項目轉換為結構化資料"""

    # CPE 命名空間定義
    NAMESPACES = {
        'cpe-23': 'http://scap.nist.gov/schema/cpe-extension/2.3',
        'def': 'http://cpe.mitre.org/dictionary/2.0',
        'xml': 'http://www.w3.org/XML/1998/namespace'
    }

    def __init__(self, xml_file_path: str):
        """初始化 CPE 分析器

        Args:
            xml_file_path (str): XML 檔案路徑
        """
        self.xml_file_path = Path(xml_file_path)
        self.logger = logging.getLogger(__name__)

        if not self.xml_file_path.exists():
            raise FileNotFoundError(f"找不到 XML 檔案: {xml_file_path}")

    @staticmethod
    def parse_cpe23_uri(cpe23uri: str) -> Dict[str, str]:
        """分析 CPE 2.3 URI 並提取各個組件

        Args:
            cpe23uri (str): CPE 2.3 URI 字串 (例如: cpe:2.3:a:vendor:product:version:...)

        Returns:
            Dict[str, str]: 包含廠商、產品和版本資訊的字典
        """
        # CPE 2.3 格式: cpe:2.3:part:vendor:product:version:update:edition:language:sw_edition:target_sw:target_hw:other
        components = cpe23uri.split(':')

        if len(components) < 6:
            return {"vendor": "", "product": "", "version": ""}

        return {
            'vendor': components[3],
            'product': components[4],
            'version': components[5]
        }

    @contextmanager
    def _open_xml_context(self) -> Iterator:
        """建立用於迭代 XML 檔案中 CPE 項目的上下文管理器

        Yields:
            Iterator: 用於迭代 XML 檔案中 CPE 項目的迭代器
        """
        try:
            context = etree.iterparse(
                str(self.xml_file_path),
                events=('end',),
                tag=f'{{{self.NAMESPACES["def"]}}}cpe-item'
            )
            yield context
        except etree.ParseError as e:
            self.logger.error(f"XML 分析錯誤: {e}")
            raise
        except Exception as e:
            self.logger.error(f"處理 XML 時發生未預期的錯誤: {e}")
            raise

    def _extract_item_data(self, item: etree._Element) -> Optional[CPEItem]:
        """從 XML 元素中提取 CPE 項目資料

        Args:
            item (etree._Element): 包含 CPE 項目資料的 XML 元素

        Returns:
            Optional[CPEItem]: 如果成功提取則返回 CPEItem 物件，否則返回 None
        """
        try:
            # 取得 CPE 2.3 URI
            cpe23_item = item.find('.//cpe-23:cpe23-item', self.NAMESPACES)
            if cpe23_item is None:
                return None

            cpe23uri = cpe23_item.get('name', '')
            if not cpe23uri:
                return None

            # 分析 CPE 組件
            cpe_components = self.parse_cpe23_uri(cpe23uri)

            # 取得標題
            title_elem = item.find(
                './/def:title[@xml:lang="en-US"]', self.NAMESPACES)
            title = title_elem.text if title_elem is not None else ""

            # 取得參考資料
            references = self._extract_references(item)

            # 建立 CPE 項目物件
            return CPEItem(
                cpe22Uri=item.get('name', ''),
                cpe23Uri=cpe23uri,
                vendor=cpe_components['vendor'],
                product=cpe_components['product'],
                version=cpe_components['version'],
                title=title,
                references=references
            )
        except Exception as e:
            self.logger.warning(f"提取 CPE 項目時發生錯誤: {e}")
            return None

    def _extract_references(self, item: etree._Element) -> str:
        """從 XML 元素中提取參考資料

        Args:
            item (etree._Element): 包含參考資料的 XML 元素

        Returns:
            str: 格式化的參考資料字串
        """
        refs = item.findall('.//def:reference', self.NAMESPACES)
        ref_texts = []

        for ref in refs:
            href = ref.get('href', '')
            ref_text = ref.text or ''

            if href and ref_text:
                ref_texts.append(f"{ref_text} ({href})")
            elif href:
                ref_texts.append(href)
            elif ref_text:
                ref_texts.append(ref_text)

        return ' '.join(ref_texts)

    def _clear_element_memory(self, item: etree._Element) -> None:
        """清理 XML 元素佔用的記憶體

        Args:
            item (etree._Element): 要清理的 XML 元素
        """
        item.clear()
        # 清理前面的同層級元素以釋放記憶體
        while item.getprevious() is not None:
            del item.getparent()[0]

    def parse_xml(self) -> List[Dict]:
        """分析整個 CPE XML 檔案

        Returns:
            List[Dict]: 分析後的 CPE 資料列表
        """
        self.logger.info(f"開始分析 XML 檔案: {self.xml_file_path}")
        cpe_items = []

        with self._open_xml_context() as context:
            for event, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    cpe_items.append(asdict(cpe_item))

                self._clear_element_memory(item)

        self.logger.info(f"分析完成，共提取 {len(cpe_items)} 個 CPE 項目")
        return cpe_items

    def process_by_chunk(self, chunk_size: int = 1000) -> Iterator[List[Dict]]:
        """使用分批處理方式處理大型 XML 檔案

        Args:
            chunk_size (int, optional): 每批處理的項目數量. 預設為 1000.

        Yields:
            List[Dict]: 每批處理的 CPE 項目列表
        """
        self.logger.info(f"開始分批處理 XML 檔案 (每批 {chunk_size} 個項目)")
        items = []
        total_processed = 0

        with self._open_xml_context() as context:
            for event, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    items.append(asdict(cpe_item))

                self._clear_element_memory(item)

                if len(items) >= chunk_size:
                    total_processed += len(items)
                    self.logger.debug(f"已處理 {total_processed} 個項目")
                    yield items
                    items = []

            if items:
                total_processed += len(items)
                self.logger.debug(f"已處理 {total_processed} 個項目")
                yield items

        self.logger.info(f"分批處理完成，總共處理 {total_processed} 個項目")

    def save_to_json(self, output_file: str, items: Optional[List[Dict]] = None) -> None:
        """將分析結果儲存為 JSON 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            cpe_items = items if items is not None else self.parse_xml()

            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(cpe_items, f, ensure_ascii=False, indent=2)

            self.logger.info(
                f"已成功儲存 {len(cpe_items)} 個項目至 JSON 檔案: {output_path}")

        except Exception as e:
            self.logger.error(f"儲存 JSON 檔案時發生錯誤: {e}")
            raise

    def save_to_csv(self, output_file: str, items: Optional[List[Dict]] = None) -> None:
        """將分析結果儲存為 CSV 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            cpe_items = items if items is not None else self.parse_xml()
            fieldnames = ['cpe22Uri', 'cpe23Uri', 'vendor', 'product',
                          'version', 'title', 'references']

            with open(output_path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(cpe_items)

            self.logger.info(
                f"已成功儲存 {len(cpe_items)} 個項目至 CSV 檔案: {output_path}")

        except Exception as e:
            self.logger.error(f"儲存 CSV 檔案時發生錯誤: {e}")
            raise


def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


def main():
    # 設定日誌
    log_file = "../logs/cpe_parser.log"
    setup_logging(log_level=logging.INFO, log_file=log_file)
    logger = logging.getLogger(__name__)

    # 設定檔案路徑
    input_file = "../data/official-cpe-dictionary_v2.3.xml"
    output_dir = Path("../data/convert")
    output_dir.mkdir(parents=True, exist_ok=True)

    output_json = output_dir / "official-cpe-dictionary_v2.3_v2.json"
    output_csv = output_dir / "official-cpe-dictionary_v2.3_v2.csv"

    try:
        logger.info(f"開始處理 CPE 字典檔案: {input_file}")
        parser = CPEParser(input_file)

        # 使用分批處理分析 XML 檔案並儲存結果
        all_items = []
        total_processed = 0

        for chunk in parser.process_by_chunk(chunk_size=1000):
            all_items.extend(chunk)
            total_processed += len(chunk)
            logger.info(f"已處理 {total_processed} 個項目")

        # 儲存為 JSON 和 CSV
        parser.save_to_json(str(output_json), all_items)
        parser.save_to_csv(str(output_csv), all_items)

        logger.info("程式執行完成")

    except FileNotFoundError as e:
        logger.error(f"找不到檔案: {e}")
    except Exception as e:
        logger.error(f"程式執行失敗: {e}", exc_info=True)


if __name__ == "__main__":
    main()
# Out:
# 2025-03-12 11:23:05,588 - __main__ - INFO - 開始處理 CPE 字典檔案: ../data/official-cpe-dictionary_v2.3.xml
# 2025-03-12 11:23:05,589 - __main__ - INFO - 開始分批處理 XML 檔案 (每批 1000 個項目)
# 2025-03-12 11:23:05,607 - __main__ - INFO - 已處理 1000 個項目
# 2025-03-12 11:23:05,638 - __main__ - INFO - 已處理 2000 個項目
# 2025-03-12 11:23:05,657 - __main__ - INFO - 已處理 3000 個項目
# 2025-03-12 11:23:05,674 - __main__ - INFO - 已處理 4000 個項目
# 2025-03-12 11:23:05,690 - __main__ - INFO - 已處理 5000 個項目
# 2025-03-12 11:23:05,707 - __main__ - INFO - 已處理 6000 個項目
# 2025-03-12 11:23:05,724 - __main__ - INFO - 已處理 7000 個項目
# 2025-03-12 11:23:05,740 - __main__ - INFO - 已處理 8000 個項目
# 2025-03-12 11:23:05,757 - __main__ - INFO - 已處理 9000 個項目
# 2025-03-12 11:23:05,774 - __main__ - INFO - 已處理 10000 個項目
# 2025-03-12 11:23:05,791 - __main__ - INFO - 已處理 11000 個項目
# 2025-03-12 11:23:05,807 - __main__ - INFO - 已處理 12000 個項目
# 2025-03-12 11:23:05,825 - __main__ - INFO - 已處理 13000 個項目
# 2025-03-12 11:23:05,843 - __main__ - INFO - 已處理 14000 個項目
# 2025-03-12 11:23:05,858 - __main__ - INFO - 已處理 15000 個項目
# 2025-03-12 11:23:05,875 - __main__ - INFO - 已處理 16000 個項目
# 2025-03-12 11:23:05,891 - __main__ - INFO - 已處理 17000 個項目
# 2025-03-12 11:23:05,907 - __main__ - INFO - 已處理 18000 個項目
# 2025-03-12 11:23:05,925 - __main__ - INFO - 已處理 19000 個項目
# 2025-03-12 11:23:05,941 - __main__ - INFO - 已處理 20000 個項目
# 2025-03-12 11:23:05,956 - __main__ - INFO - 已處理 21000 個項目
# 2025-03-12 11:23:05,973 - __main__ - INFO - 已處理 22000 個項目
# 2025-03-12 11:23:05,990 - __main__ - INFO - 已處理 23000 個項目
# 2025-03-12 11:23:06,007 - __main__ - INFO - 已處理 24000 個項目
# 2025-03-12 11:23:06,025 - __main__ - INFO - 已處理 25000 個項目
# 2025-03-12 11:23:06,041 - __main__ - INFO - 已處理 26000 個項目
# 2025-03-12 11:23:06,058 - __main__ - INFO - 已處理 27000 個項目
# 2025-03-12 11:23:06,075 - __main__ - INFO - 已處理 28000 個項目
# 2025-03-12 11:23:06,092 - __main__ - INFO - 已處理 29000 個項目
# 2025-03-12 11:23:06,108 - __main__ - INFO - 已處理 30000 個項目
# 2025-03-12 11:23:06,125 - __main__ - INFO - 已處理 31000 個項目
# 2025-03-12 11:23:06,145 - __main__ - INFO - 已處理 32000 個項目
# 2025-03-12 11:23:06,160 - __main__ - INFO - 已處理 33000 個項目
# 2025-03-12 11:23:06,178 - __main__ - INFO - 已處理 34000 個項目
# 2025-03-12 11:23:06,197 - __main__ - INFO - 已處理 35000 個項目
# 2025-03-12 11:23:06,214 - __main__ - INFO - 已處理 36000 個項目
# 2025-03-12 11:23:06,230 - __main__ - INFO - 已處理 37000 個項目
# 2025-03-12 11:23:06,247 - __main__ - INFO - 已處理 38000 個項目
# 2025-03-12 11:23:06,264 - __main__ - INFO - 已處理 39000 個項目
# 2025-03-12 11:23:06,281 - __main__ - INFO - 已處理 40000 個項目
# 2025-03-12 11:23:06,299 - __main__ - INFO - 已處理 41000 個項目
# 2025-03-12 11:23:06,316 - __main__ - INFO - 已處理 42000 個項目
# 2025-03-12 11:23:06,332 - __main__ - INFO - 已處理 43000 個項目
# 2025-03-12 11:23:06,350 - __main__ - INFO - 已處理 44000 個項目
# 2025-03-12 11:23:06,366 - __main__ - INFO - 已處理 45000 個項目
# 2025-03-12 11:23:06,383 - __main__ - INFO - 已處理 46000 個項目
# 2025-03-12 11:23:06,400 - __main__ - INFO - 已處理 47000 個項目
# 2025-03-12 11:23:06,417 - __main__ - INFO - 已處理 48000 個項目
# 2025-03-12 11:23:06,434 - __main__ - INFO - 已處理 49000 個項目
# 2025-03-12 11:23:06,450 - __main__ - INFO - 已處理 50000 個項目
# 2025-03-12 11:23:06,468 - __main__ - INFO - 已處理 51000 個項目
# 2025-03-12 11:23:06,484 - __main__ - INFO - 已處理 52000 個項目
# 2025-03-12 11:23:06,515 - __main__ - INFO - 已處理 53000 個項目
# 2025-03-12 11:23:06,532 - __main__ - INFO - 已處理 54000 個項目
# 2025-03-12 11:23:06,548 - __main__ - INFO - 已處理 55000 個項目
# 2025-03-12 11:23:06,564 - __main__ - INFO - 已處理 56000 個項目
# 2025-03-12 11:23:06,581 - __main__ - INFO - 已處理 57000 個項目
# 2025-03-12 11:23:06,599 - __main__ - INFO - 已處理 58000 個項目
# 2025-03-12 11:23:06,615 - __main__ - INFO - 已處理 59000 個項目
# 2025-03-12 11:23:06,633 - __main__ - INFO - 已處理 60000 個項目
# 2025-03-12 11:23:06,649 - __main__ - INFO - 已處理 61000 個項目
# 2025-03-12 11:23:06,665 - __main__ - INFO - 已處理 62000 個項目
# 2025-03-12 11:23:06,683 - __main__ - INFO - 已處理 63000 個項目
# 2025-03-12 11:23:06,700 - __main__ - INFO - 已處理 64000 個項目
# 2025-03-12 11:23:06,717 - __main__ - INFO - 已處理 65000 個項目
# 2025-03-12 11:23:06,733 - __main__ - INFO - 已處理 66000 個項目
# 2025-03-12 11:23:06,749 - __main__ - INFO - 已處理 67000 個項目
# 2025-03-12 11:23:06,765 - __main__ - INFO - 已處理 68000 個項目
# 2025-03-12 11:23:06,780 - __main__ - INFO - 已處理 69000 個項目
# 2025-03-12 11:23:06,796 - __main__ - INFO - 已處理 70000 個項目
# 2025-03-12 11:23:06,813 - __main__ - INFO - 已處理 71000 個項目
# 2025-03-12 11:23:06,830 - __main__ - INFO - 已處理 72000 個項目
# 2025-03-12 11:23:06,847 - __main__ - INFO - 已處理 73000 個項目
# 2025-03-12 11:23:06,863 - __main__ - INFO - 已處理 74000 個項目
# 2025-03-12 11:23:06,880 - __main__ - INFO - 已處理 75000 個項目
# 2025-03-12 11:23:06,895 - __main__ - INFO - 已處理 76000 個項目
# 2025-03-12 11:23:06,909 - __main__ - INFO - 已處理 77000 個項目
# 2025-03-12 11:23:06,925 - __main__ - INFO - 已處理 78000 個項目
# 2025-03-12 11:23:06,942 - __main__ - INFO - 已處理 79000 個項目
# 2025-03-12 11:23:06,958 - __main__ - INFO - 已處理 80000 個項目
# 2025-03-12 11:23:06,976 - __main__ - INFO - 已處理 81000 個項目
# 2025-03-12 11:23:06,993 - __main__ - INFO - 已處理 82000 個項目
# 2025-03-12 11:23:07,009 - __main__ - INFO - 已處理 83000 個項目
# 2025-03-12 11:23:07,027 - __main__ - INFO - 已處理 84000 個項目
# 2025-03-12 11:23:07,044 - __main__ - INFO - 已處理 85000 個項目
# 2025-03-12 11:23:07,060 - __main__ - INFO - 已處理 86000 個項目
# 2025-03-12 11:23:07,076 - __main__ - INFO - 已處理 87000 個項目
# 2025-03-12 11:23:07,092 - __main__ - INFO - 已處理 88000 個項目
# 2025-03-12 11:23:07,108 - __main__ - INFO - 已處理 89000 個項目
# 2025-03-12 11:23:07,124 - __main__ - INFO - 已處理 90000 個項目
# 2025-03-12 11:23:07,140 - __main__ - INFO - 已處理 91000 個項目
# 2025-03-12 11:23:07,155 - __main__ - INFO - 已處理 92000 個項目
# 2025-03-12 11:23:07,172 - __main__ - INFO - 已處理 93000 個項目
# 2025-03-12 11:23:07,189 - __main__ - INFO - 已處理 94000 個項目
# 2025-03-12 11:23:07,206 - __main__ - INFO - 已處理 95000 個項目
# 2025-03-12 11:23:07,222 - __main__ - INFO - 已處理 96000 個項目
# 2025-03-12 11:23:07,237 - __main__ - INFO - 已處理 97000 個項目
# 2025-03-12 11:23:07,254 - __main__ - INFO - 已處理 98000 個項目
# 2025-03-12 11:23:07,272 - __main__ - INFO - 已處理 99000 個項目
# 2025-03-12 11:23:07,288 - __main__ - INFO - 已處理 100000 個項目
# 2025-03-12 11:23:07,305 - __main__ - INFO - 已處理 101000 個項目
# 2025-03-12 11:23:07,321 - __main__ - INFO - 已處理 102000 個項目
# 2025-03-12 11:23:07,341 - __main__ - INFO - 已處理 103000 個項目
# 2025-03-12 11:23:07,357 - __main__ - INFO - 已處理 104000 個項目
# 2025-03-12 11:23:07,375 - __main__ - INFO - 已處理 105000 個項目
# 2025-03-12 11:23:07,391 - __main__ - INFO - 已處理 106000 個項目
# 2025-03-12 11:23:07,411 - __main__ - INFO - 已處理 107000 個項目
# 2025-03-12 11:23:07,430 - __main__ - INFO - 已處理 108000 個項目
# 2025-03-12 11:23:07,447 - __main__ - INFO - 已處理 109000 個項目
# 2025-03-12 11:23:07,464 - __main__ - INFO - 已處理 110000 個項目
# 2025-03-12 11:23:07,481 - __main__ - INFO - 已處理 111000 個項目
# 2025-03-12 11:23:07,538 - __main__ - INFO - 已處理 112000 個項目
# 2025-03-12 11:23:07,558 - __main__ - INFO - 已處理 113000 個項目
# 2025-03-12 11:23:07,576 - __main__ - INFO - 已處理 114000 個項目
# 2025-03-12 11:23:07,596 - __main__ - INFO - 已處理 115000 個項目
# 2025-03-12 11:23:07,613 - __main__ - INFO - 已處理 116000 個項目
# 2025-03-12 11:23:07,631 - __main__ - INFO - 已處理 117000 個項目
# 2025-03-12 11:23:07,648 - __main__ - INFO - 已處理 118000 個項目
# 2025-03-12 11:23:07,666 - __main__ - INFO - 已處理 119000 個項目
# 2025-03-12 11:23:07,684 - __main__ - INFO - 已處理 120000 個項目
# 2025-03-12 11:23:07,699 - __main__ - INFO - 已處理 121000 個項目
# 2025-03-12 11:23:07,715 - __main__ - INFO - 已處理 122000 個項目
# 2025-03-12 11:23:07,734 - __main__ - INFO - 已處理 123000 個項目
# 2025-03-12 11:23:07,752 - __main__ - INFO - 已處理 124000 個項目
# 2025-03-12 11:23:07,769 - __main__ - INFO - 已處理 125000 個項目
# 2025-03-12 11:23:07,786 - __main__ - INFO - 已處理 126000 個項目
# 2025-03-12 11:23:07,803 - __main__ - INFO - 已處理 127000 個項目
# 2025-03-12 11:23:07,819 - __main__ - INFO - 已處理 128000 個項目
# 2025-03-12 11:23:07,836 - __main__ - INFO - 已處理 129000 個項目
# 2025-03-12 11:23:07,853 - __main__ - INFO - 已處理 130000 個項目
# 2025-03-12 11:23:07,871 - __main__ - INFO - 已處理 131000 個項目
# 2025-03-12 11:23:07,888 - __main__ - INFO - 已處理 132000 個項目
# 2025-03-12 11:23:07,905 - __main__ - INFO - 已處理 133000 個項目
# 2025-03-12 11:23:07,922 - __main__ - INFO - 已處理 134000 個項目
# 2025-03-12 11:23:07,939 - __main__ - INFO - 已處理 135000 個項目
# 2025-03-12 11:23:07,957 - __main__ - INFO - 已處理 136000 個項目
# 2025-03-12 11:23:07,975 - __main__ - INFO - 已處理 137000 個項目
# 2025-03-12 11:23:07,992 - __main__ - INFO - 已處理 138000 個項目
# 2025-03-12 11:23:08,010 - __main__ - INFO - 已處理 139000 個項目
# 2025-03-12 11:23:08,027 - __main__ - INFO - 已處理 140000 個項目
# 2025-03-12 11:23:08,049 - __main__ - INFO - 已處理 141000 個項目
# 2025-03-12 11:23:08,067 - __main__ - INFO - 已處理 142000 個項目
# 2025-03-12 11:23:08,083 - __main__ - INFO - 已處理 143000 個項目
# 2025-03-12 11:23:08,104 - __main__ - INFO - 已處理 144000 個項目
# 2025-03-12 11:23:08,127 - __main__ - INFO - 已處理 145000 個項目
# 2025-03-12 11:23:08,144 - __main__ - INFO - 已處理 146000 個項目
# 2025-03-12 11:23:08,164 - __main__ - INFO - 已處理 147000 個項目
# 2025-03-12 11:23:08,183 - __main__ - INFO - 已處理 148000 個項目
# 2025-03-12 11:23:08,200 - __main__ - INFO - 已處理 149000 個項目
# 2025-03-12 11:23:08,218 - __main__ - INFO - 已處理 150000 個項目
# 2025-03-12 11:23:08,235 - __main__ - INFO - 已處理 151000 個項目
# 2025-03-12 11:23:08,251 - __main__ - INFO - 已處理 152000 個項目
# 2025-03-12 11:23:08,271 - __main__ - INFO - 已處理 153000 個項目
# 2025-03-12 11:23:08,291 - __main__ - INFO - 已處理 154000 個項目
# 2025-03-12 11:23:08,309 - __main__ - INFO - 已處理 155000 個項目
# 2025-03-12 11:23:08,325 - __main__ - INFO - 已處理 156000 個項目
# 2025-03-12 11:23:08,341 - __main__ - INFO - 已處理 157000 個項目
# 2025-03-12 11:23:08,358 - __main__ - INFO - 已處理 158000 個項目
# 2025-03-12 11:23:08,378 - __main__ - INFO - 已處理 159000 個項目
# 2025-03-12 11:23:08,397 - __main__ - INFO - 已處理 160000 個項目
# 2025-03-12 11:23:08,414 - __main__ - INFO - 已處理 161000 個項目
# 2025-03-12 11:23:08,472 - __main__ - INFO - 已處理 162000 個項目
# 2025-03-12 11:23:08,493 - __main__ - INFO - 已處理 163000 個項目
# 2025-03-12 11:23:08,514 - __main__ - INFO - 已處理 164000 個項目
# 2025-03-12 11:23:08,533 - __main__ - INFO - 已處理 165000 個項目
# 2025-03-12 11:23:08,552 - __main__ - INFO - 已處理 166000 個項目
# 2025-03-12 11:23:08,571 - __main__ - INFO - 已處理 167000 個項目
# 2025-03-12 11:23:08,589 - __main__ - INFO - 已處理 168000 個項目
# 2025-03-12 11:23:08,607 - __main__ - INFO - 已處理 169000 個項目
# 2025-03-12 11:23:08,627 - __main__ - INFO - 已處理 170000 個項目
# 2025-03-12 11:23:08,645 - __main__ - INFO - 已處理 171000 個項目
# 2025-03-12 11:23:08,663 - __main__ - INFO - 已處理 172000 個項目
# 2025-03-12 11:23:08,682 - __main__ - INFO - 已處理 173000 個項目
# 2025-03-12 11:23:08,699 - __main__ - INFO - 已處理 174000 個項目
# 2025-03-12 11:23:08,717 - __main__ - INFO - 已處理 175000 個項目
# 2025-03-12 11:23:08,736 - __main__ - INFO - 已處理 176000 個項目
# 2025-03-12 11:23:08,753 - __main__ - INFO - 已處理 177000 個項目
# 2025-03-12 11:23:08,772 - __main__ - INFO - 已處理 178000 個項目
# 2025-03-12 11:23:08,789 - __main__ - INFO - 已處理 179000 個項目
# 2025-03-12 11:23:08,806 - __main__ - INFO - 已處理 180000 個項目
# 2025-03-12 11:23:08,822 - __main__ - INFO - 已處理 181000 個項目
# 2025-03-12 11:23:08,840 - __main__ - INFO - 已處理 182000 個項目
# 2025-03-12 11:23:08,857 - __main__ - INFO - 已處理 183000 個項目
# 2025-03-12 11:23:08,874 - __main__ - INFO - 已處理 184000 個項目
# 2025-03-12 11:23:08,892 - __main__ - INFO - 已處理 185000 個項目
# 2025-03-12 11:23:08,910 - __main__ - INFO - 已處理 186000 個項目
# 2025-03-12 11:23:08,926 - __main__ - INFO - 已處理 187000 個項目
# 2025-03-12 11:23:08,944 - __main__ - INFO - 已處理 188000 個項目
# 2025-03-12 11:23:08,964 - __main__ - INFO - 已處理 189000 個項目
# 2025-03-12 11:23:08,982 - __main__ - INFO - 已處理 190000 個項目
# 2025-03-12 11:23:09,002 - __main__ - INFO - 已處理 191000 個項目
# 2025-03-12 11:23:09,020 - __main__ - INFO - 已處理 192000 個項目
# 2025-03-12 11:23:09,041 - __main__ - INFO - 已處理 193000 個項目
# 2025-03-12 11:23:09,062 - __main__ - INFO - 已處理 194000 個項目
# 2025-03-12 11:23:09,083 - __main__ - INFO - 已處理 195000 個項目
# 2025-03-12 11:23:09,101 - __main__ - INFO - 已處理 196000 個項目
# 2025-03-12 11:23:09,118 - __main__ - INFO - 已處理 197000 個項目
# 2025-03-12 11:23:09,137 - __main__ - INFO - 已處理 198000 個項目
# 2025-03-12 11:23:09,153 - __main__ - INFO - 已處理 199000 個項目
# 2025-03-12 11:23:09,174 - __main__ - INFO - 已處理 200000 個項目
# 2025-03-12 11:23:09,193 - __main__ - INFO - 已處理 201000 個項目
# 2025-03-12 11:23:09,210 - __main__ - INFO - 已處理 202000 個項目
# 2025-03-12 11:23:09,227 - __main__ - INFO - 已處理 203000 個項目
# 2025-03-12 11:23:09,244 - __main__ - INFO - 已處理 204000 個項目
# 2025-03-12 11:23:09,258 - __main__ - INFO - 已處理 205000 個項目
# 2025-03-12 11:23:09,273 - __main__ - INFO - 已處理 206000 個項目
# 2025-03-12 11:23:09,288 - __main__ - INFO - 已處理 207000 個項目
# 2025-03-12 11:23:09,303 - __main__ - INFO - 已處理 208000 個項目
# 2025-03-12 11:23:09,320 - __main__ - INFO - 已處理 209000 個項目
# 2025-03-12 11:23:09,337 - __main__ - INFO - 已處理 210000 個項目
# 2025-03-12 11:23:09,354 - __main__ - INFO - 已處理 211000 個項目
# 2025-03-12 11:23:09,373 - __main__ - INFO - 已處理 212000 個項目
# 2025-03-12 11:23:09,391 - __main__ - INFO - 已處理 213000 個項目
# 2025-03-12 11:23:09,409 - __main__ - INFO - 已處理 214000 個項目
# 2025-03-12 11:23:09,426 - __main__ - INFO - 已處理 215000 個項目
# 2025-03-12 11:23:09,444 - __main__ - INFO - 已處理 216000 個項目
# 2025-03-12 11:23:09,462 - __main__ - INFO - 已處理 217000 個項目
# 2025-03-12 11:23:09,478 - __main__ - INFO - 已處理 218000 個項目
# 2025-03-12 11:23:09,496 - __main__ - INFO - 已處理 219000 個項目
# 2025-03-12 11:23:09,513 - __main__ - INFO - 已處理 220000 個項目
# 2025-03-12 11:23:09,532 - __main__ - INFO - 已處理 221000 個項目
# 2025-03-12 11:23:09,548 - __main__ - INFO - 已處理 222000 個項目
# 2025-03-12 11:23:09,565 - __main__ - INFO - 已處理 223000 個項目
# 2025-03-12 11:23:09,582 - __main__ - INFO - 已處理 224000 個項目
# 2025-03-12 11:23:09,599 - __main__ - INFO - 已處理 225000 個項目
# 2025-03-12 11:23:09,617 - __main__ - INFO - 已處理 226000 個項目
# 2025-03-12 11:23:09,634 - __main__ - INFO - 已處理 227000 個項目
# 2025-03-12 11:23:09,651 - __main__ - INFO - 已處理 228000 個項目
# 2025-03-12 11:23:09,669 - __main__ - INFO - 已處理 229000 個項目
# 2025-03-12 11:23:09,686 - __main__ - INFO - 已處理 230000 個項目
# 2025-03-12 11:23:09,704 - __main__ - INFO - 已處理 231000 個項目
# 2025-03-12 11:23:09,723 - __main__ - INFO - 已處理 232000 個項目
# 2025-03-12 11:23:09,742 - __main__ - INFO - 已處理 233000 個項目
# 2025-03-12 11:23:09,759 - __main__ - INFO - 已處理 234000 個項目
# 2025-03-12 11:23:09,776 - __main__ - INFO - 已處理 235000 個項目
# 2025-03-12 11:23:09,793 - __main__ - INFO - 已處理 236000 個項目
# 2025-03-12 11:23:09,810 - __main__ - INFO - 已處理 237000 個項目
# 2025-03-12 11:23:09,828 - __main__ - INFO - 已處理 238000 個項目
# 2025-03-12 11:23:09,850 - __main__ - INFO - 已處理 239000 個項目
# 2025-03-12 11:23:09,867 - __main__ - INFO - 已處理 240000 個項目
# 2025-03-12 11:23:09,885 - __main__ - INFO - 已處理 241000 個項目
# 2025-03-12 11:23:09,903 - __main__ - INFO - 已處理 242000 個項目
# 2025-03-12 11:23:09,922 - __main__ - INFO - 已處理 243000 個項目
# 2025-03-12 11:23:09,943 - __main__ - INFO - 已處理 244000 個項目
# 2025-03-12 11:23:09,959 - __main__ - INFO - 已處理 245000 個項目
# 2025-03-12 11:23:09,974 - __main__ - INFO - 已處理 246000 個項目
# 2025-03-12 11:23:09,995 - __main__ - INFO - 已處理 247000 個項目
# 2025-03-12 11:23:10,014 - __main__ - INFO - 已處理 248000 個項目
# 2025-03-12 11:23:10,033 - __main__ - INFO - 已處理 249000 個項目
# 2025-03-12 11:23:10,081 - __main__ - INFO - 已處理 250000 個項目
# 2025-03-12 11:23:10,101 - __main__ - INFO - 已處理 251000 個項目
# 2025-03-12 11:23:10,119 - __main__ - INFO - 已處理 252000 個項目
# 2025-03-12 11:23:10,135 - __main__ - INFO - 已處理 253000 個項目
# 2025-03-12 11:23:10,152 - __main__ - INFO - 已處理 254000 個項目
# 2025-03-12 11:23:10,172 - __main__ - INFO - 已處理 255000 個項目
# 2025-03-12 11:23:10,189 - __main__ - INFO - 已處理 256000 個項目
# 2025-03-12 11:23:10,210 - __main__ - INFO - 已處理 257000 個項目
# 2025-03-12 11:23:10,227 - __main__ - INFO - 已處理 258000 個項目
# 2025-03-12 11:23:10,246 - __main__ - INFO - 已處理 259000 個項目
# 2025-03-12 11:23:10,263 - __main__ - INFO - 已處理 260000 個項目
# 2025-03-12 11:23:10,281 - __main__ - INFO - 已處理 261000 個項目
# 2025-03-12 11:23:10,299 - __main__ - INFO - 已處理 262000 個項目
# 2025-03-12 11:23:10,316 - __main__ - INFO - 已處理 263000 個項目
# 2025-03-12 11:23:10,333 - __main__ - INFO - 已處理 264000 個項目
# 2025-03-12 11:23:10,349 - __main__ - INFO - 已處理 265000 個項目
# 2025-03-12 11:23:10,366 - __main__ - INFO - 已處理 266000 個項目
# 2025-03-12 11:23:10,386 - __main__ - INFO - 已處理 267000 個項目
# 2025-03-12 11:23:10,408 - __main__ - INFO - 已處理 268000 個項目
# 2025-03-12 11:23:10,426 - __main__ - INFO - 已處理 269000 個項目
# 2025-03-12 11:23:10,443 - __main__ - INFO - 已處理 270000 個項目
# 2025-03-12 11:23:10,459 - __main__ - INFO - 已處理 271000 個項目
# 2025-03-12 11:23:10,477 - __main__ - INFO - 已處理 272000 個項目
# 2025-03-12 11:23:10,495 - __main__ - INFO - 已處理 273000 個項目
# 2025-03-12 11:23:10,512 - __main__ - INFO - 已處理 274000 個項目
# 2025-03-12 11:23:10,530 - __main__ - INFO - 已處理 275000 個項目
# 2025-03-12 11:23:10,550 - __main__ - INFO - 已處理 276000 個項目
# 2025-03-12 11:23:10,569 - __main__ - INFO - 已處理 277000 個項目
# 2025-03-12 11:23:10,586 - __main__ - INFO - 已處理 278000 個項目
# 2025-03-12 11:23:10,605 - __main__ - INFO - 已處理 279000 個項目
# 2025-03-12 11:23:10,623 - __main__ - INFO - 已處理 280000 個項目
# 2025-03-12 11:23:10,642 - __main__ - INFO - 已處理 281000 個項目
# 2025-03-12 11:23:10,661 - __main__ - INFO - 已處理 282000 個項目
# 2025-03-12 11:23:10,678 - __main__ - INFO - 已處理 283000 個項目
# 2025-03-12 11:23:10,695 - __main__ - INFO - 已處理 284000 個項目
# 2025-03-12 11:23:10,712 - __main__ - INFO - 已處理 285000 個項目
# 2025-03-12 11:23:10,730 - __main__ - INFO - 已處理 286000 個項目
# 2025-03-12 11:23:10,747 - __main__ - INFO - 已處理 287000 個項目
# 2025-03-12 11:23:10,763 - __main__ - INFO - 已處理 288000 個項目
# 2025-03-12 11:23:10,781 - __main__ - INFO - 已處理 289000 個項目
# 2025-03-12 11:23:10,798 - __main__ - INFO - 已處理 290000 個項目
# 2025-03-12 11:23:10,815 - __main__ - INFO - 已處理 291000 個項目
# 2025-03-12 11:23:10,833 - __main__ - INFO - 已處理 292000 個項目
# 2025-03-12 11:23:10,850 - __main__ - INFO - 已處理 293000 個項目
# 2025-03-12 11:23:10,867 - __main__ - INFO - 已處理 294000 個項目
# 2025-03-12 11:23:10,885 - __main__ - INFO - 已處理 295000 個項目
# 2025-03-12 11:23:10,904 - __main__ - INFO - 已處理 296000 個項目
# 2025-03-12 11:23:10,923 - __main__ - INFO - 已處理 297000 個項目
# 2025-03-12 11:23:10,940 - __main__ - INFO - 已處理 298000 個項目
# 2025-03-12 11:23:10,959 - __main__ - INFO - 已處理 299000 個項目
# 2025-03-12 11:23:10,978 - __main__ - INFO - 已處理 300000 個項目
# 2025-03-12 11:23:10,995 - __main__ - INFO - 已處理 301000 個項目
# 2025-03-12 11:23:11,013 - __main__ - INFO - 已處理 302000 個項目
# 2025-03-12 11:23:11,029 - __main__ - INFO - 已處理 303000 個項目
# 2025-03-12 11:23:11,047 - __main__ - INFO - 已處理 304000 個項目
# 2025-03-12 11:23:11,065 - __main__ - INFO - 已處理 305000 個項目
# 2025-03-12 11:23:11,084 - __main__ - INFO - 已處理 306000 個項目
# 2025-03-12 11:23:11,103 - __main__ - INFO - 已處理 307000 個項目
# 2025-03-12 11:23:11,120 - __main__ - INFO - 已處理 308000 個項目
# 2025-03-12 11:23:11,136 - __main__ - INFO - 已處理 309000 個項目
# 2025-03-12 11:23:11,154 - __main__ - INFO - 已處理 310000 個項目
# 2025-03-12 11:23:11,171 - __main__ - INFO - 已處理 311000 個項目
# 2025-03-12 11:23:11,188 - __main__ - INFO - 已處理 312000 個項目
# 2025-03-12 11:23:11,210 - __main__ - INFO - 已處理 313000 個項目
# 2025-03-12 11:23:11,229 - __main__ - INFO - 已處理 314000 個項目
# 2025-03-12 11:23:11,247 - __main__ - INFO - 已處理 315000 個項目
# 2025-03-12 11:23:11,264 - __main__ - INFO - 已處理 316000 個項目
# 2025-03-12 11:23:11,283 - __main__ - INFO - 已處理 317000 個項目
# 2025-03-12 11:23:11,305 - __main__ - INFO - 已處理 318000 個項目
# 2025-03-12 11:23:11,324 - __main__ - INFO - 已處理 319000 個項目
# 2025-03-12 11:23:11,346 - __main__ - INFO - 已處理 320000 個項目
# 2025-03-12 11:23:11,364 - __main__ - INFO - 已處理 321000 個項目
# 2025-03-12 11:23:11,381 - __main__ - INFO - 已處理 322000 個項目
# 2025-03-12 11:23:11,401 - __main__ - INFO - 已處理 323000 個項目
# 2025-03-12 11:23:11,419 - __main__ - INFO - 已處理 324000 個項目
# 2025-03-12 11:23:11,436 - __main__ - INFO - 已處理 325000 個項目
# 2025-03-12 11:23:11,455 - __main__ - INFO - 已處理 326000 個項目
# 2025-03-12 11:23:11,474 - __main__ - INFO - 已處理 327000 個項目
# 2025-03-12 11:23:11,491 - __main__ - INFO - 已處理 328000 個項目
# 2025-03-12 11:23:11,509 - __main__ - INFO - 已處理 329000 個項目
# 2025-03-12 11:23:11,526 - __main__ - INFO - 已處理 330000 個項目
# 2025-03-12 11:23:11,544 - __main__ - INFO - 已處理 331000 個項目
# 2025-03-12 11:23:11,562 - __main__ - INFO - 已處理 332000 個項目
# 2025-03-12 11:23:11,580 - __main__ - INFO - 已處理 333000 個項目
# 2025-03-12 11:23:11,598 - __main__ - INFO - 已處理 334000 個項目
# 2025-03-12 11:23:11,614 - __main__ - INFO - 已處理 335000 個項目
# 2025-03-12 11:23:11,632 - __main__ - INFO - 已處理 336000 個項目
# 2025-03-12 11:23:11,650 - __main__ - INFO - 已處理 337000 個項目
# 2025-03-12 11:23:11,666 - __main__ - INFO - 已處理 338000 個項目
# 2025-03-12 11:23:11,684 - __main__ - INFO - 已處理 339000 個項目
# 2025-03-12 11:23:11,706 - __main__ - INFO - 已處理 340000 個項目
# 2025-03-12 11:23:11,728 - __main__ - INFO - 已處理 341000 個項目
# 2025-03-12 11:23:11,747 - __main__ - INFO - 已處理 342000 個項目
# 2025-03-12 11:23:11,766 - __main__ - INFO - 已處理 343000 個項目
# 2025-03-12 11:23:11,782 - __main__ - INFO - 已處理 344000 個項目
# 2025-03-12 11:23:11,799 - __main__ - INFO - 已處理 345000 個項目
# 2025-03-12 11:23:11,816 - __main__ - INFO - 已處理 346000 個項目
# 2025-03-12 11:23:11,858 - __main__ - INFO - 已處理 347000 個項目
# 2025-03-12 11:23:11,876 - __main__ - INFO - 已處理 348000 個項目
# 2025-03-12 11:23:11,894 - __main__ - INFO - 已處理 349000 個項目
# 2025-03-12 11:23:11,912 - __main__ - INFO - 已處理 350000 個項目
# 2025-03-12 11:23:11,929 - __main__ - INFO - 已處理 351000 個項目
# 2025-03-12 11:23:11,945 - __main__ - INFO - 已處理 352000 個項目
# 2025-03-12 11:23:11,963 - __main__ - INFO - 已處理 353000 個項目
# 2025-03-12 11:23:11,981 - __main__ - INFO - 已處理 354000 個項目
# 2025-03-12 11:23:11,998 - __main__ - INFO - 已處理 355000 個項目
# 2025-03-12 11:23:12,014 - __main__ - INFO - 已處理 356000 個項目
# 2025-03-12 11:23:12,032 - __main__ - INFO - 已處理 357000 個項目
# 2025-03-12 11:23:12,048 - __main__ - INFO - 已處理 358000 個項目
# 2025-03-12 11:23:12,065 - __main__ - INFO - 已處理 359000 個項目
# 2025-03-12 11:23:12,083 - __main__ - INFO - 已處理 360000 個項目
# 2025-03-12 11:23:12,100 - __main__ - INFO - 已處理 361000 個項目
# 2025-03-12 11:23:12,116 - __main__ - INFO - 已處理 362000 個項目
# 2025-03-12 11:23:12,135 - __main__ - INFO - 已處理 363000 個項目
# 2025-03-12 11:23:12,152 - __main__ - INFO - 已處理 364000 個項目
# 2025-03-12 11:23:12,169 - __main__ - INFO - 已處理 365000 個項目
# 2025-03-12 11:23:12,188 - __main__ - INFO - 已處理 366000 個項目
# 2025-03-12 11:23:12,205 - __main__ - INFO - 已處理 367000 個項目
# 2025-03-12 11:23:12,222 - __main__ - INFO - 已處理 368000 個項目
# 2025-03-12 11:23:12,238 - __main__ - INFO - 已處理 369000 個項目
# 2025-03-12 11:23:12,255 - __main__ - INFO - 已處理 370000 個項目
# 2025-03-12 11:23:12,276 - __main__ - INFO - 已處理 371000 個項目
# 2025-03-12 11:23:12,292 - __main__ - INFO - 已處理 372000 個項目
# 2025-03-12 11:23:12,308 - __main__ - INFO - 已處理 373000 個項目
# 2025-03-12 11:23:12,326 - __main__ - INFO - 已處理 374000 個項目
# 2025-03-12 11:23:12,342 - __main__ - INFO - 已處理 375000 個項目
# 2025-03-12 11:23:12,361 - __main__ - INFO - 已處理 376000 個項目
# 2025-03-12 11:23:12,379 - __main__ - INFO - 已處理 377000 個項目
# 2025-03-12 11:23:12,397 - __main__ - INFO - 已處理 378000 個項目
# 2025-03-12 11:23:12,415 - __main__ - INFO - 已處理 379000 個項目
# 2025-03-12 11:23:12,431 - __main__ - INFO - 已處理 380000 個項目
# 2025-03-12 11:23:12,447 - __main__ - INFO - 已處理 381000 個項目
# 2025-03-12 11:23:12,463 - __main__ - INFO - 已處理 382000 個項目
# 2025-03-12 11:23:12,482 - __main__ - INFO - 已處理 383000 個項目
# 2025-03-12 11:23:12,500 - __main__ - INFO - 已處理 384000 個項目
# 2025-03-12 11:23:12,517 - __main__ - INFO - 已處理 385000 個項目
# 2025-03-12 11:23:12,536 - __main__ - INFO - 已處理 386000 個項目
# 2025-03-12 11:23:12,554 - __main__ - INFO - 已處理 387000 個項目
# 2025-03-12 11:23:12,572 - __main__ - INFO - 已處理 388000 個項目
# 2025-03-12 11:23:12,589 - __main__ - INFO - 已處理 389000 個項目
# 2025-03-12 11:23:12,607 - __main__ - INFO - 已處理 390000 個項目
# 2025-03-12 11:23:12,625 - __main__ - INFO - 已處理 391000 個項目
# 2025-03-12 11:23:12,643 - __main__ - INFO - 已處理 392000 個項目
# 2025-03-12 11:23:12,661 - __main__ - INFO - 已處理 393000 個項目
# 2025-03-12 11:23:12,680 - __main__ - INFO - 已處理 394000 個項目
# 2025-03-12 11:23:12,696 - __main__ - INFO - 已處理 395000 個項目
# 2025-03-12 11:23:12,714 - __main__ - INFO - 已處理 396000 個項目
# 2025-03-12 11:23:12,731 - __main__ - INFO - 已處理 397000 個項目
# 2025-03-12 11:23:12,748 - __main__ - INFO - 已處理 398000 個項目
# 2025-03-12 11:23:12,766 - __main__ - INFO - 已處理 399000 個項目
# 2025-03-12 11:23:12,785 - __main__ - INFO - 已處理 400000 個項目
# 2025-03-12 11:23:12,803 - __main__ - INFO - 已處理 401000 個項目
# 2025-03-12 11:23:12,819 - __main__ - INFO - 已處理 402000 個項目
# 2025-03-12 11:23:12,836 - __main__ - INFO - 已處理 403000 個項目
# 2025-03-12 11:23:12,853 - __main__ - INFO - 已處理 404000 個項目
# 2025-03-12 11:23:12,871 - __main__ - INFO - 已處理 405000 個項目
# 2025-03-12 11:23:12,888 - __main__ - INFO - 已處理 406000 個項目
# 2025-03-12 11:23:12,905 - __main__ - INFO - 已處理 407000 個項目
# 2025-03-12 11:23:12,923 - __main__ - INFO - 已處理 408000 個項目
# 2025-03-12 11:23:12,940 - __main__ - INFO - 已處理 409000 個項目
# 2025-03-12 11:23:12,958 - __main__ - INFO - 已處理 410000 個項目
# 2025-03-12 11:23:12,977 - __main__ - INFO - 已處理 411000 個項目
# 2025-03-12 11:23:12,993 - __main__ - INFO - 已處理 412000 個項目
# 2025-03-12 11:23:13,011 - __main__ - INFO - 已處理 413000 個項目
# 2025-03-12 11:23:13,029 - __main__ - INFO - 已處理 414000 個項目
# 2025-03-12 11:23:13,047 - __main__ - INFO - 已處理 415000 個項目
# 2025-03-12 11:23:13,065 - __main__ - INFO - 已處理 416000 個項目
# 2025-03-12 11:23:13,083 - __main__ - INFO - 已處理 417000 個項目
# 2025-03-12 11:23:13,100 - __main__ - INFO - 已處理 418000 個項目
# 2025-03-12 11:23:13,117 - __main__ - INFO - 已處理 419000 個項目
# 2025-03-12 11:23:13,134 - __main__ - INFO - 已處理 420000 個項目
# 2025-03-12 11:23:13,154 - __main__ - INFO - 已處理 421000 個項目
# 2025-03-12 11:23:13,172 - __main__ - INFO - 已處理 422000 個項目
# 2025-03-12 11:23:13,189 - __main__ - INFO - 已處理 423000 個項目
# 2025-03-12 11:23:13,211 - __main__ - INFO - 已處理 424000 個項目
# 2025-03-12 11:23:13,229 - __main__ - INFO - 已處理 425000 個項目
# 2025-03-12 11:23:13,247 - __main__ - INFO - 已處理 426000 個項目
# 2025-03-12 11:23:13,266 - __main__ - INFO - 已處理 427000 個項目
# 2025-03-12 11:23:13,286 - __main__ - INFO - 已處理 428000 個項目
# 2025-03-12 11:23:13,304 - __main__ - INFO - 已處理 429000 個項目
# 2025-03-12 11:23:13,321 - __main__ - INFO - 已處理 430000 個項目
# 2025-03-12 11:23:13,340 - __main__ - INFO - 已處理 431000 個項目
# 2025-03-12 11:23:13,357 - __main__ - INFO - 已處理 432000 個項目
# 2025-03-12 11:23:13,375 - __main__ - INFO - 已處理 433000 個項目
# 2025-03-12 11:23:13,392 - __main__ - INFO - 已處理 434000 個項目
# 2025-03-12 11:23:13,409 - __main__ - INFO - 已處理 435000 個項目
# 2025-03-12 11:23:13,425 - __main__ - INFO - 已處理 436000 個項目
# 2025-03-12 11:23:13,443 - __main__ - INFO - 已處理 437000 個項目
# 2025-03-12 11:23:13,462 - __main__ - INFO - 已處理 438000 個項目
# 2025-03-12 11:23:13,480 - __main__ - INFO - 已處理 439000 個項目
# 2025-03-12 11:23:13,499 - __main__ - INFO - 已處理 440000 個項目
# 2025-03-12 11:23:13,516 - __main__ - INFO - 已處理 441000 個項目
# 2025-03-12 11:23:13,533 - __main__ - INFO - 已處理 442000 個項目
# 2025-03-12 11:23:13,551 - __main__ - INFO - 已處理 443000 個項目
# 2025-03-12 11:23:13,575 - __main__ - INFO - 已處理 444000 個項目
# 2025-03-12 11:23:13,591 - __main__ - INFO - 已處理 445000 個項目
# 2025-03-12 11:23:13,607 - __main__ - INFO - 已處理 446000 個項目
# 2025-03-12 11:23:13,622 - __main__ - INFO - 已處理 447000 個項目
# 2025-03-12 11:23:13,640 - __main__ - INFO - 已處理 448000 個項目
# 2025-03-12 11:23:13,659 - __main__ - INFO - 已處理 449000 個項目
# 2025-03-12 11:23:13,680 - __main__ - INFO - 已處理 450000 個項目
# 2025-03-12 11:23:13,697 - __main__ - INFO - 已處理 451000 個項目
# 2025-03-12 11:23:13,714 - __main__ - INFO - 已處理 452000 個項目
# 2025-03-12 11:23:13,730 - __main__ - INFO - 已處理 453000 個項目
# 2025-03-12 11:23:13,747 - __main__ - INFO - 已處理 454000 個項目
# 2025-03-12 11:23:13,766 - __main__ - INFO - 已處理 455000 個項目
# 2025-03-12 11:23:13,785 - __main__ - INFO - 已處理 456000 個項目
# 2025-03-12 11:23:13,803 - __main__ - INFO - 已處理 457000 個項目
# 2025-03-12 11:23:13,821 - __main__ - INFO - 已處理 458000 個項目
# 2025-03-12 11:23:13,838 - __main__ - INFO - 已處理 459000 個項目
# 2025-03-12 11:23:13,853 - __main__ - INFO - 已處理 460000 個項目
# 2025-03-12 11:23:13,869 - __main__ - INFO - 已處理 461000 個項目
# 2025-03-12 11:23:13,886 - __main__ - INFO - 已處理 462000 個項目
# 2025-03-12 11:23:13,902 - __main__ - INFO - 已處理 463000 個項目
# 2025-03-12 11:23:13,918 - __main__ - INFO - 已處理 464000 個項目
# 2025-03-12 11:23:13,935 - __main__ - INFO - 已處理 465000 個項目
# 2025-03-12 11:23:13,952 - __main__ - INFO - 已處理 466000 個項目
# 2025-03-12 11:23:13,968 - __main__ - INFO - 已處理 467000 個項目
# 2025-03-12 11:23:13,984 - __main__ - INFO - 已處理 468000 個項目
# 2025-03-12 11:23:14,032 - __main__ - INFO - 已處理 469000 個項目
# 2025-03-12 11:23:14,049 - __main__ - INFO - 已處理 470000 個項目
# 2025-03-12 11:23:14,070 - __main__ - INFO - 已處理 471000 個項目
# 2025-03-12 11:23:14,087 - __main__ - INFO - 已處理 472000 個項目
# 2025-03-12 11:23:14,106 - __main__ - INFO - 已處理 473000 個項目
# 2025-03-12 11:23:14,123 - __main__ - INFO - 已處理 474000 個項目
# 2025-03-12 11:23:14,141 - __main__ - INFO - 已處理 475000 個項目
# 2025-03-12 11:23:14,159 - __main__ - INFO - 已處理 476000 個項目
# 2025-03-12 11:23:14,176 - __main__ - INFO - 已處理 477000 個項目
# 2025-03-12 11:23:14,195 - __main__ - INFO - 已處理 478000 個項目
# 2025-03-12 11:23:14,213 - __main__ - INFO - 已處理 479000 個項目
# 2025-03-12 11:23:14,230 - __main__ - INFO - 已處理 480000 個項目
# 2025-03-12 11:23:14,248 - __main__ - INFO - 已處理 481000 個項目
# 2025-03-12 11:23:14,266 - __main__ - INFO - 已處理 482000 個項目
# 2025-03-12 11:23:14,284 - __main__ - INFO - 已處理 483000 個項目
# 2025-03-12 11:23:14,303 - __main__ - INFO - 已處理 484000 個項目
# 2025-03-12 11:23:14,320 - __main__ - INFO - 已處理 485000 個項目
# 2025-03-12 11:23:14,338 - __main__ - INFO - 已處理 486000 個項目
# 2025-03-12 11:23:14,354 - __main__ - INFO - 已處理 487000 個項目
# 2025-03-12 11:23:14,371 - __main__ - INFO - 已處理 488000 個項目
# 2025-03-12 11:23:14,392 - __main__ - INFO - 已處理 489000 個項目
# 2025-03-12 11:23:14,411 - __main__ - INFO - 已處理 490000 個項目
# 2025-03-12 11:23:14,427 - __main__ - INFO - 已處理 491000 個項目
# 2025-03-12 11:23:14,445 - __main__ - INFO - 已處理 492000 個項目
# 2025-03-12 11:23:14,462 - __main__ - INFO - 已處理 493000 個項目
# 2025-03-12 11:23:14,479 - __main__ - INFO - 已處理 494000 個項目
# 2025-03-12 11:23:14,499 - __main__ - INFO - 已處理 495000 個項目
# 2025-03-12 11:23:14,518 - __main__ - INFO - 已處理 496000 個項目
# 2025-03-12 11:23:14,535 - __main__ - INFO - 已處理 497000 個項目
# 2025-03-12 11:23:14,553 - __main__ - INFO - 已處理 498000 個項目
# 2025-03-12 11:23:14,572 - __main__ - INFO - 已處理 499000 個項目
# 2025-03-12 11:23:14,589 - __main__ - INFO - 已處理 500000 個項目
# 2025-03-12 11:23:14,606 - __main__ - INFO - 已處理 501000 個項目
# 2025-03-12 11:23:14,626 - __main__ - INFO - 已處理 502000 個項目
# 2025-03-12 11:23:14,644 - __main__ - INFO - 已處理 503000 個項目
# 2025-03-12 11:23:14,660 - __main__ - INFO - 已處理 504000 個項目
# 2025-03-12 11:23:14,680 - __main__ - INFO - 已處理 505000 個項目
# 2025-03-12 11:23:14,697 - __main__ - INFO - 已處理 506000 個項目
# 2025-03-12 11:23:14,716 - __main__ - INFO - 已處理 507000 個項目
# 2025-03-12 11:23:14,734 - __main__ - INFO - 已處理 508000 個項目
# 2025-03-12 11:23:14,754 - __main__ - INFO - 已處理 509000 個項目
# 2025-03-12 11:23:14,770 - __main__ - INFO - 已處理 510000 個項目
# 2025-03-12 11:23:14,787 - __main__ - INFO - 已處理 511000 個項目
# 2025-03-12 11:23:14,809 - __main__ - INFO - 已處理 512000 個項目
# 2025-03-12 11:23:14,828 - __main__ - INFO - 已處理 513000 個項目
# 2025-03-12 11:23:14,844 - __main__ - INFO - 已處理 514000 個項目
# 2025-03-12 11:23:14,861 - __main__ - INFO - 已處理 515000 個項目
# 2025-03-12 11:23:14,879 - __main__ - INFO - 已處理 516000 個項目
# 2025-03-12 11:23:14,896 - __main__ - INFO - 已處理 517000 個項目
# 2025-03-12 11:23:14,913 - __main__ - INFO - 已處理 518000 個項目
# 2025-03-12 11:23:14,930 - __main__ - INFO - 已處理 519000 個項目
# 2025-03-12 11:23:14,946 - __main__ - INFO - 已處理 520000 個項目
# 2025-03-12 11:23:14,961 - __main__ - INFO - 已處理 521000 個項目
# 2025-03-12 11:23:14,977 - __main__ - INFO - 已處理 522000 個項目
# 2025-03-12 11:23:14,993 - __main__ - INFO - 已處理 523000 個項目
# 2025-03-12 11:23:15,010 - __main__ - INFO - 已處理 524000 個項目
# 2025-03-12 11:23:15,026 - __main__ - INFO - 已處理 525000 個項目
# 2025-03-12 11:23:15,043 - __main__ - INFO - 已處理 526000 個項目
# 2025-03-12 11:23:15,059 - __main__ - INFO - 已處理 527000 個項目
# 2025-03-12 11:23:15,077 - __main__ - INFO - 已處理 528000 個項目
# 2025-03-12 11:23:15,094 - __main__ - INFO - 已處理 529000 個項目
# 2025-03-12 11:23:15,110 - __main__ - INFO - 已處理 530000 個項目
# 2025-03-12 11:23:15,126 - __main__ - INFO - 已處理 531000 個項目
# 2025-03-12 11:23:15,142 - __main__ - INFO - 已處理 532000 個項目
# 2025-03-12 11:23:15,158 - __main__ - INFO - 已處理 533000 個項目
# 2025-03-12 11:23:15,176 - __main__ - INFO - 已處理 534000 個項目
# 2025-03-12 11:23:15,192 - __main__ - INFO - 已處理 535000 個項目
# 2025-03-12 11:23:15,210 - __main__ - INFO - 已處理 536000 個項目
# 2025-03-12 11:23:15,227 - __main__ - INFO - 已處理 537000 個項目
# 2025-03-12 11:23:15,243 - __main__ - INFO - 已處理 538000 個項目
# 2025-03-12 11:23:15,258 - __main__ - INFO - 已處理 539000 個項目
# 2025-03-12 11:23:15,276 - __main__ - INFO - 已處理 540000 個項目
# 2025-03-12 11:23:15,292 - __main__ - INFO - 已處理 541000 個項目
# 2025-03-12 11:23:15,309 - __main__ - INFO - 已處理 542000 個項目
# 2025-03-12 11:23:15,326 - __main__ - INFO - 已處理 543000 個項目
# 2025-03-12 11:23:15,342 - __main__ - INFO - 已處理 544000 個項目
# 2025-03-12 11:23:15,359 - __main__ - INFO - 已處理 545000 個項目
# 2025-03-12 11:23:15,377 - __main__ - INFO - 已處理 546000 個項目
# 2025-03-12 11:23:15,394 - __main__ - INFO - 已處理 547000 個項目
# 2025-03-12 11:23:15,411 - __main__ - INFO - 已處理 548000 個項目
# 2025-03-12 11:23:15,428 - __main__ - INFO - 已處理 549000 個項目
# 2025-03-12 11:23:15,449 - __main__ - INFO - 已處理 550000 個項目
# 2025-03-12 11:23:15,466 - __main__ - INFO - 已處理 551000 個項目
# 2025-03-12 11:23:15,484 - __main__ - INFO - 已處理 552000 個項目
# 2025-03-12 11:23:15,499 - __main__ - INFO - 已處理 553000 個項目
# 2025-03-12 11:23:15,516 - __main__ - INFO - 已處理 554000 個項目
# 2025-03-12 11:23:15,532 - __main__ - INFO - 已處理 555000 個項目
# 2025-03-12 11:23:15,549 - __main__ - INFO - 已處理 556000 個項目
# 2025-03-12 11:23:15,566 - __main__ - INFO - 已處理 557000 個項目
# 2025-03-12 11:23:15,584 - __main__ - INFO - 已處理 558000 個項目
# 2025-03-12 11:23:15,601 - __main__ - INFO - 已處理 559000 個項目
# 2025-03-12 11:23:15,618 - __main__ - INFO - 已處理 560000 個項目
# 2025-03-12 11:23:15,636 - __main__ - INFO - 已處理 561000 個項目
# 2025-03-12 11:23:15,652 - __main__ - INFO - 已處理 562000 個項目
# 2025-03-12 11:23:15,671 - __main__ - INFO - 已處理 563000 個項目
# 2025-03-12 11:23:15,688 - __main__ - INFO - 已處理 564000 個項目
# 2025-03-12 11:23:15,707 - __main__ - INFO - 已處理 565000 個項目
# 2025-03-12 11:23:15,724 - __main__ - INFO - 已處理 566000 個項目
# 2025-03-12 11:23:15,740 - __main__ - INFO - 已處理 567000 個項目
# 2025-03-12 11:23:15,756 - __main__ - INFO - 已處理 568000 個項目
# 2025-03-12 11:23:15,774 - __main__ - INFO - 已處理 569000 個項目
# 2025-03-12 11:23:15,791 - __main__ - INFO - 已處理 570000 個項目
# 2025-03-12 11:23:15,806 - __main__ - INFO - 已處理 571000 個項目
# 2025-03-12 11:23:15,824 - __main__ - INFO - 已處理 572000 個項目
# 2025-03-12 11:23:15,842 - __main__ - INFO - 已處理 573000 個項目
# 2025-03-12 11:23:15,860 - __main__ - INFO - 已處理 574000 個項目
# 2025-03-12 11:23:15,879 - __main__ - INFO - 已處理 575000 個項目
# 2025-03-12 11:23:15,896 - __main__ - INFO - 已處理 576000 個項目
# 2025-03-12 11:23:15,914 - __main__ - INFO - 已處理 577000 個項目
# 2025-03-12 11:23:15,931 - __main__ - INFO - 已處理 578000 個項目
# 2025-03-12 11:23:15,948 - __main__ - INFO - 已處理 579000 個項目
# 2025-03-12 11:23:15,965 - __main__ - INFO - 已處理 580000 個項目
# 2025-03-12 11:23:15,983 - __main__ - INFO - 已處理 581000 個項目
# 2025-03-12 11:23:16,000 - __main__ - INFO - 已處理 582000 個項目
# 2025-03-12 11:23:16,016 - __main__ - INFO - 已處理 583000 個項目
# 2025-03-12 11:23:16,033 - __main__ - INFO - 已處理 584000 個項目
# 2025-03-12 11:23:16,050 - __main__ - INFO - 已處理 585000 個項目
# 2025-03-12 11:23:16,068 - __main__ - INFO - 已處理 586000 個項目
# 2025-03-12 11:23:16,085 - __main__ - INFO - 已處理 587000 個項目
# 2025-03-12 11:23:16,106 - __main__ - INFO - 已處理 588000 個項目
# 2025-03-12 11:23:16,123 - __main__ - INFO - 已處理 589000 個項目
# 2025-03-12 11:23:16,140 - __main__ - INFO - 已處理 590000 個項目
# 2025-03-12 11:23:16,158 - __main__ - INFO - 已處理 591000 個項目
# 2025-03-12 11:23:16,175 - __main__ - INFO - 已處理 592000 個項目
# 2025-03-12 11:23:16,192 - __main__ - INFO - 已處理 593000 個項目
# 2025-03-12 11:23:16,208 - __main__ - INFO - 已處理 594000 個項目
# 2025-03-12 11:23:16,225 - __main__ - INFO - 已處理 595000 個項目
# 2025-03-12 11:23:16,243 - __main__ - INFO - 已處理 596000 個項目
# 2025-03-12 11:23:16,260 - __main__ - INFO - 已處理 597000 個項目
# 2025-03-12 11:23:16,278 - __main__ - INFO - 已處理 598000 個項目
# 2025-03-12 11:23:16,296 - __main__ - INFO - 已處理 599000 個項目
# 2025-03-12 11:23:16,315 - __main__ - INFO - 已處理 600000 個項目
# 2025-03-12 11:23:16,331 - __main__ - INFO - 已處理 601000 個項目
# 2025-03-12 11:23:16,350 - __main__ - INFO - 已處理 602000 個項目
# 2025-03-12 11:23:16,365 - __main__ - INFO - 已處理 603000 個項目
# 2025-03-12 11:23:16,382 - __main__ - INFO - 已處理 604000 個項目
# 2025-03-12 11:23:16,398 - __main__ - INFO - 已處理 605000 個項目
# 2025-03-12 11:23:16,415 - __main__ - INFO - 已處理 606000 個項目
# 2025-03-12 11:23:16,432 - __main__ - INFO - 已處理 607000 個項目
# 2025-03-12 11:23:16,449 - __main__ - INFO - 已處理 608000 個項目
# 2025-03-12 11:23:16,466 - __main__ - INFO - 已處理 609000 個項目
# 2025-03-12 11:23:16,482 - __main__ - INFO - 已處理 610000 個項目
# 2025-03-12 11:23:16,524 - __main__ - INFO - 已處理 611000 個項目
# 2025-03-12 11:23:16,544 - __main__ - INFO - 已處理 612000 個項目
# 2025-03-12 11:23:16,560 - __main__ - INFO - 已處理 613000 個項目
# 2025-03-12 11:23:16,577 - __main__ - INFO - 已處理 614000 個項目
# 2025-03-12 11:23:16,595 - __main__ - INFO - 已處理 615000 個項目
# 2025-03-12 11:23:16,617 - __main__ - INFO - 已處理 616000 個項目
# 2025-03-12 11:23:16,634 - __main__ - INFO - 已處理 617000 個項目
# 2025-03-12 11:23:16,651 - __main__ - INFO - 已處理 618000 個項目
# 2025-03-12 11:23:16,667 - __main__ - INFO - 已處理 619000 個項目
# 2025-03-12 11:23:16,683 - __main__ - INFO - 已處理 620000 個項目
# 2025-03-12 11:23:16,700 - __main__ - INFO - 已處理 621000 個項目
# 2025-03-12 11:23:16,721 - __main__ - INFO - 已處理 622000 個項目
# 2025-03-12 11:23:16,738 - __main__ - INFO - 已處理 623000 個項目
# 2025-03-12 11:23:16,755 - __main__ - INFO - 已處理 624000 個項目
# 2025-03-12 11:23:16,772 - __main__ - INFO - 已處理 625000 個項目
# 2025-03-12 11:23:16,790 - __main__ - INFO - 已處理 626000 個項目
# 2025-03-12 11:23:16,807 - __main__ - INFO - 已處理 627000 個項目
# 2025-03-12 11:23:16,824 - __main__ - INFO - 已處理 628000 個項目
# 2025-03-12 11:23:16,841 - __main__ - INFO - 已處理 629000 個項目
# 2025-03-12 11:23:16,859 - __main__ - INFO - 已處理 630000 個項目
# 2025-03-12 11:23:16,876 - __main__ - INFO - 已處理 631000 個項目
# 2025-03-12 11:23:16,894 - __main__ - INFO - 已處理 632000 個項目
# 2025-03-12 11:23:16,912 - __main__ - INFO - 已處理 633000 個項目
# 2025-03-12 11:23:16,931 - __main__ - INFO - 已處理 634000 個項目
# 2025-03-12 11:23:16,948 - __main__ - INFO - 已處理 635000 個項目
# 2025-03-12 11:23:16,967 - __main__ - INFO - 已處理 636000 個項目
# 2025-03-12 11:23:16,985 - __main__ - INFO - 已處理 637000 個項目
# 2025-03-12 11:23:17,001 - __main__ - INFO - 已處理 638000 個項目
# 2025-03-12 11:23:17,018 - __main__ - INFO - 已處理 639000 個項目
# 2025-03-12 11:23:17,036 - __main__ - INFO - 已處理 640000 個項目
# 2025-03-12 11:23:17,054 - __main__ - INFO - 已處理 641000 個項目
# 2025-03-12 11:23:17,071 - __main__ - INFO - 已處理 642000 個項目
# 2025-03-12 11:23:17,089 - __main__ - INFO - 已處理 643000 個項目
# 2025-03-12 11:23:17,105 - __main__ - INFO - 已處理 644000 個項目
# 2025-03-12 11:23:17,123 - __main__ - INFO - 已處理 645000 個項目
# 2025-03-12 11:23:17,140 - __main__ - INFO - 已處理 646000 個項目
# 2025-03-12 11:23:17,157 - __main__ - INFO - 已處理 647000 個項目
# 2025-03-12 11:23:17,175 - __main__ - INFO - 已處理 648000 個項目
# 2025-03-12 11:23:17,193 - __main__ - INFO - 已處理 649000 個項目
# 2025-03-12 11:23:17,210 - __main__ - INFO - 已處理 650000 個項目
# 2025-03-12 11:23:17,227 - __main__ - INFO - 已處理 651000 個項目
# 2025-03-12 11:23:17,245 - __main__ - INFO - 已處理 652000 個項目
# 2025-03-12 11:23:17,262 - __main__ - INFO - 已處理 653000 個項目
# 2025-03-12 11:23:17,284 - __main__ - INFO - 已處理 654000 個項目
# 2025-03-12 11:23:17,303 - __main__ - INFO - 已處理 655000 個項目
# 2025-03-12 11:23:17,319 - __main__ - INFO - 已處理 656000 個項目
# 2025-03-12 11:23:17,335 - __main__ - INFO - 已處理 657000 個項目
# 2025-03-12 11:23:17,351 - __main__ - INFO - 已處理 658000 個項目
# 2025-03-12 11:23:17,367 - __main__ - INFO - 已處理 659000 個項目
# 2025-03-12 11:23:17,385 - __main__ - INFO - 已處理 660000 個項目
# 2025-03-12 11:23:17,402 - __main__ - INFO - 已處理 661000 個項目
# 2025-03-12 11:23:17,419 - __main__ - INFO - 已處理 662000 個項目
# 2025-03-12 11:23:17,436 - __main__ - INFO - 已處理 663000 個項目
# 2025-03-12 11:23:17,452 - __main__ - INFO - 已處理 664000 個項目
# 2025-03-12 11:23:17,469 - __main__ - INFO - 已處理 665000 個項目
# 2025-03-12 11:23:17,488 - __main__ - INFO - 已處理 666000 個項目
# 2025-03-12 11:23:17,506 - __main__ - INFO - 已處理 667000 個項目
# 2025-03-12 11:23:17,523 - __main__ - INFO - 已處理 668000 個項目
# 2025-03-12 11:23:17,540 - __main__ - INFO - 已處理 669000 個項目
# 2025-03-12 11:23:17,558 - __main__ - INFO - 已處理 670000 個項目
# 2025-03-12 11:23:17,575 - __main__ - INFO - 已處理 671000 個項目
# 2025-03-12 11:23:17,594 - __main__ - INFO - 已處理 672000 個項目
# 2025-03-12 11:23:17,612 - __main__ - INFO - 已處理 673000 個項目
# 2025-03-12 11:23:17,629 - __main__ - INFO - 已處理 674000 個項目
# 2025-03-12 11:23:17,646 - __main__ - INFO - 已處理 675000 個項目
# 2025-03-12 11:23:17,661 - __main__ - INFO - 已處理 676000 個項目
# 2025-03-12 11:23:17,678 - __main__ - INFO - 已處理 677000 個項目
# 2025-03-12 11:23:17,695 - __main__ - INFO - 已處理 678000 個項目
# 2025-03-12 11:23:17,711 - __main__ - INFO - 已處理 679000 個項目
# 2025-03-12 11:23:17,728 - __main__ - INFO - 已處理 680000 個項目
# 2025-03-12 11:23:17,744 - __main__ - INFO - 已處理 681000 個項目
# 2025-03-12 11:23:17,762 - __main__ - INFO - 已處理 682000 個項目
# 2025-03-12 11:23:17,779 - __main__ - INFO - 已處理 683000 個項目
# 2025-03-12 11:23:17,798 - __main__ - INFO - 已處理 684000 個項目
# 2025-03-12 11:23:17,815 - __main__ - INFO - 已處理 685000 個項目
# 2025-03-12 11:23:17,836 - __main__ - INFO - 已處理 686000 個項目
# 2025-03-12 11:23:17,852 - __main__ - INFO - 已處理 687000 個項目
# 2025-03-12 11:23:17,868 - __main__ - INFO - 已處理 688000 個項目
# 2025-03-12 11:23:17,884 - __main__ - INFO - 已處理 689000 個項目
# 2025-03-12 11:23:17,900 - __main__ - INFO - 已處理 690000 個項目
# 2025-03-12 11:23:17,917 - __main__ - INFO - 已處理 691000 個項目
# 2025-03-12 11:23:17,934 - __main__ - INFO - 已處理 692000 個項目
# 2025-03-12 11:23:17,951 - __main__ - INFO - 已處理 693000 個項目
# 2025-03-12 11:23:17,968 - __main__ - INFO - 已處理 694000 個項目
# 2025-03-12 11:23:17,985 - __main__ - INFO - 已處理 695000 個項目
# 2025-03-12 11:23:18,002 - __main__ - INFO - 已處理 696000 個項目
# 2025-03-12 11:23:18,019 - __main__ - INFO - 已處理 697000 個項目
# 2025-03-12 11:23:18,037 - __main__ - INFO - 已處理 698000 個項目
# 2025-03-12 11:23:18,054 - __main__ - INFO - 已處理 699000 個項目
# 2025-03-12 11:23:18,070 - __main__ - INFO - 已處理 700000 個項目
# 2025-03-12 11:23:18,085 - __main__ - INFO - 已處理 701000 個項目
# 2025-03-12 11:23:18,101 - __main__ - INFO - 已處理 702000 個項目
# 2025-03-12 11:23:18,118 - __main__ - INFO - 已處理 703000 個項目
# 2025-03-12 11:23:18,134 - __main__ - INFO - 已處理 704000 個項目
# 2025-03-12 11:23:18,154 - __main__ - INFO - 已處理 705000 個項目
# 2025-03-12 11:23:18,172 - __main__ - INFO - 已處理 706000 個項目
# 2025-03-12 11:23:18,193 - __main__ - INFO - 已處理 707000 個項目
# 2025-03-12 11:23:18,213 - __main__ - INFO - 已處理 708000 個項目
# 2025-03-12 11:23:18,232 - __main__ - INFO - 已處理 709000 個項目
# 2025-03-12 11:23:18,251 - __main__ - INFO - 已處理 710000 個項目
# 2025-03-12 11:23:18,272 - __main__ - INFO - 已處理 711000 個項目
# 2025-03-12 11:23:18,290 - __main__ - INFO - 已處理 712000 個項目
# 2025-03-12 11:23:18,308 - __main__ - INFO - 已處理 713000 個項目
# 2025-03-12 11:23:18,330 - __main__ - INFO - 已處理 714000 個項目
# 2025-03-12 11:23:18,348 - __main__ - INFO - 已處理 715000 個項目
# 2025-03-12 11:23:18,403 - __main__ - INFO - 已處理 716000 個項目
# 2025-03-12 11:23:18,422 - __main__ - INFO - 已處理 717000 個項目
# 2025-03-12 11:23:18,439 - __main__ - INFO - 已處理 718000 個項目
# 2025-03-12 11:23:18,456 - __main__ - INFO - 已處理 719000 個項目
# 2025-03-12 11:23:18,476 - __main__ - INFO - 已處理 720000 個項目
# 2025-03-12 11:23:18,496 - __main__ - INFO - 已處理 721000 個項目
# 2025-03-12 11:23:18,514 - __main__ - INFO - 已處理 722000 個項目
# 2025-03-12 11:23:18,533 - __main__ - INFO - 已處理 723000 個項目
# 2025-03-12 11:23:18,550 - __main__ - INFO - 已處理 724000 個項目
# 2025-03-12 11:23:18,570 - __main__ - INFO - 已處理 725000 個項目
# 2025-03-12 11:23:18,589 - __main__ - INFO - 已處理 726000 個項目
# 2025-03-12 11:23:18,606 - __main__ - INFO - 已處理 727000 個項目
# 2025-03-12 11:23:18,624 - __main__ - INFO - 已處理 728000 個項目
# 2025-03-12 11:23:18,642 - __main__ - INFO - 已處理 729000 個項目
# 2025-03-12 11:23:18,659 - __main__ - INFO - 已處理 730000 個項目
# 2025-03-12 11:23:18,678 - __main__ - INFO - 已處理 731000 個項目
# 2025-03-12 11:23:18,696 - __main__ - INFO - 已處理 732000 個項目
# 2025-03-12 11:23:18,714 - __main__ - INFO - 已處理 733000 個項目
# 2025-03-12 11:23:18,733 - __main__ - INFO - 已處理 734000 個項目
# 2025-03-12 11:23:18,750 - __main__ - INFO - 已處理 735000 個項目
# 2025-03-12 11:23:18,767 - __main__ - INFO - 已處理 736000 個項目
# 2025-03-12 11:23:18,785 - __main__ - INFO - 已處理 737000 個項目
# 2025-03-12 11:23:18,804 - __main__ - INFO - 已處理 738000 個項目
# 2025-03-12 11:23:18,822 - __main__ - INFO - 已處理 739000 個項目
# 2025-03-12 11:23:18,841 - __main__ - INFO - 已處理 740000 個項目
# 2025-03-12 11:23:18,856 - __main__ - INFO - 已處理 741000 個項目
# 2025-03-12 11:23:18,875 - __main__ - INFO - 已處理 742000 個項目
# 2025-03-12 11:23:18,892 - __main__ - INFO - 已處理 743000 個項目
# 2025-03-12 11:23:18,909 - __main__ - INFO - 已處理 744000 個項目
# 2025-03-12 11:23:18,929 - __main__ - INFO - 已處理 745000 個項目
# 2025-03-12 11:23:18,948 - __main__ - INFO - 已處理 746000 個項目
# 2025-03-12 11:23:18,964 - __main__ - INFO - 已處理 747000 個項目
# 2025-03-12 11:23:18,982 - __main__ - INFO - 已處理 748000 個項目
# 2025-03-12 11:23:19,000 - __main__ - INFO - 已處理 749000 個項目
# 2025-03-12 11:23:19,017 - __main__ - INFO - 已處理 750000 個項目
# 2025-03-12 11:23:19,035 - __main__ - INFO - 已處理 751000 個項目
# 2025-03-12 11:23:19,053 - __main__ - INFO - 已處理 752000 個項目
# 2025-03-12 11:23:19,071 - __main__ - INFO - 已處理 753000 個項目
# 2025-03-12 11:23:19,088 - __main__ - INFO - 已處理 754000 個項目
# 2025-03-12 11:23:19,106 - __main__ - INFO - 已處理 755000 個項目
# 2025-03-12 11:23:19,124 - __main__ - INFO - 已處理 756000 個項目
# 2025-03-12 11:23:19,141 - __main__ - INFO - 已處理 757000 個項目
# 2025-03-12 11:23:19,158 - __main__ - INFO - 已處理 758000 個項目
# 2025-03-12 11:23:19,175 - __main__ - INFO - 已處理 759000 個項目
# 2025-03-12 11:23:19,193 - __main__ - INFO - 已處理 760000 個項目
# 2025-03-12 11:23:19,211 - __main__ - INFO - 已處理 761000 個項目
# 2025-03-12 11:23:19,229 - __main__ - INFO - 已處理 762000 個項目
# 2025-03-12 11:23:19,247 - __main__ - INFO - 已處理 763000 個項目
# 2025-03-12 11:23:19,265 - __main__ - INFO - 已處理 764000 個項目
# 2025-03-12 11:23:19,281 - __main__ - INFO - 已處理 765000 個項目
# 2025-03-12 11:23:19,299 - __main__ - INFO - 已處理 766000 個項目
# 2025-03-12 11:23:19,316 - __main__ - INFO - 已處理 767000 個項目
# 2025-03-12 11:23:19,333 - __main__ - INFO - 已處理 768000 個項目
# 2025-03-12 11:23:19,349 - __main__ - INFO - 已處理 769000 個項目
# 2025-03-12 11:23:19,365 - __main__ - INFO - 已處理 770000 個項目
# 2025-03-12 11:23:19,383 - __main__ - INFO - 已處理 771000 個項目
# 2025-03-12 11:23:19,400 - __main__ - INFO - 已處理 772000 個項目
# 2025-03-12 11:23:19,416 - __main__ - INFO - 已處理 773000 個項目
# 2025-03-12 11:23:19,433 - __main__ - INFO - 已處理 774000 個項目
# 2025-03-12 11:23:19,454 - __main__ - INFO - 已處理 775000 個項目
# 2025-03-12 11:23:19,471 - __main__ - INFO - 已處理 776000 個項目
# 2025-03-12 11:23:19,488 - __main__ - INFO - 已處理 777000 個項目
# 2025-03-12 11:23:19,506 - __main__ - INFO - 已處理 778000 個項目
# 2025-03-12 11:23:19,523 - __main__ - INFO - 已處理 779000 個項目
# 2025-03-12 11:23:19,541 - __main__ - INFO - 已處理 780000 個項目
# 2025-03-12 11:23:19,558 - __main__ - INFO - 已處理 781000 個項目
# 2025-03-12 11:23:19,575 - __main__ - INFO - 已處理 782000 個項目
# 2025-03-12 11:23:19,591 - __main__ - INFO - 已處理 783000 個項目
# 2025-03-12 11:23:19,610 - __main__ - INFO - 已處理 784000 個項目
# 2025-03-12 11:23:19,627 - __main__ - INFO - 已處理 785000 個項目
# 2025-03-12 11:23:19,643 - __main__ - INFO - 已處理 786000 個項目
# 2025-03-12 11:23:19,661 - __main__ - INFO - 已處理 787000 個項目
# 2025-03-12 11:23:19,678 - __main__ - INFO - 已處理 788000 個項目
# 2025-03-12 11:23:19,696 - __main__ - INFO - 已處理 789000 個項目
# 2025-03-12 11:23:19,711 - __main__ - INFO - 已處理 790000 個項目
# 2025-03-12 11:23:19,728 - __main__ - INFO - 已處理 791000 個項目
# 2025-03-12 11:23:19,746 - __main__ - INFO - 已處理 792000 個項目
# 2025-03-12 11:23:19,763 - __main__ - INFO - 已處理 793000 個項目
# 2025-03-12 11:23:19,780 - __main__ - INFO - 已處理 794000 個項目
# 2025-03-12 11:23:19,798 - __main__ - INFO - 已處理 795000 個項目
# 2025-03-12 11:23:19,816 - __main__ - INFO - 已處理 796000 個項目
# 2025-03-12 11:23:19,832 - __main__ - INFO - 已處理 797000 個項目
# 2025-03-12 11:23:19,848 - __main__ - INFO - 已處理 798000 個項目
# 2025-03-12 11:23:19,865 - __main__ - INFO - 已處理 799000 個項目
# 2025-03-12 11:23:19,883 - __main__ - INFO - 已處理 800000 個項目
# 2025-03-12 11:23:19,899 - __main__ - INFO - 已處理 801000 個項目
# 2025-03-12 11:23:19,915 - __main__ - INFO - 已處理 802000 個項目
# 2025-03-12 11:23:19,931 - __main__ - INFO - 已處理 803000 個項目
# 2025-03-12 11:23:19,952 - __main__ - INFO - 已處理 804000 個項目
# 2025-03-12 11:23:19,971 - __main__ - INFO - 已處理 805000 個項目
# 2025-03-12 11:23:19,989 - __main__ - INFO - 已處理 806000 個項目
# 2025-03-12 11:23:20,007 - __main__ - INFO - 已處理 807000 個項目
# 2025-03-12 11:23:20,027 - __main__ - INFO - 已處理 808000 個項目
# 2025-03-12 11:23:20,069 - __main__ - INFO - 已處理 809000 個項目
# 2025-03-12 11:23:20,086 - __main__ - INFO - 已處理 810000 個項目
# 2025-03-12 11:23:20,102 - __main__ - INFO - 已處理 811000 個項目
# 2025-03-12 11:23:20,120 - __main__ - INFO - 已處理 812000 個項目
# ...
# 2025-03-12 11:23:25,677 - __main__ - INFO - 已處理 1119000 個項目
# 2025-03-12 11:23:25,696 - __main__ - INFO - 已處理 1120000 個項目
# 2025-03-12 11:23:25,714 - __main__ - INFO - 已處理 1121000 個項目
# 2025-03-12 11:23:25,732 - __main__ - INFO - 已處理 1122000 個項目
# 2025-03-12 11:23:25,749 - __main__ - INFO - 已處理 1123000 個項目
# 2025-03-12 11:23:25,770 - __main__ - INFO - 已處理 1124000 個項目
# 2025-03-12 11:23:25,787 - __main__ - INFO - 已處理 1125000 個項目
# 2025-03-12 11:23:25,805 - __main__ - INFO - 已處理 1126000 個項目
# 2025-03-12 11:23:25,823 - __main__ - INFO - 已處理 1127000 個項目
# 2025-03-12 11:23:25,839 - __main__ - INFO - 已處理 1128000 個項目
# 2025-03-12 11:23:25,856 - __main__ - INFO - 已處理 1129000 個項目
# 2025-03-12 11:23:25,872 - __main__ - INFO - 已處理 1130000 個項目
# 2025-03-12 11:23:25,893 - __main__ - INFO - 已處理 1131000 個項目
# 2025-03-12 11:23:25,910 - __main__ - INFO - 已處理 1132000 個項目
# 2025-03-12 11:23:25,928 - __main__ - INFO - 已處理 1133000 個項目
# 2025-03-12 11:23:25,947 - __main__ - INFO - 已處理 1134000 個項目
# 2025-03-12 11:23:25,964 - __main__ - INFO - 已處理 1135000 個項目
# 2025-03-12 11:23:25,982 - __main__ - INFO - 已處理 1136000 個項目
# 2025-03-12 11:23:25,999 - __main__ - INFO - 已處理 1137000 個項目
# 2025-03-12 11:23:26,017 - __main__ - INFO - 已處理 1138000 個項目
# 2025-03-12 11:23:26,036 - __main__ - INFO - 已處理 1139000 個項目
# 2025-03-12 11:23:26,056 - __main__ - INFO - 已處理 1140000 個項目
# 2025-03-12 11:23:26,109 - __main__ - INFO - 已處理 1141000 個項目
# 2025-03-12 11:23:26,127 - __main__ - INFO - 已處理 1142000 個項目
# 2025-03-12 11:23:26,145 - __main__ - INFO - 已處理 1143000 個項目
# 2025-03-12 11:23:26,163 - __main__ - INFO - 已處理 1144000 個項目
# 2025-03-12 11:23:26,182 - __main__ - INFO - 已處理 1145000 個項目
# 2025-03-12 11:23:26,202 - __main__ - INFO - 已處理 1146000 個項目
# 2025-03-12 11:23:26,221 - __main__ - INFO - 已處理 1147000 個項目
# 2025-03-12 11:23:26,241 - __main__ - INFO - 已處理 1148000 個項目
# 2025-03-12 11:23:26,264 - __main__ - INFO - 已處理 1149000 個項目
# 2025-03-12 11:23:26,283 - __main__ - INFO - 已處理 1150000 個項目
# 2025-03-12 11:23:26,301 - __main__ - INFO - 已處理 1151000 個項目
# 2025-03-12 11:23:26,321 - __main__ - INFO - 已處理 1152000 個項目
# 2025-03-12 11:23:26,336 - __main__ - INFO - 已處理 1153000 個項目
# 2025-03-12 11:23:26,354 - __main__ - INFO - 已處理 1154000 個項目
# 2025-03-12 11:23:26,372 - __main__ - INFO - 已處理 1155000 個項目
# 2025-03-12 11:23:26,391 - __main__ - INFO - 已處理 1156000 個項目
# 2025-03-12 11:23:26,409 - __main__ - INFO - 已處理 1157000 個項目
# 2025-03-12 11:23:26,426 - __main__ - INFO - 已處理 1158000 個項目
# 2025-03-12 11:23:26,445 - __main__ - INFO - 已處理 1159000 個項目
# 2025-03-12 11:23:26,462 - __main__ - INFO - 已處理 1160000 個項目
# 2025-03-12 11:23:26,480 - __main__ - INFO - 已處理 1161000 個項目
# 2025-03-12 11:23:26,499 - __main__ - INFO - 已處理 1162000 個項目
# 2025-03-12 11:23:26,516 - __main__ - INFO - 已處理 1163000 個項目
# 2025-03-12 11:23:26,534 - __main__ - INFO - 已處理 1164000 個項目
# 2025-03-12 11:23:26,550 - __main__ - INFO - 已處理 1165000 個項目
# 2025-03-12 11:23:26,566 - __main__ - INFO - 已處理 1166000 個項目
# 2025-03-12 11:23:26,583 - __main__ - INFO - 已處理 1167000 個項目
# 2025-03-12 11:23:26,601 - __main__ - INFO - 已處理 1168000 個項目
# 2025-03-12 11:23:26,623 - __main__ - INFO - 已處理 1169000 個項目
# 2025-03-12 11:23:26,641 - __main__ - INFO - 已處理 1170000 個項目
# 2025-03-12 11:23:26,657 - __main__ - INFO - 已處理 1171000 個項目
# 2025-03-12 11:23:26,676 - __main__ - INFO - 已處理 1172000 個項目
# 2025-03-12 11:23:26,692 - __main__ - INFO - 已處理 1173000 個項目
# 2025-03-12 11:23:26,710 - __main__ - INFO - 已處理 1174000 個項目
# 2025-03-12 11:23:26,725 - __main__ - INFO - 已處理 1175000 個項目
# 2025-03-12 11:23:26,742 - __main__ - INFO - 已處理 1176000 個項目
# 2025-03-12 11:23:26,760 - __main__ - INFO - 已處理 1177000 個項目
# 2025-03-12 11:23:26,777 - __main__ - INFO - 已處理 1178000 個項目
# 2025-03-12 11:23:26,794 - __main__ - INFO - 已處理 1179000 個項目
# 2025-03-12 11:23:26,813 - __main__ - INFO - 已處理 1180000 個項目
# 2025-03-12 11:23:26,830 - __main__ - INFO - 已處理 1181000 個項目
# 2025-03-12 11:23:26,846 - __main__ - INFO - 已處理 1182000 個項目
# 2025-03-12 11:23:26,863 - __main__ - INFO - 已處理 1183000 個項目
# 2025-03-12 11:23:26,881 - __main__ - INFO - 已處理 1184000 個項目
# 2025-03-12 11:23:26,899 - __main__ - INFO - 已處理 1185000 個項目
# 2025-03-12 11:23:26,921 - __main__ - INFO - 已處理 1186000 個項目
# 2025-03-12 11:23:26,939 - __main__ - INFO - 已處理 1187000 個項目
# 2025-03-12 11:23:26,956 - __main__ - INFO - 已處理 1188000 個項目
# 2025-03-12 11:23:26,975 - __main__ - INFO - 已處理 1189000 個項目
# 2025-03-12 11:23:26,993 - __main__ - INFO - 已處理 1190000 個項目
# 2025-03-12 11:23:27,011 - __main__ - INFO - 已處理 1191000 個項目
# 2025-03-12 11:23:27,029 - __main__ - INFO - 已處理 1192000 個項目
# 2025-03-12 11:23:27,048 - __main__ - INFO - 已處理 1193000 個項目
# 2025-03-12 11:23:27,067 - __main__ - INFO - 已處理 1194000 個項目
# 2025-03-12 11:23:27,085 - __main__ - INFO - 已處理 1195000 個項目
# 2025-03-12 11:23:27,103 - __main__ - INFO - 已處理 1196000 個項目
# 2025-03-12 11:23:27,121 - __main__ - INFO - 已處理 1197000 個項目
# 2025-03-12 11:23:27,138 - __main__ - INFO - 已處理 1198000 個項目
# 2025-03-12 11:23:27,156 - __main__ - INFO - 已處理 1199000 個項目
# 2025-03-12 11:23:27,173 - __main__ - INFO - 已處理 1200000 個項目
# 2025-03-12 11:23:27,190 - __main__ - INFO - 已處理 1201000 個項目
# 2025-03-12 11:23:27,208 - __main__ - INFO - 已處理 1202000 個項目
# 2025-03-12 11:23:27,231 - __main__ - INFO - 已處理 1203000 個項目
# 2025-03-12 11:23:27,249 - __main__ - INFO - 已處理 1204000 個項目
# 2025-03-12 11:23:27,267 - __main__ - INFO - 已處理 1205000 個項目
# 2025-03-12 11:23:27,284 - __main__ - INFO - 已處理 1206000 個項目
# 2025-03-12 11:23:27,302 - __main__ - INFO - 已處理 1207000 個項目
# 2025-03-12 11:23:27,320 - __main__ - INFO - 已處理 1208000 個項目
# 2025-03-12 11:23:27,338 - __main__ - INFO - 已處理 1209000 個項目
# 2025-03-12 11:23:27,355 - __main__ - INFO - 已處理 1210000 個項目
# 2025-03-12 11:23:27,373 - __main__ - INFO - 已處理 1211000 個項目
# 2025-03-12 11:23:27,391 - __main__ - INFO - 已處理 1212000 個項目
# 2025-03-12 11:23:27,407 - __main__ - INFO - 已處理 1213000 個項目
# 2025-03-12 11:23:27,451 - __main__ - INFO - 已處理 1214000 個項目
# 2025-03-12 11:23:27,470 - __main__ - INFO - 已處理 1215000 個項目
# 2025-03-12 11:23:27,488 - __main__ - INFO - 已處理 1216000 個項目
# 2025-03-12 11:23:27,504 - __main__ - INFO - 已處理 1217000 個項目
# 2025-03-12 11:23:27,522 - __main__ - INFO - 已處理 1218000 個項目
# 2025-03-12 11:23:27,538 - __main__ - INFO - 已處理 1219000 個項目
# 2025-03-12 11:23:27,556 - __main__ - INFO - 已處理 1220000 個項目
# 2025-03-12 11:23:27,574 - __main__ - INFO - 已處理 1221000 個項目
# 2025-03-12 11:23:27,597 - __main__ - INFO - 已處理 1222000 個項目
# 2025-03-12 11:23:27,614 - __main__ - INFO - 已處理 1223000 個項目
# 2025-03-12 11:23:27,631 - __main__ - INFO - 已處理 1224000 個項目
# 2025-03-12 11:23:27,649 - __main__ - INFO - 已處理 1225000 個項目
# 2025-03-12 11:23:27,667 - __main__ - INFO - 已處理 1226000 個項目
# 2025-03-12 11:23:27,684 - __main__ - INFO - 已處理 1227000 個項目
# 2025-03-12 11:23:27,701 - __main__ - INFO - 已處理 1228000 個項目
# 2025-03-12 11:23:27,719 - __main__ - INFO - 已處理 1229000 個項目
# 2025-03-12 11:23:27,737 - __main__ - INFO - 已處理 1230000 個項目
# 2025-03-12 11:23:27,754 - __main__ - INFO - 已處理 1231000 個項目
# 2025-03-12 11:23:27,772 - __main__ - INFO - 已處理 1232000 個項目
# 2025-03-12 11:23:27,792 - __main__ - INFO - 已處理 1233000 個項目
# 2025-03-12 11:23:27,809 - __main__ - INFO - 已處理 1234000 個項目
# 2025-03-12 11:23:27,827 - __main__ - INFO - 已處理 1235000 個項目
# 2025-03-12 11:23:27,845 - __main__ - INFO - 已處理 1236000 個項目
# 2025-03-12 11:23:27,864 - __main__ - INFO - 已處理 1237000 個項目
# 2025-03-12 11:23:27,881 - __main__ - INFO - 已處理 1238000 個項目
# 2025-03-12 11:23:27,901 - __main__ - INFO - 已處理 1239000 個項目
# 2025-03-12 11:23:27,919 - __main__ - INFO - 已處理 1240000 個項目
# 2025-03-12 11:23:27,936 - __main__ - INFO - 已處理 1241000 個項目
# 2025-03-12 11:23:27,955 - __main__ - INFO - 已處理 1242000 個項目
# 2025-03-12 11:23:27,973 - __main__ - INFO - 已處理 1243000 個項目
# 2025-03-12 11:23:27,991 - __main__ - INFO - 已處理 1244000 個項目
# 2025-03-12 11:23:28,011 - __main__ - INFO - 已處理 1245000 個項目
# 2025-03-12 11:23:28,029 - __main__ - INFO - 已處理 1246000 個項目
# 2025-03-12 11:23:28,047 - __main__ - INFO - 已處理 1247000 個項目
# 2025-03-12 11:23:28,065 - __main__ - INFO - 已處理 1248000 個項目
# 2025-03-12 11:23:28,083 - __main__ - INFO - 已處理 1249000 個項目
# 2025-03-12 11:23:28,100 - __main__ - INFO - 已處理 1250000 個項目
# 2025-03-12 11:23:28,117 - __main__ - INFO - 已處理 1251000 個項目
# 2025-03-12 11:23:28,134 - __main__ - INFO - 已處理 1252000 個項目
# 2025-03-12 11:23:28,152 - __main__ - INFO - 已處理 1253000 個項目
# 2025-03-12 11:23:28,169 - __main__ - INFO - 已處理 1254000 個項目
# 2025-03-12 11:23:28,187 - __main__ - INFO - 已處理 1255000 個項目
# 2025-03-12 11:23:28,210 - __main__ - INFO - 已處理 1256000 個項目
# 2025-03-12 11:23:28,230 - __main__ - INFO - 已處理 1257000 個項目
# 2025-03-12 11:23:28,250 - __main__ - INFO - 已處理 1258000 個項目
# 2025-03-12 11:23:28,266 - __main__ - INFO - 已處理 1259000 個項目
# 2025-03-12 11:23:28,283 - __main__ - INFO - 已處理 1260000 個項目
# 2025-03-12 11:23:28,300 - __main__ - INFO - 已處理 1261000 個項目
# 2025-03-12 11:23:28,317 - __main__ - INFO - 已處理 1262000 個項目
# 2025-03-12 11:23:28,333 - __main__ - INFO - 已處理 1263000 個項目
# 2025-03-12 11:23:28,348 - __main__ - INFO - 已處理 1264000 個項目
# 2025-03-12 11:23:28,364 - __main__ - INFO - 已處理 1265000 個項目
# 2025-03-12 11:23:28,381 - __main__ - INFO - 已處理 1266000 個項目
# 2025-03-12 11:23:28,399 - __main__ - INFO - 已處理 1267000 個項目
# 2025-03-12 11:23:28,415 - __main__ - INFO - 已處理 1268000 個項目
# 2025-03-12 11:23:28,432 - __main__ - INFO - 已處理 1269000 個項目
# 2025-03-12 11:23:28,450 - __main__ - INFO - 已處理 1270000 個項目
# 2025-03-12 11:23:28,468 - __main__ - INFO - 已處理 1271000 個項目
# 2025-03-12 11:23:28,487 - __main__ - INFO - 已處理 1272000 個項目
# 2025-03-12 11:23:28,503 - __main__ - INFO - 已處理 1273000 個項目
# 2025-03-12 11:23:28,526 - __main__ - INFO - 已處理 1274000 個項目
# 2025-03-12 11:23:28,543 - __main__ - INFO - 已處理 1275000 個項目
# 2025-03-12 11:23:28,559 - __main__ - INFO - 已處理 1276000 個項目
# 2025-03-12 11:23:28,578 - __main__ - INFO - 已處理 1277000 個項目
# 2025-03-12 11:23:28,595 - __main__ - INFO - 已處理 1278000 個項目
# 2025-03-12 11:23:28,613 - __main__ - INFO - 已處理 1279000 個項目
# 2025-03-12 11:23:28,632 - __main__ - INFO - 已處理 1280000 個項目
# 2025-03-12 11:23:28,649 - __main__ - INFO - 已處理 1281000 個項目
# 2025-03-12 11:23:28,666 - __main__ - INFO - 已處理 1282000 個項目
# 2025-03-12 11:23:28,684 - __main__ - INFO - 已處理 1283000 個項目
# 2025-03-12 11:23:28,702 - __main__ - INFO - 已處理 1284000 個項目
# 2025-03-12 11:23:28,722 - __main__ - INFO - 已處理 1285000 個項目
# 2025-03-12 11:23:28,739 - __main__ - INFO - 已處理 1286000 個項目
# 2025-03-12 11:23:28,779 - __main__ - INFO - 已處理 1287000 個項目
# 2025-03-12 11:23:28,799 - __main__ - INFO - 已處理 1288000 個項目
# 2025-03-12 11:23:28,817 - __main__ - INFO - 已處理 1289000 個項目
# 2025-03-12 11:23:28,839 - __main__ - INFO - 已處理 1290000 個項目
# 2025-03-12 11:23:28,856 - __main__ - INFO - 已處理 1291000 個項目
# 2025-03-12 11:23:28,875 - __main__ - INFO - 已處理 1292000 個項目
# 2025-03-12 11:23:28,891 - __main__ - INFO - 已處理 1293000 個項目
# 2025-03-12 11:23:28,909 - __main__ - INFO - 已處理 1294000 個項目
# 2025-03-12 11:23:28,927 - __main__ - INFO - 已處理 1295000 個項目
# 2025-03-12 11:23:28,945 - __main__ - INFO - 已處理 1296000 個項目
# 2025-03-12 11:23:28,962 - __main__ - INFO - 已處理 1297000 個項目
# 2025-03-12 11:23:28,978 - __main__ - INFO - 已處理 1298000 個項目
# 2025-03-12 11:23:28,995 - __main__ - INFO - 已處理 1299000 個項目
# 2025-03-12 11:23:29,014 - __main__ - INFO - 已處理 1300000 個項目
# 2025-03-12 11:23:29,031 - __main__ - INFO - 已處理 1301000 個項目
# 2025-03-12 11:23:29,048 - __main__ - INFO - 已處理 1302000 個項目
# 2025-03-12 11:23:29,066 - __main__ - INFO - 已處理 1303000 個項目
# 2025-03-12 11:23:29,087 - __main__ - INFO - 已處理 1304000 個項目
# 2025-03-12 11:23:29,114 - __main__ - INFO - 已處理 1305000 個項目
# 2025-03-12 11:23:29,134 - __main__ - INFO - 已處理 1306000 個項目
# 2025-03-12 11:23:29,152 - __main__ - INFO - 已處理 1307000 個項目
# 2025-03-12 11:23:29,174 - __main__ - INFO - 已處理 1308000 個項目
# 2025-03-12 11:23:29,193 - __main__ - INFO - 已處理 1309000 個項目
# 2025-03-12 11:23:29,211 - __main__ - INFO - 已處理 1310000 個項目
# 2025-03-12 11:23:29,230 - __main__ - INFO - 已處理 1311000 個項目
# 2025-03-12 11:23:29,249 - __main__ - INFO - 已處理 1312000 個項目
# 2025-03-12 11:23:29,269 - __main__ - INFO - 已處理 1313000 個項目
# 2025-03-12 11:23:29,287 - __main__ - INFO - 已處理 1314000 個項目
# 2025-03-12 11:23:29,305 - __main__ - INFO - 已處理 1315000 個項目
# 2025-03-12 11:23:29,324 - __main__ - INFO - 已處理 1316000 個項目
# 2025-03-12 11:23:29,344 - __main__ - INFO - 已處理 1317000 個項目
# 2025-03-12 11:23:29,361 - __main__ - INFO - 已處理 1318000 個項目
# 2025-03-12 11:23:29,380 - __main__ - INFO - 已處理 1319000 個項目
# 2025-03-12 11:23:29,398 - __main__ - INFO - 已處理 1320000 個項目
# 2025-03-12 11:23:29,417 - __main__ - INFO - 已處理 1321000 個項目
# 2025-03-12 11:23:29,435 - __main__ - INFO - 已處理 1322000 個項目
# 2025-03-12 11:23:29,458 - __main__ - INFO - 已處理 1323000 個項目
# 2025-03-12 11:23:29,477 - __main__ - INFO - 已處理 1324000 個項目
# 2025-03-12 11:23:29,496 - __main__ - INFO - 已處理 1325000 個項目
# 2025-03-12 11:23:29,515 - __main__ - INFO - 已處理 1326000 個項目
# 2025-03-12 11:23:29,534 - __main__ - INFO - 已處理 1327000 個項目
# 2025-03-12 11:23:29,553 - __main__ - INFO - 已處理 1328000 個項目
# 2025-03-12 11:23:29,570 - __main__ - INFO - 已處理 1329000 個項目
# 2025-03-12 11:23:29,589 - __main__ - INFO - 已處理 1330000 個項目
# 2025-03-12 11:23:29,606 - __main__ - INFO - 已處理 1331000 個項目
# 2025-03-12 11:23:29,624 - __main__ - INFO - 已處理 1332000 個項目
# 2025-03-12 11:23:29,643 - __main__ - INFO - 已處理 1333000 個項目
# 2025-03-12 11:23:29,661 - __main__ - INFO - 已處理 1334000 個項目
# 2025-03-12 11:23:29,678 - __main__ - INFO - 已處理 1335000 個項目
# 2025-03-12 11:23:29,695 - __main__ - INFO - 已處理 1336000 個項目
# 2025-03-12 11:23:29,713 - __main__ - INFO - 已處理 1337000 個項目
# 2025-03-12 11:23:29,731 - __main__ - INFO - 已處理 1338000 個項目
# 2025-03-12 11:23:29,747 - __main__ - INFO - 已處理 1339000 個項目
# 2025-03-12 11:23:29,769 - __main__ - INFO - 已處理 1340000 個項目
# 2025-03-12 11:23:29,786 - __main__ - INFO - 已處理 1341000 個項目
# 2025-03-12 11:23:29,804 - __main__ - INFO - 已處理 1342000 個項目
# 2025-03-12 11:23:29,822 - __main__ - INFO - 已處理 1343000 個項目
# 2025-03-12 11:23:29,839 - __main__ - INFO - 已處理 1344000 個項目
# 2025-03-12 11:23:29,855 - __main__ - INFO - 已處理 1345000 個項目
# 2025-03-12 11:23:29,872 - __main__ - INFO - 已處理 1346000 個項目
# 2025-03-12 11:23:29,891 - __main__ - INFO - 已處理 1347000 個項目
# 2025-03-12 11:23:29,908 - __main__ - INFO - 已處理 1348000 個項目
# 2025-03-12 11:23:29,927 - __main__ - INFO - 已處理 1349000 個項目
# 2025-03-12 11:23:29,944 - __main__ - INFO - 已處理 1350000 個項目
# 2025-03-12 11:23:29,961 - __main__ - INFO - 已處理 1351000 個項目
# 2025-03-12 11:23:29,978 - __main__ - INFO - 已處理 1352000 個項目
# 2025-03-12 11:23:29,996 - __main__ - INFO - 已處理 1353000 個項目
# 2025-03-12 11:23:30,014 - __main__ - INFO - 已處理 1354000 個項目
# 2025-03-12 11:23:30,035 - __main__ - INFO - 已處理 1355000 個項目
# 2025-03-12 11:23:30,075 - __main__ - INFO - 已處理 1356000 個項目
# 2025-03-12 11:23:30,096 - __main__ - INFO - 已處理 1357000 個項目
# 2025-03-12 11:23:30,114 - __main__ - INFO - 已處理 1358000 個項目
# 2025-03-12 11:23:30,132 - __main__ - INFO - 已處理 1359000 個項目
# 2025-03-12 11:23:30,147 - __main__ - INFO - 已處理 1360000 個項目
# 2025-03-12 11:23:30,165 - __main__ - INFO - 已處理 1361000 個項目
# 2025-03-12 11:23:30,181 - __main__ - INFO - 已處理 1362000 個項目
# 2025-03-12 11:23:30,198 - __main__ - INFO - 已處理 1363000 個項目
# 2025-03-12 11:23:30,215 - __main__ - INFO - 已處理 1364000 個項目
# 2025-03-12 11:23:30,232 - __main__ - INFO - 已處理 1365000 個項目
# 2025-03-12 11:23:30,250 - __main__ - INFO - 已處理 1366000 個項目
# 2025-03-12 11:23:30,266 - __main__ - INFO - 已處理 1367000 個項目
# 2025-03-12 11:23:30,285 - __main__ - INFO - 已處理 1368000 個項目
# 2025-03-12 11:23:30,303 - __main__ - INFO - 已處理 1369000 個項目
# 2025-03-12 11:23:30,321 - __main__ - INFO - 已處理 1370000 個項目
# 2025-03-12 11:23:30,338 - __main__ - INFO - 已處理 1371000 個項目
# 2025-03-12 11:23:30,359 - __main__ - INFO - 已處理 1372000 個項目
# 2025-03-12 11:23:30,377 - __main__ - INFO - 已處理 1373000 個項目
# 2025-03-12 11:23:30,395 - __main__ - INFO - 已處理 1374000 個項目
# 2025-03-12 11:23:30,411 - __main__ - INFO - 已處理 1375000 個項目
# 2025-03-12 11:23:30,429 - __main__ - INFO - 已處理 1376000 個項目
# 2025-03-12 11:23:30,446 - __main__ - INFO - 已處理 1377000 個項目
# 2025-03-12 11:23:30,447 - __main__ - INFO - 已處理 1377010 個項目
# 2025-03-12 11:23:30,447 - __main__ - INFO - 分批處理完成，總共處理 1377010 個項目
# 2025-03-12 11:23:37,300 - __main__ - INFO - 已成功儲存 1377010 個項目至 JSON 檔案: ../data/convert/official-cpe-dictionary_v2.3_v2.json
# 2025-03-12 11:23:43,649 - __main__ - INFO - 已成功儲存 1377010 個項目至 CSV 檔案: ../data/convert/official-cpe-dictionary_v2.3_v2.csv
# 2025-03-12 11:23:43,649 - __main__ - INFO - 程式執行完成

# %% [markdown]
# ### Example of converted format
#
# #### JSON Format
#
# ```JSON
# {
#   "cpe22Uri": "cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~",
#   "cpe23Uri": "cpe:2.3:a:\\$0.99_kindle_books_project:\\$0.99_kindle_books:6:*:*:*:*:android:*:*",
#   "vendor": "\\$0.99_kindle_books_project",
#   "product": "\\$0.99_kindle_books",
#   "version": "6",
#   "title": "$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0",
#   "references": "Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)"
# },
# ```
#
# #### CSV Format
#
# ```CSV
# cpe22Uri,cpe23Uri,vendor,product,version,title,references
# cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~,cpe:2.3:a:\$0.99_kindle_books_project:\$0.99_kindle_books:6:*:*:*:*:android:*:*,\$0.99_kindle_books_project,\$0.99_kindle_books,6,$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0,Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)
# ```

# %% [markdown]
# ## Step 3: Create a vector database (using Chromadb as an example)
#
# To quickly retrieve the closest Common Platform Enumeration (CPE) data based on user input, we will utilize the similarity search capabilities of a vector database. Vector databases excel at transforming complex data (such as images, audio, etc.) into vector representations for mathematical operations. Given the variability of user input, the potential for different registration formats of vendor and product names within the CPE database, and the varying relevance of references included in CPE entries, we aim to leverage the similarity comparison capabilities of the vector database to effectively identify the desired CPE entries. Therefore, we need to import the National Vulnerability Database (NVD) CPE Directory List into Chromadb and convert it into vectors for subsequent similarity comparisons.
#
# > 為了能根據使用者輸入，快速取得最接近的通用平台列舉（CPE）資料，我們將利用向量資料庫的相似性搜尋功能。向量資料庫擅長將複雜資料（如圖像、聲音等）轉換為可進行數學運算的向量表示。由於使用者輸入的多樣性，以及廠商、產品名稱在 CPE 資料庫中可能存在不同形式的登記方式，加上 CPE 條目中包含的參考資料（References）有時相關、有時不相關，我們希望藉由向量資料庫的相似性比較能力，有效識別出期望的 CPE 條目。因此，我們需要將美國國家漏洞資料庫（NVD）的 CPE 目錄列表匯入 Chromadb，並將其轉換為向量，以便後續的相似性比對。
#
# ### Structure of the created to vector database
#
# ```Markdown
#           (Periodic or Manual)
# ┌───────────────────────────────────────┐
# │    NVD CPE Directory (ZIP/XML)        │
# └───────────────────────────────────────┘
#                │
#                ▼
#      CPE Directory Updater
#                │
#                ▼
#      CPE Parser & Transformer
#                │  (structured JSON)
#                ▼
#      Embedding Service (Huggingface)
#                │ (vector)
#                ▼
#   ┌────────────────────────────────────┐
#   │         Chromadb Vector DB         │
#   └────────────────────────────────────┘
# ```

# %%
import json
import logging
import os
import csv
from typing import Tuple, List, Dict, Any, Optional, Union
from pathlib import Path
import chromadb
from chromadb.utils import embedding_functions
from dataclasses import dataclass
import datetime


# 設定日誌
def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


# 設定日誌
setup_logging(logging.INFO, "../logs/cpe_database.log")
logger = logging.getLogger(__name__)


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class EmbeddingModelProvider:
    """提供不同的嵌入模型選項"""

    @staticmethod
    def get_default_embedding():
        """獲取預設的嵌入函數

        Returns:
            embedding_function: 預設的嵌入函數
        """
        return embedding_functions.DefaultEmbeddingFunction()

    # TODO: 此區域程式碼修正中，後續引入 GPU 加速時完成修正
    # @staticmethod
    # def get_huggingface_embedding(model_name: str = "sentence-transformers/all-MiniLM-L6-v2", use_gpu: bool = False):
    #     """獲取基於 HuggingFace 的嵌入函數

    #     Args:
    #         model_name (str, optional): 模型名稱. 預設為 "sentence-transformers/all-MiniLM-L6-v2".
    #         use_gpu (bool, optional): 是否使用 GPU. 預設為 False.

    #     Returns:
    #         embedding_function: HuggingFace 嵌入函數
    #     """
    #     try:
    #         from sentence_transformers import SentenceTransformer

    #         # 設定設備
    #         device = "cuda" if use_gpu else "cpu"
    #         logger.info(f"使用 HuggingFace 模型: {model_name}，設備: {device}")

    #         model = SentenceTransformer(model_name, device=device)

    #         # 建立自訂的嵌入函數
    #         def huggingface_embedder(texts):
    #             return model.encode(texts).tolist()

    #         return embedding_functions.EmbeddingFunction(huggingface_embedder)

    #     except ImportError:
    #         logger.warning("未安裝 sentence-transformers 庫，請使用 pip install sentence-transformers 進行安裝")
    #         logger.warning("將使用預設嵌入函數代替")
    #         return EmbeddingModelProvider.get_default_embedding()
    #     except Exception as e:
    #         logger.error(f"加載 HuggingFace 模型時發生錯誤: {str(e)}")
    #         logger.warning("將使用預設嵌入函數代替")
    #         return EmbeddingModelProvider.get_default_embedding()


class CPEDatabaseManager:
    def __init__(self,
                 db_path: str = "../database/cpe_database",
                 use_gpu: bool = False,
                 embedding_model: str = "default"):
        """初始化 CPE 資料庫管理器

        Args:
            db_path (str): 資料庫存放路徑
            use_gpu (bool, optional): 是否使用 GPU. 預設為 False.
            embedding_model (str, optional): 要使用的嵌入模型類型.
                                             可選值: "default", "huggingface". 預設為 "default".
        """
        self.db_path = Path(db_path)
        self.db_path.mkdir(parents=True, exist_ok=True)

        self.client = None
        self.collection = None

        # 設定 GPU 使用選項
        self.use_gpu = use_gpu

        # 選擇嵌入模型
        self.setup_embedding_function(embedding_model)

        # 設定資料庫
        self.setup_database()

    def setup_embedding_function(self, embedding_model: str):
        """設定嵌入函數

        Args:
            embedding_model (str): 嵌入模型類型
        """
        # if embedding_model.lower() == "huggingface":
        #     self.embedding_function = EmbeddingModelProvider.get_huggingface_embedding(use_gpu=self.use_gpu)
        #     device_info = "GPU" if self.use_gpu else "CPU"
        #     embedding_description = f"HuggingFace (device: {device_info})"
        # else:
        #     self.embedding_function = EmbeddingModelProvider.get_default_embedding()
        #     embedding_description = "預設"
        self.embedding_function = EmbeddingModelProvider.get_default_embedding()
        embedding_description = "預設"

        logger.info(f"使用嵌入模型: {embedding_description}")

    def setup_database(self) -> None:
        """設定資料庫連接和集合"""
        try:
            self.client = chromadb.PersistentClient(path=str(self.db_path))

            # 使用設定的 embedding 函數建立集合
            self.collection = self.client.get_or_create_collection(
                name="cpe_dictionary",
                metadata={"description": "CPE Dictionary Collection"},
                embedding_function=self.embedding_function
            )
            logger.info(f"成功設定資料庫連接，儲存位置: {self.db_path}")
        except Exception as e:
            logger.error(f"設定資料庫時發生錯誤: {str(e)}")
            raise

    def load_cpe_data(self, file_path: Union[str, Path]) -> List[Dict[str, Any]]:
        """讀取並解析 CPE JSON 檔案

        Args:
            file_path (Union[str, Path]): JSON 檔案路徑

        Returns:
            List[Dict[str, Any]]: 解析後的 CPE 資料
        """
        file_path = Path(file_path)
        if not file_path.exists():
            raise FileNotFoundError(f"找不到檔案: {file_path}")

        try:
            logger.info(f"開始讀取 CPE 資料: {file_path}")
            with open(file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
            logger.info(f"成功讀取 {len(data)} 筆 CPE 資料")
            return data
        except json.JSONDecodeError as e:
            logger.error(f"解析 JSON 檔案時發生錯誤: {str(e)}")
            raise
        except Exception as e:
            logger.error(f"讀取 CPE 資料時發生錯誤: {str(e)}")
            raise

    def prepare_search_text(self, item: Dict[str, Any]) -> str:
        """準備用於向量搜尋的文字內容

        這個文字將被轉換為向量，並用於相似度搜尋。
        根據使用者需求，我們優化文字內容以支援廠商、產品和版本的搜尋。

        Args:
            item (Dict[str, Any]): CPE 項目資料

        Returns:
            str: 用於向量搜尋的文字
        """
        # 將最重要的資訊放在前面，並重複以增加權重
        title = item.get('title', '').strip()
        vendor = item.get('vendor', '').strip()
        product = item.get('product', '').strip()
        version = item.get('version', '').strip()

        # 構建優化的搜尋文字
        search_text = f"{vendor} {product} {version} "
        search_text += f"{title} "
        search_text += f"{vendor} {product} "

        # 加入完整的資訊
        search_text += f"""
        Title: {title}
        Vendor: {vendor}
        Product: {product}
        Version: {version}
        """

        return search_text.strip()

    def prepare_documents(self, cpe_data: List[Dict[str, Any]]) -> Tuple[List[str], List[Dict[str, str]], List[str]]:
        """準備要導入到資料庫的文件資料

        Args:
            cpe_data (List[Dict[str, Any]]): CPE 資料列表

        Returns:
            Tuple[List[str], List[Dict[str, str]], List[str]]: 
            返回文件內容、中繼資料和ID的元組
        """
        documents = []
        metadatas = []
        ids = []

        for i, item in enumerate(cpe_data):
            try:
                # 取得 CPE 2.3 URI 作為唯一識別符
                cpe23uri = item.get('cpe23Uri', '')
                if not cpe23uri:
                    logger.warning(f"第 {i} 筆資料缺少 cpe23Uri，將略過")
                    continue

                # 使用 CPE 2.3 URI 作為 ID
                doc_id = cpe23uri

                # 製作優化的文件內容
                doc_content = self.prepare_search_text(item)

                # 準備豐富的中繼資料，方便後續檢索和過濾
                metadata = {
                    'vendor': item.get('vendor', ''),
                    'product': item.get('product', ''),
                    'version': item.get('version', ''),
                    'cpe22Uri': item.get('cpe22Uri', ''),
                    'cpe23Uri': cpe23uri,
                    'title': item.get('title', ''),
                    # 將 references 截斷以避免過長
                    'references': item.get('references', '')[:1000] if item.get('references') else ''
                }

                documents.append(doc_content)
                metadatas.append(metadata)
                ids.append(doc_id)

            except Exception as e:
                logger.warning(f"處理第 {i} 筆資料時發生錯誤: {str(e)}")
                continue

        return documents, metadatas, ids

    def import_data(self, file_path: Union[str, Path], batch_size: int = 1000,
                    reset_collection: bool = False) -> None:
        """導入 CPE 資料到資料庫

        Args:
            file_path (Union[str, Path]): CPE JSON 檔案路徑
            batch_size (int, optional): 批次處理大小. 預設為 1000.
            reset_collection (bool, optional): 是否重置集合. 預設為 False.
        """
        try:
            # 如果需要重置集合
            if reset_collection:
                logger.info("重置集合...")
                # ChromaDB v0.6.0 兼容性處理
                try:
                    collection_names = [
                        col for col in self.client.list_collections()]
                    if "cpe_dictionary" in collection_names:
                        self.client.delete_collection("cpe_dictionary")
                except Exception as e:
                    logger.warning(f"檢查集合時發生錯誤 (可能是 ChromaDB 版本不同): {str(e)}")
                    # 嘗試不同的方法
                    try:
                        self.client.get_collection("cpe_dictionary")
                        self.client.delete_collection("cpe_dictionary")
                    except Exception:
                        # 如果集合不存在，忽略錯誤
                        pass

                self.collection = self.client.create_collection(
                    name="cpe_dictionary",
                    metadata={"description": "CPE Dictionary Collection"},
                    embedding_function=self.embedding_function
                )
                logger.info("集合已重置")

            # 讀取資料
            cpe_data = self.load_cpe_data(file_path)

            # 準備文件
            logger.info("準備文件資料...")
            documents, metadatas, ids = self.prepare_documents(cpe_data)
            logger.info(f"準備了 {len(documents)} 筆有效的 CPE 資料")

            # 批次處理
            total_items = len(documents)
            for i in range(0, total_items, batch_size):
                batch_end = min(i + batch_size, total_items)
                batch_docs = documents[i:batch_end]
                batch_meta = metadatas[i:batch_end]
                batch_ids = ids[i:batch_end]

                logger.info(f"正在導入批次 {i//batch_size + 1}/{(total_items-1)//batch_size + 1} " +
                            f"({i+1}-{batch_end}/{total_items})...")

                try:
                    # 使用 upsert 而非 add，以便處理重複的 CPE ID
                    self.collection.upsert(
                        documents=batch_docs,
                        metadatas=batch_meta,
                        ids=batch_ids
                    )
                    logger.info(f"已處理 {batch_end}/{total_items} 筆資料")
                except Exception as e:
                    logger.error(f"批次處理時發生錯誤: {str(e)}")
                    logger.error(f"問題批次範圍: {i+1}-{batch_end}")
                    # 繼續處理下一批，而不是中斷整個過程
                    continue

            logger.info(f"成功導入 CPE 資料，總計 {total_items} 筆")

        except Exception as e:
            logger.error(f"導入資料時發生錯誤: {str(e)}")
            raise

    def search(self,
               vendor: str = None,
               product: str = None,
               version: str = None,
               n_results: int = 5) -> Dict[str, Any]:
        """搜尋 CPE 資料，僅使用廠商、產品、版本進行搜尋

        Args:
            vendor (str, optional): 廠商名稱，可為空
            product (str, optional): 產品名稱，可為空
            version (str, optional): 版本號，可為空
            n_results (int): 返回結果數量，預設為5

        Returns:
            Dict[str, Any]: 搜尋結果，包含過濾前和過濾後的結果
        """
        try:
            # 確保至少提供一個搜尋條件
            if not any([vendor, product, version]):
                raise ValueError(
                    "必須提供至少一個搜尋條件 (vendor, product, version)")

            # 構建搜尋關鍵字
            search_parts = []
            if vendor:
                search_parts.append(f"{vendor}")
            if product:
                search_parts.append(f"{product}")
            if version:
                search_parts.append(f"{version}")

            search_query = " ".join(search_parts)

            # 使用文本搜尋
            original_results = self.collection.query(
                query_texts=[search_query],
                n_results=n_results,
                include=['metadatas', 'distances']
            )

            # 進行精確過濾
            filtered_indices = []
            for i, metadata in enumerate(original_results['metadatas'][0]):
                match = True
                if vendor and vendor.lower() not in metadata['vendor'].lower():
                    match = False
                if product and product.lower() not in metadata['product'].lower():
                    match = False
                if version and version.lower() not in metadata['version'].lower():
                    match = False

                if match:
                    filtered_indices.append(i)

            # 創建結果字典，包含過濾前後的結果
            results = {
                'original_results': original_results,
                'filtered_results': None,
                'is_filtered': True
            }

            # 根據過濾後的索引重建結果
            if filtered_indices:
                filtered_results = {
                    'ids': [[original_results['ids'][0][i] for i in filtered_indices]],
                    'metadatas': [[original_results['metadatas'][0][i] for i in filtered_indices]],
                    'distances': [[original_results['distances'][0][i] for i in filtered_indices]]
                }

                # 如果原結果包含 documents，也過濾它
                if 'documents' in original_results:
                    filtered_results['documents'] = [
                        [original_results['documents'][0][i] for i in filtered_indices]]

                results['filtered_results'] = filtered_results
            else:
                # 如果過濾後沒有結果，設定空結果
                results['filtered_results'] = {
                    'ids': [[]],
                    'metadatas': [[]],
                    'distances': [[]]
                }

            return results

        except Exception as e:
            logger.error(f"搜尋時發生錯誤: {str(e)}")
            raise

    def get_collection_info(self) -> Dict[str, Any]:
        """獲取集合資訊

        Returns:
            Dict[str, Any]: 集合資訊
        """
        try:
            # 獲取集合計數
            count = self.collection.count()

            # 判斷使用的嵌入模型類型
            try:
                # 嘗試檢查嵌入函數的類型
                if hasattr(embedding_functions, 'DefaultEmbeddingFunction') and \
                   isinstance(self.embedding_function, embedding_functions.DefaultEmbeddingFunction):
                    model_type = "Default"
                else:
                    # 嘗試使用不同的方式判斷
                    model_name = getattr(
                        self.embedding_function, '_model_name', None)
                    if model_name and 'huggingface' in str(model_name).lower():
                        model_type = "HuggingFace"
                    else:
                        model_type = "Default" if not self.use_gpu else "HuggingFace"
            except Exception as e:
                logger.warning(f"判斷嵌入模型類型時發生錯誤: {str(e)}")
                # 回退到基於 use_gpu 的簡單判斷
                model_type = "Default" if not self.use_gpu else "HuggingFace"

            # 獲取集合中繼資料
            collection_info = {
                "name": self.collection.name,
                "metadata": self.collection.metadata,
                "count": count,
                "embedding_model": model_type,
                "device": "GPU" if self.use_gpu else "CPU"
            }

            return collection_info
        except Exception as e:
            logger.error(f"獲取集合資訊時發生錯誤: {str(e)}")
            raise


def format_search_results(results: Dict[str, Any]) -> str:
    """格式化搜尋結果為可讀的文字，包含過濾前和過濾後的結果

    Args:
        results (Dict[str, Any]): 搜尋結果

    Returns:
        str: 格式化的搜尋結果文字
    """
    if not results:
        return "未找到符合的結果"

    output = []

    # 處理原始結果
    original_results = results.get('original_results', {})
    if original_results and original_results.get('metadatas') and original_results['metadatas'][0]:
        output.append("\n=== 原始搜尋結果 ===")
        for i, (metadata, distance) in enumerate(zip(original_results['metadatas'][0],
                                                     original_results.get('distances', [[0] * len(original_results['metadatas'][0])])[0])):
            score = 1.0 - (distance / 2.0)  # 將距離轉換為可理解的分數

            output.append(f"\n原始結果 {i+1} (相似度: {score:.2f}):")
            output.append(f"產品: {metadata['product']}")
            output.append(f"廠商: {metadata['vendor']}")
            output.append(f"版本: {metadata['version']}")
            output.append(f"CPE23: {metadata['cpe23Uri']}")

    # 處理過濾結果
    filtered_results = results.get('filtered_results', {})
    if results.get('is_filtered') and filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
        output.append("\n=== 過濾後的結果 ===")
        for i, (metadata, distance) in enumerate(zip(filtered_results['metadatas'][0],
                                                     filtered_results.get('distances', [[0] * len(filtered_results['metadatas'][0])])[0])):
            score = 1.0 - (distance / 2.0)

            output.append(f"\n過濾結果 {i+1} (相似度: {score:.2f}):")
            output.append(f"產品: {metadata['product']}")
            output.append(f"廠商: {metadata['vendor']}")
            output.append(f"版本: {metadata['version']}")
            output.append(f"CPE23: {metadata['cpe23Uri']}")
    elif results.get('is_filtered') and (not filtered_results or not filtered_results.get('metadatas') or not filtered_results['metadatas'][0]):
        output.append("\n=== 過濾後的結果 ===")
        output.append("過濾後沒有符合條件的結果")

    return "\n".join(output)


def batch_search_from_csv(db_manager, csv_file_path, output_file_path=None):
    """從CSV檔案批次搜尋CPE資料並輸出結果

    Args:
        db_manager: CPE資料庫管理器實例
        csv_file_path (str): 輸入CSV檔案路徑
        output_file_path (str, optional): 輸出檔案路徑。如果為None，會自動生成檔名

    Returns:
        str: 輸出檔案路徑
    """
    if not output_file_path:
        # 生成輸出檔名，包含時間戳記
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        output_file_path = f"search_results_{timestamp}.txt"

    # 統計搜尋資訊
    total_items = 0
    items_with_results = 0

    logger.info(f"開始從 {csv_file_path} 批次搜尋，結果將輸出到 {output_file_path}")

    try:
        with open(csv_file_path, 'r', encoding='utf-8') as csv_file, \
                open(output_file_path, 'w', encoding='utf-8') as output_file:

            # 寫入檔案標頭
            output_file.write(f"CPE資料庫搜尋結果 - 批次處理\n")
            output_file.write(f"輸入檔案: {csv_file_path}\n")
            output_file.write(
                f"處理時間: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            output_file.write(f"{'='*60}\n\n")

            # 讀取CSV
            csv_reader = csv.DictReader(csv_file)

            # 檢查CSV是否有必要的欄位
            required_fields = ['vendor', 'product', 'version']
            missing_fields = [
                field for field in required_fields if field not in csv_reader.fieldnames]
            if missing_fields:
                raise ValueError(f"CSV檔案缺少必要欄位: {', '.join(missing_fields)}")

            # 處理每一行
            for i, row in enumerate(csv_reader, 1):
                total_items += 1

                vendor = row.get('vendor', '').strip() or None
                product = row.get('product', '').strip() or None
                version = row.get('version', '').strip() or None

                # 如果所有欄位都是空的，跳過這一行
                if not any([vendor, product, version]):
                    logger.warning(f"第 {i} 行: 所有搜尋條件為空，跳過")
                    output_file.write(f"項目 {i}: 所有搜尋條件為空，跳過\n\n")
                    continue

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {i}:\n")
                output_file.write(f"  廠商: {vendor or '無'}\n")
                output_file.write(f"  產品: {product or '無'}\n")
                output_file.write(f"  版本: {version or '無'}\n\n")

                # 搜尋
                try:
                    results = db_manager.search(
                        vendor=vendor, product=product, version=version)
                    result_text = format_search_results(results)

                    # 檢查是否有搜尋結果
                    has_results = False
                    filtered_results = results.get('filtered_results', {})
                    if filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
                        has_results = True
                        items_with_results += 1

                    # 寫入搜尋結果
                    output_file.write(result_text)
                    output_file.write(f"\n{'='*60}\n\n")

                    # 記錄日誌
                    if has_results:
                        logger.info(
                            f"第 {i} 行: 搜尋成功，找到 {len(filtered_results['metadatas'][0])} 筆結果")
                    else:
                        logger.info(f"第 {i} 行: 搜尋成功，但沒有符合的結果")

                except Exception as e:
                    logger.error(f"第 {i} 行: 搜尋時發生錯誤: {str(e)}")
                    output_file.write(f"搜尋時發生錯誤: {str(e)}\n\n")
                    output_file.write(f"{'='*60}\n\n")

            # 寫入摘要
            output_file.write(f"批次搜尋摘要:\n")
            output_file.write(f"總項目數: {total_items}\n")
            output_file.write(f"有結果的項目數: {items_with_results}\n")
            output_file.write(f"無結果的項目數: {total_items - items_with_results}\n")

        logger.info(f"批次搜尋完成，共處理 {total_items} 項，{items_with_results} 項有結果")
        return output_file_path

    except Exception as e:
        logger.error(f"批次搜尋過程中發生錯誤: {str(e)}")
        raise


def main():
    # 設定檔案路徑
    file_path = "../data/convert/official-cpe-dictionary_v2.3_v2.json"

    try:
        use_gpu = False
        embedding_model = "default"
        logger.info("使用預設嵌入模型 (CPU)")

        # 初始化資料庫管理器
        db_manager = CPEDatabaseManager(
            use_gpu=use_gpu, embedding_model=embedding_model)

        # 匯入資料 (如果需要)
        import_data = input("是否要導入 CPE 資料？(y/n): ").strip().lower() == 'y'
        if import_data:
            reset = input("是否要重置現有集合？(y/n): ").strip().lower() == 'y'
            db_manager.import_data(file_path, reset_collection=reset)

        # 顯示更新後的集合資訊
        collection_info = db_manager.get_collection_info()
        print(f"\n更新後集合資訊:")
        print(f"名稱: {collection_info['name']}")
        print(f"項目數量: {collection_info['count']}")
        print(f"嵌入模型: {collection_info['embedding_model']}")
        print(f"使用裝置: {collection_info['device']}")

        # 選擇搜尋模式
        print("\n請選擇搜尋模式:")
        print("1. 單次搜尋")
        print("2. 從CSV檔案批次搜尋")

        mode = input("請選擇 (1-2): ").strip()

        if mode == "2":
            # 批次搜尋模式
            csv_file_path = input("請輸入CSV檔案路徑: ").strip()
            if not os.path.exists(csv_file_path):
                print(f"找不到檔案: {csv_file_path}")
                return

            output_path = batch_search_from_csv(db_manager, csv_file_path)
            print(f"\n批次搜尋完成! 結果已輸出至: {output_path}")

        else:
            # 單次搜尋模式 (預設)
            while True:
                print("\n請輸入搜尋條件 (直接按 Enter 跳過):")
                vendor = input("廠商名稱: ").strip() or None
                product = input("產品名稱: ").strip() or None
                version = input("版本號: ").strip() or None

                if not any([vendor, product, version]):
                    print("至少需要提供一個搜尋條件")
                    continue

                try:
                    results = db_manager.search(
                        vendor=vendor, product=product, version=version)
                    print(format_search_results(results))

                    if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                        break
                except Exception as e:
                    print(f"搜尋過程中發生錯誤: {str(e)}")
                    if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                        break

    except Exception as e:
        logger.error(f"程式執行時發生錯誤: {str(e)}")
        raise


if __name__ == "__main__":
    main()
# Out:
# 2025-03-13 02:21:20,532 - __main__ - INFO - 使用預設嵌入模型 (CPU)
# 2025-03-13 02:21:20,534 - __main__ - INFO - 使用嵌入模型: 預設
# 2025-03-13 02:21:20,541 - __main__ - INFO - 成功設定資料庫連接，儲存位置: ../database/cpe_database
# 2025-03-13 02:21:24,076 - __main__ - WARNING - 判斷嵌入模型類型時發生錯誤: isinstance() arg 2 must be a type, a tuple of types, or a union
# 更新後集合資訊:
# 名稱: cpe_dictionary
# 項目數量: 1377010
# 嵌入模型: Default
# 使用裝置: CPU
#
# 請選擇搜尋模式:
# 1. 單次搜尋
# 2. 從CSV檔案批次搜尋
# 2025-03-13 02:21:34,848 - __main__ - INFO - 開始從 ./transform_data.csv 批次搜尋，結果將輸出到 search_results_20250313_022134.txt
# 2025-03-13 02:21:35,051 - __main__ - INFO - 第 1 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,132 - __main__ - INFO - 第 2 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,198 - __main__ - INFO - 第 3 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,276 - __main__ - INFO - 第 4 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,332 - __main__ - INFO - 第 5 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,384 - __main__ - INFO - 第 6 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,441 - __main__ - INFO - 第 7 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,513 - __main__ - INFO - 第 8 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,584 - __main__ - INFO - 第 9 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,652 - __main__ - INFO - 第 10 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,707 - __main__ - INFO - 第 11 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,770 - __main__ - INFO - 第 12 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,839 - __main__ - INFO - 第 13 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,896 - __main__ - INFO - 第 14 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:35,981 - __main__ - INFO - 第 15 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,056 - __main__ - INFO - 第 16 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,117 - __main__ - INFO - 第 17 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,188 - __main__ - INFO - 第 18 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,254 - __main__ - INFO - 第 19 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,318 - __main__ - INFO - 第 20 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,383 - __main__ - INFO - 第 21 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,445 - __main__ - INFO - 第 22 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,516 - __main__ - INFO - 第 23 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,564 - __main__ - INFO - 第 24 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,635 - __main__ - INFO - 第 25 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,689 - __main__ - INFO - 第 26 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,744 - __main__ - INFO - 第 27 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,809 - __main__ - INFO - 第 28 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,880 - __main__ - INFO - 第 29 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:36,937 - __main__ - INFO - 第 30 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,009 - __main__ - INFO - 第 31 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,065 - __main__ - INFO - 第 32 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,101 - __main__ - INFO - 第 33 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,175 - __main__ - INFO - 第 34 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,243 - __main__ - INFO - 第 35 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,337 - __main__ - INFO - 第 36 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,403 - __main__ - INFO - 第 37 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,462 - __main__ - INFO - 第 38 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,517 - __main__ - INFO - 第 39 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,577 - __main__ - INFO - 第 40 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,622 - __main__ - INFO - 第 41 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,678 - __main__ - INFO - 第 42 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,728 - __main__ - INFO - 第 43 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,794 - __main__ - INFO - 第 44 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,851 - __main__ - INFO - 第 45 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,914 - __main__ - INFO - 第 46 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:37,976 - __main__ - INFO - 第 47 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,040 - __main__ - INFO - 第 48 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,103 - __main__ - INFO - 第 49 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,173 - __main__ - INFO - 第 50 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,246 - __main__ - INFO - 第 51 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,311 - __main__ - INFO - 第 52 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,376 - __main__ - INFO - 第 53 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,443 - __main__ - INFO - 第 54 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,508 - __main__ - INFO - 第 55 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,561 - __main__ - INFO - 第 56 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,623 - __main__ - INFO - 第 57 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,696 - __main__ - INFO - 第 58 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,778 - __main__ - INFO - 第 59 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,840 - __main__ - INFO - 第 60 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,892 - __main__ - INFO - 第 61 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:38,965 - __main__ - INFO - 第 62 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,028 - __main__ - INFO - 第 63 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,087 - __main__ - INFO - 第 64 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,159 - __main__ - INFO - 第 65 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,233 - __main__ - INFO - 第 66 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,294 - __main__ - INFO - 第 67 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,343 - __main__ - INFO - 第 68 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,411 - __main__ - INFO - 第 69 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,479 - __main__ - INFO - 第 70 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,540 - __main__ - INFO - 第 71 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,648 - __main__ - INFO - 第 72 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,692 - __main__ - INFO - 第 73 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,761 - __main__ - INFO - 第 74 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,833 - __main__ - INFO - 第 75 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,898 - __main__ - INFO - 第 76 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:39,953 - __main__ - INFO - 第 77 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,013 - __main__ - INFO - 第 78 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,085 - __main__ - INFO - 第 79 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,153 - __main__ - INFO - 第 80 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,214 - __main__ - INFO - 第 81 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,285 - __main__ - INFO - 第 82 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,344 - __main__ - INFO - 第 83 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,418 - __main__ - INFO - 第 84 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,481 - __main__ - INFO - 第 85 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,535 - __main__ - INFO - 第 86 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,611 - __main__ - INFO - 第 87 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,672 - __main__ - INFO - 第 88 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,749 - __main__ - INFO - 第 89 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,822 - __main__ - INFO - 第 90 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,880 - __main__ - INFO - 第 91 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:40,945 - __main__ - INFO - 第 92 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,006 - __main__ - INFO - 第 93 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,082 - __main__ - INFO - 第 94 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,148 - __main__ - INFO - 第 95 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,219 - __main__ - INFO - 第 96 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,268 - __main__ - INFO - 第 97 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,336 - __main__ - INFO - 第 98 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,398 - __main__ - INFO - 第 99 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,487 - __main__ - INFO - 第 100 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,567 - __main__ - INFO - 第 101 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,632 - __main__ - INFO - 第 102 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,696 - __main__ - INFO - 第 103 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,745 - __main__ - INFO - 第 104 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,800 - __main__ - INFO - 第 105 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:41,894 - __main__ - INFO - 第 106 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,002 - __main__ - INFO - 第 107 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,055 - __main__ - INFO - 第 108 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,131 - __main__ - INFO - 第 109 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,228 - __main__ - INFO - 第 110 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,305 - __main__ - INFO - 第 111 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,374 - __main__ - INFO - 第 112 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,455 - __main__ - INFO - 第 113 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,532 - __main__ - INFO - 第 114 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,597 - __main__ - INFO - 第 115 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,678 - __main__ - INFO - 第 116 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,778 - __main__ - INFO - 第 117 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,852 - __main__ - INFO - 第 118 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,911 - __main__ - INFO - 第 119 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:42,988 - __main__ - INFO - 第 120 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,037 - __main__ - INFO - 第 121 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,098 - __main__ - INFO - 第 122 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,167 - __main__ - INFO - 第 123 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,221 - __main__ - INFO - 第 124 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,293 - __main__ - INFO - 第 125 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,351 - __main__ - INFO - 第 126 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,419 - __main__ - INFO - 第 127 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,492 - __main__ - INFO - 第 128 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,544 - __main__ - INFO - 第 129 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,604 - __main__ - INFO - 第 130 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,678 - __main__ - INFO - 第 131 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,737 - __main__ - INFO - 第 132 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,794 - __main__ - INFO - 第 133 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,848 - __main__ - INFO - 第 134 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,888 - __main__ - INFO - 第 135 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,937 - __main__ - INFO - 第 136 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:43,981 - __main__ - INFO - 第 137 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,039 - __main__ - INFO - 第 138 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,113 - __main__ - INFO - 第 139 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,165 - __main__ - INFO - 第 140 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,226 - __main__ - INFO - 第 141 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,290 - __main__ - INFO - 第 142 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,346 - __main__ - INFO - 第 143 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,405 - __main__ - INFO - 第 144 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,456 - __main__ - INFO - 第 145 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,512 - __main__ - INFO - 第 146 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,579 - __main__ - INFO - 第 147 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,635 - __main__ - INFO - 第 148 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,700 - __main__ - INFO - 第 149 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,763 - __main__ - INFO - 第 150 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,827 - __main__ - INFO - 第 151 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,885 - __main__ - INFO - 第 152 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,906 - __main__ - INFO - 第 153 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:44,963 - __main__ - INFO - 第 154 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,019 - __main__ - INFO - 第 155 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,081 - __main__ - INFO - 第 156 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,139 - __main__ - INFO - 第 157 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,189 - __main__ - INFO - 第 158 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,242 - __main__ - INFO - 第 159 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,312 - __main__ - INFO - 第 160 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,379 - __main__ - INFO - 第 161 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,434 - __main__ - INFO - 第 162 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,495 - __main__ - INFO - 第 163 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,565 - __main__ - INFO - 第 164 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,624 - __main__ - INFO - 第 165 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,682 - __main__ - INFO - 第 166 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,738 - __main__ - INFO - 第 167 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,787 - __main__ - INFO - 第 168 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,851 - __main__ - INFO - 第 169 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,904 - __main__ - INFO - 第 170 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:45,987 - __main__ - INFO - 第 171 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,065 - __main__ - INFO - 第 172 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,129 - __main__ - INFO - 第 173 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,190 - __main__ - INFO - 第 174 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,241 - __main__ - INFO - 第 175 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,300 - __main__ - INFO - 第 176 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,356 - __main__ - INFO - 第 177 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,424 - __main__ - INFO - 第 178 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,478 - __main__ - INFO - 第 179 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,542 - __main__ - INFO - 第 180 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,598 - __main__ - INFO - 第 181 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,658 - __main__ - INFO - 第 182 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,758 - __main__ - INFO - 第 183 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,815 - __main__ - INFO - 第 184 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,891 - __main__ - INFO - 第 185 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:46,959 - __main__ - INFO - 第 186 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,032 - __main__ - INFO - 第 187 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,101 - __main__ - INFO - 第 188 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,175 - __main__ - INFO - 第 189 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,230 - __main__ - INFO - 第 190 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,294 - __main__ - INFO - 第 191 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,359 - __main__ - INFO - 第 192 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,414 - __main__ - INFO - 第 193 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,460 - __main__ - INFO - 第 194 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,517 - __main__ - INFO - 第 195 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,572 - __main__ - INFO - 第 196 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,639 - __main__ - INFO - 第 197 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,717 - __main__ - INFO - 第 198 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,760 - __main__ - INFO - 第 199 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,821 - __main__ - INFO - 第 200 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,892 - __main__ - INFO - 第 201 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,945 - __main__ - INFO - 第 202 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:47,997 - __main__ - INFO - 第 203 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,063 - __main__ - INFO - 第 204 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,122 - __main__ - INFO - 第 205 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,189 - __main__ - INFO - 第 206 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,253 - __main__ - INFO - 第 207 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,323 - __main__ - INFO - 第 208 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,378 - __main__ - INFO - 第 209 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,441 - __main__ - INFO - 第 210 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,498 - __main__ - INFO - 第 211 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,549 - __main__ - INFO - 第 212 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,604 - __main__ - INFO - 第 213 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,660 - __main__ - INFO - 第 214 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,724 - __main__ - INFO - 第 215 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,769 - __main__ - INFO - 第 216 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,828 - __main__ - INFO - 第 217 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,889 - __main__ - INFO - 第 218 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:48,952 - __main__ - INFO - 第 219 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,011 - __main__ - INFO - 第 220 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,085 - __main__ - INFO - 第 221 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,150 - __main__ - INFO - 第 222 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,204 - __main__ - INFO - 第 223 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,266 - __main__ - INFO - 第 224 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,321 - __main__ - INFO - 第 225 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,376 - __main__ - INFO - 第 226 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,443 - __main__ - INFO - 第 227 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,500 - __main__ - INFO - 第 228 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,562 - __main__ - INFO - 第 229 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,619 - __main__ - INFO - 第 230 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,679 - __main__ - INFO - 第 231 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,745 - __main__ - INFO - 第 232 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,803 - __main__ - INFO - 第 233 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,857 - __main__ - INFO - 第 234 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,909 - __main__ - INFO - 第 235 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:49,997 - __main__ - INFO - 第 236 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:50,055 - __main__ - INFO - 第 237 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:50,135 - __main__ - INFO - 第 238 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:50,190 - __main__ - INFO - 第 239 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 02:21:50,191 - __main__ - INFO - 批次搜尋完成，共處理 239 項，0 項有結果
# 批次搜尋完成! 結果已輸出至: search_results_20250313_022134.txt
