# %% [markdown]
# # CPE Format Converter (POC) example Jupyter Notebook
#
# This is a proof of concept for a CPE Format Converter.
#
# ## Description
#
# Due to time constraints, the construction logic and thought process of this Proof of Concept (PoC) will be initially presented in this Jupyter Notebook. Further development and maintenance will continue to implement more comprehensive functionalities, such as automation and a Web User Interface.
#
# > 由於時間限制，此概念驗證（PoC）的建構邏輯與思路將以本 Jupyter Notebook 的形式初步呈現。後續將持續進行開發與維護，以實現自動化、Web 使用者介面等更完善的功能。
#
# ## Design
#
# This Proof of Concept (PoC) aims to provide users with a tool to search for vulnerabilities associated with specific products by inputting Vendor, Product, and Version information. The tool will interact with the National Vulnerability Database (NVD) Common Vulnerabilities and Exposures (CVE) database to retrieve relevant CVE vulnerability data. Since the NVD Vulnerability API (CVE API) uses Common Platform Enumeration (CPE) for searching, user input needs to be converted into CPE format. However, while the CPE format has a standardized specification, there is no standard conversion process, and it cannot be guaranteed that the converted CPE is included in the NVD. To address this issue, we will use the NVD's CPE Directory List as a foundation to convert user input and obtain or generate the correct CPE, subsequently using the NVD Vulnerability API to retrieve further vulnerability data.
#
# > 本概念驗證（PoC）旨在提供使用者一個工具，透過輸入廠商（Vendor）、產品（Product）和版本（Version）資訊，搜尋相關產品的漏洞（Vulnerability）。此工具將與美國國家漏洞資料庫（NVD）的通用漏洞披露（CVE）資料庫互動，取得相關的 CVE 漏洞資訊。由於 NVD 的漏洞應用程式介面（CVE API）使用通用平台列舉（CPE）進行搜尋，因此需要將使用者輸入轉換為 CPE 格式。然而，儘管 CPE 格式具有標準化的規範，卻缺乏標準的轉換流程，且無法確定轉換後的 CPE 是否已被 NVD 收錄。為解決此問題，我們將利用 NVD 提供的 CPE 目錄列表（CPE Directory List）作為基礎，進行使用者輸入的轉換，並取得或產生正確的 CPE，進而使用 NVD 的漏洞應用程式介面取得後續的漏洞資料。
#
# ## Usage
#
# We will leverage the interactive features of Jupyter Notebook to provide detailed explanations of the operational process through segmented code, allowing users to reproduce the same operational results by executing this notebook. Please follow the subsequent operational instructions and code comments for adjustments and execution.
#
# > 我們將利用 Jupyter Notebook 的互動式特性，以分段程式碼的方式詳細說明操作流程，並允許使用者透過執行本 Notebook 複現相同的操作結果。請依照後續的操作說明與程式碼註解進行調整與執行。

# %% [markdown]
# ## Step 1: Get Offical CPE Directory List
#
# Please manually download the CPE Directory List from the official National Vulnerability Database (NVD) website and place the file in the `data` directory of the project repository (Repo). If you have any questions about the operation, please refer to the README file in the `data` directory.
#
# > 請手動自美國國家漏洞資料庫（NVD）官方網站下載 CPE 目錄列表（CPE Directory List），並將檔案放置於專案儲存庫（Repo）的 `data` 目錄中。若對操作方式有疑問，請參閱 `data` 目錄中的 README 檔案。

# %% [markdown]
# ## Step 2: Decompression and Data Pre-processing
#
# The Common Platform Enumeration (CPE) list provided by the National Vulnerability Database (NVD) is in XML format. While detailed and comprehensive, its structure is not ideal for direct import into Chromadb for subsequent operations. Therefore, we will filter and organize the XML content of the CPE list and output it in Comma-Separated Values (CSV) format.
#
# (Converting to CSV format is a non-essential transitional step, primarily to facilitate the review of the organized XML data and accelerate data utilization and analysis.)
#
# The resulting structured CSV data (or Dataframe) will be processed and imported into Chromadb in the subsequent steps.
#
#
# > 由於美國國家漏洞資料庫（NVD）提供的通用平台列舉（CPE）列表為 XML 格式，其結構雖詳盡完整，但不利於直接匯入 Chromadb 進行後續操作。因此，我們將對 CPE 列表的 XML 內容進行篩選與整理，並轉換為逗號分隔值（CSV）格式輸出。
# >
# > （轉換為 CSV 格式為一非必要的過渡步驟，主要目的是為了方便檢視整理後的 XML 資料，以加速資料的使用與分析。）
# >
# > 轉換後的 CSV 結構化資料（或 Dataframe）將於後續步驟中進行計算並匯入 Chromadb。

# %%
from lxml import etree
import json
import csv
import re
from typing import Dict, List, Iterator, Optional, Any, Set, Tuple
import logging
from pathlib import Path
from dataclasses import dataclass, asdict, field
from contextlib import contextmanager


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    normalized_vendor: str  # 新增標準化廠商名稱欄位
    product: str
    version: str
    title: str
    references: str
    variations: List[str] = field(default_factory=list)  # 存儲同一廠商的不同名稱變體


class CPEParser:
    """CPE XML 字典的分析器，用於將 CPE 項目轉換為結構化資料，並處理廠商名稱的標準化"""

    # CPE 命名空間定義
    NAMESPACES = {
        'cpe-23': 'http://scap.nist.gov/schema/cpe-extension/2.3',
        'def': 'http://cpe.mitre.org/dictionary/2.0',
        'xml': 'http://www.w3.org/XML/1998/namespace'
    }

    def __init__(self, xml_file_path: str):
        """初始化 CPE 分析器

        Args:
            xml_file_path (str): XML 檔案路徑
        """
        self.xml_file_path = Path(xml_file_path)
        self.logger = logging.getLogger(__name__)
        self.vendor_variations = {}  # 用於追蹤廠商名稱變體的字典
        self.vendor_canonical_forms = {}  # 用於存儲廠商名稱的標準形式

        if not self.xml_file_path.exists():
            raise FileNotFoundError(f"找不到 XML 檔案: {xml_file_path}")

    @staticmethod
    def normalize_vendor_name(vendor: str) -> str:
        """標準化廠商名稱，處理不同的分隔符號

        Args:
            vendor (str): 原始廠商名稱

        Returns:
            str: 標準化後的廠商名稱
        """
        # 將所有特殊分隔符號（如 '-' 和 '_'）統一替換為一種標準分隔符號
        # 這裡選擇使用 '_' 作為標準分隔符號
        normalized = re.sub(r'[-_]+', '_', vendor.lower())
        return normalized

    def track_vendor_variation(self, original: str, normalized: str) -> None:
        """追蹤廠商名稱的變體

        Args:
            original (str): 原始廠商名稱
            normalized (str): 標準化後的廠商名稱
        """
        if normalized not in self.vendor_variations:
            self.vendor_variations[normalized] = set()

        self.vendor_variations[normalized].add(original)

        # 如果這是我們第一次看到這個標準化廠商名稱，或者如果原始名稱比當前的標準形式更具代表性，
        # 則將其設為標準形式
        if normalized not in self.vendor_canonical_forms or len(original) < len(self.vendor_canonical_forms[normalized]):
            self.vendor_canonical_forms[normalized] = original

    @staticmethod
    def parse_cpe23_uri(cpe23uri: str) -> Dict[str, str]:
        """分析 CPE 2.3 URI 並提取各個組件

        Args:
            cpe23uri (str): CPE 2.3 URI 字串 (例如: cpe:2.3:a:vendor:product:version:...)

        Returns:
            Dict[str, str]: 包含廠商、產品和版本資訊的字典
        """
        # CPE 2.3 格式: cpe:2.3:part:vendor:product:version:update:edition:language:sw_edition:target_sw:target_hw:other
        components = cpe23uri.split(':')

        if len(components) < 6:
            return {"vendor": "", "product": "", "version": ""}

        return {
            'vendor': components[3],
            'product': components[4],
            'version': components[5]
        }

    @contextmanager
    def _open_xml_context(self) -> Iterator:
        """建立用於迭代 XML 檔案中 CPE 項目的上下文管理器

        Yields:
            Iterator: 用於迭代 XML 檔案中 CPE 項目的迭代器
        """
        try:
            context = etree.iterparse(
                str(self.xml_file_path),
                events=('end',),
                tag=f'{{{self.NAMESPACES["def"]}}}cpe-item'
            )
            yield context
        except etree.ParseError as e:
            self.logger.error(f"XML 分析錯誤: {e}")
            raise
        except Exception as e:
            self.logger.error(f"處理 XML 時發生未預期的錯誤: {e}")
            raise

    def _extract_item_data(self, item: etree._Element) -> Optional[CPEItem]:
        """從 XML 元素中提取 CPE 項目資料

        Args:
            item (etree._Element): 包含 CPE 項目資料的 XML 元素

        Returns:
            Optional[CPEItem]: 如果成功提取則返回 CPEItem 物件，否則返回 None
        """
        try:
            # 取得 CPE 2.3 URI
            cpe23_item = item.find('.//cpe-23:cpe23-item', self.NAMESPACES)
            if cpe23_item is None:
                return None

            cpe23uri = cpe23_item.get('name', '')
            if not cpe23uri:
                return None

            # 分析 CPE 組件
            cpe_components = self.parse_cpe23_uri(cpe23uri)

            # 取得並標準化廠商名稱
            original_vendor = cpe_components['vendor']
            normalized_vendor = self.normalize_vendor_name(original_vendor)

            # 追蹤廠商名稱變體
            self.track_vendor_variation(original_vendor, normalized_vendor)

            # 取得標題
            title_elem = item.find(
                './/def:title[@xml:lang="en-US"]', self.NAMESPACES)
            title = title_elem.text if title_elem is not None else ""

            # 取得參考資料
            references = self._extract_references(item)

            # 建立 CPE 項目物件
            return CPEItem(
                cpe22Uri=item.get('name', ''),
                cpe23Uri=cpe23uri,
                vendor=original_vendor,
                normalized_vendor=normalized_vendor,
                product=cpe_components['product'],
                version=cpe_components['version'],
                title=title,
                references=references
            )
        except Exception as e:
            self.logger.warning(f"提取 CPE 項目時發生錯誤: {e}")
            return None

    def _extract_references(self, item: etree._Element) -> str:
        """從 XML 元素中提取參考資料

        Args:
            item (etree._Element): 包含參考資料的 XML 元素

        Returns:
            str: 格式化的參考資料字串
        """
        refs = item.findall('.//def:reference', self.NAMESPACES)
        ref_texts = []

        for ref in refs:
            href = ref.get('href', '')
            ref_text = ref.text or ''

            if href and ref_text:
                ref_texts.append(f"{ref_text} ({href})")
            elif href:
                ref_texts.append(href)
            elif ref_text:
                ref_texts.append(ref_text)

        return ' '.join(ref_texts)

    def _clear_element_memory(self, item: etree._Element) -> None:
        """清理 XML 元素佔用的記憶體

        Args:
            item (etree._Element): 要清理的 XML 元素
        """
        item.clear()
        # 清理前面的同層級元素以釋放記憶體
        while item.getprevious() is not None:
            del item.getparent()[0]

    def parse_xml(self) -> List[Dict[str, Any]]:
        """分析整個 CPE XML 檔案

        Returns:
            List[Dict[str, Any]]: 分析後的 CPE 資料列表
        """
        self.logger.info(f"開始分析 XML 檔案: {self.xml_file_path}")
        cpe_items = []

        with self._open_xml_context() as context:
            for _, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    cpe_items.append(asdict(cpe_item))

                self._clear_element_memory(item)

        # 處理完所有項目後，添加廠商名稱的變體信息
        self._enrich_vendor_variations(cpe_items)

        self.logger.info(f"分析完成，共提取 {len(cpe_items)} 個 CPE 項目")
        return cpe_items

    def _enrich_vendor_variations(self, cpe_items: List[Dict[str, Any]]) -> None:
        """豐富 CPE 項目中的廠商變體信息

        Args:
            cpe_items (List[Dict[str, Any]]): CPE 項目列表
        """
        # 為每個項目添加該廠商的所有已知變體
        for item in cpe_items:
            normalized_vendor = item['normalized_vendor']
            item['variations'] = list(
                self.vendor_variations.get(normalized_vendor, []))

            # 使用標準形式替換原始廠商名稱
            if normalized_vendor in self.vendor_canonical_forms:
                item['canonical_vendor'] = self.vendor_canonical_forms[normalized_vendor]

    def process_by_chunk(self, chunk_size: int = 1000) -> Iterator[List[Dict[str, Any]]]:
        """使用分批處理方式處理大型 XML 檔案

        Args:
            chunk_size (int, optional): 每批處理的項目數量. 預設為 1000.

        Yields:
            List[Dict[str, Any]]: 每批處理的 CPE 項目列表
        """
        self.logger.info(f"開始分批處理 XML 檔案 (每批 {chunk_size} 個項目)")
        items = []
        total_processed = 0

        with self._open_xml_context() as context:
            for _, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    items.append(asdict(cpe_item))

                self._clear_element_memory(item)

                if len(items) >= chunk_size:
                    total_processed += len(items)
                    self.logger.debug(f"已處理 {total_processed} 個項目")
                    yield items
                    items = []

            # 處理剩餘項目
            if items:
                total_processed += len(items)
                self.logger.debug(f"已處理 {total_processed} 個項目")
                yield items

        self.logger.info(f"分批處理完成，總共處理 {total_processed} 個項目")

    def _save_data(self, output_file: str, data: List[Dict[str, Any]], save_func: callable) -> None:
        """通用資料儲存函數

        Args:
            output_file (str): 輸出檔案路徑
            data (List[Dict[str, Any]]): 要儲存的資料
            save_func (callable): 儲存函數
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            save_func(output_path, data)
            self.logger.info(f"已成功儲存 {len(data)} 個項目至檔案: {output_path}")
        except Exception as e:
            self.logger.error(f"儲存檔案時發生錯誤: {e}")
            raise

    def save_to_json(self, output_file: str, items: Optional[List[Dict[str, Any]]] = None) -> None:
        """將分析結果儲存為 JSON 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict[str, Any]]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        cpe_items = items if items is not None else self.parse_xml()

        def save_json(path: Path, data: List[Dict[str, Any]]) -> None:
            with open(path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

        self._save_data(output_file, cpe_items, save_json)

    def save_to_csv(self, output_file: str, items: Optional[List[Dict[str, Any]]] = None) -> None:
        """將分析結果儲存為 CSV 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict[str, Any]]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        cpe_items = items if items is not None else self.parse_xml()

        def save_csv(path: Path, data: List[Dict[str, Any]]) -> None:
            fieldnames = ['cpe22Uri', 'cpe23Uri', 'vendor', 'normalized_vendor', 'canonical_vendor',
                          'product', 'version', 'title', 'references', 'variations']
            with open(path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=fieldnames)
                writer.writeheader()
                for item in data:
                    # 確保變體列表被正確格式化為字串
                    if 'variations' in item and isinstance(item['variations'], list):
                        item['variations'] = ', '.join(item['variations'])
                    writer.writerow(item)

        self._save_data(output_file, cpe_items, save_csv)

    def save_vendor_variations(self, output_file: str) -> None:
        """儲存廠商名稱變體對照表

        Args:
            output_file (str): 輸出檔案路徑
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        # 建立廠商變體資料
        vendor_data = []
        for normalized, variations in self.vendor_variations.items():
            canonical = self.vendor_canonical_forms.get(normalized, normalized)
            vendor_data.append({
                'normalized_vendor': normalized,
                'canonical_vendor': canonical,
                'variations': list(variations)
            })

        # 依照正規化名稱排序
        vendor_data.sort(key=lambda x: x['normalized_vendor'])

        try:
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(vendor_data, f, ensure_ascii=False, indent=2)
            self.logger.info(
                f"已成功儲存 {len(vendor_data)} 個廠商變體資訊至檔案: {output_path}")
        except Exception as e:
            self.logger.error(f"儲存廠商變體檔案時發生錯誤: {e}")
            raise

    def analyze_vendor_variations(self) -> Dict[str, Any]:
        """分析廠商名稱變體統計資訊

        Returns:
            Dict[str, Any]: 包含廠商變體統計資訊的字典
        """
        # 計算有變體的廠商數量
        vendors_with_variations = sum(
            1 for variations in self.vendor_variations.values() if len(variations) > 1)

        # 找出變體最多的廠商
        max_variations = 0
        max_variations_vendor = None
        for normalized, variations in self.vendor_variations.items():
            if len(variations) > max_variations:
                max_variations = len(variations)
                max_variations_vendor = normalized

        # 構建分析結果
        analysis = {
            'total_vendors': len(self.vendor_variations),
            'vendors_with_variations': vendors_with_variations,
            'percentage_with_variations': round(vendors_with_variations / len(self.vendor_variations) * 100, 2) if self.vendor_variations else 0,
            'max_variations': max_variations,
            'max_variations_vendor': max_variations_vendor,
            'max_variations_list': list(self.vendor_variations.get(max_variations_vendor, [])) if max_variations_vendor else []
        }

        return analysis


def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = [logging.StreamHandler()]  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


def main():
    # 設定日誌
    log_file = "../logs/cpe_parser.log"
    setup_logging(log_level=logging.INFO, log_file=log_file)
    logger = logging.getLogger(__name__)

    # 設定檔案路徑
    input_file = "../data/official-cpe-dictionary_v2.3.xml"
    output_dir = Path("../data/convert")
    output_dir.mkdir(parents=True, exist_ok=True)

    output_json = output_dir / "official-cpe-dictionary_v2.3.json"
    output_csv = output_dir / "official-cpe-dictionary_v2.3.csv"
    vendor_variations_json = output_dir / "vendor_variations.json"

    try:
        logger.info(f"開始處理 CPE 字典檔案: {input_file}")
        parser = CPEParser(input_file)

        # 使用分批處理分析 XML 檔案並儲存結果
        all_items = []

        for chunk in parser.process_by_chunk(chunk_size=1000):
            all_items.extend(chunk)
            logger.info(f"已處理 {len(all_items)} 個項目")

        # 豐富廠商變體信息
        parser._enrich_vendor_variations(all_items)

        # 儲存為 JSON 和 CSV
        parser.save_to_json(str(output_json), all_items)
        parser.save_to_csv(str(output_csv), all_items)

        # 儲存廠商名稱變體對照表
        parser.save_vendor_variations(str(vendor_variations_json))

        # 輸出廠商變體分析結果
        vendor_analysis = parser.analyze_vendor_variations()
        logger.info(
            f"廠商變體分析結果: {json.dumps(vendor_analysis, ensure_ascii=False, indent=2)}")

        logger.info("程式執行完成")

    except FileNotFoundError as e:
        logger.error(f"找不到檔案: {e}")
    except Exception as e:
        logger.error(f"程式執行失敗: {e}", exc_info=True)


if __name__ == "__main__":
    main()
# Out:
# 2025-03-14 01:24:25,786 - __main__ - INFO - 開始處理 CPE 字典檔案: ../data/official-cpe-dictionary_v2.3.xml
# 2025-03-14 01:24:25,787 - __main__ - INFO - 開始分批處理 XML 檔案 (每批 1000 個項目)
# 2025-03-14 01:24:25,813 - __main__ - INFO - 已處理 1000 個項目
# 2025-03-14 01:24:25,832 - __main__ - INFO - 已處理 2000 個項目
# 2025-03-14 01:24:25,850 - __main__ - INFO - 已處理 3000 個項目
# 2025-03-14 01:24:25,893 - __main__ - INFO - 已處理 4000 個項目
# 2025-03-14 01:24:25,914 - __main__ - INFO - 已處理 5000 個項目
# 2025-03-14 01:24:25,934 - __main__ - INFO - 已處理 6000 個項目
# 2025-03-14 01:24:25,954 - __main__ - INFO - 已處理 7000 個項目
# 2025-03-14 01:24:25,973 - __main__ - INFO - 已處理 8000 個項目
# 2025-03-14 01:24:25,992 - __main__ - INFO - 已處理 9000 個項目
# 2025-03-14 01:24:26,010 - __main__ - INFO - 已處理 10000 個項目
# 2025-03-14 01:24:26,030 - __main__ - INFO - 已處理 11000 個項目
# 2025-03-14 01:24:26,048 - __main__ - INFO - 已處理 12000 個項目
# 2025-03-14 01:24:26,068 - __main__ - INFO - 已處理 13000 個項目
# 2025-03-14 01:24:26,088 - __main__ - INFO - 已處理 14000 個項目
# 2025-03-14 01:24:26,108 - __main__ - INFO - 已處理 15000 個項目
# 2025-03-14 01:24:26,127 - __main__ - INFO - 已處理 16000 個項目
# 2025-03-14 01:24:26,147 - __main__ - INFO - 已處理 17000 個項目
# 2025-03-14 01:24:26,166 - __main__ - INFO - 已處理 18000 個項目
# 2025-03-14 01:24:26,188 - __main__ - INFO - 已處理 19000 個項目
# 2025-03-14 01:24:26,208 - __main__ - INFO - 已處理 20000 個項目
# 2025-03-14 01:24:26,225 - __main__ - INFO - 已處理 21000 個項目
# 2025-03-14 01:24:26,245 - __main__ - INFO - 已處理 22000 個項目
# 2025-03-14 01:24:26,266 - __main__ - INFO - 已處理 23000 個項目
# 2025-03-14 01:24:26,310 - __main__ - INFO - 已處理 24000 個項目
# 2025-03-14 01:24:26,330 - __main__ - INFO - 已處理 25000 個項目
# 2025-03-14 01:24:26,348 - __main__ - INFO - 已處理 26000 個項目
# 2025-03-14 01:24:26,369 - __main__ - INFO - 已處理 27000 個項目
# 2025-03-14 01:24:26,389 - __main__ - INFO - 已處理 28000 個項目
# 2025-03-14 01:24:26,408 - __main__ - INFO - 已處理 29000 個項目
# 2025-03-14 01:24:26,427 - __main__ - INFO - 已處理 30000 個項目
# 2025-03-14 01:24:26,447 - __main__ - INFO - 已處理 31000 個項目
# 2025-03-14 01:24:26,467 - __main__ - INFO - 已處理 32000 個項目
# 2025-03-14 01:24:26,485 - __main__ - INFO - 已處理 33000 個項目
# 2025-03-14 01:24:26,504 - __main__ - INFO - 已處理 34000 個項目
# 2025-03-14 01:24:26,524 - __main__ - INFO - 已處理 35000 個項目
# 2025-03-14 01:24:26,543 - __main__ - INFO - 已處理 36000 個項目
# 2025-03-14 01:24:26,566 - __main__ - INFO - 已處理 37000 個項目
# 2025-03-14 01:24:26,588 - __main__ - INFO - 已處理 38000 個項目
# 2025-03-14 01:24:26,607 - __main__ - INFO - 已處理 39000 個項目
# 2025-03-14 01:24:26,627 - __main__ - INFO - 已處理 40000 個項目
# 2025-03-14 01:24:26,647 - __main__ - INFO - 已處理 41000 個項目
# 2025-03-14 01:24:26,665 - __main__ - INFO - 已處理 42000 個項目
# 2025-03-14 01:24:26,684 - __main__ - INFO - 已處理 43000 個項目
# 2025-03-14 01:24:26,705 - __main__ - INFO - 已處理 44000 個項目
# 2025-03-14 01:24:26,724 - __main__ - INFO - 已處理 45000 個項目
# 2025-03-14 01:24:26,744 - __main__ - INFO - 已處理 46000 個項目
# 2025-03-14 01:24:26,762 - __main__ - INFO - 已處理 47000 個項目
# 2025-03-14 01:24:26,783 - __main__ - INFO - 已處理 48000 個項目
# 2025-03-14 01:24:26,802 - __main__ - INFO - 已處理 49000 個項目
# 2025-03-14 01:24:26,822 - __main__ - INFO - 已處理 50000 個項目
# 2025-03-14 01:24:26,843 - __main__ - INFO - 已處理 51000 個項目
# 2025-03-14 01:24:26,863 - __main__ - INFO - 已處理 52000 個項目
# 2025-03-14 01:24:26,882 - __main__ - INFO - 已處理 53000 個項目
# 2025-03-14 01:24:26,901 - __main__ - INFO - 已處理 54000 個項目
# 2025-03-14 01:24:26,921 - __main__ - INFO - 已處理 55000 個項目
# 2025-03-14 01:24:26,939 - __main__ - INFO - 已處理 56000 個項目
# 2025-03-14 01:24:26,959 - __main__ - INFO - 已處理 57000 個項目
# 2025-03-14 01:24:26,979 - __main__ - INFO - 已處理 58000 個項目
# 2025-03-14 01:24:26,996 - __main__ - INFO - 已處理 59000 個項目
# 2025-03-14 01:24:27,017 - __main__ - INFO - 已處理 60000 個項目
# 2025-03-14 01:24:27,037 - __main__ - INFO - 已處理 61000 個項目
# 2025-03-14 01:24:27,055 - __main__ - INFO - 已處理 62000 個項目
# 2025-03-14 01:24:27,074 - __main__ - INFO - 已處理 63000 個項目
# 2025-03-14 01:24:27,093 - __main__ - INFO - 已處理 64000 個項目
# 2025-03-14 01:24:27,111 - __main__ - INFO - 已處理 65000 個項目
# 2025-03-14 01:24:27,131 - __main__ - INFO - 已處理 66000 個項目
# 2025-03-14 01:24:27,150 - __main__ - INFO - 已處理 67000 個項目
# 2025-03-14 01:24:27,168 - __main__ - INFO - 已處理 68000 個項目
# 2025-03-14 01:24:27,188 - __main__ - INFO - 已處理 69000 個項目
# 2025-03-14 01:24:27,244 - __main__ - INFO - 已處理 70000 個項目
# 2025-03-14 01:24:27,262 - __main__ - INFO - 已處理 71000 個項目
# 2025-03-14 01:24:27,282 - __main__ - INFO - 已處理 72000 個項目
# 2025-03-14 01:24:27,304 - __main__ - INFO - 已處理 73000 個項目
# 2025-03-14 01:24:27,323 - __main__ - INFO - 已處理 74000 個項目
# 2025-03-14 01:24:27,341 - __main__ - INFO - 已處理 75000 個項目
# 2025-03-14 01:24:27,359 - __main__ - INFO - 已處理 76000 個項目
# 2025-03-14 01:24:27,375 - __main__ - INFO - 已處理 77000 個項目
# 2025-03-14 01:24:27,423 - __main__ - INFO - 已處理 78000 個項目
# 2025-03-14 01:24:27,443 - __main__ - INFO - 已處理 79000 個項目
# 2025-03-14 01:24:27,461 - __main__ - INFO - 已處理 80000 個項目
# 2025-03-14 01:24:27,481 - __main__ - INFO - 已處理 81000 個項目
# 2025-03-14 01:24:27,500 - __main__ - INFO - 已處理 82000 個項目
# 2025-03-14 01:24:27,520 - __main__ - INFO - 已處理 83000 個項目
# 2025-03-14 01:24:27,542 - __main__ - INFO - 已處理 84000 個項目
# 2025-03-14 01:24:27,562 - __main__ - INFO - 已處理 85000 個項目
# 2025-03-14 01:24:27,583 - __main__ - INFO - 已處理 86000 個項目
# 2025-03-14 01:24:27,603 - __main__ - INFO - 已處理 87000 個項目
# 2025-03-14 01:24:27,622 - __main__ - INFO - 已處理 88000 個項目
# 2025-03-14 01:24:27,642 - __main__ - INFO - 已處理 89000 個項目
# 2025-03-14 01:24:27,661 - __main__ - INFO - 已處理 90000 個項目
# 2025-03-14 01:24:27,680 - __main__ - INFO - 已處理 91000 個項目
# 2025-03-14 01:24:27,701 - __main__ - INFO - 已處理 92000 個項目
# 2025-03-14 01:24:27,722 - __main__ - INFO - 已處理 93000 個項目
# 2025-03-14 01:24:27,741 - __main__ - INFO - 已處理 94000 個項目
# 2025-03-14 01:24:27,765 - __main__ - INFO - 已處理 95000 個項目
# 2025-03-14 01:24:27,788 - __main__ - INFO - 已處理 96000 個項目
# 2025-03-14 01:24:27,806 - __main__ - INFO - 已處理 97000 個項目
# 2025-03-14 01:24:27,825 - __main__ - INFO - 已處理 98000 個項目
# 2025-03-14 01:24:27,844 - __main__ - INFO - 已處理 99000 個項目
# 2025-03-14 01:24:27,863 - __main__ - INFO - 已處理 100000 個項目
# 2025-03-14 01:24:27,883 - __main__ - INFO - 已處理 101000 個項目
# 2025-03-14 01:24:27,901 - __main__ - INFO - 已處理 102000 個項目
# 2025-03-14 01:24:27,921 - __main__ - INFO - 已處理 103000 個項目
# 2025-03-14 01:24:27,939 - __main__ - INFO - 已處理 104000 個項目
# 2025-03-14 01:24:27,959 - __main__ - INFO - 已處理 105000 個項目
# 2025-03-14 01:24:27,978 - __main__ - INFO - 已處理 106000 個項目
# 2025-03-14 01:24:27,998 - __main__ - INFO - 已處理 107000 個項目
# 2025-03-14 01:24:28,018 - __main__ - INFO - 已處理 108000 個項目
# 2025-03-14 01:24:28,036 - __main__ - INFO - 已處理 109000 個項目
# 2025-03-14 01:24:28,056 - __main__ - INFO - 已處理 110000 個項目
# 2025-03-14 01:24:28,075 - __main__ - INFO - 已處理 111000 個項目
# 2025-03-14 01:24:28,097 - __main__ - INFO - 已處理 112000 個項目
# 2025-03-14 01:24:28,115 - __main__ - INFO - 已處理 113000 個項目
# 2025-03-14 01:24:28,136 - __main__ - INFO - 已處理 114000 個項目
# 2025-03-14 01:24:28,157 - __main__ - INFO - 已處理 115000 個項目
# 2025-03-14 01:24:28,225 - __main__ - INFO - 已處理 116000 個項目
# 2025-03-14 01:24:28,244 - __main__ - INFO - 已處理 117000 個項目
# 2025-03-14 01:24:28,264 - __main__ - INFO - 已處理 118000 個項目
# 2025-03-14 01:24:28,284 - __main__ - INFO - 已處理 119000 個項目
# 2025-03-14 01:24:28,303 - __main__ - INFO - 已處理 120000 個項目
# 2025-03-14 01:24:28,321 - __main__ - INFO - 已處理 121000 個項目
# 2025-03-14 01:24:28,340 - __main__ - INFO - 已處理 122000 個項目
# 2025-03-14 01:24:28,359 - __main__ - INFO - 已處理 123000 個項目
# 2025-03-14 01:24:28,378 - __main__ - INFO - 已處理 124000 個項目
# 2025-03-14 01:24:28,399 - __main__ - INFO - 已處理 125000 個項目
# 2025-03-14 01:24:28,420 - __main__ - INFO - 已處理 126000 個項目
# 2025-03-14 01:24:28,439 - __main__ - INFO - 已處理 127000 個項目
# 2025-03-14 01:24:28,458 - __main__ - INFO - 已處理 128000 個項目
# 2025-03-14 01:24:28,476 - __main__ - INFO - 已處理 129000 個項目
# 2025-03-14 01:24:28,495 - __main__ - INFO - 已處理 130000 個項目
# 2025-03-14 01:24:28,514 - __main__ - INFO - 已處理 131000 個項目
# 2025-03-14 01:24:28,533 - __main__ - INFO - 已處理 132000 個項目
# 2025-03-14 01:24:28,550 - __main__ - INFO - 已處理 133000 個項目
# 2025-03-14 01:24:28,568 - __main__ - INFO - 已處理 134000 個項目
# 2025-03-14 01:24:28,588 - __main__ - INFO - 已處理 135000 個項目
# 2025-03-14 01:24:28,607 - __main__ - INFO - 已處理 136000 個項目
# 2025-03-14 01:24:28,627 - __main__ - INFO - 已處理 137000 個項目
# 2025-03-14 01:24:28,645 - __main__ - INFO - 已處理 138000 個項目
# 2025-03-14 01:24:28,664 - __main__ - INFO - 已處理 139000 個項目
# 2025-03-14 01:24:28,682 - __main__ - INFO - 已處理 140000 個項目
# 2025-03-14 01:24:28,701 - __main__ - INFO - 已處理 141000 個項目
# 2025-03-14 01:24:28,719 - __main__ - INFO - 已處理 142000 個項目
# 2025-03-14 01:24:28,738 - __main__ - INFO - 已處理 143000 個項目
# 2025-03-14 01:24:28,759 - __main__ - INFO - 已處理 144000 個項目
# 2025-03-14 01:24:28,777 - __main__ - INFO - 已處理 145000 個項目
# 2025-03-14 01:24:28,796 - __main__ - INFO - 已處理 146000 個項目
# 2025-03-14 01:24:28,815 - __main__ - INFO - 已處理 147000 個項目
# 2025-03-14 01:24:28,837 - __main__ - INFO - 已處理 148000 個項目
# 2025-03-14 01:24:28,855 - __main__ - INFO - 已處理 149000 個項目
# 2025-03-14 01:24:28,875 - __main__ - INFO - 已處理 150000 個項目
# 2025-03-14 01:24:28,894 - __main__ - INFO - 已處理 151000 個項目
# 2025-03-14 01:24:28,912 - __main__ - INFO - 已處理 152000 個項目
# 2025-03-14 01:24:28,931 - __main__ - INFO - 已處理 153000 個項目
# 2025-03-14 01:24:28,950 - __main__ - INFO - 已處理 154000 個項目
# 2025-03-14 01:24:28,969 - __main__ - INFO - 已處理 155000 個項目
# 2025-03-14 01:24:28,987 - __main__ - INFO - 已處理 156000 個項目
# 2025-03-14 01:24:29,005 - __main__ - INFO - 已處理 157000 個項目
# 2025-03-14 01:24:29,023 - __main__ - INFO - 已處理 158000 個項目
# 2025-03-14 01:24:29,043 - __main__ - INFO - 已處理 159000 個項目
# 2025-03-14 01:24:29,062 - __main__ - INFO - 已處理 160000 個項目
# 2025-03-14 01:24:29,140 - __main__ - INFO - 已處理 161000 個項目
# 2025-03-14 01:24:29,157 - __main__ - INFO - 已處理 162000 個項目
# 2025-03-14 01:24:29,177 - __main__ - INFO - 已處理 163000 個項目
# 2025-03-14 01:24:29,195 - __main__ - INFO - 已處理 164000 個項目
# 2025-03-14 01:24:29,215 - __main__ - INFO - 已處理 165000 個項目
# 2025-03-14 01:24:29,234 - __main__ - INFO - 已處理 166000 個項目
# 2025-03-14 01:24:29,253 - __main__ - INFO - 已處理 167000 個項目
# 2025-03-14 01:24:29,272 - __main__ - INFO - 已處理 168000 個項目
# 2025-03-14 01:24:29,289 - __main__ - INFO - 已處理 169000 個項目
# 2025-03-14 01:24:29,308 - __main__ - INFO - 已處理 170000 個項目
# 2025-03-14 01:24:29,327 - __main__ - INFO - 已處理 171000 個項目
# 2025-03-14 01:24:29,347 - __main__ - INFO - 已處理 172000 個項目
# 2025-03-14 01:24:29,364 - __main__ - INFO - 已處理 173000 個項目
# 2025-03-14 01:24:29,383 - __main__ - INFO - 已處理 174000 個項目
# 2025-03-14 01:24:29,404 - __main__ - INFO - 已處理 175000 個項目
# 2025-03-14 01:24:29,422 - __main__ - INFO - 已處理 176000 個項目
# 2025-03-14 01:24:29,441 - __main__ - INFO - 已處理 177000 個項目
# 2025-03-14 01:24:29,461 - __main__ - INFO - 已處理 178000 個項目
# 2025-03-14 01:24:29,480 - __main__ - INFO - 已處理 179000 個項目
# 2025-03-14 01:24:29,498 - __main__ - INFO - 已處理 180000 個項目
# 2025-03-14 01:24:29,517 - __main__ - INFO - 已處理 181000 個項目
# 2025-03-14 01:24:29,535 - __main__ - INFO - 已處理 182000 個項目
# 2025-03-14 01:24:29,554 - __main__ - INFO - 已處理 183000 個項目
# 2025-03-14 01:24:29,571 - __main__ - INFO - 已處理 184000 個項目
# 2025-03-14 01:24:29,590 - __main__ - INFO - 已處理 185000 個項目
# 2025-03-14 01:24:29,608 - __main__ - INFO - 已處理 186000 個項目
# 2025-03-14 01:24:29,625 - __main__ - INFO - 已處理 187000 個項目
# 2025-03-14 01:24:29,642 - __main__ - INFO - 已處理 188000 個項目
# 2025-03-14 01:24:29,660 - __main__ - INFO - 已處理 189000 個項目
# 2025-03-14 01:24:29,678 - __main__ - INFO - 已處理 190000 個項目
# 2025-03-14 01:24:29,697 - __main__ - INFO - 已處理 191000 個項目
# 2025-03-14 01:24:29,715 - __main__ - INFO - 已處理 192000 個項目
# 2025-03-14 01:24:29,736 - __main__ - INFO - 已處理 193000 個項目
# 2025-03-14 01:24:29,755 - __main__ - INFO - 已處理 194000 個項目
# 2025-03-14 01:24:29,774 - __main__ - INFO - 已處理 195000 個項目
# 2025-03-14 01:24:29,793 - __main__ - INFO - 已處理 196000 個項目
# 2025-03-14 01:24:29,812 - __main__ - INFO - 已處理 197000 個項目
# 2025-03-14 01:24:29,831 - __main__ - INFO - 已處理 198000 個項目
# 2025-03-14 01:24:29,849 - __main__ - INFO - 已處理 199000 個項目
# 2025-03-14 01:24:29,867 - __main__ - INFO - 已處理 200000 個項目
# 2025-03-14 01:24:29,887 - __main__ - INFO - 已處理 201000 個項目
# 2025-03-14 01:24:29,905 - __main__ - INFO - 已處理 202000 個項目
# 2025-03-14 01:24:29,923 - __main__ - INFO - 已處理 203000 個項目
# 2025-03-14 01:24:29,944 - __main__ - INFO - 已處理 204000 個項目
# 2025-03-14 01:24:29,961 - __main__ - INFO - 已處理 205000 個項目
# 2025-03-14 01:24:29,979 - __main__ - INFO - 已處理 206000 個項目
# 2025-03-14 01:24:29,995 - __main__ - INFO - 已處理 207000 個項目
# 2025-03-14 01:24:30,014 - __main__ - INFO - 已處理 208000 個項目
# 2025-03-14 01:24:30,032 - __main__ - INFO - 已處理 209000 個項目
# 2025-03-14 01:24:30,078 - __main__ - INFO - 已處理 210000 個項目
# 2025-03-14 01:24:30,174 - __main__ - INFO - 已處理 211000 個項目
# 2025-03-14 01:24:30,194 - __main__ - INFO - 已處理 212000 個項目
# 2025-03-14 01:24:30,213 - __main__ - INFO - 已處理 213000 個項目
# 2025-03-14 01:24:30,231 - __main__ - INFO - 已處理 214000 個項目
# 2025-03-14 01:24:30,250 - __main__ - INFO - 已處理 215000 個項目
# 2025-03-14 01:24:30,269 - __main__ - INFO - 已處理 216000 個項目
# 2025-03-14 01:24:30,288 - __main__ - INFO - 已處理 217000 個項目
# 2025-03-14 01:24:30,306 - __main__ - INFO - 已處理 218000 個項目
# 2025-03-14 01:24:30,324 - __main__ - INFO - 已處理 219000 個項目
# 2025-03-14 01:24:30,342 - __main__ - INFO - 已處理 220000 個項目
# 2025-03-14 01:24:30,360 - __main__ - INFO - 已處理 221000 個項目
# 2025-03-14 01:24:30,379 - __main__ - INFO - 已處理 222000 個項目
# 2025-03-14 01:24:30,397 - __main__ - INFO - 已處理 223000 個項目
# 2025-03-14 01:24:30,415 - __main__ - INFO - 已處理 224000 個項目
# 2025-03-14 01:24:30,433 - __main__ - INFO - 已處理 225000 個項目
# 2025-03-14 01:24:30,451 - __main__ - INFO - 已處理 226000 個項目
# 2025-03-14 01:24:30,470 - __main__ - INFO - 已處理 227000 個項目
# 2025-03-14 01:24:30,490 - __main__ - INFO - 已處理 228000 個項目
# 2025-03-14 01:24:30,507 - __main__ - INFO - 已處理 229000 個項目
# 2025-03-14 01:24:30,525 - __main__ - INFO - 已處理 230000 個項目
# 2025-03-14 01:24:30,547 - __main__ - INFO - 已處理 231000 個項目
# 2025-03-14 01:24:30,566 - __main__ - INFO - 已處理 232000 個項目
# 2025-03-14 01:24:30,585 - __main__ - INFO - 已處理 233000 個項目
# 2025-03-14 01:24:30,604 - __main__ - INFO - 已處理 234000 個項目
# 2025-03-14 01:24:30,624 - __main__ - INFO - 已處理 235000 個項目
# 2025-03-14 01:24:30,643 - __main__ - INFO - 已處理 236000 個項目
# 2025-03-14 01:24:30,665 - __main__ - INFO - 已處理 237000 個項目
# 2025-03-14 01:24:30,685 - __main__ - INFO - 已處理 238000 個項目
# 2025-03-14 01:24:30,706 - __main__ - INFO - 已處理 239000 個項目
# 2025-03-14 01:24:30,724 - __main__ - INFO - 已處理 240000 個項目
# 2025-03-14 01:24:30,743 - __main__ - INFO - 已處理 241000 個項目
# 2025-03-14 01:24:30,763 - __main__ - INFO - 已處理 242000 個項目
# 2025-03-14 01:24:30,783 - __main__ - INFO - 已處理 243000 個項目
# 2025-03-14 01:24:30,803 - __main__ - INFO - 已處理 244000 個項目
# 2025-03-14 01:24:30,822 - __main__ - INFO - 已處理 245000 個項目
# 2025-03-14 01:24:30,841 - __main__ - INFO - 已處理 246000 個項目
# 2025-03-14 01:24:30,861 - __main__ - INFO - 已處理 247000 個項目
# 2025-03-14 01:24:30,882 - __main__ - INFO - 已處理 248000 個項目
# 2025-03-14 01:24:30,901 - __main__ - INFO - 已處理 249000 個項目
# 2025-03-14 01:24:30,921 - __main__ - INFO - 已處理 250000 個項目
# 2025-03-14 01:24:30,941 - __main__ - INFO - 已處理 251000 個項目
# 2025-03-14 01:24:30,964 - __main__ - INFO - 已處理 252000 個項目
# 2025-03-14 01:24:30,982 - __main__ - INFO - 已處理 253000 個項目
# 2025-03-14 01:24:31,002 - __main__ - INFO - 已處理 254000 個項目
# 2025-03-14 01:24:31,022 - __main__ - INFO - 已處理 255000 個項目
# 2025-03-14 01:24:31,041 - __main__ - INFO - 已處理 256000 個項目
# 2025-03-14 01:24:31,060 - __main__ - INFO - 已處理 257000 個項目
# 2025-03-14 01:24:31,079 - __main__ - INFO - 已處理 258000 個項目
# 2025-03-14 01:24:31,099 - __main__ - INFO - 已處理 259000 個項目
# 2025-03-14 01:24:31,118 - __main__ - INFO - 已處理 260000 個項目
# 2025-03-14 01:24:31,137 - __main__ - INFO - 已處理 261000 個項目
# 2025-03-14 01:24:31,157 - __main__ - INFO - 已處理 262000 個項目
# 2025-03-14 01:24:31,174 - __main__ - INFO - 已處理 263000 個項目
# 2025-03-14 01:24:31,194 - __main__ - INFO - 已處理 264000 個項目
# 2025-03-14 01:24:31,212 - __main__ - INFO - 已處理 265000 個項目
# 2025-03-14 01:24:31,232 - __main__ - INFO - 已處理 266000 個項目
# 2025-03-14 01:24:31,251 - __main__ - INFO - 已處理 267000 個項目
# 2025-03-14 01:24:31,270 - __main__ - INFO - 已處理 268000 個項目
# 2025-03-14 01:24:31,290 - __main__ - INFO - 已處理 269000 個項目
# 2025-03-14 01:24:31,311 - __main__ - INFO - 已處理 270000 個項目
# 2025-03-14 01:24:31,329 - __main__ - INFO - 已處理 271000 個項目
# 2025-03-14 01:24:31,349 - __main__ - INFO - 已處理 272000 個項目
# 2025-03-14 01:24:31,462 - __main__ - INFO - 已處理 273000 個項目
# 2025-03-14 01:24:31,482 - __main__ - INFO - 已處理 274000 個項目
# 2025-03-14 01:24:31,501 - __main__ - INFO - 已處理 275000 個項目
# 2025-03-14 01:24:31,520 - __main__ - INFO - 已處理 276000 個項目
# 2025-03-14 01:24:31,539 - __main__ - INFO - 已處理 277000 個項目
# 2025-03-14 01:24:31,557 - __main__ - INFO - 已處理 278000 個項目
# 2025-03-14 01:24:31,575 - __main__ - INFO - 已處理 279000 個項目
# 2025-03-14 01:24:31,594 - __main__ - INFO - 已處理 280000 個項目
# 2025-03-14 01:24:31,612 - __main__ - INFO - 已處理 281000 個項目
# 2025-03-14 01:24:31,630 - __main__ - INFO - 已處理 282000 個項目
# 2025-03-14 01:24:31,649 - __main__ - INFO - 已處理 283000 個項目
# 2025-03-14 01:24:31,669 - __main__ - INFO - 已處理 284000 個項目
# 2025-03-14 01:24:31,688 - __main__ - INFO - 已處理 285000 個項目
# 2025-03-14 01:24:31,707 - __main__ - INFO - 已處理 286000 個項目
# 2025-03-14 01:24:31,725 - __main__ - INFO - 已處理 287000 個項目
# 2025-03-14 01:24:31,744 - __main__ - INFO - 已處理 288000 個項目
# 2025-03-14 01:24:31,762 - __main__ - INFO - 已處理 289000 個項目
# 2025-03-14 01:24:31,780 - __main__ - INFO - 已處理 290000 個項目
# 2025-03-14 01:24:31,799 - __main__ - INFO - 已處理 291000 個項目
# 2025-03-14 01:24:31,817 - __main__ - INFO - 已處理 292000 個項目
# 2025-03-14 01:24:31,836 - __main__ - INFO - 已處理 293000 個項目
# 2025-03-14 01:24:31,854 - __main__ - INFO - 已處理 294000 個項目
# 2025-03-14 01:24:31,872 - __main__ - INFO - 已處理 295000 個項目
# 2025-03-14 01:24:31,890 - __main__ - INFO - 已處理 296000 個項目
# 2025-03-14 01:24:31,911 - __main__ - INFO - 已處理 297000 個項目
# 2025-03-14 01:24:31,929 - __main__ - INFO - 已處理 298000 個項目
# 2025-03-14 01:24:31,948 - __main__ - INFO - 已處理 299000 個項目
# 2025-03-14 01:24:31,966 - __main__ - INFO - 已處理 300000 個項目
# 2025-03-14 01:24:31,986 - __main__ - INFO - 已處理 301000 個項目
# 2025-03-14 01:24:32,006 - __main__ - INFO - 已處理 302000 個項目
# 2025-03-14 01:24:32,023 - __main__ - INFO - 已處理 303000 個項目
# 2025-03-14 01:24:32,042 - __main__ - INFO - 已處理 304000 個項目
# 2025-03-14 01:24:32,065 - __main__ - INFO - 已處理 305000 個項目
# 2025-03-14 01:24:32,087 - __main__ - INFO - 已處理 306000 個項目
# 2025-03-14 01:24:32,105 - __main__ - INFO - 已處理 307000 個項目
# 2025-03-14 01:24:32,124 - __main__ - INFO - 已處理 308000 個項目
# 2025-03-14 01:24:32,142 - __main__ - INFO - 已處理 309000 個項目
# 2025-03-14 01:24:32,160 - __main__ - INFO - 已處理 310000 個項目
# 2025-03-14 01:24:32,179 - __main__ - INFO - 已處理 311000 個項目
# 2025-03-14 01:24:32,197 - __main__ - INFO - 已處理 312000 個項目
# 2025-03-14 01:24:32,215 - __main__ - INFO - 已處理 313000 個項目
# 2025-03-14 01:24:32,235 - __main__ - INFO - 已處理 314000 個項目
# 2025-03-14 01:24:32,254 - __main__ - INFO - 已處理 315000 個項目
# 2025-03-14 01:24:32,272 - __main__ - INFO - 已處理 316000 個項目
# 2025-03-14 01:24:32,290 - __main__ - INFO - 已處理 317000 個項目
# 2025-03-14 01:24:32,309 - __main__ - INFO - 已處理 318000 個項目
# 2025-03-14 01:24:32,328 - __main__ - INFO - 已處理 319000 個項目
# 2025-03-14 01:24:32,347 - __main__ - INFO - 已處理 320000 個項目
# 2025-03-14 01:24:32,366 - __main__ - INFO - 已處理 321000 個項目
# 2025-03-14 01:24:32,385 - __main__ - INFO - 已處理 322000 個項目
# 2025-03-14 01:24:32,404 - __main__ - INFO - 已處理 323000 個項目
# 2025-03-14 01:24:32,423 - __main__ - INFO - 已處理 324000 個項目
# 2025-03-14 01:24:32,442 - __main__ - INFO - 已處理 325000 個項目
# 2025-03-14 01:24:32,462 - __main__ - INFO - 已處理 326000 個項目
# 2025-03-14 01:24:32,481 - __main__ - INFO - 已處理 327000 個項目
# 2025-03-14 01:24:32,499 - __main__ - INFO - 已處理 328000 個項目
# 2025-03-14 01:24:32,518 - __main__ - INFO - 已處理 329000 個項目
# 2025-03-14 01:24:32,537 - __main__ - INFO - 已處理 330000 個項目
# 2025-03-14 01:24:32,558 - __main__ - INFO - 已處理 331000 個項目
# 2025-03-14 01:24:32,577 - __main__ - INFO - 已處理 332000 個項目
# 2025-03-14 01:24:32,598 - __main__ - INFO - 已處理 333000 個項目
# 2025-03-14 01:24:32,618 - __main__ - INFO - 已處理 334000 個項目
# 2025-03-14 01:24:32,637 - __main__ - INFO - 已處理 335000 個項目
# 2025-03-14 01:24:32,655 - __main__ - INFO - 已處理 336000 個項目
# 2025-03-14 01:24:32,674 - __main__ - INFO - 已處理 337000 個項目
# 2025-03-14 01:24:32,693 - __main__ - INFO - 已處理 338000 個項目
# 2025-03-14 01:24:32,712 - __main__ - INFO - 已處理 339000 個項目
# 2025-03-14 01:24:32,734 - __main__ - INFO - 已處理 340000 個項目
# 2025-03-14 01:24:32,757 - __main__ - INFO - 已處理 341000 個項目
# 2025-03-14 01:24:32,776 - __main__ - INFO - 已處理 342000 個項目
# 2025-03-14 01:24:32,795 - __main__ - INFO - 已處理 343000 個項目
# 2025-03-14 01:24:32,814 - __main__ - INFO - 已處理 344000 個項目
# 2025-03-14 01:24:32,832 - __main__ - INFO - 已處理 345000 個項目
# 2025-03-14 01:24:32,850 - __main__ - INFO - 已處理 346000 個項目
# 2025-03-14 01:24:32,870 - __main__ - INFO - 已處理 347000 個項目
# 2025-03-14 01:24:32,888 - __main__ - INFO - 已處理 348000 個項目
# 2025-03-14 01:24:32,907 - __main__ - INFO - 已處理 349000 個項目
# 2025-03-14 01:24:32,925 - __main__ - INFO - 已處理 350000 個項目
# 2025-03-14 01:24:32,943 - __main__ - INFO - 已處理 351000 個項目
# 2025-03-14 01:24:33,077 - __main__ - INFO - 已處理 352000 個項目
# 2025-03-14 01:24:33,095 - __main__ - INFO - 已處理 353000 個項目
# 2025-03-14 01:24:33,114 - __main__ - INFO - 已處理 354000 個項目
# 2025-03-14 01:24:33,137 - __main__ - INFO - 已處理 355000 個項目
# 2025-03-14 01:24:33,156 - __main__ - INFO - 已處理 356000 個項目
# 2025-03-14 01:24:33,175 - __main__ - INFO - 已處理 357000 個項目
# 2025-03-14 01:24:33,193 - __main__ - INFO - 已處理 358000 個項目
# 2025-03-14 01:24:33,213 - __main__ - INFO - 已處理 359000 個項目
# 2025-03-14 01:24:33,232 - __main__ - INFO - 已處理 360000 個項目
# 2025-03-14 01:24:33,252 - __main__ - INFO - 已處理 361000 個項目
# 2025-03-14 01:24:33,270 - __main__ - INFO - 已處理 362000 個項目
# 2025-03-14 01:24:33,289 - __main__ - INFO - 已處理 363000 個項目
# 2025-03-14 01:24:33,309 - __main__ - INFO - 已處理 364000 個項目
# 2025-03-14 01:24:33,328 - __main__ - INFO - 已處理 365000 個項目
# 2025-03-14 01:24:33,347 - __main__ - INFO - 已處理 366000 個項目
# 2025-03-14 01:24:33,366 - __main__ - INFO - 已處理 367000 個項目
# 2025-03-14 01:24:33,411 - __main__ - INFO - 已處理 368000 個項目
# 2025-03-14 01:24:33,433 - __main__ - INFO - 已處理 369000 個項目
# 2025-03-14 01:24:33,452 - __main__ - INFO - 已處理 370000 個項目
# 2025-03-14 01:24:33,471 - __main__ - INFO - 已處理 371000 個項目
# 2025-03-14 01:24:33,489 - __main__ - INFO - 已處理 372000 個項目
# 2025-03-14 01:24:33,507 - __main__ - INFO - 已處理 373000 個項目
# 2025-03-14 01:24:33,527 - __main__ - INFO - 已處理 374000 個項目
# 2025-03-14 01:24:33,545 - __main__ - INFO - 已處理 375000 個項目
# 2025-03-14 01:24:33,564 - __main__ - INFO - 已處理 376000 個項目
# 2025-03-14 01:24:33,582 - __main__ - INFO - 已處理 377000 個項目
# 2025-03-14 01:24:33,602 - __main__ - INFO - 已處理 378000 個項目
# 2025-03-14 01:24:33,623 - __main__ - INFO - 已處理 379000 個項目
# 2025-03-14 01:24:33,643 - __main__ - INFO - 已處理 380000 個項目
# 2025-03-14 01:24:33,662 - __main__ - INFO - 已處理 381000 個項目
# 2025-03-14 01:24:33,680 - __main__ - INFO - 已處理 382000 個項目
# 2025-03-14 01:24:33,698 - __main__ - INFO - 已處理 383000 個項目
# 2025-03-14 01:24:33,719 - __main__ - INFO - 已處理 384000 個項目
# 2025-03-14 01:24:33,738 - __main__ - INFO - 已處理 385000 個項目
# 2025-03-14 01:24:33,758 - __main__ - INFO - 已處理 386000 個項目
# 2025-03-14 01:24:33,777 - __main__ - INFO - 已處理 387000 個項目
# 2025-03-14 01:24:33,799 - __main__ - INFO - 已處理 388000 個項目
# 2025-03-14 01:24:33,819 - __main__ - INFO - 已處理 389000 個項目
# 2025-03-14 01:24:33,839 - __main__ - INFO - 已處理 390000 個項目
# 2025-03-14 01:24:33,859 - __main__ - INFO - 已處理 391000 個項目
# 2025-03-14 01:24:33,879 - __main__ - INFO - 已處理 392000 個項目
# 2025-03-14 01:24:33,900 - __main__ - INFO - 已處理 393000 個項目
# 2025-03-14 01:24:33,920 - __main__ - INFO - 已處理 394000 個項目
# 2025-03-14 01:24:33,939 - __main__ - INFO - 已處理 395000 個項目
# 2025-03-14 01:24:33,958 - __main__ - INFO - 已處理 396000 個項目
# 2025-03-14 01:24:33,976 - __main__ - INFO - 已處理 397000 個項目
# 2025-03-14 01:24:33,995 - __main__ - INFO - 已處理 398000 個項目
# 2025-03-14 01:24:34,013 - __main__ - INFO - 已處理 399000 個項目
# 2025-03-14 01:24:34,031 - __main__ - INFO - 已處理 400000 個項目
# 2025-03-14 01:24:34,050 - __main__ - INFO - 已處理 401000 個項目
# 2025-03-14 01:24:34,068 - __main__ - INFO - 已處理 402000 個項目
# 2025-03-14 01:24:34,085 - __main__ - INFO - 已處理 403000 個項目
# 2025-03-14 01:24:34,104 - __main__ - INFO - 已處理 404000 個項目
# 2025-03-14 01:24:34,123 - __main__ - INFO - 已處理 405000 個項目
# 2025-03-14 01:24:34,145 - __main__ - INFO - 已處理 406000 個項目
# 2025-03-14 01:24:34,163 - __main__ - INFO - 已處理 407000 個項目
# 2025-03-14 01:24:34,183 - __main__ - INFO - 已處理 408000 個項目
# 2025-03-14 01:24:34,201 - __main__ - INFO - 已處理 409000 個項目
# 2025-03-14 01:24:34,221 - __main__ - INFO - 已處理 410000 個項目
# 2025-03-14 01:24:34,241 - __main__ - INFO - 已處理 411000 個項目
# 2025-03-14 01:24:34,259 - __main__ - INFO - 已處理 412000 個項目
# 2025-03-14 01:24:34,277 - __main__ - INFO - 已處理 413000 個項目
# 2025-03-14 01:24:34,298 - __main__ - INFO - 已處理 414000 個項目
# 2025-03-14 01:24:34,317 - __main__ - INFO - 已處理 415000 個項目
# 2025-03-14 01:24:34,336 - __main__ - INFO - 已處理 416000 個項目
# 2025-03-14 01:24:34,355 - __main__ - INFO - 已處理 417000 個項目
# 2025-03-14 01:24:34,374 - __main__ - INFO - 已處理 418000 個項目
# 2025-03-14 01:24:34,392 - __main__ - INFO - 已處理 419000 個項目
# 2025-03-14 01:24:34,411 - __main__ - INFO - 已處理 420000 個項目
# 2025-03-14 01:24:34,430 - __main__ - INFO - 已處理 421000 個項目
# 2025-03-14 01:24:34,449 - __main__ - INFO - 已處理 422000 個項目
# 2025-03-14 01:24:34,467 - __main__ - INFO - 已處理 423000 個項目
# 2025-03-14 01:24:34,486 - __main__ - INFO - 已處理 424000 個項目
# 2025-03-14 01:24:34,505 - __main__ - INFO - 已處理 425000 個項目
# 2025-03-14 01:24:34,524 - __main__ - INFO - 已處理 426000 個項目
# 2025-03-14 01:24:34,544 - __main__ - INFO - 已處理 427000 個項目
# 2025-03-14 01:24:34,564 - __main__ - INFO - 已處理 428000 個項目
# 2025-03-14 01:24:34,582 - __main__ - INFO - 已處理 429000 個項目
# 2025-03-14 01:24:34,601 - __main__ - INFO - 已處理 430000 個項目
# 2025-03-14 01:24:34,619 - __main__ - INFO - 已處理 431000 個項目
# 2025-03-14 01:24:34,637 - __main__ - INFO - 已處理 432000 個項目
# 2025-03-14 01:24:34,653 - __main__ - INFO - 已處理 433000 個項目
# 2025-03-14 01:24:34,673 - __main__ - INFO - 已處理 434000 個項目
# 2025-03-14 01:24:34,691 - __main__ - INFO - 已處理 435000 個項目
# 2025-03-14 01:24:34,708 - __main__ - INFO - 已處理 436000 個項目
# 2025-03-14 01:24:34,726 - __main__ - INFO - 已處理 437000 個項目
# 2025-03-14 01:24:34,745 - __main__ - INFO - 已處理 438000 個項目
# 2025-03-14 01:24:34,764 - __main__ - INFO - 已處理 439000 個項目
# 2025-03-14 01:24:34,783 - __main__ - INFO - 已處理 440000 個項目
# 2025-03-14 01:24:34,801 - __main__ - INFO - 已處理 441000 個項目
# 2025-03-14 01:24:34,818 - __main__ - INFO - 已處理 442000 個項目
# 2025-03-14 01:24:34,835 - __main__ - INFO - 已處理 443000 個項目
# 2025-03-14 01:24:34,852 - __main__ - INFO - 已處理 444000 個項目
# 2025-03-14 01:24:34,869 - __main__ - INFO - 已處理 445000 個項目
# 2025-03-14 01:24:34,887 - __main__ - INFO - 已處理 446000 個項目
# 2025-03-14 01:24:34,904 - __main__ - INFO - 已處理 447000 個項目
# 2025-03-14 01:24:35,098 - __main__ - INFO - 已處理 448000 個項目
# 2025-03-14 01:24:35,116 - __main__ - INFO - 已處理 449000 個項目
# 2025-03-14 01:24:35,133 - __main__ - INFO - 已處理 450000 個項目
# 2025-03-14 01:24:35,152 - __main__ - INFO - 已處理 451000 個項目
# 2025-03-14 01:24:35,170 - __main__ - INFO - 已處理 452000 個項目
# 2025-03-14 01:24:35,186 - __main__ - INFO - 已處理 453000 個項目
# 2025-03-14 01:24:35,204 - __main__ - INFO - 已處理 454000 個項目
# 2025-03-14 01:24:35,228 - __main__ - INFO - 已處理 455000 個項目
# 2025-03-14 01:24:35,247 - __main__ - INFO - 已處理 456000 個項目
# 2025-03-14 01:24:35,266 - __main__ - INFO - 已處理 457000 個項目
# 2025-03-14 01:24:35,286 - __main__ - INFO - 已處理 458000 個項目
# 2025-03-14 01:24:35,302 - __main__ - INFO - 已處理 459000 個項目
# 2025-03-14 01:24:35,318 - __main__ - INFO - 已處理 460000 個項目
# 2025-03-14 01:24:35,335 - __main__ - INFO - 已處理 461000 個項目
# 2025-03-14 01:24:35,351 - __main__ - INFO - 已處理 462000 個項目
# 2025-03-14 01:24:35,367 - __main__ - INFO - 已處理 463000 個項目
# 2025-03-14 01:24:35,385 - __main__ - INFO - 已處理 464000 個項目
# 2025-03-14 01:24:35,402 - __main__ - INFO - 已處理 465000 個項目
# 2025-03-14 01:24:35,418 - __main__ - INFO - 已處理 466000 個項目
# 2025-03-14 01:24:35,434 - __main__ - INFO - 已處理 467000 個項目
# 2025-03-14 01:24:35,450 - __main__ - INFO - 已處理 468000 個項目
# 2025-03-14 01:24:35,469 - __main__ - INFO - 已處理 469000 個項目
# 2025-03-14 01:24:35,488 - __main__ - INFO - 已處理 470000 個項目
# 2025-03-14 01:24:35,508 - __main__ - INFO - 已處理 471000 個項目
# 2025-03-14 01:24:35,526 - __main__ - INFO - 已處理 472000 個項目
# 2025-03-14 01:24:35,546 - __main__ - INFO - 已處理 473000 個項目
# 2025-03-14 01:24:35,566 - __main__ - INFO - 已處理 474000 個項目
# 2025-03-14 01:24:35,584 - __main__ - INFO - 已處理 475000 個項目
# 2025-03-14 01:24:35,604 - __main__ - INFO - 已處理 476000 個項目
# 2025-03-14 01:24:35,623 - __main__ - INFO - 已處理 477000 個項目
# 2025-03-14 01:24:35,642 - __main__ - INFO - 已處理 478000 個項目
# 2025-03-14 01:24:35,661 - __main__ - INFO - 已處理 479000 個項目
# 2025-03-14 01:24:35,681 - __main__ - INFO - 已處理 480000 個項目
# 2025-03-14 01:24:35,701 - __main__ - INFO - 已處理 481000 個項目
# 2025-03-14 01:24:35,721 - __main__ - INFO - 已處理 482000 個項目
# 2025-03-14 01:24:35,741 - __main__ - INFO - 已處理 483000 個項目
# 2025-03-14 01:24:35,760 - __main__ - INFO - 已處理 484000 個項目
# 2025-03-14 01:24:35,779 - __main__ - INFO - 已處理 485000 個項目
# 2025-03-14 01:24:35,799 - __main__ - INFO - 已處理 486000 個項目
# 2025-03-14 01:24:35,819 - __main__ - INFO - 已處理 487000 個項目
# 2025-03-14 01:24:35,839 - __main__ - INFO - 已處理 488000 個項目
# 2025-03-14 01:24:35,859 - __main__ - INFO - 已處理 489000 個項目
# 2025-03-14 01:24:35,882 - __main__ - INFO - 已處理 490000 個項目
# 2025-03-14 01:24:35,900 - __main__ - INFO - 已處理 491000 個項目
# 2025-03-14 01:24:35,919 - __main__ - INFO - 已處理 492000 個項目
# 2025-03-14 01:24:35,939 - __main__ - INFO - 已處理 493000 個項目
# 2025-03-14 01:24:35,959 - __main__ - INFO - 已處理 494000 個項目
# 2025-03-14 01:24:35,979 - __main__ - INFO - 已處理 495000 個項目
# 2025-03-14 01:24:35,998 - __main__ - INFO - 已處理 496000 個項目
# 2025-03-14 01:24:36,016 - __main__ - INFO - 已處理 497000 個項目
# 2025-03-14 01:24:36,036 - __main__ - INFO - 已處理 498000 個項目
# 2025-03-14 01:24:36,055 - __main__ - INFO - 已處理 499000 個項目
# 2025-03-14 01:24:36,075 - __main__ - INFO - 已處理 500000 個項目
# 2025-03-14 01:24:36,092 - __main__ - INFO - 已處理 501000 個項目
# 2025-03-14 01:24:36,111 - __main__ - INFO - 已處理 502000 個項目
# 2025-03-14 01:24:36,131 - __main__ - INFO - 已處理 503000 個項目
# 2025-03-14 01:24:36,149 - __main__ - INFO - 已處理 504000 個項目
# 2025-03-14 01:24:36,167 - __main__ - INFO - 已處理 505000 個項目
# 2025-03-14 01:24:36,186 - __main__ - INFO - 已處理 506000 個項目
# 2025-03-14 01:24:36,205 - __main__ - INFO - 已處理 507000 個項目
# 2025-03-14 01:24:36,225 - __main__ - INFO - 已處理 508000 個項目
# 2025-03-14 01:24:36,242 - __main__ - INFO - 已處理 509000 個項目
# 2025-03-14 01:24:36,261 - __main__ - INFO - 已處理 510000 個項目
# 2025-03-14 01:24:36,281 - __main__ - INFO - 已處理 511000 個項目
# 2025-03-14 01:24:36,300 - __main__ - INFO - 已處理 512000 個項目
# 2025-03-14 01:24:36,319 - __main__ - INFO - 已處理 513000 個項目
# 2025-03-14 01:24:36,339 - __main__ - INFO - 已處理 514000 個項目
# 2025-03-14 01:24:36,357 - __main__ - INFO - 已處理 515000 個項目
# 2025-03-14 01:24:36,376 - __main__ - INFO - 已處理 516000 個項目
# 2025-03-14 01:24:36,394 - __main__ - INFO - 已處理 517000 個項目
# 2025-03-14 01:24:36,413 - __main__ - INFO - 已處理 518000 個項目
# 2025-03-14 01:24:36,432 - __main__ - INFO - 已處理 519000 個項目
# 2025-03-14 01:24:36,449 - __main__ - INFO - 已處理 520000 個項目
# 2025-03-14 01:24:36,466 - __main__ - INFO - 已處理 521000 個項目
# 2025-03-14 01:24:36,485 - __main__ - INFO - 已處理 522000 個項目
# 2025-03-14 01:24:36,503 - __main__ - INFO - 已處理 523000 個項目
# 2025-03-14 01:24:36,521 - __main__ - INFO - 已處理 524000 個項目
# 2025-03-14 01:24:36,539 - __main__ - INFO - 已處理 525000 個項目
# 2025-03-14 01:24:36,558 - __main__ - INFO - 已處理 526000 個項目
# 2025-03-14 01:24:36,575 - __main__ - INFO - 已處理 527000 個項目
# 2025-03-14 01:24:36,593 - __main__ - INFO - 已處理 528000 個項目
# 2025-03-14 01:24:36,611 - __main__ - INFO - 已處理 529000 個項目
# 2025-03-14 01:24:36,628 - __main__ - INFO - 已處理 530000 個項目
# 2025-03-14 01:24:36,650 - __main__ - INFO - 已處理 531000 個項目
# 2025-03-14 01:24:36,667 - __main__ - INFO - 已處理 532000 個項目
# 2025-03-14 01:24:36,686 - __main__ - INFO - 已處理 533000 個項目
# 2025-03-14 01:24:36,705 - __main__ - INFO - 已處理 534000 個項目
# 2025-03-14 01:24:36,724 - __main__ - INFO - 已處理 535000 個項目
# 2025-03-14 01:24:36,745 - __main__ - INFO - 已處理 536000 個項目
# 2025-03-14 01:24:36,764 - __main__ - INFO - 已處理 537000 個項目
# 2025-03-14 01:24:36,783 - __main__ - INFO - 已處理 538000 個項目
# 2025-03-14 01:24:36,801 - __main__ - INFO - 已處理 539000 個項目
# 2025-03-14 01:24:36,820 - __main__ - INFO - 已處理 540000 個項目
# 2025-03-14 01:24:36,837 - __main__ - INFO - 已處理 541000 個項目
# 2025-03-14 01:24:36,857 - __main__ - INFO - 已處理 542000 個項目
# 2025-03-14 01:24:36,877 - __main__ - INFO - 已處理 543000 個項目
# 2025-03-14 01:24:36,896 - __main__ - INFO - 已處理 544000 個項目
# 2025-03-14 01:24:36,916 - __main__ - INFO - 已處理 545000 個項目
# 2025-03-14 01:24:36,935 - __main__ - INFO - 已處理 546000 個項目
# 2025-03-14 01:24:36,954 - __main__ - INFO - 已處理 547000 個項目
# 2025-03-14 01:24:36,973 - __main__ - INFO - 已處理 548000 個項目
# 2025-03-14 01:24:36,991 - __main__ - INFO - 已處理 549000 個項目
# 2025-03-14 01:24:37,010 - __main__ - INFO - 已處理 550000 個項目
# 2025-03-14 01:24:37,030 - __main__ - INFO - 已處理 551000 個項目
# 2025-03-14 01:24:37,047 - __main__ - INFO - 已處理 552000 個項目
# 2025-03-14 01:24:37,064 - __main__ - INFO - 已處理 553000 個項目
# 2025-03-14 01:24:37,083 - __main__ - INFO - 已處理 554000 個項目
# 2025-03-14 01:24:37,100 - __main__ - INFO - 已處理 555000 個項目
# 2025-03-14 01:24:37,119 - __main__ - INFO - 已處理 556000 個項目
# 2025-03-14 01:24:37,139 - __main__ - INFO - 已處理 557000 個項目
# 2025-03-14 01:24:37,158 - __main__ - INFO - 已處理 558000 個項目
# 2025-03-14 01:24:37,177 - __main__ - INFO - 已處理 559000 個項目
# 2025-03-14 01:24:37,196 - __main__ - INFO - 已處理 560000 個項目
# 2025-03-14 01:24:37,215 - __main__ - INFO - 已處理 561000 個項目
# 2025-03-14 01:24:37,232 - __main__ - INFO - 已處理 562000 個項目
# 2025-03-14 01:24:37,252 - __main__ - INFO - 已處理 563000 個項目
# 2025-03-14 01:24:37,271 - __main__ - INFO - 已處理 564000 個項目
# 2025-03-14 01:24:37,292 - __main__ - INFO - 已處理 565000 個項目
# 2025-03-14 01:24:37,312 - __main__ - INFO - 已處理 566000 個項目
# 2025-03-14 01:24:37,331 - __main__ - INFO - 已處理 567000 個項目
# 2025-03-14 01:24:37,349 - __main__ - INFO - 已處理 568000 個項目
# 2025-03-14 01:24:37,370 - __main__ - INFO - 已處理 569000 個項目
# 2025-03-14 01:24:37,562 - __main__ - INFO - 已處理 570000 個項目
# 2025-03-14 01:24:37,578 - __main__ - INFO - 已處理 571000 個項目
# 2025-03-14 01:24:37,597 - __main__ - INFO - 已處理 572000 個項目
# 2025-03-14 01:24:37,619 - __main__ - INFO - 已處理 573000 個項目
# 2025-03-14 01:24:37,638 - __main__ - INFO - 已處理 574000 個項目
# 2025-03-14 01:24:37,660 - __main__ - INFO - 已處理 575000 個項目
# 2025-03-14 01:24:37,678 - __main__ - INFO - 已處理 576000 個項目
# 2025-03-14 01:24:37,697 - __main__ - INFO - 已處理 577000 個項目
# 2025-03-14 01:24:37,716 - __main__ - INFO - 已處理 578000 個項目
# 2025-03-14 01:24:37,735 - __main__ - INFO - 已處理 579000 個項目
# 2025-03-14 01:24:37,753 - __main__ - INFO - 已處理 580000 個項目
# 2025-03-14 01:24:37,772 - __main__ - INFO - 已處理 581000 個項目
# 2025-03-14 01:24:37,793 - __main__ - INFO - 已處理 582000 個項目
# 2025-03-14 01:24:37,818 - __main__ - INFO - 已處理 583000 個項目
# 2025-03-14 01:24:37,854 - __main__ - INFO - 已處理 584000 個項目
# 2025-03-14 01:24:37,874 - __main__ - INFO - 已處理 585000 個項目
# 2025-03-14 01:24:37,894 - __main__ - INFO - 已處理 586000 個項目
# 2025-03-14 01:24:37,912 - __main__ - INFO - 已處理 587000 個項目
# 2025-03-14 01:24:37,930 - __main__ - INFO - 已處理 588000 個項目
# 2025-03-14 01:24:37,948 - __main__ - INFO - 已處理 589000 個項目
# 2025-03-14 01:24:37,967 - __main__ - INFO - 已處理 590000 個項目
# 2025-03-14 01:24:37,986 - __main__ - INFO - 已處理 591000 個項目
# 2025-03-14 01:24:38,005 - __main__ - INFO - 已處理 592000 個項目
# 2025-03-14 01:24:38,024 - __main__ - INFO - 已處理 593000 個項目
# 2025-03-14 01:24:38,043 - __main__ - INFO - 已處理 594000 個項目
# 2025-03-14 01:24:38,062 - __main__ - INFO - 已處理 595000 個項目
# 2025-03-14 01:24:38,081 - __main__ - INFO - 已處理 596000 個項目
# 2025-03-14 01:24:38,101 - __main__ - INFO - 已處理 597000 個項目
# 2025-03-14 01:24:38,122 - __main__ - INFO - 已處理 598000 個項目
# 2025-03-14 01:24:38,141 - __main__ - INFO - 已處理 599000 個項目
# 2025-03-14 01:24:38,160 - __main__ - INFO - 已處理 600000 個項目
# 2025-03-14 01:24:38,178 - __main__ - INFO - 已處理 601000 個項目
# 2025-03-14 01:24:38,200 - __main__ - INFO - 已處理 602000 個項目
# 2025-03-14 01:24:38,217 - __main__ - INFO - 已處理 603000 個項目
# 2025-03-14 01:24:38,235 - __main__ - INFO - 已處理 604000 個項目
# 2025-03-14 01:24:38,257 - __main__ - INFO - 已處理 605000 個項目
# 2025-03-14 01:24:38,277 - __main__ - INFO - 已處理 606000 個項目
# 2025-03-14 01:24:38,296 - __main__ - INFO - 已處理 607000 個項目
# 2025-03-14 01:24:38,315 - __main__ - INFO - 已處理 608000 個項目
# 2025-03-14 01:24:38,334 - __main__ - INFO - 已處理 609000 個項目
# 2025-03-14 01:24:38,353 - __main__ - INFO - 已處理 610000 個項目
# 2025-03-14 01:24:38,370 - __main__ - INFO - 已處理 611000 個項目
# 2025-03-14 01:24:38,388 - __main__ - INFO - 已處理 612000 個項目
# 2025-03-14 01:24:38,407 - __main__ - INFO - 已處理 613000 個項目
# 2025-03-14 01:24:38,425 - __main__ - INFO - 已處理 614000 個項目
# 2025-03-14 01:24:38,444 - __main__ - INFO - 已處理 615000 個項目
# 2025-03-14 01:24:38,466 - __main__ - INFO - 已處理 616000 個項目
# 2025-03-14 01:24:38,487 - __main__ - INFO - 已處理 617000 個項目
# 2025-03-14 01:24:38,505 - __main__ - INFO - 已處理 618000 個項目
# 2025-03-14 01:24:38,524 - __main__ - INFO - 已處理 619000 個項目
# 2025-03-14 01:24:38,542 - __main__ - INFO - 已處理 620000 個項目
# 2025-03-14 01:24:38,561 - __main__ - INFO - 已處理 621000 個項目
# 2025-03-14 01:24:38,578 - __main__ - INFO - 已處理 622000 個項目
# 2025-03-14 01:24:38,597 - __main__ - INFO - 已處理 623000 個項目
# 2025-03-14 01:24:38,616 - __main__ - INFO - 已處理 624000 個項目
# 2025-03-14 01:24:38,634 - __main__ - INFO - 已處理 625000 個項目
# 2025-03-14 01:24:38,653 - __main__ - INFO - 已處理 626000 個項目
# 2025-03-14 01:24:38,672 - __main__ - INFO - 已處理 627000 個項目
# 2025-03-14 01:24:38,692 - __main__ - INFO - 已處理 628000 個項目
# 2025-03-14 01:24:38,710 - __main__ - INFO - 已處理 629000 個項目
# 2025-03-14 01:24:38,730 - __main__ - INFO - 已處理 630000 個項目
# 2025-03-14 01:24:38,750 - __main__ - INFO - 已處理 631000 個項目
# 2025-03-14 01:24:38,770 - __main__ - INFO - 已處理 632000 個項目
# 2025-03-14 01:24:38,789 - __main__ - INFO - 已處理 633000 個項目
# 2025-03-14 01:24:38,809 - __main__ - INFO - 已處理 634000 個項目
# 2025-03-14 01:24:38,828 - __main__ - INFO - 已處理 635000 個項目
# 2025-03-14 01:24:38,849 - __main__ - INFO - 已處理 636000 個項目
# 2025-03-14 01:24:38,867 - __main__ - INFO - 已處理 637000 個項目
# 2025-03-14 01:24:38,886 - __main__ - INFO - 已處理 638000 個項目
# 2025-03-14 01:24:38,908 - __main__ - INFO - 已處理 639000 個項目
# 2025-03-14 01:24:38,927 - __main__ - INFO - 已處理 640000 個項目
# 2025-03-14 01:24:38,946 - __main__ - INFO - 已處理 641000 個項目
# 2025-03-14 01:24:38,965 - __main__ - INFO - 已處理 642000 個項目
# 2025-03-14 01:24:38,984 - __main__ - INFO - 已處理 643000 個項目
# 2025-03-14 01:24:39,002 - __main__ - INFO - 已處理 644000 個項目
# 2025-03-14 01:24:39,023 - __main__ - INFO - 已處理 645000 個項目
# 2025-03-14 01:24:39,041 - __main__ - INFO - 已處理 646000 個項目
# 2025-03-14 01:24:39,061 - __main__ - INFO - 已處理 647000 個項目
# 2025-03-14 01:24:39,081 - __main__ - INFO - 已處理 648000 個項目
# 2025-03-14 01:24:39,100 - __main__ - INFO - 已處理 649000 個項目
# 2025-03-14 01:24:39,120 - __main__ - INFO - 已處理 650000 個項目
# 2025-03-14 01:24:39,138 - __main__ - INFO - 已處理 651000 個項目
# 2025-03-14 01:24:39,156 - __main__ - INFO - 已處理 652000 個項目
# 2025-03-14 01:24:39,176 - __main__ - INFO - 已處理 653000 個項目
# 2025-03-14 01:24:39,194 - __main__ - INFO - 已處理 654000 個項目
# 2025-03-14 01:24:39,212 - __main__ - INFO - 已處理 655000 個項目
# 2025-03-14 01:24:39,230 - __main__ - INFO - 已處理 656000 個項目
# 2025-03-14 01:24:39,249 - __main__ - INFO - 已處理 657000 個項目
# 2025-03-14 01:24:39,268 - __main__ - INFO - 已處理 658000 個項目
# 2025-03-14 01:24:39,287 - __main__ - INFO - 已處理 659000 個項目
# 2025-03-14 01:24:39,306 - __main__ - INFO - 已處理 660000 個項目
# 2025-03-14 01:24:39,327 - __main__ - INFO - 已處理 661000 個項目
# 2025-03-14 01:24:39,344 - __main__ - INFO - 已處理 662000 個項目
# 2025-03-14 01:24:39,363 - __main__ - INFO - 已處理 663000 個項目
# 2025-03-14 01:24:39,383 - __main__ - INFO - 已處理 664000 個項目
# 2025-03-14 01:24:39,403 - __main__ - INFO - 已處理 665000 個項目
# 2025-03-14 01:24:39,421 - __main__ - INFO - 已處理 666000 個項目
# 2025-03-14 01:24:39,440 - __main__ - INFO - 已處理 667000 個項目
# 2025-03-14 01:24:39,458 - __main__ - INFO - 已處理 668000 個項目
# 2025-03-14 01:24:39,476 - __main__ - INFO - 已處理 669000 個項目
# 2025-03-14 01:24:39,501 - __main__ - INFO - 已處理 670000 個項目
# 2025-03-14 01:24:39,520 - __main__ - INFO - 已處理 671000 個項目
# 2025-03-14 01:24:39,540 - __main__ - INFO - 已處理 672000 個項目
# 2025-03-14 01:24:39,561 - __main__ - INFO - 已處理 673000 個項目
# 2025-03-14 01:24:39,580 - __main__ - INFO - 已處理 674000 個項目
# 2025-03-14 01:24:39,597 - __main__ - INFO - 已處理 675000 個項目
# 2025-03-14 01:24:39,615 - __main__ - INFO - 已處理 676000 個項目
# 2025-03-14 01:24:39,632 - __main__ - INFO - 已處理 677000 個項目
# 2025-03-14 01:24:39,674 - __main__ - INFO - 已處理 678000 個項目
# 2025-03-14 01:24:39,692 - __main__ - INFO - 已處理 679000 個項目
# 2025-03-14 01:24:39,710 - __main__ - INFO - 已處理 680000 個項目
# 2025-03-14 01:24:39,729 - __main__ - INFO - 已處理 681000 個項目
# 2025-03-14 01:24:39,748 - __main__ - INFO - 已處理 682000 個項目
# 2025-03-14 01:24:39,766 - __main__ - INFO - 已處理 683000 個項目
# 2025-03-14 01:24:39,787 - __main__ - INFO - 已處理 684000 個項目
# 2025-03-14 01:24:39,806 - __main__ - INFO - 已處理 685000 個項目
# 2025-03-14 01:24:39,824 - __main__ - INFO - 已處理 686000 個項目
# 2025-03-14 01:24:39,842 - __main__ - INFO - 已處理 687000 個項目
# 2025-03-14 01:24:39,861 - __main__ - INFO - 已處理 688000 個項目
# 2025-03-14 01:24:39,879 - __main__ - INFO - 已處理 689000 個項目
# 2025-03-14 01:24:39,899 - __main__ - INFO - 已處理 690000 個項目
# 2025-03-14 01:24:39,919 - __main__ - INFO - 已處理 691000 個項目
# 2025-03-14 01:24:39,938 - __main__ - INFO - 已處理 692000 個項目
# 2025-03-14 01:24:39,958 - __main__ - INFO - 已處理 693000 個項目
# 2025-03-14 01:24:39,976 - __main__ - INFO - 已處理 694000 個項目
# 2025-03-14 01:24:39,996 - __main__ - INFO - 已處理 695000 個項目
# 2025-03-14 01:24:40,017 - __main__ - INFO - 已處理 696000 個項目
# 2025-03-14 01:24:40,037 - __main__ - INFO - 已處理 697000 個項目
# 2025-03-14 01:24:40,057 - __main__ - INFO - 已處理 698000 個項目
# 2025-03-14 01:24:40,077 - __main__ - INFO - 已處理 699000 個項目
# 2025-03-14 01:24:40,094 - __main__ - INFO - 已處理 700000 個項目
# 2025-03-14 01:24:40,111 - __main__ - INFO - 已處理 701000 個項目
# 2025-03-14 01:24:40,132 - __main__ - INFO - 已處理 702000 個項目
# 2025-03-14 01:24:40,150 - __main__ - INFO - 已處理 703000 個項目
# 2025-03-14 01:24:40,168 - __main__ - INFO - 已處理 704000 個項目
# 2025-03-14 01:24:40,186 - __main__ - INFO - 已處理 705000 個項目
# 2025-03-14 01:24:40,205 - __main__ - INFO - 已處理 706000 個項目
# 2025-03-14 01:24:40,227 - __main__ - INFO - 已處理 707000 個項目
# 2025-03-14 01:24:40,248 - __main__ - INFO - 已處理 708000 個項目
# 2025-03-14 01:24:40,270 - __main__ - INFO - 已處理 709000 個項目
# 2025-03-14 01:24:40,290 - __main__ - INFO - 已處理 710000 個項目
# 2025-03-14 01:24:40,309 - __main__ - INFO - 已處理 711000 個項目
# 2025-03-14 01:24:40,329 - __main__ - INFO - 已處理 712000 個項目
# 2025-03-14 01:24:40,347 - __main__ - INFO - 已處理 713000 個項目
# 2025-03-14 01:24:40,370 - __main__ - INFO - 已處理 714000 個項目
# 2025-03-14 01:24:40,389 - __main__ - INFO - 已處理 715000 個項目
# 2025-03-14 01:24:40,408 - __main__ - INFO - 已處理 716000 個項目
# 2025-03-14 01:24:40,427 - __main__ - INFO - 已處理 717000 個項目
# 2025-03-14 01:24:40,446 - __main__ - INFO - 已處理 718000 個項目
# 2025-03-14 01:24:40,464 - __main__ - INFO - 已處理 719000 個項目
# 2025-03-14 01:24:40,484 - __main__ - INFO - 已處理 720000 個項目
# 2025-03-14 01:24:40,715 - __main__ - INFO - 已處理 721000 個項目
# 2025-03-14 01:24:40,732 - __main__ - INFO - 已處理 722000 個項目
# 2025-03-14 01:24:40,751 - __main__ - INFO - 已處理 723000 個項目
# 2025-03-14 01:24:40,771 - __main__ - INFO - 已處理 724000 個項目
# 2025-03-14 01:24:40,790 - __main__ - INFO - 已處理 725000 個項目
# 2025-03-14 01:24:40,809 - __main__ - INFO - 已處理 726000 個項目
# 2025-03-14 01:24:40,827 - __main__ - INFO - 已處理 727000 個項目
# 2025-03-14 01:24:40,847 - __main__ - INFO - 已處理 728000 個項目
# 2025-03-14 01:24:40,866 - __main__ - INFO - 已處理 729000 個項目
# 2025-03-14 01:24:40,883 - __main__ - INFO - 已處理 730000 個項目
# 2025-03-14 01:24:40,906 - __main__ - INFO - 已處理 731000 個項目
# 2025-03-14 01:24:40,926 - __main__ - INFO - 已處理 732000 個項目
# 2025-03-14 01:24:40,945 - __main__ - INFO - 已處理 733000 個項目
# 2025-03-14 01:24:40,965 - __main__ - INFO - 已處理 734000 個項目
# 2025-03-14 01:24:40,984 - __main__ - INFO - 已處理 735000 個項目
# 2025-03-14 01:24:41,003 - __main__ - INFO - 已處理 736000 個項目
# 2025-03-14 01:24:41,023 - __main__ - INFO - 已處理 737000 個項目
# 2025-03-14 01:24:41,042 - __main__ - INFO - 已處理 738000 個項目
# 2025-03-14 01:24:41,061 - __main__ - INFO - 已處理 739000 個項目
# 2025-03-14 01:24:41,080 - __main__ - INFO - 已處理 740000 個項目
# 2025-03-14 01:24:41,099 - __main__ - INFO - 已處理 741000 個項目
# 2025-03-14 01:24:41,119 - __main__ - INFO - 已處理 742000 個項目
# 2025-03-14 01:24:41,139 - __main__ - INFO - 已處理 743000 個項目
# 2025-03-14 01:24:41,158 - __main__ - INFO - 已處理 744000 個項目
# 2025-03-14 01:24:41,176 - __main__ - INFO - 已處理 745000 個項目
# 2025-03-14 01:24:41,194 - __main__ - INFO - 已處理 746000 個項目
# 2025-03-14 01:24:41,212 - __main__ - INFO - 已處理 747000 個項目
# 2025-03-14 01:24:41,230 - __main__ - INFO - 已處理 748000 個項目
# 2025-03-14 01:24:41,248 - __main__ - INFO - 已處理 749000 個項目
# 2025-03-14 01:24:41,267 - __main__ - INFO - 已處理 750000 個項目
# 2025-03-14 01:24:41,285 - __main__ - INFO - 已處理 751000 個項目
# 2025-03-14 01:24:41,305 - __main__ - INFO - 已處理 752000 個項目
# 2025-03-14 01:24:41,326 - __main__ - INFO - 已處理 753000 個項目
# 2025-03-14 01:24:41,345 - __main__ - INFO - 已處理 754000 個項目
# 2025-03-14 01:24:41,364 - __main__ - INFO - 已處理 755000 個項目
# 2025-03-14 01:24:41,383 - __main__ - INFO - 已處理 756000 個項目
# 2025-03-14 01:24:41,403 - __main__ - INFO - 已處理 757000 個項目
# 2025-03-14 01:24:41,423 - __main__ - INFO - 已處理 758000 個項目
# 2025-03-14 01:24:41,441 - __main__ - INFO - 已處理 759000 個項目
# 2025-03-14 01:24:41,466 - __main__ - INFO - 已處理 760000 個項目
# 2025-03-14 01:24:41,485 - __main__ - INFO - 已處理 761000 個項目
# 2025-03-14 01:24:41,504 - __main__ - INFO - 已處理 762000 個項目
# 2025-03-14 01:24:41,524 - __main__ - INFO - 已處理 763000 個項目
# 2025-03-14 01:24:41,543 - __main__ - INFO - 已處理 764000 個項目
# 2025-03-14 01:24:41,561 - __main__ - INFO - 已處理 765000 個項目
# 2025-03-14 01:24:41,581 - __main__ - INFO - 已處理 766000 個項目
# 2025-03-14 01:24:41,599 - __main__ - INFO - 已處理 767000 個項目
# 2025-03-14 01:24:41,640 - __main__ - INFO - 已處理 768000 個項目
# 2025-03-14 01:24:41,660 - __main__ - INFO - 已處理 769000 個項目
# 2025-03-14 01:24:41,679 - __main__ - INFO - 已處理 770000 個項目
# 2025-03-14 01:24:41,697 - __main__ - INFO - 已處理 771000 個項目
# 2025-03-14 01:24:41,716 - __main__ - INFO - 已處理 772000 個項目
# 2025-03-14 01:24:41,734 - __main__ - INFO - 已處理 773000 個項目
# 2025-03-14 01:24:41,753 - __main__ - INFO - 已處理 774000 個項目
# 2025-03-14 01:24:41,772 - __main__ - INFO - 已處理 775000 個項目
# 2025-03-14 01:24:41,791 - __main__ - INFO - 已處理 776000 個項目
# 2025-03-14 01:24:41,812 - __main__ - INFO - 已處理 777000 個項目
# 2025-03-14 01:24:41,832 - __main__ - INFO - 已處理 778000 個項目
# 2025-03-14 01:24:41,852 - __main__ - INFO - 已處理 779000 個項目
# 2025-03-14 01:24:41,871 - __main__ - INFO - 已處理 780000 個項目
# 2025-03-14 01:24:41,891 - __main__ - INFO - 已處理 781000 個項目
# 2025-03-14 01:24:41,910 - __main__ - INFO - 已處理 782000 個項目
# 2025-03-14 01:24:41,928 - __main__ - INFO - 已處理 783000 個項目
# 2025-03-14 01:24:41,947 - __main__ - INFO - 已處理 784000 個項目
# 2025-03-14 01:24:41,967 - __main__ - INFO - 已處理 785000 個項目
# 2025-03-14 01:24:41,989 - __main__ - INFO - 已處理 786000 個項目
# 2025-03-14 01:24:42,009 - __main__ - INFO - 已處理 787000 個項目
# 2025-03-14 01:24:42,028 - __main__ - INFO - 已處理 788000 個項目
# 2025-03-14 01:24:42,048 - __main__ - INFO - 已處理 789000 個項目
# 2025-03-14 01:24:42,066 - __main__ - INFO - 已處理 790000 個項目
# 2025-03-14 01:24:42,085 - __main__ - INFO - 已處理 791000 個項目
# 2025-03-14 01:24:42,106 - __main__ - INFO - 已處理 792000 個項目
# 2025-03-14 01:24:42,125 - __main__ - INFO - 已處理 793000 個項目
# 2025-03-14 01:24:42,145 - __main__ - INFO - 已處理 794000 個項目
# 2025-03-14 01:24:42,164 - __main__ - INFO - 已處理 795000 個項目
# 2025-03-14 01:24:42,184 - __main__ - INFO - 已處理 796000 個項目
# 2025-03-14 01:24:42,202 - __main__ - INFO - 已處理 797000 個項目
# 2025-03-14 01:24:42,220 - __main__ - INFO - 已處理 798000 個項目
# 2025-03-14 01:24:42,239 - __main__ - INFO - 已處理 799000 個項目
# 2025-03-14 01:24:42,259 - __main__ - INFO - 已處理 800000 個項目
# 2025-03-14 01:24:42,276 - __main__ - INFO - 已處理 801000 個項目
# 2025-03-14 01:24:42,295 - __main__ - INFO - 已處理 802000 個項目
# 2025-03-14 01:24:42,313 - __main__ - INFO - 已處理 803000 個項目
# 2025-03-14 01:24:42,332 - __main__ - INFO - 已處理 804000 個項目
# 2025-03-14 01:24:42,353 - __main__ - INFO - 已處理 805000 個項目
# 2025-03-14 01:24:42,373 - __main__ - INFO - 已處理 806000 個項目
# 2025-03-14 01:24:42,392 - __main__ - INFO - 已處理 807000 個項目
# 2025-03-14 01:24:42,413 - __main__ - INFO - 已處理 808000 個項目
# 2025-03-14 01:24:42,432 - __main__ - INFO - 已處理 809000 個項目
# 2025-03-14 01:24:42,450 - __main__ - INFO - 已處理 810000 個項目
# 2025-03-14 01:24:42,469 - __main__ - INFO - 已處理 811000 個項目
# 2025-03-14 01:24:42,488 - __main__ - INFO - 已處理 812000 個項目
# ...
# 2025-03-14 01:24:49,012 - __main__ - INFO - 已處理 1127000 個項目
# 2025-03-14 01:24:49,031 - __main__ - INFO - 已處理 1128000 個項目
# 2025-03-14 01:24:49,050 - __main__ - INFO - 已處理 1129000 個項目
# 2025-03-14 01:24:49,070 - __main__ - INFO - 已處理 1130000 個項目
# 2025-03-14 01:24:49,089 - __main__ - INFO - 已處理 1131000 個項目
# 2025-03-14 01:24:49,110 - __main__ - INFO - 已處理 1132000 個項目
# 2025-03-14 01:24:49,131 - __main__ - INFO - 已處理 1133000 個項目
# 2025-03-14 01:24:49,150 - __main__ - INFO - 已處理 1134000 個項目
# 2025-03-14 01:24:49,169 - __main__ - INFO - 已處理 1135000 個項目
# 2025-03-14 01:24:49,190 - __main__ - INFO - 已處理 1136000 個項目
# 2025-03-14 01:24:49,211 - __main__ - INFO - 已處理 1137000 個項目
# 2025-03-14 01:24:49,233 - __main__ - INFO - 已處理 1138000 個項目
# 2025-03-14 01:24:49,253 - __main__ - INFO - 已處理 1139000 個項目
# 2025-03-14 01:24:49,272 - __main__ - INFO - 已處理 1140000 個項目
# 2025-03-14 01:24:49,293 - __main__ - INFO - 已處理 1141000 個項目
# 2025-03-14 01:24:49,313 - __main__ - INFO - 已處理 1142000 個項目
# 2025-03-14 01:24:49,685 - __main__ - INFO - 已處理 1143000 個項目
# 2025-03-14 01:24:49,704 - __main__ - INFO - 已處理 1144000 個項目
# 2025-03-14 01:24:49,726 - __main__ - INFO - 已處理 1145000 個項目
# 2025-03-14 01:24:49,746 - __main__ - INFO - 已處理 1146000 個項目
# 2025-03-14 01:24:49,766 - __main__ - INFO - 已處理 1147000 個項目
# 2025-03-14 01:24:49,789 - __main__ - INFO - 已處理 1148000 個項目
# 2025-03-14 01:24:49,808 - __main__ - INFO - 已處理 1149000 個項目
# 2025-03-14 01:24:49,828 - __main__ - INFO - 已處理 1150000 個項目
# 2025-03-14 01:24:49,848 - __main__ - INFO - 已處理 1151000 個項目
# 2025-03-14 01:24:49,866 - __main__ - INFO - 已處理 1152000 個項目
# 2025-03-14 01:24:49,881 - __main__ - INFO - 已處理 1153000 個項目
# 2025-03-14 01:24:49,900 - __main__ - INFO - 已處理 1154000 個項目
# 2025-03-14 01:24:49,920 - __main__ - INFO - 已處理 1155000 個項目
# 2025-03-14 01:24:49,940 - __main__ - INFO - 已處理 1156000 個項目
# 2025-03-14 01:24:49,960 - __main__ - INFO - 已處理 1157000 個項目
# 2025-03-14 01:24:49,979 - __main__ - INFO - 已處理 1158000 個項目
# 2025-03-14 01:24:49,998 - __main__ - INFO - 已處理 1159000 個項目
# 2025-03-14 01:24:50,018 - __main__ - INFO - 已處理 1160000 個項目
# 2025-03-14 01:24:50,038 - __main__ - INFO - 已處理 1161000 個項目
# 2025-03-14 01:24:50,092 - __main__ - INFO - 已處理 1162000 個項目
# 2025-03-14 01:24:50,112 - __main__ - INFO - 已處理 1163000 個項目
# 2025-03-14 01:24:50,134 - __main__ - INFO - 已處理 1164000 個項目
# 2025-03-14 01:24:50,165 - __main__ - INFO - 已處理 1165000 個項目
# 2025-03-14 01:24:50,228 - __main__ - INFO - 已處理 1166000 個項目
# 2025-03-14 01:24:50,258 - __main__ - INFO - 已處理 1167000 個項目
# 2025-03-14 01:24:50,284 - __main__ - INFO - 已處理 1168000 個項目
# 2025-03-14 01:24:50,309 - __main__ - INFO - 已處理 1169000 個項目
# 2025-03-14 01:24:50,330 - __main__ - INFO - 已處理 1170000 個項目
# 2025-03-14 01:24:50,353 - __main__ - INFO - 已處理 1171000 個項目
# 2025-03-14 01:24:50,378 - __main__ - INFO - 已處理 1172000 個項目
# 2025-03-14 01:24:50,402 - __main__ - INFO - 已處理 1173000 個項目
# 2025-03-14 01:24:50,425 - __main__ - INFO - 已處理 1174000 個項目
# 2025-03-14 01:24:50,446 - __main__ - INFO - 已處理 1175000 個項目
# 2025-03-14 01:24:50,466 - __main__ - INFO - 已處理 1176000 個項目
# 2025-03-14 01:24:50,490 - __main__ - INFO - 已處理 1177000 個項目
# 2025-03-14 01:24:50,520 - __main__ - INFO - 已處理 1178000 個項目
# 2025-03-14 01:24:50,542 - __main__ - INFO - 已處理 1179000 個項目
# 2025-03-14 01:24:50,564 - __main__ - INFO - 已處理 1180000 個項目
# 2025-03-14 01:24:50,593 - __main__ - INFO - 已處理 1181000 個項目
# 2025-03-14 01:24:50,613 - __main__ - INFO - 已處理 1182000 個項目
# 2025-03-14 01:24:50,635 - __main__ - INFO - 已處理 1183000 個項目
# 2025-03-14 01:24:50,655 - __main__ - INFO - 已處理 1184000 個項目
# 2025-03-14 01:24:50,675 - __main__ - INFO - 已處理 1185000 個項目
# 2025-03-14 01:24:50,702 - __main__ - INFO - 已處理 1186000 個項目
# 2025-03-14 01:24:50,723 - __main__ - INFO - 已處理 1187000 個項目
# 2025-03-14 01:24:50,745 - __main__ - INFO - 已處理 1188000 個項目
# 2025-03-14 01:24:50,765 - __main__ - INFO - 已處理 1189000 個項目
# 2025-03-14 01:24:50,785 - __main__ - INFO - 已處理 1190000 個項目
# 2025-03-14 01:24:50,818 - __main__ - INFO - 已處理 1191000 個項目
# 2025-03-14 01:24:50,840 - __main__ - INFO - 已處理 1192000 個項目
# 2025-03-14 01:24:50,862 - __main__ - INFO - 已處理 1193000 個項目
# 2025-03-14 01:24:50,885 - __main__ - INFO - 已處理 1194000 個項目
# 2025-03-14 01:24:50,906 - __main__ - INFO - 已處理 1195000 個項目
# 2025-03-14 01:24:50,938 - __main__ - INFO - 已處理 1196000 個項目
# 2025-03-14 01:24:50,959 - __main__ - INFO - 已處理 1197000 個項目
# 2025-03-14 01:24:50,980 - __main__ - INFO - 已處理 1198000 個項目
# 2025-03-14 01:24:51,001 - __main__ - INFO - 已處理 1199000 個項目
# 2025-03-14 01:24:51,023 - __main__ - INFO - 已處理 1200000 個項目
# 2025-03-14 01:24:51,043 - __main__ - INFO - 已處理 1201000 個項目
# 2025-03-14 01:24:51,074 - __main__ - INFO - 已處理 1202000 個項目
# 2025-03-14 01:24:51,096 - __main__ - INFO - 已處理 1203000 個項目
# 2025-03-14 01:24:51,118 - __main__ - INFO - 已處理 1204000 個項目
# 2025-03-14 01:24:51,140 - __main__ - INFO - 已處理 1205000 個項目
# 2025-03-14 01:24:51,159 - __main__ - INFO - 已處理 1206000 個項目
# 2025-03-14 01:24:51,178 - __main__ - INFO - 已處理 1207000 個項目
# 2025-03-14 01:24:51,198 - __main__ - INFO - 已處理 1208000 個項目
# 2025-03-14 01:24:51,218 - __main__ - INFO - 已處理 1209000 個項目
# 2025-03-14 01:24:51,239 - __main__ - INFO - 已處理 1210000 個項目
# 2025-03-14 01:24:51,257 - __main__ - INFO - 已處理 1211000 個項目
# 2025-03-14 01:24:51,277 - __main__ - INFO - 已處理 1212000 個項目
# 2025-03-14 01:24:51,297 - __main__ - INFO - 已處理 1213000 個項目
# 2025-03-14 01:24:51,317 - __main__ - INFO - 已處理 1214000 個項目
# 2025-03-14 01:24:51,337 - __main__ - INFO - 已處理 1215000 個項目
# 2025-03-14 01:24:51,359 - __main__ - INFO - 已處理 1216000 個項目
# 2025-03-14 01:24:51,380 - __main__ - INFO - 已處理 1217000 個項目
# 2025-03-14 01:24:51,399 - __main__ - INFO - 已處理 1218000 個項目
# 2025-03-14 01:24:51,418 - __main__ - INFO - 已處理 1219000 個項目
# 2025-03-14 01:24:51,437 - __main__ - INFO - 已處理 1220000 個項目
# 2025-03-14 01:24:51,459 - __main__ - INFO - 已處理 1221000 個項目
# 2025-03-14 01:24:51,478 - __main__ - INFO - 已處理 1222000 個項目
# 2025-03-14 01:24:51,498 - __main__ - INFO - 已處理 1223000 個項目
# 2025-03-14 01:24:51,515 - __main__ - INFO - 已處理 1224000 個項目
# 2025-03-14 01:24:51,536 - __main__ - INFO - 已處理 1225000 個項目
# 2025-03-14 01:24:51,555 - __main__ - INFO - 已處理 1226000 個項目
# 2025-03-14 01:24:51,576 - __main__ - INFO - 已處理 1227000 個項目
# 2025-03-14 01:24:51,596 - __main__ - INFO - 已處理 1228000 個項目
# 2025-03-14 01:24:51,615 - __main__ - INFO - 已處理 1229000 個項目
# 2025-03-14 01:24:51,635 - __main__ - INFO - 已處理 1230000 個項目
# 2025-03-14 01:24:51,654 - __main__ - INFO - 已處理 1231000 個項目
# 2025-03-14 01:24:51,674 - __main__ - INFO - 已處理 1232000 個項目
# 2025-03-14 01:24:51,699 - __main__ - INFO - 已處理 1233000 個項目
# 2025-03-14 01:24:51,719 - __main__ - INFO - 已處理 1234000 個項目
# 2025-03-14 01:24:51,742 - __main__ - INFO - 已處理 1235000 個項目
# 2025-03-14 01:24:51,765 - __main__ - INFO - 已處理 1236000 個項目
# 2025-03-14 01:24:51,785 - __main__ - INFO - 已處理 1237000 個項目
# 2025-03-14 01:24:51,804 - __main__ - INFO - 已處理 1238000 個項目
# 2025-03-14 01:24:51,848 - __main__ - INFO - 已處理 1239000 個項目
# 2025-03-14 01:24:51,875 - __main__ - INFO - 已處理 1240000 個項目
# 2025-03-14 01:24:51,895 - __main__ - INFO - 已處理 1241000 個項目
# 2025-03-14 01:24:51,917 - __main__ - INFO - 已處理 1242000 個項目
# 2025-03-14 01:24:51,936 - __main__ - INFO - 已處理 1243000 個項目
# 2025-03-14 01:24:51,956 - __main__ - INFO - 已處理 1244000 個項目
# 2025-03-14 01:24:51,976 - __main__ - INFO - 已處理 1245000 個項目
# 2025-03-14 01:24:51,995 - __main__ - INFO - 已處理 1246000 個項目
# 2025-03-14 01:24:52,015 - __main__ - INFO - 已處理 1247000 個項目
# 2025-03-14 01:24:52,035 - __main__ - INFO - 已處理 1248000 個項目
# 2025-03-14 01:24:52,056 - __main__ - INFO - 已處理 1249000 個項目
# 2025-03-14 01:24:52,075 - __main__ - INFO - 已處理 1250000 個項目
# 2025-03-14 01:24:52,094 - __main__ - INFO - 已處理 1251000 個項目
# 2025-03-14 01:24:52,113 - __main__ - INFO - 已處理 1252000 個項目
# 2025-03-14 01:24:52,132 - __main__ - INFO - 已處理 1253000 個項目
# 2025-03-14 01:24:52,150 - __main__ - INFO - 已處理 1254000 個項目
# 2025-03-14 01:24:52,170 - __main__ - INFO - 已處理 1255000 個項目
# 2025-03-14 01:24:52,189 - __main__ - INFO - 已處理 1256000 個項目
# 2025-03-14 01:24:52,206 - __main__ - INFO - 已處理 1257000 個項目
# 2025-03-14 01:24:52,224 - __main__ - INFO - 已處理 1258000 個項目
# 2025-03-14 01:24:52,243 - __main__ - INFO - 已處理 1259000 個項目
# 2025-03-14 01:24:52,260 - __main__ - INFO - 已處理 1260000 個項目
# 2025-03-14 01:24:52,280 - __main__ - INFO - 已處理 1261000 個項目
# 2025-03-14 01:24:52,299 - __main__ - INFO - 已處理 1262000 個項目
# 2025-03-14 01:24:52,317 - __main__ - INFO - 已處理 1263000 個項目
# 2025-03-14 01:24:52,336 - __main__ - INFO - 已處理 1264000 個項目
# 2025-03-14 01:24:52,354 - __main__ - INFO - 已處理 1265000 個項目
# 2025-03-14 01:24:52,373 - __main__ - INFO - 已處理 1266000 個項目
# 2025-03-14 01:24:52,393 - __main__ - INFO - 已處理 1267000 個項目
# 2025-03-14 01:24:52,412 - __main__ - INFO - 已處理 1268000 個項目
# 2025-03-14 01:24:52,431 - __main__ - INFO - 已處理 1269000 個項目
# 2025-03-14 01:24:52,451 - __main__ - INFO - 已處理 1270000 個項目
# 2025-03-14 01:24:52,471 - __main__ - INFO - 已處理 1271000 個項目
# 2025-03-14 01:24:52,493 - __main__ - INFO - 已處理 1272000 個項目
# 2025-03-14 01:24:52,512 - __main__ - INFO - 已處理 1273000 個項目
# 2025-03-14 01:24:52,531 - __main__ - INFO - 已處理 1274000 個項目
# 2025-03-14 01:24:52,551 - __main__ - INFO - 已處理 1275000 個項目
# 2025-03-14 01:24:52,570 - __main__ - INFO - 已處理 1276000 個項目
# 2025-03-14 01:24:52,590 - __main__ - INFO - 已處理 1277000 個項目
# 2025-03-14 01:24:52,607 - __main__ - INFO - 已處理 1278000 個項目
# 2025-03-14 01:24:52,628 - __main__ - INFO - 已處理 1279000 個項目
# 2025-03-14 01:24:52,649 - __main__ - INFO - 已處理 1280000 個項目
# 2025-03-14 01:24:52,668 - __main__ - INFO - 已處理 1281000 個項目
# 2025-03-14 01:24:52,689 - __main__ - INFO - 已處理 1282000 個項目
# 2025-03-14 01:24:52,708 - __main__ - INFO - 已處理 1283000 個項目
# 2025-03-14 01:24:52,728 - __main__ - INFO - 已處理 1284000 個項目
# 2025-03-14 01:24:52,750 - __main__ - INFO - 已處理 1285000 個項目
# 2025-03-14 01:24:52,772 - __main__ - INFO - 已處理 1286000 個項目
# 2025-03-14 01:24:52,791 - __main__ - INFO - 已處理 1287000 個項目
# 2025-03-14 01:24:52,812 - __main__ - INFO - 已處理 1288000 個項目
# 2025-03-14 01:24:52,833 - __main__ - INFO - 已處理 1289000 個項目
# 2025-03-14 01:24:52,853 - __main__ - INFO - 已處理 1290000 個項目
# 2025-03-14 01:24:52,874 - __main__ - INFO - 已處理 1291000 個項目
# 2025-03-14 01:24:52,894 - __main__ - INFO - 已處理 1292000 個項目
# 2025-03-14 01:24:52,915 - __main__ - INFO - 已處理 1293000 個項目
# 2025-03-14 01:24:52,936 - __main__ - INFO - 已處理 1294000 個項目
# 2025-03-14 01:24:52,956 - __main__ - INFO - 已處理 1295000 個項目
# 2025-03-14 01:24:52,978 - __main__ - INFO - 已處理 1296000 個項目
# 2025-03-14 01:24:52,998 - __main__ - INFO - 已處理 1297000 個項目
# 2025-03-14 01:24:53,019 - __main__ - INFO - 已處理 1298000 個項目
# 2025-03-14 01:24:53,038 - __main__ - INFO - 已處理 1299000 個項目
# 2025-03-14 01:24:53,057 - __main__ - INFO - 已處理 1300000 個項目
# 2025-03-14 01:24:53,075 - __main__ - INFO - 已處理 1301000 個項目
# 2025-03-14 01:24:53,094 - __main__ - INFO - 已處理 1302000 個項目
# 2025-03-14 01:24:53,114 - __main__ - INFO - 已處理 1303000 個項目
# 2025-03-14 01:24:53,135 - __main__ - INFO - 已處理 1304000 個項目
# 2025-03-14 01:24:53,165 - __main__ - INFO - 已處理 1305000 個項目
# 2025-03-14 01:24:53,186 - __main__ - INFO - 已處理 1306000 個項目
# 2025-03-14 01:24:53,207 - __main__ - INFO - 已處理 1307000 個項目
# 2025-03-14 01:24:53,227 - __main__ - INFO - 已處理 1308000 個項目
# 2025-03-14 01:24:53,247 - __main__ - INFO - 已處理 1309000 個項目
# 2025-03-14 01:24:53,269 - __main__ - INFO - 已處理 1310000 個項目
# 2025-03-14 01:24:53,289 - __main__ - INFO - 已處理 1311000 個項目
# 2025-03-14 01:24:53,309 - __main__ - INFO - 已處理 1312000 個項目
# 2025-03-14 01:24:53,329 - __main__ - INFO - 已處理 1313000 個項目
# 2025-03-14 01:24:53,349 - __main__ - INFO - 已處理 1314000 個項目
# 2025-03-14 01:24:53,367 - __main__ - INFO - 已處理 1315000 個項目
# 2025-03-14 01:24:53,388 - __main__ - INFO - 已處理 1316000 個項目
# 2025-03-14 01:24:53,409 - __main__ - INFO - 已處理 1317000 個項目
# 2025-03-14 01:24:53,429 - __main__ - INFO - 已處理 1318000 個項目
# 2025-03-14 01:24:53,450 - __main__ - INFO - 已處理 1319000 個項目
# 2025-03-14 01:24:53,471 - __main__ - INFO - 已處理 1320000 個項目
# 2025-03-14 01:24:53,515 - __main__ - INFO - 已處理 1321000 個項目
# 2025-03-14 01:24:53,541 - __main__ - INFO - 已處理 1322000 個項目
# 2025-03-14 01:24:53,561 - __main__ - INFO - 已處理 1323000 個項目
# 2025-03-14 01:24:53,582 - __main__ - INFO - 已處理 1324000 個項目
# 2025-03-14 01:24:53,603 - __main__ - INFO - 已處理 1325000 個項目
# 2025-03-14 01:24:53,624 - __main__ - INFO - 已處理 1326000 個項目
# 2025-03-14 01:24:53,646 - __main__ - INFO - 已處理 1327000 個項目
# 2025-03-14 01:24:53,667 - __main__ - INFO - 已處理 1328000 個項目
# 2025-03-14 01:24:53,689 - __main__ - INFO - 已處理 1329000 個項目
# 2025-03-14 01:24:53,709 - __main__ - INFO - 已處理 1330000 個項目
# 2025-03-14 01:24:53,732 - __main__ - INFO - 已處理 1331000 個項目
# 2025-03-14 01:24:53,752 - __main__ - INFO - 已處理 1332000 個項目
# 2025-03-14 01:24:53,773 - __main__ - INFO - 已處理 1333000 個項目
# 2025-03-14 01:24:53,793 - __main__ - INFO - 已處理 1334000 個項目
# 2025-03-14 01:24:53,812 - __main__ - INFO - 已處理 1335000 個項目
# 2025-03-14 01:24:53,831 - __main__ - INFO - 已處理 1336000 個項目
# 2025-03-14 01:24:53,851 - __main__ - INFO - 已處理 1337000 個項目
# 2025-03-14 01:24:53,872 - __main__ - INFO - 已處理 1338000 個項目
# 2025-03-14 01:24:53,891 - __main__ - INFO - 已處理 1339000 個項目
# 2025-03-14 01:24:53,912 - __main__ - INFO - 已處理 1340000 個項目
# 2025-03-14 01:24:53,930 - __main__ - INFO - 已處理 1341000 個項目
# 2025-03-14 01:24:53,951 - __main__ - INFO - 已處理 1342000 個項目
# 2025-03-14 01:24:53,972 - __main__ - INFO - 已處理 1343000 個項目
# 2025-03-14 01:24:53,991 - __main__ - INFO - 已處理 1344000 個項目
# 2025-03-14 01:24:54,010 - __main__ - INFO - 已處理 1345000 個項目
# 2025-03-14 01:24:54,028 - __main__ - INFO - 已處理 1346000 個項目
# 2025-03-14 01:24:54,048 - __main__ - INFO - 已處理 1347000 個項目
# 2025-03-14 01:24:54,067 - __main__ - INFO - 已處理 1348000 個項目
# 2025-03-14 01:24:54,087 - __main__ - INFO - 已處理 1349000 個項目
# 2025-03-14 01:24:54,107 - __main__ - INFO - 已處理 1350000 個項目
# 2025-03-14 01:24:54,127 - __main__ - INFO - 已處理 1351000 個項目
# 2025-03-14 01:24:54,147 - __main__ - INFO - 已處理 1352000 個項目
# 2025-03-14 01:24:54,166 - __main__ - INFO - 已處理 1353000 個項目
# 2025-03-14 01:24:54,186 - __main__ - INFO - 已處理 1354000 個項目
# 2025-03-14 01:24:54,205 - __main__ - INFO - 已處理 1355000 個項目
# 2025-03-14 01:24:54,224 - __main__ - INFO - 已處理 1356000 個項目
# 2025-03-14 01:24:54,244 - __main__ - INFO - 已處理 1357000 個項目
# 2025-03-14 01:24:54,264 - __main__ - INFO - 已處理 1358000 個項目
# 2025-03-14 01:24:54,287 - __main__ - INFO - 已處理 1359000 個項目
# 2025-03-14 01:24:54,307 - __main__ - INFO - 已處理 1360000 個項目
# 2025-03-14 01:24:54,325 - __main__ - INFO - 已處理 1361000 個項目
# 2025-03-14 01:24:54,344 - __main__ - INFO - 已處理 1362000 個項目
# 2025-03-14 01:24:54,365 - __main__ - INFO - 已處理 1363000 個項目
# 2025-03-14 01:24:54,386 - __main__ - INFO - 已處理 1364000 個項目
# 2025-03-14 01:24:54,405 - __main__ - INFO - 已處理 1365000 個項目
# 2025-03-14 01:24:54,424 - __main__ - INFO - 已處理 1366000 個項目
# 2025-03-14 01:24:54,444 - __main__ - INFO - 已處理 1367000 個項目
# 2025-03-14 01:24:54,466 - __main__ - INFO - 已處理 1368000 個項目
# 2025-03-14 01:24:54,484 - __main__ - INFO - 已處理 1369000 個項目
# 2025-03-14 01:24:54,503 - __main__ - INFO - 已處理 1370000 個項目
# 2025-03-14 01:24:54,522 - __main__ - INFO - 已處理 1371000 個項目
# 2025-03-14 01:24:54,541 - __main__ - INFO - 已處理 1372000 個項目
# 2025-03-14 01:24:54,561 - __main__ - INFO - 已處理 1373000 個項目
# 2025-03-14 01:24:54,580 - __main__ - INFO - 已處理 1374000 個項目
# 2025-03-14 01:24:54,598 - __main__ - INFO - 已處理 1375000 個項目
# 2025-03-14 01:24:54,617 - __main__ - INFO - 已處理 1376000 個項目
# 2025-03-14 01:24:54,636 - __main__ - INFO - 已處理 1377000 個項目
# 2025-03-14 01:24:54,637 - __main__ - INFO - 已處理 1377010 個項目
# 2025-03-14 01:24:54,637 - __main__ - INFO - 分批處理完成，總共處理 1377010 個項目
# 2025-03-14 01:25:05,375 - __main__ - INFO - 已成功儲存 1377010 個項目至檔案: ../data/convert/official-cpe-dictionary_v2.3.json
# 2025-03-14 01:25:13,104 - __main__ - INFO - 已成功儲存 1377010 個項目至檔案: ../data/convert/official-cpe-dictionary_v2.3.csv
# 2025-03-14 01:25:13,197 - __main__ - INFO - 已成功儲存 22566 個廠商變體資訊至檔案: ../data/convert/vendor_variations.json
# 2025-03-14 01:25:13,206 - __main__ - INFO - 廠商變體分析結果: {
#   "total_vendors": 22566,
#   "vendors_with_variations": 25,
#   "percentage_with_variations": 0.11,
#   "max_variations": 2,
#   "max_variations_vendor": "alphaware_simple_e_commerce_system_project",
#   "max_variations_list": [
#     "alphaware_simple_e-commerce_system_project",
#     "alphaware_-_simple_e-commerce_system_project"
#   ]
# }
# 2025-03-14 01:25:13,207 - __main__ - INFO - 程式執行完成

# %% [markdown]
# ### Example of converted format
#
# #### JSON Format
#
# ```JSON
# {
#   "cpe22Uri": "cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~",
#   "cpe23Uri": "cpe:2.3:a:\\$0.99_kindle_books_project:\\$0.99_kindle_books:6:*:*:*:*:android:*:*",
#   "vendor": "\\$0.99_kindle_books_project",
#   "product": "\\$0.99_kindle_books",
#   "version": "6",
#   "title": "$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0",
#   "references": "Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)"
# },
# ```
#
# #### CSV Format
#
# ```CSV
# cpe22Uri,cpe23Uri,vendor,product,version,title,references
# cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~,cpe:2.3:a:\$0.99_kindle_books_project:\$0.99_kindle_books:6:*:*:*:*:android:*:*,\$0.99_kindle_books_project,\$0.99_kindle_books,6,$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0,Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)
# ```

# %% [markdown]
# ## Step 3: Create a vector database (using Chromadb as an example)
#
# To quickly retrieve the closest Common Platform Enumeration (CPE) data based on user input, we will utilize the similarity search capabilities of a vector database. Vector databases excel at transforming complex data (such as images, audio, etc.) into vector representations for mathematical operations. Given the variability of user input, the potential for different registration formats of vendor and product names within the CPE database, and the varying relevance of references included in CPE entries, we aim to leverage the similarity comparison capabilities of the vector database to effectively identify the desired CPE entries. Therefore, we need to import the National Vulnerability Database (NVD) CPE Directory List into Chromadb and convert it into vectors for subsequent similarity comparisons.
#
# > 為了能根據使用者輸入，快速取得最接近的通用平台列舉（CPE）資料，我們將利用向量資料庫的相似性搜尋功能。向量資料庫擅長將複雜資料（如圖像、聲音等）轉換為可進行數學運算的向量表示。由於使用者輸入的多樣性，以及廠商、產品名稱在 CPE 資料庫中可能存在不同形式的登記方式，加上 CPE 條目中包含的參考資料（References）有時相關、有時不相關，我們希望藉由向量資料庫的相似性比較能力，有效識別出期望的 CPE 條目。因此，我們需要將美國國家漏洞資料庫（NVD）的 CPE 目錄列表匯入 Chromadb，並將其轉換為向量，以便後續的相似性比對。
#
# ### Structure of the created to vector database
#
# ```Markdown
#           (Periodic or Manual)
# ┌───────────────────────────────────────┐
# │    NVD CPE Directory (ZIP/XML)        │
# └───────────────────────────────────────┘
#                │
#                ▼
#      CPE Directory Updater
#                │
#                ▼
#      CPE Parser & Transformer
#                │  (structured JSON)
#                ▼
#      Embedding Service (Huggingface)
#                │ (vector)
#                ▼
#   ┌────────────────────────────────────┐
#   │         Chromadb Vector DB         │
#   └────────────────────────────────────┘
# ```

# %%
import csv
import datetime
import json
import logging
import os
from dataclasses import dataclass
from functools import lru_cache
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple, Union

import chromadb
from chromadb.utils import embedding_functions


# 設定日誌
def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


# 設定日誌
setup_logging(logging.INFO, "../logs/cpe_database.log")
logger = logging.getLogger(__name__)


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class EmbeddingModelProvider:
    """提供不同的嵌入模型選項"""

    @staticmethod
    def get_default_embedding():
        """獲取預設的嵌入函數

        Returns:
            embedding_function: 預設的嵌入函數
        """
        return embedding_functions.DefaultEmbeddingFunction()


class CPEInputStandardizer:
    """CPE輸入標準化預處理器"""

    @staticmethod
    def standardize_text(text: Optional[str]) -> Optional[str]:
        """
        標準化文本:
        1. 轉換為小寫
        2. 替換標準化特殊字符
        3. 清理多餘空格

        Args:
            text: 要標準化的文本

        Returns:
            標準化後的文本，如果輸入為空則返回None
        """
        if not text:
            return None

        # 轉換為小寫
        text = text.lower().strip()

        # 替換特殊字符
        special_chars = [' ', '-', '.', '/', ':', '(', ')', '[', ']', '+', '&']
        for char in special_chars:
            text = text.replace(char, '_')

        # 合併連續底線
        while '__' in text:
            text = text.replace('__', '_')

        # 去除首尾底線
        text = text.strip('_')

        return text

    @staticmethod
    def standardize_version(version: Optional[str]) -> Optional[str]:
        """
        標準化版本號:
        1. 移除版本前綴
        2. 替換非標準分隔符
        3. 處理特殊版本格式
        4. 正規化數字部分（例如將001變為1）

        Args:
            version: 要標準化的版本號

        Returns:
            標準化後的版本號，如果輸入為空則返回None
        """
        if not version:
            return None

        # 去除空白
        version = version.strip()

        # 移除版本前綴 (v, ver, version等)
        prefixes = ['v', 'ver', 'version', 'release', 'rel']

        lower_version = version.lower()
        for prefix in prefixes:
            if lower_version.startswith(prefix):
                # 處理不同格式的前綴
                if len(version) > len(prefix):
                    if version[len(prefix)].isdigit():
                        # v1.0 格式
                        version = version[len(prefix):]
                    elif version[len(prefix)] in [' ', '.', '-', '_']:
                        # v 1.0, v.1.0, v-1.0 格式
                        version = version[len(prefix)+1:]

        # 清理版本號開頭的非數字字符
        while version and not version[0].isdigit():
            version = version[1:]

        # 如果清理後為空，返回None
        if not version:
            return None

        # 將常見的版本分隔符標準化為點
        for sep in ['-', '_', ' ']:
            version = version.replace(sep, '.')

        # 處理重複的分隔符
        while '..' in version:
            version = version.replace('..', '.')

        # 處理版本號的每個部分，移除無意義的前導零
        parts = version.split('.')
        normalized_parts = []
        for part in parts:
            if part.isdigit():
                # 移除前導零但保留單個零
                normalized_part = part.lstrip('0')
                normalized_part = normalized_part if normalized_part else '0'
                normalized_parts.append(normalized_part)
            else:
                normalized_parts.append(part)

        return '.'.join(normalized_parts)

    @staticmethod
    def standardize_input(vendor: Optional[str] = None,
                          product: Optional[str] = None,
                          version: Optional[str] = None) -> Tuple[Optional[str], Optional[str], Optional[str]]:
        """
        標準化處理用戶輸入的廠商、產品和版本

        Args:
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號

        Returns:
            標準化後的廠商、產品和版本
        """
        std_vendor = CPEInputStandardizer.standardize_text(vendor)
        std_product = CPEInputStandardizer.standardize_text(product)
        std_version = CPEInputStandardizer.standardize_version(version)

        return std_vendor, std_product, std_version

    @staticmethod
    def standardize_csv_row(row: Dict[str, str]) -> Dict[str, str]:
        """
        標準化CSV檔案中的一行

        Args:
            row: CSV行資料

        Returns:
            標準化後的行資料
        """
        vendor = row.get('vendor', '').strip() or None
        product = row.get('product', '').strip() or None
        version = row.get('version', '').strip() or None

        std_vendor, std_product, std_version = CPEInputStandardizer.standardize_input(
            vendor, product, version
        )

        # 建立新的標準化後的行
        standardized_row = row.copy()

        # 保存原始值
        standardized_row['original_vendor'] = vendor
        standardized_row['original_product'] = product
        standardized_row['original_version'] = version

        # 添加標準化值
        standardized_row['vendor'] = std_vendor
        standardized_row['product'] = std_product
        standardized_row['version'] = std_version

        return standardized_row


class StringMatcher:
    """字串相似度比對工具類"""

    @staticmethod
    @lru_cache(maxsize=1000)
    def levenshtein_distance(s1: str, s2: str) -> int:
        """計算兩個字符串之間的Levenshtein距離

        Args:
            s1: 第一個字串
            s2: 第二個字串

        Returns:
            Levenshtein距離
        """
        if len(s1) < len(s2):
            return StringMatcher.levenshtein_distance(s2, s1)

        if len(s2) == 0:
            return len(s1)

        previous_row = range(len(s2) + 1)
        for i, c1 in enumerate(s1):
            current_row = [i + 1]
            for j, c2 in enumerate(s2):
                insertions = previous_row[j + 1] + 1
                deletions = current_row[j] + 1
                substitutions = previous_row[j] + (c1 != c2)
                current_row.append(min(insertions, deletions, substitutions))
            previous_row = current_row

        return previous_row[-1]

    @staticmethod
    def calculate_similarity(s1: str, s2: str) -> float:
        """計算兩個字串的相似度

        Args:
            s1: 第一個字串
            s2: 第二個字串

        Returns:
            相似度分數，範圍為0到1，1表示完全相同
        """
        s1 = s1.lower().strip()
        s2 = s2.lower().strip()

        # 快速檢查
        if s1 == s2:
            return 1.0
        elif s1 in s2 or s2 in s1:
            return 0.8

        # 使用Levenshtein距離計算相似度
        distance = StringMatcher.levenshtein_distance(s1, s2)
        max_len = max(len(s1), len(s2))

        if max_len == 0:
            return 0.0

        return 1.0 - (distance / max_len)

    @staticmethod
    @lru_cache(maxsize=1000)
    def version_match(query_version: str, db_version: str) -> bool:
        """改進的版本號匹配邏輯

        Args:
            query_version: 查詢的版本號
            db_version: 資料庫中的版本號

        Returns:
            是否匹配
        """
        # 簡化版本號，移除不必要的零
        def normalize_version(v):
            if not v:
                return ""
            # 將版本號拆分為數字和非數字部分
            parts = []
            current = ""
            for c in v:
                if current and ((c.isdigit() and not current[-1].isdigit()) or
                                (not c.isdigit() and current[-1].isdigit())):
                    parts.append(current)
                    current = c
                else:
                    current += c
            if current:
                parts.append(current)

            # 對數字部分進行處理，移除前導零
            norm_parts = []
            for part in parts:
                if part.isdigit():
                    # 移除前導零但保留單個零
                    norm_part = part.lstrip('0')
                    norm_part = norm_part if norm_part else '0'
                    norm_parts.append(norm_part)
                else:
                    norm_parts.append(part)

            return "".join(norm_parts)

        norm_query = normalize_version(query_version)
        norm_db = normalize_version(db_version)

        # 先檢查完全匹配
        if norm_query == norm_db:
            return True

        # 再檢查部分匹配
        return norm_query in norm_db or norm_db in norm_query


class CPEDatabaseManager:
    """CPE資料庫管理器"""

    def __init__(self,
                 db_path: str = "../database/cpe_database",
                 use_gpu: bool = False,
                 embedding_model: str = "default"):
        """初始化 CPE 資料庫管理器

        Args:
            db_path: 資料庫存放路徑
            use_gpu: 是否使用 GPU. 預設為 False.
            embedding_model: 要使用的嵌入模型類型. 預設為 "default".
        """
        self.db_path = Path(db_path)
        self.db_path.mkdir(parents=True, exist_ok=True)

        self.client = None
        self.collection = None

        # 設定 GPU 使用選項
        self.use_gpu = use_gpu

        # 選擇嵌入模型
        self.setup_embedding_function(embedding_model)

        # 設定資料庫
        self.setup_database()

    def setup_embedding_function(self, embedding_model: str) -> None:
        """設定嵌入函數

        Args:
            embedding_model: 嵌入模型類型
        """
        self.embedding_function = EmbeddingModelProvider.get_default_embedding()
        embedding_description = "預設"

        logger.info(f"使用嵌入模型: {embedding_description}")

    def setup_database(self) -> None:
        """設定資料庫連接和集合"""
        try:
            self.client = chromadb.PersistentClient(path=str(self.db_path))

            # 使用設定的 embedding 函數建立集合
            self.collection = self.client.get_or_create_collection(
                name="cpe_dictionary",
                metadata={"description": "CPE Dictionary Collection"},
                embedding_function=self.embedding_function
            )
            logger.info(f"成功設定資料庫連接，儲存位置: {self.db_path}")
        except Exception as e:
            logger.error(f"設定資料庫時發生錯誤: {str(e)}")
            raise

    def load_cpe_data(self, file_path: Union[str, Path]) -> List[Dict[str, Any]]:
        """讀取並解析 CPE JSON 檔案

        Args:
            file_path: JSON 檔案路徑

        Returns:
            解析後的 CPE 資料
        """
        file_path = Path(file_path)
        if not file_path.exists():
            raise FileNotFoundError(f"找不到檔案: {file_path}")

        try:
            logger.info(f"開始讀取 CPE 資料: {file_path}")
            with open(file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
            logger.info(f"成功讀取 {len(data)} 筆 CPE 資料")
            return data
        except json.JSONDecodeError as e:
            logger.error(f"解析 JSON 檔案時發生錯誤: {str(e)}")
            raise
        except Exception as e:
            logger.error(f"讀取 CPE 資料時發生錯誤: {str(e)}")
            raise

    def prepare_search_text(self, item: Dict[str, Any]) -> str:
        """優化的搜尋文本準備函數，增加title的權重

        Args:
            item: CPE 項目資料

        Returns:
            用於向量搜尋的文字
        """
        # 提取基本資訊
        title = item.get('title', '').strip()
        vendor = item.get('vendor', '').strip()
        product = item.get('product', '').strip()
        version = item.get('version', '').strip()

        # 構建優化的搜尋文字
        # 將 title 作為最高優先級
        search_text = f"{title} {title} {title} {title} "  # 重複四次增加權重
        search_text += f"{vendor} {vendor} "  # 重複兩次增加權重
        search_text += f"{product} {product} "  # 重複兩次增加權重
        search_text += f"{version} "

        # 加入結構化資訊
        search_text += f"""
        Title: {title}
        Vendor: {vendor}
        Product: {product}
        Version: {version}
        """

        return search_text.strip()

    def prepare_documents(self, cpe_data: List[Dict[str, Any]]) -> Tuple[List[str], List[Dict[str, str]], List[str]]:
        """準備要導入到資料庫的文件資料

        Args:
            cpe_data: CPE 資料列表

        Returns:
            返回文件內容、中繼資料和ID的元組
        """
        documents = []
        metadatas = []
        ids = []

        for i, item in enumerate(cpe_data):
            try:
                # 取得 CPE 2.3 URI 作為唯一識別符
                cpe23uri = item.get('cpe23Uri', '')
                if not cpe23uri:
                    logger.warning(f"第 {i} 筆資料缺少 cpe23Uri，將略過")
                    continue

                # 使用 CPE 2.3 URI 作為 ID
                doc_id = cpe23uri

                # 製作優化的文件內容
                doc_content = self.prepare_search_text(item)

                # 準備豐富的中繼資料，方便後續檢索和過濾
                metadata = {
                    'vendor': item.get('vendor', ''),
                    'product': item.get('product', ''),
                    'version': item.get('version', ''),
                    'cpe22Uri': item.get('cpe22Uri', ''),
                    'cpe23Uri': cpe23uri,
                    'title': item.get('title', ''),
                    # 將 references 截斷以避免過長
                    'references': item.get('references', '')[:1000] if item.get('references') else ''
                }

                documents.append(doc_content)
                metadatas.append(metadata)
                ids.append(doc_id)

            except Exception as e:
                logger.warning(f"處理第 {i} 筆資料時發生錯誤: {str(e)}")
                continue

        return documents, metadatas, ids

    def import_data(self, file_path: Union[str, Path], batch_size: int = 1000,
                    reset_collection: bool = False) -> None:
        """導入 CPE 資料到資料庫

        Args:
            file_path: CPE JSON 檔案路徑
            batch_size: 批次處理大小. 預設為 1000.
            reset_collection: 是否重置集合. 預設為 False.
        """
        try:
            # 如果需要重置集合
            if reset_collection:
                self._reset_collection()

            # 讀取資料
            cpe_data = self.load_cpe_data(file_path)

            # 準備文件
            logger.info("準備文件資料...")
            documents, metadatas, ids = self.prepare_documents(cpe_data)
            logger.info(f"準備了 {len(documents)} 筆有效的 CPE 資料")

            # 批次處理
            total_items = len(documents)
            for i in range(0, total_items, batch_size):
                batch_end = min(i + batch_size, total_items)
                batch_docs = documents[i:batch_end]
                batch_meta = metadatas[i:batch_end]
                batch_ids = ids[i:batch_end]

                logger.info(f"正在導入批次 {i//batch_size + 1}/{(total_items-1)//batch_size + 1} " +
                            f"({i+1}-{batch_end}/{total_items})...")

                try:
                    # 使用 upsert 而非 add，以便處理重複的 CPE ID
                    self.collection.upsert(
                        documents=batch_docs,
                        metadatas=batch_meta,
                        ids=batch_ids
                    )
                    logger.info(f"已處理 {batch_end}/{total_items} 筆資料")
                except Exception as e:
                    logger.error(f"批次處理時發生錯誤: {str(e)}")
                    logger.error(f"問題批次範圍: {i+1}-{batch_end}")
                    # 繼續處理下一批，而不是中斷整個過程
                    continue

            logger.info(f"成功導入 CPE 資料，總計 {total_items} 筆")

        except Exception as e:
            logger.error(f"導入資料時發生錯誤: {str(e)}")
            raise

    def _reset_collection(self) -> None:
        """重置集合，處理不同版本的ChromaDB可能的差異"""
        logger.info("重置集合...")
        try:
            # 嘗試列出所有集合，然後刪除目標集合
            collection_names = [col for col in self.client.list_collections()]
            if "cpe_dictionary" in collection_names:
                self.client.delete_collection("cpe_dictionary")
            logger.info("成功刪除現有集合")
        except Exception as e:
            logger.warning(f"使用list_collections刪除集合時發生錯誤: {str(e)}")
            # 備用方法: 嘗試直接獲取然後刪除
            try:
                self.client.get_collection("cpe_dictionary")
                self.client.delete_collection("cpe_dictionary")
                logger.info("使用備用方法成功刪除現有集合")
            except Exception:
                # 如果集合不存在，忽略錯誤
                logger.info("集合不存在，將新建集合")
                pass

        # 創建新集合
        self.collection = self.client.create_collection(
            name="cpe_dictionary",
            metadata={"description": "CPE Dictionary Collection"},
            embedding_function=self.embedding_function
        )
        logger.info("集合已重置")

    def search(self,
               vendor: Optional[str] = None,
               product: Optional[str] = None,
               version: Optional[str] = None,
               n_results: int = 5) -> Dict[str, Any]:
        """優化的搜尋方法，使用多階段匹配邏輯，並加強title比對

        Args:
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號
            n_results: 返回結果數量

        Returns:
            搜尋結果
        """
        try:
            # 確保至少提供一個搜尋條件
            if not any([vendor, product, version]):
                raise ValueError("必須提供至少一個搜尋條件 (vendor, product, version)")

            # 構建搜尋關鍵字 - 增加一個模擬的title搜尋字串
            search_parts = []

            # 模擬可能的title格式
            simulated_title = []
            if vendor:
                simulated_title.append(vendor.strip())
            if product:
                simulated_title.append(product.strip())
            if simulated_title:
                search_parts.append(" ".join(simulated_title))

            # 加入原始的搜尋條件
            if vendor:
                search_parts.append(f"{vendor}")
            if product:
                search_parts.append(f"{product}")
            if version:
                search_parts.append(f"{version}")

            search_query = " ".join(search_parts)

            # 獲取初步結果
            original_results = self.collection.query(
                query_texts=[search_query],
                n_results=n_results * 3,  # 擴大搜尋範圍，後續會篩選
                include=['metadatas', 'distances']
            )

            # 重新排序和過濾結果
            sorted_results = self._process_search_results(
                original_results, vendor, product, version, n_results
            )

            return sorted_results

        except Exception as e:
            logger.error(f"搜尋時發生錯誤: {str(e)}")
            raise

    def _process_search_results(self, original_results, vendor, product, version, n_results):
        """處理搜尋結果，重新排序和過濾，加強對title的匹配考量

        Args:
            original_results: 原始搜尋結果
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號
            n_results: 返回結果數量

        Returns:
            處理後的搜尋結果
        """
        # 如果沒有得到任何結果，直接返回空結果
        if not original_results['metadatas'][0]:
            return {
                'original_results': original_results,
                'filtered_results': {
                    'ids': [[]],
                    'metadatas': [[]],
                    'distances': [[]]
                },
                'is_filtered': True
            }

        # 計算每個結果的綜合分數
        combined_scores = []

        # 權重設定
        title_weight = 0.5  # title匹配度的權重
        vendor_weight = 0.3  # 廠商匹配度的權重
        distance_weight = 0.2  # 原始距離的權重

        for i, meta in enumerate(original_results['metadatas'][0]):
            # 初始化分數
            title_score = 0.0
            vendor_score = 0.0

            # 原始距離分數
            distance = original_results['distances'][0][i]

            # 1. 計算title匹配度
            if vendor or product:
                db_title = meta['title'].lower()

                # 使用輸入構建可能的title片段
                search_fragments = []
                if vendor:
                    search_fragments.append(vendor.lower())
                if product:
                    search_fragments.append(product.lower())

                # 計算每個片段與title的相似度
                fragment_scores = []
                for fragment in search_fragments:
                    if fragment in db_title:
                        fragment_scores.append(0.9)  # 直接包含給予高分
                    else:
                        fragment_scores.append(
                            StringMatcher.calculate_similarity(fragment, db_title))

                # 取平均作為title分數
                if fragment_scores:
                    title_score = sum(fragment_scores) / len(fragment_scores)

            # 2. 計算廠商匹配度
            if vendor:
                db_vendor = meta['vendor'].lower()
                vendor_score = StringMatcher.calculate_similarity(
                    vendor.lower(), db_vendor)

            # 3. 計算版本匹配度
            version_match = 1.0
            if version and meta['version']:
                version_match = 1.0 if StringMatcher.version_match(
                    version, meta['version']) else 0.2

            # 計算綜合分數 (分數越低越好，與距離概念一致)
            combined_distance = (
                (1 - title_score) * title_weight +
                (1 - vendor_score) * vendor_weight +
                distance * distance_weight
            )

            # 如果版本不匹配，增加距離
            if version and not StringMatcher.version_match(version, meta['version']):
                combined_distance += 0.5

            combined_scores.append(combined_distance)

        # 根據綜合分數排序
        indices = sorted(range(len(combined_scores)),
                         key=lambda i: combined_scores[i])
        sorted_ids = [original_results['ids'][0][i] for i in indices]
        sorted_metadatas = [original_results['metadatas'][0][i]
                            for i in indices]
        sorted_distances = [combined_scores[i] for i in indices]

        # 提取前n_results個作為原始結果
        original_results = {
            'ids': [sorted_ids[:n_results]],
            'metadatas': [sorted_metadatas[:n_results]],
            'distances': [sorted_distances[:n_results]]
        }

        # 進行最終的精確過濾
        filtered_indices = []
        for i, metadata in enumerate(original_results['metadatas'][0]):
            # 先檢查title是否有匹配
            title_match = True
            if vendor or product:
                title_match = False
                title_lower = metadata['title'].lower()

                # 檢查vendor和product是否出現在title中
                if vendor and vendor.lower() in title_lower:
                    title_match = True
                if product and product.lower() in title_lower:
                    title_match = True

            # 再檢查具體欄位
            field_match = True
            if vendor and vendor.lower() not in metadata['vendor'].lower():
                field_match = False
            if product and product.lower() not in metadata['product'].lower():
                field_match = False
            if version and not StringMatcher.version_match(version, metadata['version']):
                field_match = False

            # title或欄位匹配時加入結果
            if title_match or field_match:
                filtered_indices.append(i)

        # 創建結果字典
        results = {
            'original_results': original_results,
            'filtered_results': None,
            'is_filtered': True
        }

        # 根據過濾後的索引重建結果
        if filtered_indices:
            filtered_results = {
                'ids': [[original_results['ids'][0][i] for i in filtered_indices]],
                'metadatas': [[original_results['metadatas'][0][i] for i in filtered_indices]],
                'distances': [[original_results['distances'][0][i] for i in filtered_indices]]
            }

            results['filtered_results'] = filtered_results
        else:
            # 如果過濾後沒有結果，設定空結果
            results['filtered_results'] = {
                'ids': [[]],
                'metadatas': [[]],
                'distances': [[]]
            }

        return results

    def get_collection_info(self) -> Dict[str, Any]:
        """獲取集合資訊

        Returns:
            集合資訊
        """
        try:
            # 獲取集合計數
            count = self.collection.count()

            # 判斷使用的嵌入模型類型
            try:
                # 嘗試檢查嵌入函數的類型
                if hasattr(embedding_functions, 'DefaultEmbeddingFunction') and \
                   isinstance(self.embedding_function, embedding_functions.DefaultEmbeddingFunction):
                    model_type = "Default"
                else:
                    # 嘗試使用不同的方式判斷
                    model_name = getattr(
                        self.embedding_function, '_model_name', None)
                    if model_name and 'huggingface' in str(model_name).lower():
                        model_type = "HuggingFace"
                    else:
                        model_type = "Default" if not self.use_gpu else "HuggingFace"
            except Exception as e:
                logger.warning(f"判斷嵌入模型類型時發生錯誤: {str(e)}")
                # 回退到基於 use_gpu 的簡單判斷
                model_type = "Default" if not self.use_gpu else "HuggingFace"

            # 獲取集合中繼資料
            collection_info = {
                "name": self.collection.name,
                "metadata": self.collection.metadata,
                "count": count,
                "embedding_model": model_type,
                "device": "GPU" if self.use_gpu else "CPU"
            }

            return collection_info
        except Exception as e:
            logger.error(f"獲取集合資訊時發生錯誤: {str(e)}")
            raise


class BatchSearcher:
    """批量搜尋處理器"""

    @staticmethod
    def batch_search_from_csv(db_manager: CPEDatabaseManager,
                              csv_file_path: str,
                              output_file_path: Optional[str] = None,
                              use_standardizer: bool = True) -> str:
        """優化的批量搜索功能，加入更好的結果篩選和相關性排序

        Args:
            db_manager: CPE資料庫管理器實例
            csv_file_path: 輸入CSV檔案路徑
            output_file_path: 輸出檔案路徑。如果為None，會自動生成檔名
            use_standardizer: 是否使用標準化預處理器。預設為True

        Returns:
            輸出檔案路徑
        """
        if not output_file_path:
            # 生成輸出檔名，包含時間戳記
            timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            output_file_path = f"search_results_{timestamp}.txt"

        # 統計搜尋資訊
        total_items = 0
        items_with_results = 0

        logger.info(f"開始從 {csv_file_path} 批次搜尋，結果將輸出到 {output_file_path}")
        logger.info(f"是否使用標準化預處理器: {use_standardizer}")

        try:
            with open(csv_file_path, 'r', encoding='utf-8') as csv_file, \
                    open(output_file_path, 'w', encoding='utf-8') as output_file:

                # 寫入檔案標頭
                BatchSearcher._write_header(
                    output_file, csv_file_path, use_standardizer)

                # 讀取CSV
                csv_reader = csv.DictReader(csv_file)

                # 檢查CSV是否有必要的欄位
                BatchSearcher._validate_csv_fields(csv_reader.fieldnames)

                # 處理每一行
                for i, row in enumerate(csv_reader, 1):
                    total_items += 1

                    # 獲取原始輸入
                    original_vendor = row.get('vendor', '').strip() or None
                    original_product = row.get('product', '').strip() or None
                    original_version = row.get('version', '').strip() or None

                    # 如果所有欄位都是空的，跳過這一行
                    if not any([original_vendor, original_product, original_version]):
                        logger.warning(f"第 {i} 行: 所有搜尋條件為空，跳過")
                        output_file.write(f"項目 {i}: 所有搜尋條件為空，跳過\n\n")
                        continue

                    # 處理輸入並進行搜尋
                    has_results = BatchSearcher._process_row(
                        i, db_manager, output_file,
                        original_vendor, original_product, original_version,
                        use_standardizer
                    )

                    if has_results:
                        items_with_results += 1

                # 寫入摘要
                BatchSearcher._write_summary(
                    output_file, total_items, items_with_results, use_standardizer
                )

            logger.info(
                f"批次搜尋完成，共處理 {total_items} 項，{items_with_results} 項有結果")
            return output_file_path

        except Exception as e:
            logger.error(f"批次搜尋過程中發生錯誤: {str(e)}")
            raise

    @staticmethod
    def _write_header(output_file, csv_file_path, use_standardizer):
        """寫入搜尋結果檔案的標頭"""
        if use_standardizer:
            output_file.write("CPE資料庫搜尋結果 - 批次處理 (含標準化預處理)\n")
        else:
            output_file.write("CPE資料庫搜尋結果 - 批次處理\n")

        output_file.write(f"輸入檔案: {csv_file_path}\n")
        output_file.write(
            f"處理時間: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        output_file.write(f"{'='*80}\n\n")

    @staticmethod
    def _validate_csv_fields(field_names):
        """驗證CSV欄位是否符合要求"""
        required_fields = ['vendor', 'product', 'version']
        missing_fields = [
            field for field in required_fields if field not in field_names]
        if missing_fields:
            raise ValueError(f"CSV檔案缺少必要欄位: {', '.join(missing_fields)}")

    @staticmethod
    def _process_row(row_num, db_manager, output_file,
                     original_vendor, original_product, original_version,
                     use_standardizer):
        """處理搜尋CSV的單行資料"""
        try:
            # 如果使用標準化預處理器，處理輸入
            if use_standardizer:
                vendor, product, version = CPEInputStandardizer.standardize_input(
                    original_vendor, original_product, original_version)

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {row_num}:\n")
                output_file.write(
                    f"  原始廠商: {original_vendor or '無'} -> 標準化: {vendor or '無'}\n")
                output_file.write(
                    f"  原始產品: {original_product or '無'} -> 標準化: {product or '無'}\n")
                output_file.write(
                    f"  原始版本: {original_version or '無'} -> 標準化: {version or '無'}\n\n")
            else:
                vendor = original_vendor
                product = original_product
                version = original_version

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {row_num}:\n")
                output_file.write(f"  廠商: {vendor or '無'}\n")
                output_file.write(f"  產品: {product or '無'}\n")
                output_file.write(f"  版本: {version or '無'}\n\n")

            # 搜尋
            results = db_manager.search(
                vendor=vendor, product=product, version=version)

            result_text = SearchResultFormatter.format_search_results(results)

            # 檢查是否有搜尋結果
            has_results = False
            filtered_results = results.get('filtered_results', {})
            if filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
                has_results = True

            # 寫入搜尋結果
            output_file.write(result_text)
            output_file.write(f"\n{'='*80}\n\n")

            # 記錄日誌
            if has_results:
                logger.info(
                    f"第 {row_num} 行: 搜尋成功，找到 {len(filtered_results['metadatas'][0])} 筆結果")
            else:
                logger.info(f"第 {row_num} 行: 搜尋成功，但沒有符合的結果")

            return has_results

        except Exception as e:
            logger.error(f"第 {row_num} 行: 搜尋時發生錯誤: {str(e)}")
            output_file.write(f"搜尋時發生錯誤: {str(e)}\n\n")
            output_file.write(f"{'='*80}\n\n")
            return False

    @staticmethod
    def _write_summary(output_file, total_items, items_with_results, use_standardizer):
        """寫入搜尋結果摘要"""
        output_file.write("批次搜尋摘要:\n")
        output_file.write(f"總項目數: {total_items}\n")
        output_file.write(f"有結果的項目數: {items_with_results}\n")
        output_file.write(f"無結果的項目數: {total_items - items_with_results}\n")
        if use_standardizer:
            output_file.write("使用標準化預處理: 是\n")
        else:
            output_file.write("使用標準化預處理: 否\n")


class SearchResultFormatter:
    """搜尋結果格式化工具類"""

    @staticmethod
    def format_search_results(results: Dict[str, Any]) -> str:
        """格式化搜尋結果為可讀的文字

        Args:
            results: 搜尋結果

        Returns:
            格式化的搜尋結果文字
        """
        if not results:
            return "未找到符合的結果"

        output = []

        # 處理原始結果
        original_results = results.get('original_results', {})
        if original_results and original_results.get('metadatas') and original_results['metadatas'][0]:
            output.append("\n=== 原始搜尋結果 ===")
            for i, (metadata, distance) in enumerate(zip(original_results['metadatas'][0],
                                                         original_results.get('distances', [[0] * len(original_results['metadatas'][0])])[0])):
                score = 1.0 - (distance / 2.0)  # 將距離轉換為可理解的分數

                output.append(f"\n原始結果 {i+1} (相似度: {score:.2f}):")
                output.append(f"完整名稱: {metadata['title']}")  # 先顯示title
                output.append(f"產品: {metadata['product']}")
                output.append(f"廠商: {metadata['vendor']}")
                output.append(f"版本: {metadata['version']}")
                output.append(f"CPE23: {metadata['cpe23Uri']}")

        # 處理過濾結果
        filtered_results = results.get('filtered_results', {})
        if results.get('is_filtered') and filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
            output.append("\n=== 過濾後的結果 ===")
            for i, (metadata, distance) in enumerate(zip(filtered_results['metadatas'][0],
                                                         filtered_results.get('distances', [[0] * len(filtered_results['metadatas'][0])])[0])):
                score = 1.0 - (distance / 2.0)

                output.append(f"\n過濾結果 {i+1} (相似度: {score:.2f}):")
                output.append(f"完整名稱: {metadata['title']}")  # 先顯示title
                output.append(f"產品: {metadata['product']}")
                output.append(f"廠商: {metadata['vendor']}")
                output.append(f"版本: {metadata['version']}")
                output.append(f"CPE23: {metadata['cpe23Uri']}")
        elif results.get('is_filtered') and (not filtered_results or not filtered_results.get('metadatas') or not filtered_results['metadatas'][0]):
            output.append("\n=== 過濾後的結果 ===")
            output.append("過濾後沒有符合條件的結果")

        return "\n".join(output)


def main():
    """主程式入口"""
    # 設定檔案路徑
    file_path = "../data/convert/official-cpe-dictionary_v2.3.json"

    try:
        use_gpu = False
        embedding_model = "default"
        logger.info("使用預設嵌入模型 (CPU)")

        # 初始化資料庫管理器
        db_manager = CPEDatabaseManager(
            use_gpu=use_gpu, embedding_model=embedding_model)

        # 顯示選單
        while True:
            print("\n=== CPE 資料庫管理工具 ===")
            print("1. 導入 CPE 資料")
            print("2. 查看集合資訊")
            print("3. 單次搜尋")
            print("4. 單次搜尋 (含標準化預處理)")
            print("5. 從CSV檔案批次搜尋")
            print("6. 從CSV檔案批次搜尋 (含標準化預處理)")
            print("0. 退出")

            choice = input("請選擇操作 (0-6): ").strip()

            if choice == "0":
                print("程式已結束。")
                break

            elif choice == "1":
                # 導入資料
                reset = input("是否要重置現有集合？(y/n): ").strip().lower() == 'y'
                db_manager.import_data(file_path, reset_collection=reset)

            elif choice == "2":
                # 顯示集合資訊
                collection_info = db_manager.get_collection_info()
                print("\n集合資訊:")
                print(f"名稱: {collection_info['name']}")
                print(f"項目數量: {collection_info['count']}")
                print(f"嵌入模型: {collection_info['embedding_model']}")
                print(f"使用裝置: {collection_info['device']}")

            elif choice == "3":
                # 單次搜尋
                main_single_search(db_manager, use_standardizer=False)

            elif choice == "4":
                # 單次搜尋(含標準化)
                main_single_search(db_manager, use_standardizer=True)

            elif choice == "5":
                # 批次搜尋
                main_batch_search(db_manager, use_standardizer=False)

            elif choice == "6":
                # 批次搜尋(含標準化)
                main_batch_search(db_manager, use_standardizer=True)

            else:
                print("無效的選擇，請重新輸入。")

    except Exception as e:
        logger.error(f"程式執行時發生錯誤: {str(e)}")
        print(f"錯誤: {str(e)}")
        raise


def main_single_search(db_manager, use_standardizer=False):
    """處理單次搜尋的主邏輯

    Args:
        db_manager: 資料庫管理器
        use_standardizer: 是否使用標準化處理
    """
    while True:
        print("\n請輸入搜尋條件 (直接按 Enter 跳過):")
        original_vendor = input("廠商名稱: ").strip() or None
        original_product = input("產品名稱: ").strip() or None
        original_version = input("版本號: ").strip() or None

        if not any([original_vendor, original_product, original_version]):
            print("至少需要提供一個搜尋條件")
            continue

        try:
            if use_standardizer:
                # 標準化處理
                vendor, product, version = CPEInputStandardizer.standardize_input(
                    original_vendor, original_product, original_version)

                # 顯示標準化結果
                print("\n標準化後的搜尋條件:")
                print(
                    f"原始廠商: {original_vendor or '無'} -> 標準化: {vendor or '無'}")
                print(
                    f"原始產品: {original_product or '無'} -> 標準化: {product or '無'}")
                print(
                    f"原始版本: {original_version or '無'} -> 標準化: {version or '無'}")

                # 詢問是否使用標準化結果
                use_std = input(
                    "\n是否使用標準化結果進行搜尋? (y/n, 預設為y): ").strip().lower() != 'n'

                if use_std:
                    # 使用標準化結果
                    results = db_manager.search(
                        vendor=vendor, product=product, version=version)
                    print("\n使用標準化條件搜尋結果:")
                else:
                    # 使用原始輸入
                    results = db_manager.search(
                        vendor=original_vendor, product=original_product, version=original_version)
                    print("\n使用原始條件搜尋結果:")
            else:
                # 不使用標準化，直接搜尋
                results = db_manager.search(
                    vendor=original_vendor, product=original_product, version=original_version)
                print("\n搜尋結果:")

            print(SearchResultFormatter.format_search_results(results))

            if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                break
        except Exception as e:
            print(f"搜尋過程中發生錯誤: {str(e)}")
            if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                break


def main_batch_search(db_manager, use_standardizer=False):
    """處理批次搜尋的主邏輯

    Args:
        db_manager: 資料庫管理器
        use_standardizer: 是否使用標準化處理
    """
    csv_file_path = input("請輸入CSV檔案路徑: ").strip()
    if not os.path.exists(csv_file_path):
        print(f"找不到檔案: {csv_file_path}")
        return

    try:
        output_path = BatchSearcher.batch_search_from_csv(
            db_manager, csv_file_path, use_standardizer=use_standardizer
        )
        print(f"\n批次搜尋完成! 結果已輸出至: {output_path}")
    except Exception as e:
        print(f"批次搜尋失敗: {str(e)}")


if __name__ == "__main__":
    main()
# Out:
# 2025-03-14 01:25:14,012 - __main__ - INFO - 使用預設嵌入模型 (CPU)
# 2025-03-14 01:25:14,013 - __main__ - INFO - 使用嵌入模型: 預設
# 2025-03-14 01:25:14,101 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-03-14 01:25:14,218 - __main__ - INFO - 成功設定資料庫連接，儲存位置: ../database/cpe_database
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 2025-03-14 01:27:26,468 - __main__ - INFO - 開始從 ./transform_data.csv 批次搜尋，結果將輸出到 search_results_20250314_012726.txt
# 2025-03-14 01:27:26,470 - __main__ - INFO - 是否使用標準化預處理器: True
# 2025-03-14 01:27:29,798 - __main__ - INFO - 第 1 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:29,857 - __main__ - INFO - 第 2 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:29,925 - __main__ - INFO - 第 3 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,014 - __main__ - INFO - 第 4 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,080 - __main__ - INFO - 第 5 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,147 - __main__ - INFO - 第 6 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,226 - __main__ - INFO - 第 7 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,297 - __main__ - INFO - 第 8 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,382 - __main__ - INFO - 第 9 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,454 - __main__ - INFO - 第 10 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,524 - __main__ - INFO - 第 11 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,597 - __main__ - INFO - 第 12 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,660 - __main__ - INFO - 第 13 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,730 - __main__ - INFO - 第 14 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,801 - __main__ - INFO - 第 15 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,875 - __main__ - INFO - 第 16 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:30,947 - __main__ - INFO - 第 17 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,012 - __main__ - INFO - 第 18 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,064 - __main__ - INFO - 第 19 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,126 - __main__ - INFO - 第 20 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,197 - __main__ - INFO - 第 21 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,273 - __main__ - INFO - 第 22 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:31,350 - __main__ - INFO - 第 23 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:31,423 - __main__ - INFO - 第 24 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,491 - __main__ - INFO - 第 25 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:31,559 - __main__ - INFO - 第 26 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,630 - __main__ - INFO - 第 27 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:31,702 - __main__ - INFO - 第 28 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,771 - __main__ - INFO - 第 29 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,851 - __main__ - INFO - 第 30 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:31,940 - __main__ - INFO - 第 31 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:32,018 - __main__ - INFO - 第 32 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,086 - __main__ - INFO - 第 33 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,154 - __main__ - INFO - 第 34 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,224 - __main__ - INFO - 第 35 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:32,287 - __main__ - INFO - 第 36 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,360 - __main__ - INFO - 第 37 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,418 - __main__ - INFO - 第 38 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:32,489 - __main__ - INFO - 第 39 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,563 - __main__ - INFO - 第 40 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,643 - __main__ - INFO - 第 41 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,720 - __main__ - INFO - 第 42 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,794 - __main__ - INFO - 第 43 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:32,866 - __main__ - INFO - 第 44 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,933 - __main__ - INFO - 第 45 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:32,996 - __main__ - INFO - 第 46 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,070 - __main__ - INFO - 第 47 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,140 - __main__ - INFO - 第 48 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:33,216 - __main__ - INFO - 第 49 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,282 - __main__ - INFO - 第 50 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,345 - __main__ - INFO - 第 51 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:33,400 - __main__ - INFO - 第 52 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,454 - __main__ - INFO - 第 53 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,519 - __main__ - INFO - 第 54 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:33,588 - __main__ - INFO - 第 55 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,659 - __main__ - INFO - 第 56 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:33,739 - __main__ - INFO - 第 57 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,794 - __main__ - INFO - 第 58 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,860 - __main__ - INFO - 第 59 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:33,940 - __main__ - INFO - 第 60 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,003 - __main__ - INFO - 第 61 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,077 - __main__ - INFO - 第 62 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,141 - __main__ - INFO - 第 63 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,208 - __main__ - INFO - 第 64 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,306 - __main__ - INFO - 第 65 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,366 - __main__ - INFO - 第 66 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,430 - __main__ - INFO - 第 67 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,489 - __main__ - INFO - 第 68 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,557 - __main__ - INFO - 第 69 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,605 - __main__ - INFO - 第 70 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,675 - __main__ - INFO - 第 71 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,743 - __main__ - INFO - 第 72 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,816 - __main__ - INFO - 第 73 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,880 - __main__ - INFO - 第 74 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:34,947 - __main__ - INFO - 第 75 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,013 - __main__ - INFO - 第 76 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,079 - __main__ - INFO - 第 77 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,144 - __main__ - INFO - 第 78 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,205 - __main__ - INFO - 第 79 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,289 - __main__ - INFO - 第 80 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,356 - __main__ - INFO - 第 81 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:35,426 - __main__ - INFO - 第 82 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,479 - __main__ - INFO - 第 83 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,540 - __main__ - INFO - 第 84 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,608 - __main__ - INFO - 第 85 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,676 - __main__ - INFO - 第 86 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,750 - __main__ - INFO - 第 87 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,826 - __main__ - INFO - 第 88 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:35,887 - __main__ - INFO - 第 89 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:35,969 - __main__ - INFO - 第 90 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,040 - __main__ - INFO - 第 91 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,098 - __main__ - INFO - 第 92 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,158 - __main__ - INFO - 第 93 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,210 - __main__ - INFO - 第 94 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,275 - __main__ - INFO - 第 95 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,357 - __main__ - INFO - 第 96 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:36,421 - __main__ - INFO - 第 97 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,484 - __main__ - INFO - 第 98 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,551 - __main__ - INFO - 第 99 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:36,619 - __main__ - INFO - 第 100 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,670 - __main__ - INFO - 第 101 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,721 - __main__ - INFO - 第 102 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:36,799 - __main__ - INFO - 第 103 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:36,875 - __main__ - INFO - 第 104 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:36,938 - __main__ - INFO - 第 105 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,011 - __main__ - INFO - 第 106 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,071 - __main__ - INFO - 第 107 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,138 - __main__ - INFO - 第 108 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,194 - __main__ - INFO - 第 109 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,268 - __main__ - INFO - 第 110 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,333 - __main__ - INFO - 第 111 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,395 - __main__ - INFO - 第 112 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,445 - __main__ - INFO - 第 113 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,510 - __main__ - INFO - 第 114 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,573 - __main__ - INFO - 第 115 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,644 - __main__ - INFO - 第 116 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:37,704 - __main__ - INFO - 第 117 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,765 - __main__ - INFO - 第 118 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,817 - __main__ - INFO - 第 119 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,890 - __main__ - INFO - 第 120 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:37,957 - __main__ - INFO - 第 121 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:38,018 - __main__ - INFO - 第 122 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,105 - __main__ - INFO - 第 123 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,183 - __main__ - INFO - 第 124 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,261 - __main__ - INFO - 第 125 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,315 - __main__ - INFO - 第 126 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:38,373 - __main__ - INFO - 第 127 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:38,440 - __main__ - INFO - 第 128 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,507 - __main__ - INFO - 第 129 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,563 - __main__ - INFO - 第 130 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,615 - __main__ - INFO - 第 131 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:38,664 - __main__ - INFO - 第 132 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:38,740 - __main__ - INFO - 第 133 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,814 - __main__ - INFO - 第 134 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:38,891 - __main__ - INFO - 第 135 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:38,934 - __main__ - INFO - 第 136 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:27:39,011 - __main__ - INFO - 第 137 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,087 - __main__ - INFO - 第 138 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,157 - __main__ - INFO - 第 139 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,217 - __main__ - INFO - 第 140 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,285 - __main__ - INFO - 第 141 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,349 - __main__ - INFO - 第 142 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,413 - __main__ - INFO - 第 143 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,480 - __main__ - INFO - 第 144 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,540 - __main__ - INFO - 第 145 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,622 - __main__ - INFO - 第 146 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,689 - __main__ - INFO - 第 147 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,765 - __main__ - INFO - 第 148 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,846 - __main__ - INFO - 第 149 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,932 - __main__ - INFO - 第 150 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:39,991 - __main__ - INFO - 第 151 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,068 - __main__ - INFO - 第 152 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,141 - __main__ - INFO - 第 153 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,230 - __main__ - INFO - 第 154 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,297 - __main__ - INFO - 第 155 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,376 - __main__ - INFO - 第 156 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,450 - __main__ - INFO - 第 157 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,529 - __main__ - INFO - 第 158 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,586 - __main__ - INFO - 第 159 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,666 - __main__ - INFO - 第 160 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,730 - __main__ - INFO - 第 161 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,802 - __main__ - INFO - 第 162 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,884 - __main__ - INFO - 第 163 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:40,955 - __main__ - INFO - 第 164 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,038 - __main__ - INFO - 第 165 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,142 - __main__ - INFO - 第 166 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,256 - __main__ - INFO - 第 167 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,327 - __main__ - INFO - 第 168 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,482 - __main__ - INFO - 第 169 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,563 - __main__ - INFO - 第 170 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,661 - __main__ - INFO - 第 171 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,748 - __main__ - INFO - 第 172 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,865 - __main__ - INFO - 第 173 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:41,951 - __main__ - INFO - 第 174 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,048 - __main__ - INFO - 第 175 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,129 - __main__ - INFO - 第 176 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,240 - __main__ - INFO - 第 177 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,343 - __main__ - INFO - 第 178 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,440 - __main__ - INFO - 第 179 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,556 - __main__ - INFO - 第 180 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,629 - __main__ - INFO - 第 181 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,716 - __main__ - INFO - 第 182 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,811 - __main__ - INFO - 第 183 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,870 - __main__ - INFO - 第 184 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:42,923 - __main__ - INFO - 第 185 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,011 - __main__ - INFO - 第 186 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,079 - __main__ - INFO - 第 187 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,186 - __main__ - INFO - 第 188 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,299 - __main__ - INFO - 第 189 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,384 - __main__ - INFO - 第 190 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,486 - __main__ - INFO - 第 191 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,556 - __main__ - INFO - 第 192 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,633 - __main__ - INFO - 第 193 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,696 - __main__ - INFO - 第 194 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,755 - __main__ - INFO - 第 195 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,815 - __main__ - INFO - 第 196 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,895 - __main__ - INFO - 第 197 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:43,974 - __main__ - INFO - 第 198 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,031 - __main__ - INFO - 第 199 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,105 - __main__ - INFO - 第 200 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,164 - __main__ - INFO - 第 201 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,231 - __main__ - INFO - 第 202 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,310 - __main__ - INFO - 第 203 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,383 - __main__ - INFO - 第 204 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,447 - __main__ - INFO - 第 205 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,517 - __main__ - INFO - 第 206 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,593 - __main__ - INFO - 第 207 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,663 - __main__ - INFO - 第 208 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,733 - __main__ - INFO - 第 209 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,810 - __main__ - INFO - 第 210 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,890 - __main__ - INFO - 第 211 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:44,956 - __main__ - INFO - 第 212 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,027 - __main__ - INFO - 第 213 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,089 - __main__ - INFO - 第 214 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,135 - __main__ - INFO - 第 215 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,202 - __main__ - INFO - 第 216 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,270 - __main__ - INFO - 第 217 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,348 - __main__ - INFO - 第 218 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,427 - __main__ - INFO - 第 219 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,489 - __main__ - INFO - 第 220 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,545 - __main__ - INFO - 第 221 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,616 - __main__ - INFO - 第 222 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,693 - __main__ - INFO - 第 223 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,758 - __main__ - INFO - 第 224 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,832 - __main__ - INFO - 第 225 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,913 - __main__ - INFO - 第 226 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:45,970 - __main__ - INFO - 第 227 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,039 - __main__ - INFO - 第 228 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,112 - __main__ - INFO - 第 229 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,190 - __main__ - INFO - 第 230 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,251 - __main__ - INFO - 第 231 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,314 - __main__ - INFO - 第 232 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,366 - __main__ - INFO - 第 233 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,427 - __main__ - INFO - 第 234 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,483 - __main__ - INFO - 第 235 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,537 - __main__ - INFO - 第 236 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,604 - __main__ - INFO - 第 237 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,661 - __main__ - INFO - 第 238 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,716 - __main__ - INFO - 第 239 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:27:46,717 - __main__ - INFO - 批次搜尋完成，共處理 239 項，78 項有結果
# 批次搜尋完成! 結果已輸出至: search_results_20250314_012726.txt
#
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 找不到檔案: ./transform.csv
#
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 2025-03-14 01:28:14,284 - __main__ - INFO - 開始從 ./transform_data.csv 批次搜尋，結果將輸出到 search_results_20250314_012814.txt
# 2025-03-14 01:28:14,286 - __main__ - INFO - 是否使用標準化預處理器: False
# 2025-03-14 01:28:14,406 - __main__ - INFO - 第 1 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,476 - __main__ - INFO - 第 2 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,535 - __main__ - INFO - 第 3 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,608 - __main__ - INFO - 第 4 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,669 - __main__ - INFO - 第 5 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,739 - __main__ - INFO - 第 6 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,826 - __main__ - INFO - 第 7 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:14,929 - __main__ - INFO - 第 8 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,004 - __main__ - INFO - 第 9 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,064 - __main__ - INFO - 第 10 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,126 - __main__ - INFO - 第 11 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,183 - __main__ - INFO - 第 12 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,247 - __main__ - INFO - 第 13 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,304 - __main__ - INFO - 第 14 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,364 - __main__ - INFO - 第 15 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,427 - __main__ - INFO - 第 16 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,481 - __main__ - INFO - 第 17 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,547 - __main__ - INFO - 第 18 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,615 - __main__ - INFO - 第 19 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,690 - __main__ - INFO - 第 20 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:15,757 - __main__ - INFO - 第 21 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,834 - __main__ - INFO - 第 22 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,906 - __main__ - INFO - 第 23 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:15,968 - __main__ - INFO - 第 24 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,042 - __main__ - INFO - 第 25 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,110 - __main__ - INFO - 第 26 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,169 - __main__ - INFO - 第 27 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,236 - __main__ - INFO - 第 28 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,303 - __main__ - INFO - 第 29 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,363 - __main__ - INFO - 第 30 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,427 - __main__ - INFO - 第 31 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,500 - __main__ - INFO - 第 32 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,555 - __main__ - INFO - 第 33 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,623 - __main__ - INFO - 第 34 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,692 - __main__ - INFO - 第 35 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,757 - __main__ - INFO - 第 36 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,824 - __main__ - INFO - 第 37 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:16,895 - __main__ - INFO - 第 38 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:16,953 - __main__ - INFO - 第 39 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,015 - __main__ - INFO - 第 40 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,086 - __main__ - INFO - 第 41 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,166 - __main__ - INFO - 第 42 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,240 - __main__ - INFO - 第 43 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:17,311 - __main__ - INFO - 第 44 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,387 - __main__ - INFO - 第 45 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:17,464 - __main__ - INFO - 第 46 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,525 - __main__ - INFO - 第 47 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,606 - __main__ - INFO - 第 48 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:17,672 - __main__ - INFO - 第 49 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:17,716 - __main__ - INFO - 第 50 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,767 - __main__ - INFO - 第 51 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:17,832 - __main__ - INFO - 第 52 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,888 - __main__ - INFO - 第 53 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:17,966 - __main__ - INFO - 第 54 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:18,035 - __main__ - INFO - 第 55 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,099 - __main__ - INFO - 第 56 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,172 - __main__ - INFO - 第 57 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,238 - __main__ - INFO - 第 58 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,334 - __main__ - INFO - 第 59 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,415 - __main__ - INFO - 第 60 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,472 - __main__ - INFO - 第 61 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,549 - __main__ - INFO - 第 62 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,627 - __main__ - INFO - 第 63 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,704 - __main__ - INFO - 第 64 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,778 - __main__ - INFO - 第 65 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,836 - __main__ - INFO - 第 66 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,906 - __main__ - INFO - 第 67 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:18,980 - __main__ - INFO - 第 68 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,045 - __main__ - INFO - 第 69 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,102 - __main__ - INFO - 第 70 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,175 - __main__ - INFO - 第 71 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,249 - __main__ - INFO - 第 72 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,317 - __main__ - INFO - 第 73 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,381 - __main__ - INFO - 第 74 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,442 - __main__ - INFO - 第 75 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,505 - __main__ - INFO - 第 76 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,562 - __main__ - INFO - 第 77 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,621 - __main__ - INFO - 第 78 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,701 - __main__ - INFO - 第 79 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:19,769 - __main__ - INFO - 第 80 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,834 - __main__ - INFO - 第 81 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:19,888 - __main__ - INFO - 第 82 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:19,950 - __main__ - INFO - 第 83 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,009 - __main__ - INFO - 第 84 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,084 - __main__ - INFO - 第 85 行: 搜尋成功，找到 1 筆結果
# 2025-03-14 01:28:20,169 - __main__ - INFO - 第 86 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,237 - __main__ - INFO - 第 87 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,317 - __main__ - INFO - 第 88 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,386 - __main__ - INFO - 第 89 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,455 - __main__ - INFO - 第 90 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,514 - __main__ - INFO - 第 91 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,570 - __main__ - INFO - 第 92 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,614 - __main__ - INFO - 第 93 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,678 - __main__ - INFO - 第 94 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,751 - __main__ - INFO - 第 95 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,815 - __main__ - INFO - 第 96 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:20,890 - __main__ - INFO - 第 97 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:20,952 - __main__ - INFO - 第 98 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,033 - __main__ - INFO - 第 99 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:21,112 - __main__ - INFO - 第 100 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,168 - __main__ - INFO - 第 101 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,228 - __main__ - INFO - 第 102 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:21,301 - __main__ - INFO - 第 103 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,372 - __main__ - INFO - 第 104 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,444 - __main__ - INFO - 第 105 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:21,521 - __main__ - INFO - 第 106 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,581 - __main__ - INFO - 第 107 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,646 - __main__ - INFO - 第 108 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,726 - __main__ - INFO - 第 109 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,781 - __main__ - INFO - 第 110 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:21,856 - __main__ - INFO - 第 111 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,927 - __main__ - INFO - 第 112 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:21,999 - __main__ - INFO - 第 113 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,075 - __main__ - INFO - 第 114 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:22,144 - __main__ - INFO - 第 115 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,212 - __main__ - INFO - 第 116 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,270 - __main__ - INFO - 第 117 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,343 - __main__ - INFO - 第 118 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,402 - __main__ - INFO - 第 119 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,469 - __main__ - INFO - 第 120 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:22,538 - __main__ - INFO - 第 121 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:22,603 - __main__ - INFO - 第 122 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,685 - __main__ - INFO - 第 123 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,763 - __main__ - INFO - 第 124 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:22,835 - __main__ - INFO - 第 125 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:22,895 - __main__ - INFO - 第 126 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:22,954 - __main__ - INFO - 第 127 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:23,008 - __main__ - INFO - 第 128 行: 搜尋成功，找到 4 筆結果
# 2025-03-14 01:28:23,071 - __main__ - INFO - 第 129 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:23,148 - __main__ - INFO - 第 130 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,218 - __main__ - INFO - 第 131 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,272 - __main__ - INFO - 第 132 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,345 - __main__ - INFO - 第 133 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:23,416 - __main__ - INFO - 第 134 行: 搜尋成功，找到 4 筆結果
# 2025-03-14 01:28:23,479 - __main__ - INFO - 第 135 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:23,541 - __main__ - INFO - 第 136 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,605 - __main__ - INFO - 第 137 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,678 - __main__ - INFO - 第 138 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,748 - __main__ - INFO - 第 139 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:23,817 - __main__ - INFO - 第 140 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:23,878 - __main__ - INFO - 第 141 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:23,956 - __main__ - INFO - 第 142 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:24,027 - __main__ - INFO - 第 143 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:24,089 - __main__ - INFO - 第 144 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:24,156 - __main__ - INFO - 第 145 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,238 - __main__ - INFO - 第 146 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:24,309 - __main__ - INFO - 第 147 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,396 - __main__ - INFO - 第 148 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,475 - __main__ - INFO - 第 149 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:24,539 - __main__ - INFO - 第 150 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,599 - __main__ - INFO - 第 151 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,670 - __main__ - INFO - 第 152 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,741 - __main__ - INFO - 第 153 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,813 - __main__ - INFO - 第 154 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:24,894 - __main__ - INFO - 第 155 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:24,966 - __main__ - INFO - 第 156 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:25,044 - __main__ - INFO - 第 157 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:25,107 - __main__ - INFO - 第 158 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,170 - __main__ - INFO - 第 159 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,242 - __main__ - INFO - 第 160 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,315 - __main__ - INFO - 第 161 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:25,400 - __main__ - INFO - 第 162 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:25,458 - __main__ - INFO - 第 163 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,531 - __main__ - INFO - 第 164 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:25,596 - __main__ - INFO - 第 165 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,655 - __main__ - INFO - 第 166 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,710 - __main__ - INFO - 第 167 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,762 - __main__ - INFO - 第 168 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,838 - __main__ - INFO - 第 169 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:25,921 - __main__ - INFO - 第 170 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:25,995 - __main__ - INFO - 第 171 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:26,060 - __main__ - INFO - 第 172 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,141 - __main__ - INFO - 第 173 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:26,213 - __main__ - INFO - 第 174 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,280 - __main__ - INFO - 第 175 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,346 - __main__ - INFO - 第 176 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,429 - __main__ - INFO - 第 177 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:26,494 - __main__ - INFO - 第 178 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:26,571 - __main__ - INFO - 第 179 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,637 - __main__ - INFO - 第 180 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,704 - __main__ - INFO - 第 181 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,775 - __main__ - INFO - 第 182 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:26,836 - __main__ - INFO - 第 183 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,902 - __main__ - INFO - 第 184 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:26,959 - __main__ - INFO - 第 185 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,017 - __main__ - INFO - 第 186 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:27,075 - __main__ - INFO - 第 187 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,139 - __main__ - INFO - 第 188 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:27,195 - __main__ - INFO - 第 189 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,264 - __main__ - INFO - 第 190 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:27,303 - __main__ - INFO - 第 191 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,362 - __main__ - INFO - 第 192 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,426 - __main__ - INFO - 第 193 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,485 - __main__ - INFO - 第 194 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,561 - __main__ - INFO - 第 195 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,616 - __main__ - INFO - 第 196 行: 搜尋成功，找到 1 筆結果
# 2025-03-14 01:28:27,679 - __main__ - INFO - 第 197 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:27,753 - __main__ - INFO - 第 198 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:27,819 - __main__ - INFO - 第 199 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,887 - __main__ - INFO - 第 200 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:27,942 - __main__ - INFO - 第 201 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,014 - __main__ - INFO - 第 202 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:28,075 - __main__ - INFO - 第 203 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,115 - __main__ - INFO - 第 204 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,191 - __main__ - INFO - 第 205 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,248 - __main__ - INFO - 第 206 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,302 - __main__ - INFO - 第 207 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:28,361 - __main__ - INFO - 第 208 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,417 - __main__ - INFO - 第 209 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:28,484 - __main__ - INFO - 第 210 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:28,547 - __main__ - INFO - 第 211 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,599 - __main__ - INFO - 第 212 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,660 - __main__ - INFO - 第 213 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:28,709 - __main__ - INFO - 第 214 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,776 - __main__ - INFO - 第 215 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,852 - __main__ - INFO - 第 216 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:28,913 - __main__ - INFO - 第 217 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:28,971 - __main__ - INFO - 第 218 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,032 - __main__ - INFO - 第 219 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,087 - __main__ - INFO - 第 220 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:29,155 - __main__ - INFO - 第 221 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,234 - __main__ - INFO - 第 222 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:29,305 - __main__ - INFO - 第 223 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:29,372 - __main__ - INFO - 第 224 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,441 - __main__ - INFO - 第 225 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,520 - __main__ - INFO - 第 226 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,585 - __main__ - INFO - 第 227 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:29,651 - __main__ - INFO - 第 228 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:29,722 - __main__ - INFO - 第 229 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,796 - __main__ - INFO - 第 230 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:29,878 - __main__ - INFO - 第 231 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:29,954 - __main__ - INFO - 第 232 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:30,052 - __main__ - INFO - 第 233 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:30,099 - __main__ - INFO - 第 234 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:30,156 - __main__ - INFO - 第 235 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:30,224 - __main__ - INFO - 第 236 行: 搜尋成功，但沒有符合的結果
# 2025-03-14 01:28:30,298 - __main__ - INFO - 第 237 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:30,363 - __main__ - INFO - 第 238 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:30,434 - __main__ - INFO - 第 239 行: 搜尋成功，找到 5 筆結果
# 2025-03-14 01:28:30,435 - __main__ - INFO - 批次搜尋完成，共處理 239 項，155 項有結果
# 批次搜尋完成! 結果已輸出至: search_results_20250314_012814.txt
#
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 程式已結束。
