# %% [markdown]
# # CPE Format Converter (POC) example Jupyter Notebook
#
# This is a proof of concept for a CPE Format Converter.
#
# ## Description
#
# Due to time constraints, the construction logic and thought process of this Proof of Concept (PoC) will be initially presented in this Jupyter Notebook. Further development and maintenance will continue to implement more comprehensive functionalities, such as automation and a Web User Interface.
#
# > 由於時間限制，此概念驗證（PoC）的建構邏輯與思路將以本 Jupyter Notebook 的形式初步呈現。後續將持續進行開發與維護，以實現自動化、Web 使用者介面等更完善的功能。
#
# ## Design
#
# This Proof of Concept (PoC) aims to provide users with a tool to search for vulnerabilities associated with specific products by inputting Vendor, Product, and Version information. The tool will interact with the National Vulnerability Database (NVD) Common Vulnerabilities and Exposures (CVE) database to retrieve relevant CVE vulnerability data. Since the NVD Vulnerability API (CVE API) uses Common Platform Enumeration (CPE) for searching, user input needs to be converted into CPE format. However, while the CPE format has a standardized specification, there is no standard conversion process, and it cannot be guaranteed that the converted CPE is included in the NVD. To address this issue, we will use the NVD's CPE Directory List as a foundation to convert user input and obtain or generate the correct CPE, subsequently using the NVD Vulnerability API to retrieve further vulnerability data.
#
# > 本概念驗證（PoC）旨在提供使用者一個工具，透過輸入廠商（Vendor）、產品（Product）和版本（Version）資訊，搜尋相關產品的漏洞（Vulnerability）。此工具將與美國國家漏洞資料庫（NVD）的通用漏洞披露（CVE）資料庫互動，取得相關的 CVE 漏洞資訊。由於 NVD 的漏洞應用程式介面（CVE API）使用通用平台列舉（CPE）進行搜尋，因此需要將使用者輸入轉換為 CPE 格式。然而，儘管 CPE 格式具有標準化的規範，卻缺乏標準的轉換流程，且無法確定轉換後的 CPE 是否已被 NVD 收錄。為解決此問題，我們將利用 NVD 提供的 CPE 目錄列表（CPE Directory List）作為基礎，進行使用者輸入的轉換，並取得或產生正確的 CPE，進而使用 NVD 的漏洞應用程式介面取得後續的漏洞資料。
#
# ## Usage
#
# We will leverage the interactive features of Jupyter Notebook to provide detailed explanations of the operational process through segmented code, allowing users to reproduce the same operational results by executing this notebook. Please follow the subsequent operational instructions and code comments for adjustments and execution.
#
# > 我們將利用 Jupyter Notebook 的互動式特性，以分段程式碼的方式詳細說明操作流程，並允許使用者透過執行本 Notebook 複現相同的操作結果。請依照後續的操作說明與程式碼註解進行調整與執行。

# %% [markdown]
# ## Step 1: Get Offical CPE Directory List
#
# Please manually download the CPE Directory List from the official National Vulnerability Database (NVD) website and place the file in the `data` directory of the project repository (Repo). If you have any questions about the operation, please refer to the README file in the `data` directory.
#
# > 請手動自美國國家漏洞資料庫（NVD）官方網站下載 CPE 目錄列表（CPE Directory List），並將檔案放置於專案儲存庫（Repo）的 `data` 目錄中。若對操作方式有疑問，請參閱 `data` 目錄中的 README 檔案。

# %% [markdown]
# ## Step 2: Decompression and Data Pre-processing
#
# The Common Platform Enumeration (CPE) list provided by the National Vulnerability Database (NVD) is in XML format. While detailed and comprehensive, its structure is not ideal for direct import into Chromadb for subsequent operations. Therefore, we will filter and organize the XML content of the CPE list and output it in Comma-Separated Values (CSV) format.
#
# (Converting to CSV format is a non-essential transitional step, primarily to facilitate the review of the organized XML data and accelerate data utilization and analysis.)
#
# The resulting structured CSV data (or Dataframe) will be processed and imported into Chromadb in the subsequent steps.
#
#
# > 由於美國國家漏洞資料庫（NVD）提供的通用平台列舉（CPE）列表為 XML 格式，其結構雖詳盡完整，但不利於直接匯入 Chromadb 進行後續操作。因此，我們將對 CPE 列表的 XML 內容進行篩選與整理，並轉換為逗號分隔值（CSV）格式輸出。
# >
# > （轉換為 CSV 格式為一非必要的過渡步驟，主要目的是為了方便檢視整理後的 XML 資料，以加速資料的使用與分析。）
# >
# > 轉換後的 CSV 結構化資料（或 Dataframe）將於後續步驟中進行計算並匯入 Chromadb。

# %%
from lxml import etree
import json
import csv
import re
from typing import Dict, List, Iterator, Optional, Any, Set, Tuple
import logging
from pathlib import Path
from dataclasses import dataclass, asdict, field
from contextlib import contextmanager


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    normalized_vendor: str  # 新增標準化廠商名稱欄位
    product: str
    version: str
    title: str
    references: str
    variations: List[str] = field(default_factory=list)  # 存儲同一廠商的不同名稱變體


class CPEParser:
    """CPE XML 字典的分析器，用於將 CPE 項目轉換為結構化資料，並處理廠商名稱的標準化"""

    # CPE 命名空間定義
    NAMESPACES = {
        'cpe-23': 'http://scap.nist.gov/schema/cpe-extension/2.3',
        'def': 'http://cpe.mitre.org/dictionary/2.0',
        'xml': 'http://www.w3.org/XML/1998/namespace'
    }

    def __init__(self, xml_file_path: str):
        """初始化 CPE 分析器

        Args:
            xml_file_path (str): XML 檔案路徑
        """
        self.xml_file_path = Path(xml_file_path)
        self.logger = logging.getLogger(__name__)
        self.vendor_variations = {}  # 用於追蹤廠商名稱變體的字典
        self.vendor_canonical_forms = {}  # 用於存儲廠商名稱的標準形式

        if not self.xml_file_path.exists():
            raise FileNotFoundError(f"找不到 XML 檔案: {xml_file_path}")

    @staticmethod
    def normalize_vendor_name(vendor: str) -> str:
        """標準化廠商名稱，處理不同的分隔符號

        Args:
            vendor (str): 原始廠商名稱

        Returns:
            str: 標準化後的廠商名稱
        """
        # 將所有特殊分隔符號（如 '-' 和 '_'）統一替換為一種標準分隔符號
        # 這裡選擇使用 '_' 作為標準分隔符號
        normalized = re.sub(r'[-_]+', '_', vendor.lower())
        return normalized

    def track_vendor_variation(self, original: str, normalized: str) -> None:
        """追蹤廠商名稱的變體

        Args:
            original (str): 原始廠商名稱
            normalized (str): 標準化後的廠商名稱
        """
        if normalized not in self.vendor_variations:
            self.vendor_variations[normalized] = set()

        self.vendor_variations[normalized].add(original)

        # 如果這是我們第一次看到這個標準化廠商名稱，或者如果原始名稱比當前的標準形式更具代表性，
        # 則將其設為標準形式
        if normalized not in self.vendor_canonical_forms or len(original) < len(self.vendor_canonical_forms[normalized]):
            self.vendor_canonical_forms[normalized] = original

    @staticmethod
    def parse_cpe23_uri(cpe23uri: str) -> Dict[str, str]:
        """分析 CPE 2.3 URI 並提取各個組件

        Args:
            cpe23uri (str): CPE 2.3 URI 字串 (例如: cpe:2.3:a:vendor:product:version:...)

        Returns:
            Dict[str, str]: 包含廠商、產品和版本資訊的字典
        """
        # CPE 2.3 格式: cpe:2.3:part:vendor:product:version:update:edition:language:sw_edition:target_sw:target_hw:other
        components = cpe23uri.split(':')

        if len(components) < 6:
            return {"vendor": "", "product": "", "version": ""}

        return {
            'vendor': components[3],
            'product': components[4],
            'version': components[5]
        }

    @contextmanager
    def _open_xml_context(self) -> Iterator:
        """建立用於迭代 XML 檔案中 CPE 項目的上下文管理器

        Yields:
            Iterator: 用於迭代 XML 檔案中 CPE 項目的迭代器
        """
        try:
            context = etree.iterparse(
                str(self.xml_file_path),
                events=('end',),
                tag=f'{{{self.NAMESPACES["def"]}}}cpe-item'
            )
            yield context
        except etree.ParseError as e:
            self.logger.error(f"XML 分析錯誤: {e}")
            raise
        except Exception as e:
            self.logger.error(f"處理 XML 時發生未預期的錯誤: {e}")
            raise

    def _extract_item_data(self, item: etree._Element) -> Optional[CPEItem]:
        """從 XML 元素中提取 CPE 項目資料

        Args:
            item (etree._Element): 包含 CPE 項目資料的 XML 元素

        Returns:
            Optional[CPEItem]: 如果成功提取則返回 CPEItem 物件，否則返回 None
        """
        try:
            # 取得 CPE 2.3 URI
            cpe23_item = item.find('.//cpe-23:cpe23-item', self.NAMESPACES)
            if cpe23_item is None:
                return None

            cpe23uri = cpe23_item.get('name', '')
            if not cpe23uri:
                return None

            # 分析 CPE 組件
            cpe_components = self.parse_cpe23_uri(cpe23uri)

            # 取得並標準化廠商名稱
            original_vendor = cpe_components['vendor']
            normalized_vendor = self.normalize_vendor_name(original_vendor)

            # 追蹤廠商名稱變體
            self.track_vendor_variation(original_vendor, normalized_vendor)

            # 取得標題
            title_elem = item.find(
                './/def:title[@xml:lang="en-US"]', self.NAMESPACES)
            title = title_elem.text if title_elem is not None else ""

            # 取得參考資料
            references = self._extract_references(item)

            # 建立 CPE 項目物件
            return CPEItem(
                cpe22Uri=item.get('name', ''),
                cpe23Uri=cpe23uri,
                vendor=original_vendor,
                normalized_vendor=normalized_vendor,
                product=cpe_components['product'],
                version=cpe_components['version'],
                title=title,
                references=references
            )
        except Exception as e:
            self.logger.warning(f"提取 CPE 項目時發生錯誤: {e}")
            return None

    def _extract_references(self, item: etree._Element) -> str:
        """從 XML 元素中提取參考資料

        Args:
            item (etree._Element): 包含參考資料的 XML 元素

        Returns:
            str: 格式化的參考資料字串
        """
        refs = item.findall('.//def:reference', self.NAMESPACES)
        ref_texts = []

        for ref in refs:
            href = ref.get('href', '')
            ref_text = ref.text or ''

            if href and ref_text:
                ref_texts.append(f"{ref_text} ({href})")
            elif href:
                ref_texts.append(href)
            elif ref_text:
                ref_texts.append(ref_text)

        return ' '.join(ref_texts)

    def _clear_element_memory(self, item: etree._Element) -> None:
        """清理 XML 元素佔用的記憶體

        Args:
            item (etree._Element): 要清理的 XML 元素
        """
        item.clear()
        # 清理前面的同層級元素以釋放記憶體
        while item.getprevious() is not None:
            del item.getparent()[0]

    def parse_xml(self) -> List[Dict[str, Any]]:
        """分析整個 CPE XML 檔案

        Returns:
            List[Dict[str, Any]]: 分析後的 CPE 資料列表
        """
        self.logger.info(f"開始分析 XML 檔案: {self.xml_file_path}")
        cpe_items = []

        with self._open_xml_context() as context:
            for _, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    cpe_items.append(asdict(cpe_item))

                self._clear_element_memory(item)

        # 處理完所有項目後，添加廠商名稱的變體信息
        self._enrich_vendor_variations(cpe_items)

        self.logger.info(f"分析完成，共提取 {len(cpe_items)} 個 CPE 項目")
        return cpe_items

    def _enrich_vendor_variations(self, cpe_items: List[Dict[str, Any]]) -> None:
        """豐富 CPE 項目中的廠商變體信息

        Args:
            cpe_items (List[Dict[str, Any]]): CPE 項目列表
        """
        # 為每個項目添加該廠商的所有已知變體
        for item in cpe_items:
            normalized_vendor = item['normalized_vendor']
            item['variations'] = list(
                self.vendor_variations.get(normalized_vendor, []))

            # 使用標準形式替換原始廠商名稱
            if normalized_vendor in self.vendor_canonical_forms:
                item['canonical_vendor'] = self.vendor_canonical_forms[normalized_vendor]

    def process_by_chunk(self, chunk_size: int = 1000) -> Iterator[List[Dict[str, Any]]]:
        """使用分批處理方式處理大型 XML 檔案

        Args:
            chunk_size (int, optional): 每批處理的項目數量. 預設為 1000.

        Yields:
            List[Dict[str, Any]]: 每批處理的 CPE 項目列表
        """
        self.logger.info(f"開始分批處理 XML 檔案 (每批 {chunk_size} 個項目)")
        items = []
        total_processed = 0

        with self._open_xml_context() as context:
            for _, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    items.append(asdict(cpe_item))

                self._clear_element_memory(item)

                if len(items) >= chunk_size:
                    total_processed += len(items)
                    self.logger.debug(f"已處理 {total_processed} 個項目")
                    yield items
                    items = []

            # 處理剩餘項目
            if items:
                total_processed += len(items)
                self.logger.debug(f"已處理 {total_processed} 個項目")
                yield items

        self.logger.info(f"分批處理完成，總共處理 {total_processed} 個項目")

    def _save_data(self, output_file: str, data: List[Dict[str, Any]], save_func: callable) -> None:
        """通用資料儲存函數

        Args:
            output_file (str): 輸出檔案路徑
            data (List[Dict[str, Any]]): 要儲存的資料
            save_func (callable): 儲存函數
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            save_func(output_path, data)
            self.logger.info(f"已成功儲存 {len(data)} 個項目至檔案: {output_path}")
        except Exception as e:
            self.logger.error(f"儲存檔案時發生錯誤: {e}")
            raise

    def save_to_json(self, output_file: str, items: Optional[List[Dict[str, Any]]] = None) -> None:
        """將分析結果儲存為 JSON 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict[str, Any]]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        cpe_items = items if items is not None else self.parse_xml()

        def save_json(path: Path, data: List[Dict[str, Any]]) -> None:
            with open(path, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=2)

        self._save_data(output_file, cpe_items, save_json)

    def save_to_csv(self, output_file: str, items: Optional[List[Dict[str, Any]]] = None) -> None:
        """將分析結果儲存為 CSV 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict[str, Any]]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        cpe_items = items if items is not None else self.parse_xml()

        def save_csv(path: Path, data: List[Dict[str, Any]]) -> None:
            fieldnames = ['cpe22Uri', 'cpe23Uri', 'vendor', 'normalized_vendor', 'canonical_vendor',
                          'product', 'version', 'title', 'references', 'variations']
            with open(path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=fieldnames)
                writer.writeheader()
                for item in data:
                    # 確保變體列表被正確格式化為字串
                    if 'variations' in item and isinstance(item['variations'], list):
                        item['variations'] = ', '.join(item['variations'])
                    writer.writerow(item)

        self._save_data(output_file, cpe_items, save_csv)

    def save_vendor_variations(self, output_file: str) -> None:
        """儲存廠商名稱變體對照表

        Args:
            output_file (str): 輸出檔案路徑
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        # 建立廠商變體資料
        vendor_data = []
        for normalized, variations in self.vendor_variations.items():
            canonical = self.vendor_canonical_forms.get(normalized, normalized)
            vendor_data.append({
                'normalized_vendor': normalized,
                'canonical_vendor': canonical,
                'variations': list(variations)
            })

        # 依照正規化名稱排序
        vendor_data.sort(key=lambda x: x['normalized_vendor'])

        try:
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(vendor_data, f, ensure_ascii=False, indent=2)
            self.logger.info(
                f"已成功儲存 {len(vendor_data)} 個廠商變體資訊至檔案: {output_path}")
        except Exception as e:
            self.logger.error(f"儲存廠商變體檔案時發生錯誤: {e}")
            raise

    def analyze_vendor_variations(self) -> Dict[str, Any]:
        """分析廠商名稱變體統計資訊

        Returns:
            Dict[str, Any]: 包含廠商變體統計資訊的字典
        """
        # 計算有變體的廠商數量
        vendors_with_variations = sum(
            1 for variations in self.vendor_variations.values() if len(variations) > 1)

        # 找出變體最多的廠商
        max_variations = 0
        max_variations_vendor = None
        for normalized, variations in self.vendor_variations.items():
            if len(variations) > max_variations:
                max_variations = len(variations)
                max_variations_vendor = normalized

        # 構建分析結果
        analysis = {
            'total_vendors': len(self.vendor_variations),
            'vendors_with_variations': vendors_with_variations,
            'percentage_with_variations': round(vendors_with_variations / len(self.vendor_variations) * 100, 2) if self.vendor_variations else 0,
            'max_variations': max_variations,
            'max_variations_vendor': max_variations_vendor,
            'max_variations_list': list(self.vendor_variations.get(max_variations_vendor, [])) if max_variations_vendor else []
        }

        return analysis


def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = [logging.StreamHandler()]  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


def main():
    # 設定日誌
    log_file = "../logs/cpe_parser.log"
    setup_logging(log_level=logging.INFO, log_file=log_file)
    logger = logging.getLogger(__name__)

    # 設定檔案路徑
    input_file = "../data/official-cpe-dictionary_v2.3.xml"
    output_dir = Path("../data/convert")
    output_dir.mkdir(parents=True, exist_ok=True)

    output_json = output_dir / "official-cpe-dictionary_v2.3.json"
    output_csv = output_dir / "official-cpe-dictionary_v2.3.csv"
    vendor_variations_json = output_dir / "vendor_variations.json"

    try:
        logger.info(f"開始處理 CPE 字典檔案: {input_file}")
        parser = CPEParser(input_file)

        # 使用分批處理分析 XML 檔案並儲存結果
        all_items = []

        for chunk in parser.process_by_chunk(chunk_size=1000):
            all_items.extend(chunk)
            logger.info(f"已處理 {len(all_items)} 個項目")

        # 豐富廠商變體信息
        parser._enrich_vendor_variations(all_items)

        # 儲存為 JSON 和 CSV
        parser.save_to_json(str(output_json), all_items)
        parser.save_to_csv(str(output_csv), all_items)

        # 儲存廠商名稱變體對照表
        parser.save_vendor_variations(str(vendor_variations_json))

        # 輸出廠商變體分析結果
        vendor_analysis = parser.analyze_vendor_variations()
        logger.info(
            f"廠商變體分析結果: {json.dumps(vendor_analysis, ensure_ascii=False, indent=2)}")

        logger.info("程式執行完成")

    except FileNotFoundError as e:
        logger.error(f"找不到檔案: {e}")
    except Exception as e:
        logger.error(f"程式執行失敗: {e}", exc_info=True)


if __name__ == "__main__":
    main()
# Out:
# 2025-03-13 08:06:55,453 - __main__ - INFO - 開始處理 CPE 字典檔案: ../data/official-cpe-dictionary_v2.3.xml
# 2025-03-13 08:06:55,455 - __main__ - INFO - 開始分批處理 XML 檔案 (每批 1000 個項目)
# 2025-03-13 08:06:55,486 - __main__ - INFO - 已處理 1000 個項目
# 2025-03-13 08:06:55,505 - __main__ - INFO - 已處理 2000 個項目
# 2025-03-13 08:06:55,525 - __main__ - INFO - 已處理 3000 個項目
# 2025-03-13 08:06:55,545 - __main__ - INFO - 已處理 4000 個項目
# 2025-03-13 08:06:55,564 - __main__ - INFO - 已處理 5000 個項目
# 2025-03-13 08:06:55,583 - __main__ - INFO - 已處理 6000 個項目
# 2025-03-13 08:06:55,604 - __main__ - INFO - 已處理 7000 個項目
# 2025-03-13 08:06:55,624 - __main__ - INFO - 已處理 8000 個項目
# 2025-03-13 08:06:55,645 - __main__ - INFO - 已處理 9000 個項目
# 2025-03-13 08:06:55,667 - __main__ - INFO - 已處理 10000 個項目
# 2025-03-13 08:06:55,686 - __main__ - INFO - 已處理 11000 個項目
# 2025-03-13 08:06:55,708 - __main__ - INFO - 已處理 12000 個項目
# 2025-03-13 08:06:55,728 - __main__ - INFO - 已處理 13000 個項目
# 2025-03-13 08:06:55,747 - __main__ - INFO - 已處理 14000 個項目
# 2025-03-13 08:06:55,772 - __main__ - INFO - 已處理 15000 個項目
# 2025-03-13 08:06:55,791 - __main__ - INFO - 已處理 16000 個項目
# 2025-03-13 08:06:55,811 - __main__ - INFO - 已處理 17000 個項目
# 2025-03-13 08:06:55,830 - __main__ - INFO - 已處理 18000 個項目
# 2025-03-13 08:06:55,852 - __main__ - INFO - 已處理 19000 個項目
# 2025-03-13 08:06:55,871 - __main__ - INFO - 已處理 20000 個項目
# 2025-03-13 08:06:55,889 - __main__ - INFO - 已處理 21000 個項目
# 2025-03-13 08:06:55,910 - __main__ - INFO - 已處理 22000 個項目
# 2025-03-13 08:06:55,930 - __main__ - INFO - 已處理 23000 個項目
# 2025-03-13 08:06:55,953 - __main__ - INFO - 已處理 24000 個項目
# 2025-03-13 08:06:55,973 - __main__ - INFO - 已處理 25000 個項目
# 2025-03-13 08:06:56,036 - __main__ - INFO - 已處理 26000 個項目
# 2025-03-13 08:06:56,055 - __main__ - INFO - 已處理 27000 個項目
# 2025-03-13 08:06:56,085 - __main__ - INFO - 已處理 28000 個項目
# 2025-03-13 08:06:56,105 - __main__ - INFO - 已處理 29000 個項目
# 2025-03-13 08:06:56,123 - __main__ - INFO - 已處理 30000 個項目
# 2025-03-13 08:06:56,142 - __main__ - INFO - 已處理 31000 個項目
# 2025-03-13 08:06:56,171 - __main__ - INFO - 已處理 32000 個項目
# 2025-03-13 08:06:56,190 - __main__ - INFO - 已處理 33000 個項目
# 2025-03-13 08:06:56,210 - __main__ - INFO - 已處理 34000 個項目
# 2025-03-13 08:06:56,229 - __main__ - INFO - 已處理 35000 個項目
# 2025-03-13 08:06:56,248 - __main__ - INFO - 已處理 36000 個項目
# 2025-03-13 08:06:56,265 - __main__ - INFO - 已處理 37000 個項目
# 2025-03-13 08:06:56,284 - __main__ - INFO - 已處理 38000 個項目
# 2025-03-13 08:06:56,303 - __main__ - INFO - 已處理 39000 個項目
# 2025-03-13 08:06:56,334 - __main__ - INFO - 已處理 40000 個項目
# 2025-03-13 08:06:56,353 - __main__ - INFO - 已處理 41000 個項目
# 2025-03-13 08:06:56,371 - __main__ - INFO - 已處理 42000 個項目
# 2025-03-13 08:06:56,389 - __main__ - INFO - 已處理 43000 個項目
# 2025-03-13 08:06:56,408 - __main__ - INFO - 已處理 44000 個項目
# 2025-03-13 08:06:56,425 - __main__ - INFO - 已處理 45000 個項目
# 2025-03-13 08:06:56,444 - __main__ - INFO - 已處理 46000 個項目
# 2025-03-13 08:06:56,461 - __main__ - INFO - 已處理 47000 個項目
# 2025-03-13 08:06:56,479 - __main__ - INFO - 已處理 48000 個項目
# 2025-03-13 08:06:56,497 - __main__ - INFO - 已處理 49000 個項目
# 2025-03-13 08:06:56,516 - __main__ - INFO - 已處理 50000 個項目
# 2025-03-13 08:06:56,535 - __main__ - INFO - 已處理 51000 個項目
# 2025-03-13 08:06:56,553 - __main__ - INFO - 已處理 52000 個項目
# 2025-03-13 08:06:56,571 - __main__ - INFO - 已處理 53000 個項目
# 2025-03-13 08:06:56,589 - __main__ - INFO - 已處理 54000 個項目
# 2025-03-13 08:06:56,607 - __main__ - INFO - 已處理 55000 個項目
# 2025-03-13 08:06:56,624 - __main__ - INFO - 已處理 56000 個項目
# 2025-03-13 08:06:56,641 - __main__ - INFO - 已處理 57000 個項目
# 2025-03-13 08:06:56,660 - __main__ - INFO - 已處理 58000 個項目
# 2025-03-13 08:06:56,678 - __main__ - INFO - 已處理 59000 個項目
# 2025-03-13 08:06:56,695 - __main__ - INFO - 已處理 60000 個項目
# 2025-03-13 08:06:56,712 - __main__ - INFO - 已處理 61000 個項目
# 2025-03-13 08:06:56,729 - __main__ - INFO - 已處理 62000 個項目
# 2025-03-13 08:06:56,746 - __main__ - INFO - 已處理 63000 個項目
# 2025-03-13 08:06:56,764 - __main__ - INFO - 已處理 64000 個項目
# 2025-03-13 08:06:56,781 - __main__ - INFO - 已處理 65000 個項目
# 2025-03-13 08:06:56,798 - __main__ - INFO - 已處理 66000 個項目
# 2025-03-13 08:06:56,815 - __main__ - INFO - 已處理 67000 個項目
# 2025-03-13 08:06:56,832 - __main__ - INFO - 已處理 68000 個項目
# 2025-03-13 08:06:56,849 - __main__ - INFO - 已處理 69000 個項目
# 2025-03-13 08:06:56,866 - __main__ - INFO - 已處理 70000 個項目
# 2025-03-13 08:06:56,884 - __main__ - INFO - 已處理 71000 個項目
# 2025-03-13 08:06:56,950 - __main__ - INFO - 已處理 72000 個項目
# 2025-03-13 08:06:56,967 - __main__ - INFO - 已處理 73000 個項目
# 2025-03-13 08:06:56,985 - __main__ - INFO - 已處理 74000 個項目
# 2025-03-13 08:06:57,005 - __main__ - INFO - 已處理 75000 個項目
# 2025-03-13 08:06:57,021 - __main__ - INFO - 已處理 76000 個項目
# 2025-03-13 08:06:57,037 - __main__ - INFO - 已處理 77000 個項目
# 2025-03-13 08:06:57,054 - __main__ - INFO - 已處理 78000 個項目
# 2025-03-13 08:06:57,072 - __main__ - INFO - 已處理 79000 個項目
# 2025-03-13 08:06:57,089 - __main__ - INFO - 已處理 80000 個項目
# 2025-03-13 08:06:57,107 - __main__ - INFO - 已處理 81000 個項目
# 2025-03-13 08:06:57,125 - __main__ - INFO - 已處理 82000 個項目
# 2025-03-13 08:06:57,142 - __main__ - INFO - 已處理 83000 個項目
# 2025-03-13 08:06:57,161 - __main__ - INFO - 已處理 84000 個項目
# 2025-03-13 08:06:57,179 - __main__ - INFO - 已處理 85000 個項目
# 2025-03-13 08:06:57,196 - __main__ - INFO - 已處理 86000 個項目
# 2025-03-13 08:06:57,213 - __main__ - INFO - 已處理 87000 個項目
# 2025-03-13 08:06:57,232 - __main__ - INFO - 已處理 88000 個項目
# 2025-03-13 08:06:57,249 - __main__ - INFO - 已處理 89000 個項目
# 2025-03-13 08:06:57,266 - __main__ - INFO - 已處理 90000 個項目
# 2025-03-13 08:06:57,283 - __main__ - INFO - 已處理 91000 個項目
# 2025-03-13 08:06:57,300 - __main__ - INFO - 已處理 92000 個項目
# 2025-03-13 08:06:57,319 - __main__ - INFO - 已處理 93000 個項目
# 2025-03-13 08:06:57,337 - __main__ - INFO - 已處理 94000 個項目
# 2025-03-13 08:06:57,354 - __main__ - INFO - 已處理 95000 個項目
# 2025-03-13 08:06:57,372 - __main__ - INFO - 已處理 96000 個項目
# 2025-03-13 08:06:57,390 - __main__ - INFO - 已處理 97000 個項目
# 2025-03-13 08:06:57,408 - __main__ - INFO - 已處理 98000 個項目
# 2025-03-13 08:06:57,427 - __main__ - INFO - 已處理 99000 個項目
# 2025-03-13 08:06:57,446 - __main__ - INFO - 已處理 100000 個項目
# 2025-03-13 08:06:57,463 - __main__ - INFO - 已處理 101000 個項目
# 2025-03-13 08:06:57,480 - __main__ - INFO - 已處理 102000 個項目
# 2025-03-13 08:06:57,500 - __main__ - INFO - 已處理 103000 個項目
# 2025-03-13 08:06:57,517 - __main__ - INFO - 已處理 104000 個項目
# 2025-03-13 08:06:57,536 - __main__ - INFO - 已處理 105000 個項目
# 2025-03-13 08:06:57,553 - __main__ - INFO - 已處理 106000 個項目
# 2025-03-13 08:06:57,571 - __main__ - INFO - 已處理 107000 個項目
# 2025-03-13 08:06:57,590 - __main__ - INFO - 已處理 108000 個項目
# 2025-03-13 08:06:57,609 - __main__ - INFO - 已處理 109000 個項目
# 2025-03-13 08:06:57,627 - __main__ - INFO - 已處理 110000 個項目
# 2025-03-13 08:06:57,645 - __main__ - INFO - 已處理 111000 個項目
# 2025-03-13 08:06:57,666 - __main__ - INFO - 已處理 112000 個項目
# 2025-03-13 08:06:57,685 - __main__ - INFO - 已處理 113000 個項目
# 2025-03-13 08:06:57,703 - __main__ - INFO - 已處理 114000 個項目
# 2025-03-13 08:06:57,725 - __main__ - INFO - 已處理 115000 個項目
# 2025-03-13 08:06:57,743 - __main__ - INFO - 已處理 116000 個項目
# 2025-03-13 08:06:57,831 - __main__ - INFO - 已處理 117000 個項目
# 2025-03-13 08:06:57,852 - __main__ - INFO - 已處理 118000 個項目
# 2025-03-13 08:06:57,872 - __main__ - INFO - 已處理 119000 個項目
# 2025-03-13 08:06:57,892 - __main__ - INFO - 已處理 120000 個項目
# 2025-03-13 08:06:57,912 - __main__ - INFO - 已處理 121000 個項目
# 2025-03-13 08:06:57,930 - __main__ - INFO - 已處理 122000 個項目
# 2025-03-13 08:06:57,950 - __main__ - INFO - 已處理 123000 個項目
# 2025-03-13 08:06:57,969 - __main__ - INFO - 已處理 124000 個項目
# 2025-03-13 08:06:57,988 - __main__ - INFO - 已處理 125000 個項目
# 2025-03-13 08:06:58,007 - __main__ - INFO - 已處理 126000 個項目
# 2025-03-13 08:06:58,024 - __main__ - INFO - 已處理 127000 個項目
# 2025-03-13 08:06:58,044 - __main__ - INFO - 已處理 128000 個項目
# 2025-03-13 08:06:58,063 - __main__ - INFO - 已處理 129000 個項目
# 2025-03-13 08:06:58,083 - __main__ - INFO - 已處理 130000 個項目
# 2025-03-13 08:06:58,101 - __main__ - INFO - 已處理 131000 個項目
# 2025-03-13 08:06:58,120 - __main__ - INFO - 已處理 132000 個項目
# 2025-03-13 08:06:58,139 - __main__ - INFO - 已處理 133000 個項目
# 2025-03-13 08:06:58,156 - __main__ - INFO - 已處理 134000 個項目
# 2025-03-13 08:06:58,175 - __main__ - INFO - 已處理 135000 個項目
# 2025-03-13 08:06:58,193 - __main__ - INFO - 已處理 136000 個項目
# 2025-03-13 08:06:58,212 - __main__ - INFO - 已處理 137000 個項目
# 2025-03-13 08:06:58,231 - __main__ - INFO - 已處理 138000 個項目
# 2025-03-13 08:06:58,249 - __main__ - INFO - 已處理 139000 個項目
# 2025-03-13 08:06:58,267 - __main__ - INFO - 已處理 140000 個項目
# 2025-03-13 08:06:58,289 - __main__ - INFO - 已處理 141000 個項目
# 2025-03-13 08:06:58,306 - __main__ - INFO - 已處理 142000 個項目
# 2025-03-13 08:06:58,325 - __main__ - INFO - 已處理 143000 個項目
# 2025-03-13 08:06:58,349 - __main__ - INFO - 已處理 144000 個項目
# 2025-03-13 08:06:58,367 - __main__ - INFO - 已處理 145000 個項目
# 2025-03-13 08:06:58,385 - __main__ - INFO - 已處理 146000 個項目
# 2025-03-13 08:06:58,405 - __main__ - INFO - 已處理 147000 個項目
# 2025-03-13 08:06:58,457 - __main__ - INFO - 已處理 148000 個項目
# 2025-03-13 08:06:58,479 - __main__ - INFO - 已處理 149000 個項目
# 2025-03-13 08:06:58,497 - __main__ - INFO - 已處理 150000 個項目
# 2025-03-13 08:06:58,515 - __main__ - INFO - 已處理 151000 個項目
# 2025-03-13 08:06:58,534 - __main__ - INFO - 已處理 152000 個項目
# 2025-03-13 08:06:58,554 - __main__ - INFO - 已處理 153000 個項目
# 2025-03-13 08:06:58,575 - __main__ - INFO - 已處理 154000 個項目
# 2025-03-13 08:06:58,595 - __main__ - INFO - 已處理 155000 個項目
# 2025-03-13 08:06:58,614 - __main__ - INFO - 已處理 156000 個項目
# 2025-03-13 08:06:58,632 - __main__ - INFO - 已處理 157000 個項目
# 2025-03-13 08:06:58,662 - __main__ - INFO - 已處理 158000 個項目
# 2025-03-13 08:06:58,681 - __main__ - INFO - 已處理 159000 個項目
# 2025-03-13 08:06:58,700 - __main__ - INFO - 已處理 160000 個項目
# 2025-03-13 08:06:58,720 - __main__ - INFO - 已處理 161000 個項目
# 2025-03-13 08:06:58,738 - __main__ - INFO - 已處理 162000 個項目
# 2025-03-13 08:06:58,757 - __main__ - INFO - 已處理 163000 個項目
# 2025-03-13 08:06:58,776 - __main__ - INFO - 已處理 164000 個項目
# 2025-03-13 08:06:58,795 - __main__ - INFO - 已處理 165000 個項目
# 2025-03-13 08:06:58,815 - __main__ - INFO - 已處理 166000 個項目
# 2025-03-13 08:06:58,918 - __main__ - INFO - 已處理 167000 個項目
# 2025-03-13 08:06:58,939 - __main__ - INFO - 已處理 168000 個項目
# 2025-03-13 08:06:58,957 - __main__ - INFO - 已處理 169000 個項目
# 2025-03-13 08:06:58,977 - __main__ - INFO - 已處理 170000 個項目
# 2025-03-13 08:06:58,995 - __main__ - INFO - 已處理 171000 個項目
# 2025-03-13 08:06:59,013 - __main__ - INFO - 已處理 172000 個項目
# 2025-03-13 08:06:59,032 - __main__ - INFO - 已處理 173000 個項目
# 2025-03-13 08:06:59,051 - __main__ - INFO - 已處理 174000 個項目
# 2025-03-13 08:06:59,070 - __main__ - INFO - 已處理 175000 個項目
# 2025-03-13 08:06:59,090 - __main__ - INFO - 已處理 176000 個項目
# 2025-03-13 08:06:59,108 - __main__ - INFO - 已處理 177000 個項目
# 2025-03-13 08:06:59,128 - __main__ - INFO - 已處理 178000 個項目
# 2025-03-13 08:06:59,147 - __main__ - INFO - 已處理 179000 個項目
# 2025-03-13 08:06:59,166 - __main__ - INFO - 已處理 180000 個項目
# 2025-03-13 08:06:59,185 - __main__ - INFO - 已處理 181000 個項目
# 2025-03-13 08:06:59,204 - __main__ - INFO - 已處理 182000 個項目
# 2025-03-13 08:06:59,223 - __main__ - INFO - 已處理 183000 個項目
# 2025-03-13 08:06:59,242 - __main__ - INFO - 已處理 184000 個項目
# 2025-03-13 08:06:59,260 - __main__ - INFO - 已處理 185000 個項目
# 2025-03-13 08:06:59,279 - __main__ - INFO - 已處理 186000 個項目
# 2025-03-13 08:06:59,297 - __main__ - INFO - 已處理 187000 個項目
# 2025-03-13 08:06:59,314 - __main__ - INFO - 已處理 188000 個項目
# 2025-03-13 08:06:59,334 - __main__ - INFO - 已處理 189000 個項目
# 2025-03-13 08:06:59,351 - __main__ - INFO - 已處理 190000 個項目
# 2025-03-13 08:06:59,371 - __main__ - INFO - 已處理 191000 個項目
# 2025-03-13 08:06:59,390 - __main__ - INFO - 已處理 192000 個項目
# 2025-03-13 08:06:59,410 - __main__ - INFO - 已處理 193000 個項目
# 2025-03-13 08:06:59,429 - __main__ - INFO - 已處理 194000 個項目
# 2025-03-13 08:06:59,448 - __main__ - INFO - 已處理 195000 個項目
# 2025-03-13 08:06:59,467 - __main__ - INFO - 已處理 196000 個項目
# 2025-03-13 08:06:59,485 - __main__ - INFO - 已處理 197000 個項目
# 2025-03-13 08:06:59,502 - __main__ - INFO - 已處理 198000 個項目
# 2025-03-13 08:06:59,520 - __main__ - INFO - 已處理 199000 個項目
# 2025-03-13 08:06:59,538 - __main__ - INFO - 已處理 200000 個項目
# 2025-03-13 08:06:59,558 - __main__ - INFO - 已處理 201000 個項目
# 2025-03-13 08:06:59,580 - __main__ - INFO - 已處理 202000 個項目
# 2025-03-13 08:06:59,599 - __main__ - INFO - 已處理 203000 個項目
# 2025-03-13 08:06:59,616 - __main__ - INFO - 已處理 204000 個項目
# 2025-03-13 08:06:59,632 - __main__ - INFO - 已處理 205000 個項目
# 2025-03-13 08:06:59,650 - __main__ - INFO - 已處理 206000 個項目
# 2025-03-13 08:06:59,667 - __main__ - INFO - 已處理 207000 個項目
# 2025-03-13 08:06:59,685 - __main__ - INFO - 已處理 208000 個項目
# 2025-03-13 08:06:59,703 - __main__ - INFO - 已處理 209000 個項目
# 2025-03-13 08:06:59,721 - __main__ - INFO - 已處理 210000 個項目
# 2025-03-13 08:06:59,741 - __main__ - INFO - 已處理 211000 個項目
# 2025-03-13 08:06:59,760 - __main__ - INFO - 已處理 212000 個項目
# 2025-03-13 08:06:59,779 - __main__ - INFO - 已處理 213000 個項目
# 2025-03-13 08:06:59,797 - __main__ - INFO - 已處理 214000 個項目
# 2025-03-13 08:06:59,816 - __main__ - INFO - 已處理 215000 個項目
# 2025-03-13 08:06:59,834 - __main__ - INFO - 已處理 216000 個項目
# 2025-03-13 08:06:59,853 - __main__ - INFO - 已處理 217000 個項目
# 2025-03-13 08:06:59,872 - __main__ - INFO - 已處理 218000 個項目
# 2025-03-13 08:06:59,891 - __main__ - INFO - 已處理 219000 個項目
# 2025-03-13 08:06:59,909 - __main__ - INFO - 已處理 220000 個項目
# 2025-03-13 08:06:59,928 - __main__ - INFO - 已處理 221000 個項目
# 2025-03-13 08:06:59,946 - __main__ - INFO - 已處理 222000 個項目
# 2025-03-13 08:06:59,963 - __main__ - INFO - 已處理 223000 個項目
# 2025-03-13 08:06:59,981 - __main__ - INFO - 已處理 224000 個項目
# 2025-03-13 08:07:00,090 - __main__ - INFO - 已處理 225000 個項目
# 2025-03-13 08:07:00,107 - __main__ - INFO - 已處理 226000 個項目
# 2025-03-13 08:07:00,124 - __main__ - INFO - 已處理 227000 個項目
# 2025-03-13 08:07:00,143 - __main__ - INFO - 已處理 228000 個項目
# 2025-03-13 08:07:00,161 - __main__ - INFO - 已處理 229000 個項目
# 2025-03-13 08:07:00,179 - __main__ - INFO - 已處理 230000 個項目
# 2025-03-13 08:07:00,198 - __main__ - INFO - 已處理 231000 個項目
# 2025-03-13 08:07:00,219 - __main__ - INFO - 已處理 232000 個項目
# 2025-03-13 08:07:00,239 - __main__ - INFO - 已處理 233000 個項目
# 2025-03-13 08:07:00,258 - __main__ - INFO - 已處理 234000 個項目
# 2025-03-13 08:07:00,277 - __main__ - INFO - 已處理 235000 個項目
# 2025-03-13 08:07:00,296 - __main__ - INFO - 已處理 236000 個項目
# 2025-03-13 08:07:00,318 - __main__ - INFO - 已處理 237000 個項目
# 2025-03-13 08:07:00,338 - __main__ - INFO - 已處理 238000 個項目
# 2025-03-13 08:07:00,356 - __main__ - INFO - 已處理 239000 個項目
# 2025-03-13 08:07:00,374 - __main__ - INFO - 已處理 240000 個項目
# 2025-03-13 08:07:00,393 - __main__ - INFO - 已處理 241000 個項目
# 2025-03-13 08:07:00,412 - __main__ - INFO - 已處理 242000 個項目
# 2025-03-13 08:07:00,432 - __main__ - INFO - 已處理 243000 個項目
# 2025-03-13 08:07:00,453 - __main__ - INFO - 已處理 244000 個項目
# 2025-03-13 08:07:00,472 - __main__ - INFO - 已處理 245000 個項目
# 2025-03-13 08:07:00,490 - __main__ - INFO - 已處理 246000 個項目
# 2025-03-13 08:07:00,511 - __main__ - INFO - 已處理 247000 個項目
# 2025-03-13 08:07:00,531 - __main__ - INFO - 已處理 248000 個項目
# 2025-03-13 08:07:00,549 - __main__ - INFO - 已處理 249000 個項目
# 2025-03-13 08:07:00,568 - __main__ - INFO - 已處理 250000 個項目
# 2025-03-13 08:07:00,588 - __main__ - INFO - 已處理 251000 個項目
# 2025-03-13 08:07:00,606 - __main__ - INFO - 已處理 252000 個項目
# 2025-03-13 08:07:00,625 - __main__ - INFO - 已處理 253000 個項目
# 2025-03-13 08:07:00,642 - __main__ - INFO - 已處理 254000 個項目
# 2025-03-13 08:07:00,661 - __main__ - INFO - 已處理 255000 個項目
# 2025-03-13 08:07:00,679 - __main__ - INFO - 已處理 256000 個項目
# 2025-03-13 08:07:00,698 - __main__ - INFO - 已處理 257000 個項目
# 2025-03-13 08:07:00,717 - __main__ - INFO - 已處理 258000 個項目
# 2025-03-13 08:07:00,737 - __main__ - INFO - 已處理 259000 個項目
# 2025-03-13 08:07:00,756 - __main__ - INFO - 已處理 260000 個項目
# 2025-03-13 08:07:00,782 - __main__ - INFO - 已處理 261000 個項目
# 2025-03-13 08:07:00,802 - __main__ - INFO - 已處理 262000 個項目
# 2025-03-13 08:07:00,820 - __main__ - INFO - 已處理 263000 個項目
# 2025-03-13 08:07:00,838 - __main__ - INFO - 已處理 264000 個項目
# 2025-03-13 08:07:00,856 - __main__ - INFO - 已處理 265000 個項目
# 2025-03-13 08:07:00,876 - __main__ - INFO - 已處理 266000 個項目
# 2025-03-13 08:07:00,895 - __main__ - INFO - 已處理 267000 個項目
# 2025-03-13 08:07:00,914 - __main__ - INFO - 已處理 268000 個項目
# 2025-03-13 08:07:00,933 - __main__ - INFO - 已處理 269000 個項目
# 2025-03-13 08:07:00,956 - __main__ - INFO - 已處理 270000 個項目
# 2025-03-13 08:07:00,974 - __main__ - INFO - 已處理 271000 個項目
# 2025-03-13 08:07:00,994 - __main__ - INFO - 已處理 272000 個項目
# 2025-03-13 08:07:01,012 - __main__ - INFO - 已處理 273000 個項目
# 2025-03-13 08:07:01,032 - __main__ - INFO - 已處理 274000 個項目
# 2025-03-13 08:07:01,051 - __main__ - INFO - 已處理 275000 個項目
# 2025-03-13 08:07:01,070 - __main__ - INFO - 已處理 276000 個項目
# 2025-03-13 08:07:01,089 - __main__ - INFO - 已處理 277000 個項目
# 2025-03-13 08:07:01,107 - __main__ - INFO - 已處理 278000 個項目
# 2025-03-13 08:07:01,125 - __main__ - INFO - 已處理 279000 個項目
# 2025-03-13 08:07:01,144 - __main__ - INFO - 已處理 280000 個項目
# 2025-03-13 08:07:01,162 - __main__ - INFO - 已處理 281000 個項目
# 2025-03-13 08:07:01,182 - __main__ - INFO - 已處理 282000 個項目
# 2025-03-13 08:07:01,200 - __main__ - INFO - 已處理 283000 個項目
# 2025-03-13 08:07:01,219 - __main__ - INFO - 已處理 284000 個項目
# 2025-03-13 08:07:01,238 - __main__ - INFO - 已處理 285000 個項目
# 2025-03-13 08:07:01,256 - __main__ - INFO - 已處理 286000 個項目
# 2025-03-13 08:07:01,275 - __main__ - INFO - 已處理 287000 個項目
# 2025-03-13 08:07:01,294 - __main__ - INFO - 已處理 288000 個項目
# 2025-03-13 08:07:01,311 - __main__ - INFO - 已處理 289000 個項目
# 2025-03-13 08:07:01,330 - __main__ - INFO - 已處理 290000 個項目
# 2025-03-13 08:07:01,348 - __main__ - INFO - 已處理 291000 個項目
# 2025-03-13 08:07:01,365 - __main__ - INFO - 已處理 292000 個項目
# 2025-03-13 08:07:01,383 - __main__ - INFO - 已處理 293000 個項目
# 2025-03-13 08:07:01,401 - __main__ - INFO - 已處理 294000 個項目
# 2025-03-13 08:07:01,419 - __main__ - INFO - 已處理 295000 個項目
# 2025-03-13 08:07:01,437 - __main__ - INFO - 已處理 296000 個項目
# 2025-03-13 08:07:01,457 - __main__ - INFO - 已處理 297000 個項目
# 2025-03-13 08:07:01,475 - __main__ - INFO - 已處理 298000 個項目
# 2025-03-13 08:07:01,495 - __main__ - INFO - 已處理 299000 個項目
# 2025-03-13 08:07:01,629 - __main__ - INFO - 已處理 300000 個項目
# 2025-03-13 08:07:01,646 - __main__ - INFO - 已處理 301000 個項目
# 2025-03-13 08:07:01,666 - __main__ - INFO - 已處理 302000 個項目
# 2025-03-13 08:07:01,683 - __main__ - INFO - 已處理 303000 個項目
# 2025-03-13 08:07:01,701 - __main__ - INFO - 已處理 304000 個項目
# 2025-03-13 08:07:01,721 - __main__ - INFO - 已處理 305000 個項目
# 2025-03-13 08:07:01,743 - __main__ - INFO - 已處理 306000 個項目
# 2025-03-13 08:07:01,763 - __main__ - INFO - 已處理 307000 個項目
# 2025-03-13 08:07:01,781 - __main__ - INFO - 已處理 308000 個項目
# 2025-03-13 08:07:01,799 - __main__ - INFO - 已處理 309000 個項目
# 2025-03-13 08:07:01,817 - __main__ - INFO - 已處理 310000 個項目
# 2025-03-13 08:07:01,838 - __main__ - INFO - 已處理 311000 個項目
# 2025-03-13 08:07:01,856 - __main__ - INFO - 已處理 312000 個項目
# 2025-03-13 08:07:01,875 - __main__ - INFO - 已處理 313000 個項目
# 2025-03-13 08:07:01,894 - __main__ - INFO - 已處理 314000 個項目
# 2025-03-13 08:07:01,913 - __main__ - INFO - 已處理 315000 個項目
# 2025-03-13 08:07:01,931 - __main__ - INFO - 已處理 316000 個項目
# 2025-03-13 08:07:01,950 - __main__ - INFO - 已處理 317000 個項目
# 2025-03-13 08:07:01,974 - __main__ - INFO - 已處理 318000 個項目
# 2025-03-13 08:07:01,994 - __main__ - INFO - 已處理 319000 個項目
# 2025-03-13 08:07:02,013 - __main__ - INFO - 已處理 320000 個項目
# 2025-03-13 08:07:02,031 - __main__ - INFO - 已處理 321000 個項目
# 2025-03-13 08:07:02,049 - __main__ - INFO - 已處理 322000 個項目
# 2025-03-13 08:07:02,067 - __main__ - INFO - 已處理 323000 個項目
# 2025-03-13 08:07:02,088 - __main__ - INFO - 已處理 324000 個項目
# 2025-03-13 08:07:02,107 - __main__ - INFO - 已處理 325000 個項目
# 2025-03-13 08:07:02,128 - __main__ - INFO - 已處理 326000 個項目
# 2025-03-13 08:07:02,148 - __main__ - INFO - 已處理 327000 個項目
# 2025-03-13 08:07:02,167 - __main__ - INFO - 已處理 328000 個項目
# 2025-03-13 08:07:02,186 - __main__ - INFO - 已處理 329000 個項目
# 2025-03-13 08:07:02,203 - __main__ - INFO - 已處理 330000 個項目
# 2025-03-13 08:07:02,222 - __main__ - INFO - 已處理 331000 個項目
# 2025-03-13 08:07:02,242 - __main__ - INFO - 已處理 332000 個項目
# 2025-03-13 08:07:02,261 - __main__ - INFO - 已處理 333000 個項目
# 2025-03-13 08:07:02,282 - __main__ - INFO - 已處理 334000 個項目
# 2025-03-13 08:07:02,299 - __main__ - INFO - 已處理 335000 個項目
# 2025-03-13 08:07:02,320 - __main__ - INFO - 已處理 336000 個項目
# 2025-03-13 08:07:02,339 - __main__ - INFO - 已處理 337000 個項目
# 2025-03-13 08:07:02,358 - __main__ - INFO - 已處理 338000 個項目
# 2025-03-13 08:07:02,379 - __main__ - INFO - 已處理 339000 個項目
# 2025-03-13 08:07:02,402 - __main__ - INFO - 已處理 340000 個項目
# 2025-03-13 08:07:02,426 - __main__ - INFO - 已處理 341000 個項目
# 2025-03-13 08:07:02,448 - __main__ - INFO - 已處理 342000 個項目
# 2025-03-13 08:07:02,468 - __main__ - INFO - 已處理 343000 個項目
# 2025-03-13 08:07:02,488 - __main__ - INFO - 已處理 344000 個項目
# 2025-03-13 08:07:02,507 - __main__ - INFO - 已處理 345000 個項目
# 2025-03-13 08:07:02,527 - __main__ - INFO - 已處理 346000 個項目
# 2025-03-13 08:07:02,546 - __main__ - INFO - 已處理 347000 個項目
# 2025-03-13 08:07:02,566 - __main__ - INFO - 已處理 348000 個項目
# 2025-03-13 08:07:02,585 - __main__ - INFO - 已處理 349000 個項目
# 2025-03-13 08:07:02,605 - __main__ - INFO - 已處理 350000 個項目
# 2025-03-13 08:07:02,623 - __main__ - INFO - 已處理 351000 個項目
# 2025-03-13 08:07:02,643 - __main__ - INFO - 已處理 352000 個項目
# 2025-03-13 08:07:02,664 - __main__ - INFO - 已處理 353000 個項目
# 2025-03-13 08:07:02,735 - __main__ - INFO - 已處理 354000 個項目
# 2025-03-13 08:07:02,755 - __main__ - INFO - 已處理 355000 個項目
# 2025-03-13 08:07:02,775 - __main__ - INFO - 已處理 356000 個項目
# 2025-03-13 08:07:02,796 - __main__ - INFO - 已處理 357000 個項目
# 2025-03-13 08:07:02,817 - __main__ - INFO - 已處理 358000 個項目
# 2025-03-13 08:07:02,837 - __main__ - INFO - 已處理 359000 個項目
# 2025-03-13 08:07:02,856 - __main__ - INFO - 已處理 360000 個項目
# 2025-03-13 08:07:02,877 - __main__ - INFO - 已處理 361000 個項目
# 2025-03-13 08:07:02,898 - __main__ - INFO - 已處理 362000 個項目
# 2025-03-13 08:07:02,920 - __main__ - INFO - 已處理 363000 個項目
# 2025-03-13 08:07:02,941 - __main__ - INFO - 已處理 364000 個項目
# 2025-03-13 08:07:02,963 - __main__ - INFO - 已處理 365000 個項目
# 2025-03-13 08:07:02,985 - __main__ - INFO - 已處理 366000 個項目
# 2025-03-13 08:07:03,005 - __main__ - INFO - 已處理 367000 個項目
# 2025-03-13 08:07:03,024 - __main__ - INFO - 已處理 368000 個項目
# 2025-03-13 08:07:03,051 - __main__ - INFO - 已處理 369000 個項目
# 2025-03-13 08:07:03,069 - __main__ - INFO - 已處理 370000 個項目
# 2025-03-13 08:07:03,088 - __main__ - INFO - 已處理 371000 個項目
# 2025-03-13 08:07:03,108 - __main__ - INFO - 已處理 372000 個項目
# 2025-03-13 08:07:03,127 - __main__ - INFO - 已處理 373000 個項目
# 2025-03-13 08:07:03,147 - __main__ - INFO - 已處理 374000 個項目
# 2025-03-13 08:07:03,167 - __main__ - INFO - 已處理 375000 個項目
# 2025-03-13 08:07:03,187 - __main__ - INFO - 已處理 376000 個項目
# 2025-03-13 08:07:03,207 - __main__ - INFO - 已處理 377000 個項目
# 2025-03-13 08:07:03,227 - __main__ - INFO - 已處理 378000 個項目
# 2025-03-13 08:07:03,246 - __main__ - INFO - 已處理 379000 個項目
# 2025-03-13 08:07:03,265 - __main__ - INFO - 已處理 380000 個項目
# 2025-03-13 08:07:03,284 - __main__ - INFO - 已處理 381000 個項目
# 2025-03-13 08:07:03,303 - __main__ - INFO - 已處理 382000 個項目
# 2025-03-13 08:07:03,322 - __main__ - INFO - 已處理 383000 個項目
# 2025-03-13 08:07:03,342 - __main__ - INFO - 已處理 384000 個項目
# 2025-03-13 08:07:03,362 - __main__ - INFO - 已處理 385000 個項目
# 2025-03-13 08:07:03,381 - __main__ - INFO - 已處理 386000 個項目
# 2025-03-13 08:07:03,402 - __main__ - INFO - 已處理 387000 個項目
# 2025-03-13 08:07:03,422 - __main__ - INFO - 已處理 388000 個項目
# 2025-03-13 08:07:03,441 - __main__ - INFO - 已處理 389000 個項目
# 2025-03-13 08:07:03,461 - __main__ - INFO - 已處理 390000 個項目
# 2025-03-13 08:07:03,626 - __main__ - INFO - 已處理 391000 個項目
# 2025-03-13 08:07:03,643 - __main__ - INFO - 已處理 392000 個項目
# 2025-03-13 08:07:03,662 - __main__ - INFO - 已處理 393000 個項目
# 2025-03-13 08:07:03,681 - __main__ - INFO - 已處理 394000 個項目
# 2025-03-13 08:07:03,701 - __main__ - INFO - 已處理 395000 個項目
# 2025-03-13 08:07:03,720 - __main__ - INFO - 已處理 396000 個項目
# 2025-03-13 08:07:03,738 - __main__ - INFO - 已處理 397000 個項目
# 2025-03-13 08:07:03,756 - __main__ - INFO - 已處理 398000 個項目
# 2025-03-13 08:07:03,774 - __main__ - INFO - 已處理 399000 個項目
# 2025-03-13 08:07:03,793 - __main__ - INFO - 已處理 400000 個項目
# 2025-03-13 08:07:03,811 - __main__ - INFO - 已處理 401000 個項目
# 2025-03-13 08:07:03,829 - __main__ - INFO - 已處理 402000 個項目
# 2025-03-13 08:07:03,848 - __main__ - INFO - 已處理 403000 個項目
# 2025-03-13 08:07:03,867 - __main__ - INFO - 已處理 404000 個項目
# 2025-03-13 08:07:03,887 - __main__ - INFO - 已處理 405000 個項目
# 2025-03-13 08:07:03,906 - __main__ - INFO - 已處理 406000 個項目
# 2025-03-13 08:07:03,925 - __main__ - INFO - 已處理 407000 個項目
# 2025-03-13 08:07:03,945 - __main__ - INFO - 已處理 408000 個項目
# 2025-03-13 08:07:03,965 - __main__ - INFO - 已處理 409000 個項目
# 2025-03-13 08:07:03,985 - __main__ - INFO - 已處理 410000 個項目
# 2025-03-13 08:07:04,006 - __main__ - INFO - 已處理 411000 個項目
# 2025-03-13 08:07:04,025 - __main__ - INFO - 已處理 412000 個項目
# 2025-03-13 08:07:04,043 - __main__ - INFO - 已處理 413000 個項目
# 2025-03-13 08:07:04,062 - __main__ - INFO - 已處理 414000 個項目
# 2025-03-13 08:07:04,082 - __main__ - INFO - 已處理 415000 個項目
# 2025-03-13 08:07:04,101 - __main__ - INFO - 已處理 416000 個項目
# 2025-03-13 08:07:04,119 - __main__ - INFO - 已處理 417000 個項目
# 2025-03-13 08:07:04,137 - __main__ - INFO - 已處理 418000 個項目
# 2025-03-13 08:07:04,157 - __main__ - INFO - 已處理 419000 個項目
# 2025-03-13 08:07:04,176 - __main__ - INFO - 已處理 420000 個項目
# 2025-03-13 08:07:04,195 - __main__ - INFO - 已處理 421000 個項目
# 2025-03-13 08:07:04,218 - __main__ - INFO - 已處理 422000 個項目
# 2025-03-13 08:07:04,238 - __main__ - INFO - 已處理 423000 個項目
# 2025-03-13 08:07:04,259 - __main__ - INFO - 已處理 424000 個項目
# 2025-03-13 08:07:04,277 - __main__ - INFO - 已處理 425000 個項目
# 2025-03-13 08:07:04,296 - __main__ - INFO - 已處理 426000 個項目
# 2025-03-13 08:07:04,317 - __main__ - INFO - 已處理 427000 個項目
# 2025-03-13 08:07:04,338 - __main__ - INFO - 已處理 428000 個項目
# 2025-03-13 08:07:04,357 - __main__ - INFO - 已處理 429000 個項目
# 2025-03-13 08:07:04,376 - __main__ - INFO - 已處理 430000 個項目
# 2025-03-13 08:07:04,394 - __main__ - INFO - 已處理 431000 個項目
# 2025-03-13 08:07:04,414 - __main__ - INFO - 已處理 432000 個項目
# 2025-03-13 08:07:04,432 - __main__ - INFO - 已處理 433000 個項目
# 2025-03-13 08:07:04,453 - __main__ - INFO - 已處理 434000 個項目
# 2025-03-13 08:07:04,472 - __main__ - INFO - 已處理 435000 個項目
# 2025-03-13 08:07:04,491 - __main__ - INFO - 已處理 436000 個項目
# 2025-03-13 08:07:04,510 - __main__ - INFO - 已處理 437000 個項目
# 2025-03-13 08:07:04,528 - __main__ - INFO - 已處理 438000 個項目
# 2025-03-13 08:07:04,548 - __main__ - INFO - 已處理 439000 個項目
# 2025-03-13 08:07:04,568 - __main__ - INFO - 已處理 440000 個項目
# 2025-03-13 08:07:04,587 - __main__ - INFO - 已處理 441000 個項目
# 2025-03-13 08:07:04,605 - __main__ - INFO - 已處理 442000 個項目
# 2025-03-13 08:07:04,624 - __main__ - INFO - 已處理 443000 個項目
# 2025-03-13 08:07:04,641 - __main__ - INFO - 已處理 444000 個項目
# 2025-03-13 08:07:04,659 - __main__ - INFO - 已處理 445000 個項目
# 2025-03-13 08:07:04,678 - __main__ - INFO - 已處理 446000 個項目
# 2025-03-13 08:07:04,696 - __main__ - INFO - 已處理 447000 個項目
# 2025-03-13 08:07:04,715 - __main__ - INFO - 已處理 448000 個項目
# 2025-03-13 08:07:04,734 - __main__ - INFO - 已處理 449000 個項目
# 2025-03-13 08:07:04,753 - __main__ - INFO - 已處理 450000 個項目
# 2025-03-13 08:07:04,771 - __main__ - INFO - 已處理 451000 個項目
# 2025-03-13 08:07:04,788 - __main__ - INFO - 已處理 452000 個項目
# 2025-03-13 08:07:04,805 - __main__ - INFO - 已處理 453000 個項目
# 2025-03-13 08:07:04,823 - __main__ - INFO - 已處理 454000 個項目
# 2025-03-13 08:07:04,842 - __main__ - INFO - 已處理 455000 個項目
# 2025-03-13 08:07:04,861 - __main__ - INFO - 已處理 456000 個項目
# 2025-03-13 08:07:04,882 - __main__ - INFO - 已處理 457000 個項目
# 2025-03-13 08:07:04,902 - __main__ - INFO - 已處理 458000 個項目
# 2025-03-13 08:07:04,920 - __main__ - INFO - 已處理 459000 個項目
# 2025-03-13 08:07:04,937 - __main__ - INFO - 已處理 460000 個項目
# 2025-03-13 08:07:04,955 - __main__ - INFO - 已處理 461000 個項目
# 2025-03-13 08:07:04,971 - __main__ - INFO - 已處理 462000 個項目
# 2025-03-13 08:07:04,988 - __main__ - INFO - 已處理 463000 個項目
# 2025-03-13 08:07:05,006 - __main__ - INFO - 已處理 464000 個項目
# 2025-03-13 08:07:05,023 - __main__ - INFO - 已處理 465000 個項目
# 2025-03-13 08:07:05,042 - __main__ - INFO - 已處理 466000 個項目
# 2025-03-13 08:07:05,060 - __main__ - INFO - 已處理 467000 個項目
# 2025-03-13 08:07:05,081 - __main__ - INFO - 已處理 468000 個項目
# 2025-03-13 08:07:05,103 - __main__ - INFO - 已處理 469000 個項目
# 2025-03-13 08:07:05,123 - __main__ - INFO - 已處理 470000 個項目
# 2025-03-13 08:07:05,145 - __main__ - INFO - 已處理 471000 個項目
# 2025-03-13 08:07:05,164 - __main__ - INFO - 已處理 472000 個項目
# 2025-03-13 08:07:05,185 - __main__ - INFO - 已處理 473000 個項目
# 2025-03-13 08:07:05,206 - __main__ - INFO - 已處理 474000 個項目
# 2025-03-13 08:07:05,226 - __main__ - INFO - 已處理 475000 個項目
# 2025-03-13 08:07:05,246 - __main__ - INFO - 已處理 476000 個項目
# 2025-03-13 08:07:05,266 - __main__ - INFO - 已處理 477000 個項目
# 2025-03-13 08:07:05,285 - __main__ - INFO - 已處理 478000 個項目
# 2025-03-13 08:07:05,306 - __main__ - INFO - 已處理 479000 個項目
# 2025-03-13 08:07:05,326 - __main__ - INFO - 已處理 480000 個項目
# 2025-03-13 08:07:05,345 - __main__ - INFO - 已處理 481000 個項目
# 2025-03-13 08:07:05,364 - __main__ - INFO - 已處理 482000 個項目
# 2025-03-13 08:07:05,384 - __main__ - INFO - 已處理 483000 個項目
# 2025-03-13 08:07:05,402 - __main__ - INFO - 已處理 484000 個項目
# 2025-03-13 08:07:05,423 - __main__ - INFO - 已處理 485000 個項目
# 2025-03-13 08:07:05,443 - __main__ - INFO - 已處理 486000 個項目
# 2025-03-13 08:07:05,465 - __main__ - INFO - 已處理 487000 個項目
# 2025-03-13 08:07:05,486 - __main__ - INFO - 已處理 488000 個項目
# 2025-03-13 08:07:05,505 - __main__ - INFO - 已處理 489000 個項目
# 2025-03-13 08:07:05,525 - __main__ - INFO - 已處理 490000 個項目
# 2025-03-13 08:07:05,546 - __main__ - INFO - 已處理 491000 個項目
# 2025-03-13 08:07:05,564 - __main__ - INFO - 已處理 492000 個項目
# 2025-03-13 08:07:05,583 - __main__ - INFO - 已處理 493000 個項目
# 2025-03-13 08:07:05,603 - __main__ - INFO - 已處理 494000 個項目
# 2025-03-13 08:07:05,622 - __main__ - INFO - 已處理 495000 個項目
# 2025-03-13 08:07:05,643 - __main__ - INFO - 已處理 496000 個項目
# 2025-03-13 08:07:05,661 - __main__ - INFO - 已處理 497000 個項目
# 2025-03-13 08:07:05,682 - __main__ - INFO - 已處理 498000 個項目
# 2025-03-13 08:07:05,701 - __main__ - INFO - 已處理 499000 個項目
# 2025-03-13 08:07:05,722 - __main__ - INFO - 已處理 500000 個項目
# 2025-03-13 08:07:05,741 - __main__ - INFO - 已處理 501000 個項目
# 2025-03-13 08:07:05,762 - __main__ - INFO - 已處理 502000 個項目
# 2025-03-13 08:07:05,782 - __main__ - INFO - 已處理 503000 個項目
# 2025-03-13 08:07:05,977 - __main__ - INFO - 已處理 504000 個項目
# 2025-03-13 08:07:05,994 - __main__ - INFO - 已處理 505000 個項目
# 2025-03-13 08:07:06,012 - __main__ - INFO - 已處理 506000 個項目
# 2025-03-13 08:07:06,032 - __main__ - INFO - 已處理 507000 個項目
# 2025-03-13 08:07:06,051 - __main__ - INFO - 已處理 508000 個項目
# 2025-03-13 08:07:06,069 - __main__ - INFO - 已處理 509000 個項目
# 2025-03-13 08:07:06,086 - __main__ - INFO - 已處理 510000 個項目
# 2025-03-13 08:07:06,110 - __main__ - INFO - 已處理 511000 個項目
# 2025-03-13 08:07:06,128 - __main__ - INFO - 已處理 512000 個項目
# 2025-03-13 08:07:06,148 - __main__ - INFO - 已處理 513000 個項目
# 2025-03-13 08:07:06,166 - __main__ - INFO - 已處理 514000 個項目
# 2025-03-13 08:07:06,183 - __main__ - INFO - 已處理 515000 個項目
# 2025-03-13 08:07:06,202 - __main__ - INFO - 已處理 516000 個項目
# 2025-03-13 08:07:06,220 - __main__ - INFO - 已處理 517000 個項目
# 2025-03-13 08:07:06,238 - __main__ - INFO - 已處理 518000 個項目
# 2025-03-13 08:07:06,258 - __main__ - INFO - 已處理 519000 個項目
# 2025-03-13 08:07:06,276 - __main__ - INFO - 已處理 520000 個項目
# 2025-03-13 08:07:06,293 - __main__ - INFO - 已處理 521000 個項目
# 2025-03-13 08:07:06,310 - __main__ - INFO - 已處理 522000 個項目
# 2025-03-13 08:07:06,327 - __main__ - INFO - 已處理 523000 個項目
# 2025-03-13 08:07:06,345 - __main__ - INFO - 已處理 524000 個項目
# 2025-03-13 08:07:06,364 - __main__ - INFO - 已處理 525000 個項目
# 2025-03-13 08:07:06,382 - __main__ - INFO - 已處理 526000 個項目
# 2025-03-13 08:07:06,399 - __main__ - INFO - 已處理 527000 個項目
# 2025-03-13 08:07:06,417 - __main__ - INFO - 已處理 528000 個項目
# 2025-03-13 08:07:06,434 - __main__ - INFO - 已處理 529000 個項目
# 2025-03-13 08:07:06,451 - __main__ - INFO - 已處理 530000 個項目
# 2025-03-13 08:07:06,468 - __main__ - INFO - 已處理 531000 個項目
# 2025-03-13 08:07:06,484 - __main__ - INFO - 已處理 532000 個項目
# 2025-03-13 08:07:06,502 - __main__ - INFO - 已處理 533000 個項目
# 2025-03-13 08:07:06,521 - __main__ - INFO - 已處理 534000 個項目
# 2025-03-13 08:07:06,539 - __main__ - INFO - 已處理 535000 個項目
# 2025-03-13 08:07:06,559 - __main__ - INFO - 已處理 536000 個項目
# 2025-03-13 08:07:06,579 - __main__ - INFO - 已處理 537000 個項目
# 2025-03-13 08:07:06,597 - __main__ - INFO - 已處理 538000 個項目
# 2025-03-13 08:07:06,616 - __main__ - INFO - 已處理 539000 個項目
# 2025-03-13 08:07:06,633 - __main__ - INFO - 已處理 540000 個項目
# 2025-03-13 08:07:06,681 - __main__ - INFO - 已處理 541000 個項目
# 2025-03-13 08:07:06,712 - __main__ - INFO - 已處理 542000 個項目
# 2025-03-13 08:07:06,734 - __main__ - INFO - 已處理 543000 個項目
# 2025-03-13 08:07:06,753 - __main__ - INFO - 已處理 544000 個項目
# 2025-03-13 08:07:06,774 - __main__ - INFO - 已處理 545000 個項目
# 2025-03-13 08:07:06,794 - __main__ - INFO - 已處理 546000 個項目
# 2025-03-13 08:07:06,814 - __main__ - INFO - 已處理 547000 個項目
# 2025-03-13 08:07:06,833 - __main__ - INFO - 已處理 548000 個項目
# 2025-03-13 08:07:06,851 - __main__ - INFO - 已處理 549000 個項目
# 2025-03-13 08:07:06,875 - __main__ - INFO - 已處理 550000 個項目
# 2025-03-13 08:07:06,894 - __main__ - INFO - 已處理 551000 個項目
# 2025-03-13 08:07:06,912 - __main__ - INFO - 已處理 552000 個項目
# 2025-03-13 08:07:06,930 - __main__ - INFO - 已處理 553000 個項目
# 2025-03-13 08:07:06,948 - __main__ - INFO - 已處理 554000 個項目
# 2025-03-13 08:07:06,966 - __main__ - INFO - 已處理 555000 個項目
# 2025-03-13 08:07:06,984 - __main__ - INFO - 已處理 556000 個項目
# 2025-03-13 08:07:07,003 - __main__ - INFO - 已處理 557000 個項目
# 2025-03-13 08:07:07,022 - __main__ - INFO - 已處理 558000 個項目
# 2025-03-13 08:07:07,042 - __main__ - INFO - 已處理 559000 個項目
# 2025-03-13 08:07:07,061 - __main__ - INFO - 已處理 560000 個項目
# 2025-03-13 08:07:07,080 - __main__ - INFO - 已處理 561000 個項目
# 2025-03-13 08:07:07,099 - __main__ - INFO - 已處理 562000 個項目
# 2025-03-13 08:07:07,119 - __main__ - INFO - 已處理 563000 個項目
# 2025-03-13 08:07:07,139 - __main__ - INFO - 已處理 564000 個項目
# 2025-03-13 08:07:07,159 - __main__ - INFO - 已處理 565000 個項目
# 2025-03-13 08:07:07,178 - __main__ - INFO - 已處理 566000 個項目
# 2025-03-13 08:07:07,199 - __main__ - INFO - 已處理 567000 個項目
# 2025-03-13 08:07:07,219 - __main__ - INFO - 已處理 568000 個項目
# 2025-03-13 08:07:07,238 - __main__ - INFO - 已處理 569000 個項目
# 2025-03-13 08:07:07,257 - __main__ - INFO - 已處理 570000 個項目
# 2025-03-13 08:07:07,275 - __main__ - INFO - 已處理 571000 個項目
# 2025-03-13 08:07:07,294 - __main__ - INFO - 已處理 572000 個項目
# 2025-03-13 08:07:07,315 - __main__ - INFO - 已處理 573000 個項目
# 2025-03-13 08:07:07,335 - __main__ - INFO - 已處理 574000 個項目
# 2025-03-13 08:07:07,357 - __main__ - INFO - 已處理 575000 個項目
# 2025-03-13 08:07:07,375 - __main__ - INFO - 已處理 576000 個項目
# 2025-03-13 08:07:07,395 - __main__ - INFO - 已處理 577000 個項目
# 2025-03-13 08:07:07,415 - __main__ - INFO - 已處理 578000 個項目
# 2025-03-13 08:07:07,436 - __main__ - INFO - 已處理 579000 個項目
# 2025-03-13 08:07:07,456 - __main__ - INFO - 已處理 580000 個項目
# 2025-03-13 08:07:07,475 - __main__ - INFO - 已處理 581000 個項目
# 2025-03-13 08:07:07,494 - __main__ - INFO - 已處理 582000 個項目
# 2025-03-13 08:07:07,512 - __main__ - INFO - 已處理 583000 個項目
# 2025-03-13 08:07:07,531 - __main__ - INFO - 已處理 584000 個項目
# 2025-03-13 08:07:07,551 - __main__ - INFO - 已處理 585000 個項目
# 2025-03-13 08:07:07,571 - __main__ - INFO - 已處理 586000 個項目
# 2025-03-13 08:07:07,589 - __main__ - INFO - 已處理 587000 個項目
# 2025-03-13 08:07:07,613 - __main__ - INFO - 已處理 588000 個項目
# 2025-03-13 08:07:07,631 - __main__ - INFO - 已處理 589000 個項目
# 2025-03-13 08:07:07,653 - __main__ - INFO - 已處理 590000 個項目
# 2025-03-13 08:07:07,673 - __main__ - INFO - 已處理 591000 個項目
# 2025-03-13 08:07:07,693 - __main__ - INFO - 已處理 592000 個項目
# 2025-03-13 08:07:07,711 - __main__ - INFO - 已處理 593000 個項目
# 2025-03-13 08:07:07,729 - __main__ - INFO - 已處理 594000 個項目
# 2025-03-13 08:07:07,750 - __main__ - INFO - 已處理 595000 個項目
# 2025-03-13 08:07:07,770 - __main__ - INFO - 已處理 596000 個項目
# 2025-03-13 08:07:07,789 - __main__ - INFO - 已處理 597000 個項目
# 2025-03-13 08:07:07,809 - __main__ - INFO - 已處理 598000 個項目
# 2025-03-13 08:07:07,829 - __main__ - INFO - 已處理 599000 個項目
# 2025-03-13 08:07:07,849 - __main__ - INFO - 已處理 600000 個項目
# 2025-03-13 08:07:07,867 - __main__ - INFO - 已處理 601000 個項目
# 2025-03-13 08:07:07,887 - __main__ - INFO - 已處理 602000 個項目
# 2025-03-13 08:07:07,906 - __main__ - INFO - 已處理 603000 個項目
# 2025-03-13 08:07:07,924 - __main__ - INFO - 已處理 604000 個項目
# 2025-03-13 08:07:07,944 - __main__ - INFO - 已處理 605000 個項目
# 2025-03-13 08:07:07,962 - __main__ - INFO - 已處理 606000 個項目
# 2025-03-13 08:07:07,982 - __main__ - INFO - 已處理 607000 個項目
# 2025-03-13 08:07:08,002 - __main__ - INFO - 已處理 608000 個項目
# 2025-03-13 08:07:08,022 - __main__ - INFO - 已處理 609000 個項目
# 2025-03-13 08:07:08,041 - __main__ - INFO - 已處理 610000 個項目
# 2025-03-13 08:07:08,071 - __main__ - INFO - 已處理 611000 個項目
# 2025-03-13 08:07:08,090 - __main__ - INFO - 已處理 612000 個項目
# 2025-03-13 08:07:08,110 - __main__ - INFO - 已處理 613000 個項目
# 2025-03-13 08:07:08,129 - __main__ - INFO - 已處理 614000 個項目
# 2025-03-13 08:07:08,147 - __main__ - INFO - 已處理 615000 個項目
# 2025-03-13 08:07:08,170 - __main__ - INFO - 已處理 616000 個項目
# 2025-03-13 08:07:08,191 - __main__ - INFO - 已處理 617000 個項目
# 2025-03-13 08:07:08,210 - __main__ - INFO - 已處理 618000 個項目
# 2025-03-13 08:07:08,228 - __main__ - INFO - 已處理 619000 個項目
# 2025-03-13 08:07:08,248 - __main__ - INFO - 已處理 620000 個項目
# 2025-03-13 08:07:08,268 - __main__ - INFO - 已處理 621000 個項目
# 2025-03-13 08:07:08,289 - __main__ - INFO - 已處理 622000 個項目
# 2025-03-13 08:07:08,310 - __main__ - INFO - 已處理 623000 個項目
# 2025-03-13 08:07:08,329 - __main__ - INFO - 已處理 624000 個項目
# 2025-03-13 08:07:08,348 - __main__ - INFO - 已處理 625000 個項目
# 2025-03-13 08:07:08,367 - __main__ - INFO - 已處理 626000 個項目
# 2025-03-13 08:07:08,387 - __main__ - INFO - 已處理 627000 個項目
# 2025-03-13 08:07:08,405 - __main__ - INFO - 已處理 628000 個項目
# 2025-03-13 08:07:08,425 - __main__ - INFO - 已處理 629000 個項目
# 2025-03-13 08:07:08,446 - __main__ - INFO - 已處理 630000 個項目
# 2025-03-13 08:07:08,466 - __main__ - INFO - 已處理 631000 個項目
# 2025-03-13 08:07:08,486 - __main__ - INFO - 已處理 632000 個項目
# 2025-03-13 08:07:08,506 - __main__ - INFO - 已處理 633000 個項目
# 2025-03-13 08:07:08,529 - __main__ - INFO - 已處理 634000 個項目
# 2025-03-13 08:07:08,549 - __main__ - INFO - 已處理 635000 個項目
# 2025-03-13 08:07:08,571 - __main__ - INFO - 已處理 636000 個項目
# 2025-03-13 08:07:08,589 - __main__ - INFO - 已處理 637000 個項目
# 2025-03-13 08:07:08,609 - __main__ - INFO - 已處理 638000 個項目
# 2025-03-13 08:07:08,628 - __main__ - INFO - 已處理 639000 個項目
# 2025-03-13 08:07:08,646 - __main__ - INFO - 已處理 640000 個項目
# 2025-03-13 08:07:08,664 - __main__ - INFO - 已處理 641000 個項目
# 2025-03-13 08:07:08,683 - __main__ - INFO - 已處理 642000 個項目
# 2025-03-13 08:07:08,702 - __main__ - INFO - 已處理 643000 個項目
# 2025-03-13 08:07:08,720 - __main__ - INFO - 已處理 644000 個項目
# 2025-03-13 08:07:08,740 - __main__ - INFO - 已處理 645000 個項目
# 2025-03-13 08:07:08,760 - __main__ - INFO - 已處理 646000 個項目
# 2025-03-13 08:07:08,989 - __main__ - INFO - 已處理 647000 個項目
# 2025-03-13 08:07:09,007 - __main__ - INFO - 已處理 648000 個項目
# 2025-03-13 08:07:09,025 - __main__ - INFO - 已處理 649000 個項目
# 2025-03-13 08:07:09,044 - __main__ - INFO - 已處理 650000 個項目
# 2025-03-13 08:07:09,062 - __main__ - INFO - 已處理 651000 個項目
# 2025-03-13 08:07:09,080 - __main__ - INFO - 已處理 652000 個項目
# 2025-03-13 08:07:09,098 - __main__ - INFO - 已處理 653000 個項目
# 2025-03-13 08:07:09,117 - __main__ - INFO - 已處理 654000 個項目
# 2025-03-13 08:07:09,140 - __main__ - INFO - 已處理 655000 個項目
# 2025-03-13 08:07:09,159 - __main__ - INFO - 已處理 656000 個項目
# 2025-03-13 08:07:09,176 - __main__ - INFO - 已處理 657000 個項目
# 2025-03-13 08:07:09,196 - __main__ - INFO - 已處理 658000 個項目
# 2025-03-13 08:07:09,214 - __main__ - INFO - 已處理 659000 個項目
# 2025-03-13 08:07:09,234 - __main__ - INFO - 已處理 660000 個項目
# 2025-03-13 08:07:09,252 - __main__ - INFO - 已處理 661000 個項目
# 2025-03-13 08:07:09,271 - __main__ - INFO - 已處理 662000 個項目
# 2025-03-13 08:07:09,290 - __main__ - INFO - 已處理 663000 個項目
# 2025-03-13 08:07:09,309 - __main__ - INFO - 已處理 664000 個項目
# 2025-03-13 08:07:09,329 - __main__ - INFO - 已處理 665000 個項目
# 2025-03-13 08:07:09,348 - __main__ - INFO - 已處理 666000 個項目
# 2025-03-13 08:07:09,367 - __main__ - INFO - 已處理 667000 個項目
# 2025-03-13 08:07:09,385 - __main__ - INFO - 已處理 668000 個項目
# 2025-03-13 08:07:09,403 - __main__ - INFO - 已處理 669000 個項目
# 2025-03-13 08:07:09,422 - __main__ - INFO - 已處理 670000 個項目
# 2025-03-13 08:07:09,442 - __main__ - INFO - 已處理 671000 個項目
# 2025-03-13 08:07:09,462 - __main__ - INFO - 已處理 672000 個項目
# 2025-03-13 08:07:09,482 - __main__ - INFO - 已處理 673000 個項目
# 2025-03-13 08:07:09,500 - __main__ - INFO - 已處理 674000 個項目
# 2025-03-13 08:07:09,518 - __main__ - INFO - 已處理 675000 個項目
# 2025-03-13 08:07:09,536 - __main__ - INFO - 已處理 676000 個項目
# 2025-03-13 08:07:09,554 - __main__ - INFO - 已處理 677000 個項目
# 2025-03-13 08:07:09,571 - __main__ - INFO - 已處理 678000 個項目
# 2025-03-13 08:07:09,590 - __main__ - INFO - 已處理 679000 個項目
# 2025-03-13 08:07:09,607 - __main__ - INFO - 已處理 680000 個項目
# 2025-03-13 08:07:09,626 - __main__ - INFO - 已處理 681000 個項目
# 2025-03-13 08:07:09,643 - __main__ - INFO - 已處理 682000 個項目
# 2025-03-13 08:07:09,662 - __main__ - INFO - 已處理 683000 個項目
# 2025-03-13 08:07:09,683 - __main__ - INFO - 已處理 684000 個項目
# 2025-03-13 08:07:09,701 - __main__ - INFO - 已處理 685000 個項目
# 2025-03-13 08:07:09,723 - __main__ - INFO - 已處理 686000 個項目
# 2025-03-13 08:07:09,742 - __main__ - INFO - 已處理 687000 個項目
# 2025-03-13 08:07:09,761 - __main__ - INFO - 已處理 688000 個項目
# 2025-03-13 08:07:09,779 - __main__ - INFO - 已處理 689000 個項目
# 2025-03-13 08:07:09,798 - __main__ - INFO - 已處理 690000 個項目
# 2025-03-13 08:07:09,817 - __main__ - INFO - 已處理 691000 個項目
# 2025-03-13 08:07:09,837 - __main__ - INFO - 已處理 692000 個項目
# 2025-03-13 08:07:09,855 - __main__ - INFO - 已處理 693000 個項目
# 2025-03-13 08:07:09,873 - __main__ - INFO - 已處理 694000 個項目
# 2025-03-13 08:07:09,892 - __main__ - INFO - 已處理 695000 個項目
# 2025-03-13 08:07:09,912 - __main__ - INFO - 已處理 696000 個項目
# 2025-03-13 08:07:09,931 - __main__ - INFO - 已處理 697000 個項目
# 2025-03-13 08:07:09,950 - __main__ - INFO - 已處理 698000 個項目
# 2025-03-13 08:07:09,969 - __main__ - INFO - 已處理 699000 個項目
# 2025-03-13 08:07:09,986 - __main__ - INFO - 已處理 700000 個項目
# 2025-03-13 08:07:10,002 - __main__ - INFO - 已處理 701000 個項目
# 2025-03-13 08:07:10,020 - __main__ - INFO - 已處理 702000 個項目
# 2025-03-13 08:07:10,038 - __main__ - INFO - 已處理 703000 個項目
# 2025-03-13 08:07:10,058 - __main__ - INFO - 已處理 704000 個項目
# 2025-03-13 08:07:10,075 - __main__ - INFO - 已處理 705000 個項目
# 2025-03-13 08:07:10,094 - __main__ - INFO - 已處理 706000 個項目
# 2025-03-13 08:07:10,114 - __main__ - INFO - 已處理 707000 個項目
# 2025-03-13 08:07:10,134 - __main__ - INFO - 已處理 708000 個項目
# 2025-03-13 08:07:10,157 - __main__ - INFO - 已處理 709000 個項目
# 2025-03-13 08:07:10,176 - __main__ - INFO - 已處理 710000 個項目
# 2025-03-13 08:07:10,196 - __main__ - INFO - 已處理 711000 個項目
# 2025-03-13 08:07:10,216 - __main__ - INFO - 已處理 712000 個項目
# 2025-03-13 08:07:10,234 - __main__ - INFO - 已處理 713000 個項目
# 2025-03-13 08:07:10,257 - __main__ - INFO - 已處理 714000 個項目
# 2025-03-13 08:07:10,275 - __main__ - INFO - 已處理 715000 個項目
# 2025-03-13 08:07:10,293 - __main__ - INFO - 已處理 716000 個項目
# 2025-03-13 08:07:10,316 - __main__ - INFO - 已處理 717000 個項目
# 2025-03-13 08:07:10,336 - __main__ - INFO - 已處理 718000 個項目
# 2025-03-13 08:07:10,354 - __main__ - INFO - 已處理 719000 個項目
# 2025-03-13 08:07:10,373 - __main__ - INFO - 已處理 720000 個項目
# 2025-03-13 08:07:10,393 - __main__ - INFO - 已處理 721000 個項目
# 2025-03-13 08:07:10,411 - __main__ - INFO - 已處理 722000 個項目
# 2025-03-13 08:07:10,429 - __main__ - INFO - 已處理 723000 個項目
# 2025-03-13 08:07:10,448 - __main__ - INFO - 已處理 724000 個項目
# 2025-03-13 08:07:10,501 - __main__ - INFO - 已處理 725000 個項目
# 2025-03-13 08:07:10,522 - __main__ - INFO - 已處理 726000 個項目
# 2025-03-13 08:07:10,541 - __main__ - INFO - 已處理 727000 個項目
# 2025-03-13 08:07:10,560 - __main__ - INFO - 已處理 728000 個項目
# 2025-03-13 08:07:10,579 - __main__ - INFO - 已處理 729000 個項目
# 2025-03-13 08:07:10,598 - __main__ - INFO - 已處理 730000 個項目
# 2025-03-13 08:07:10,618 - __main__ - INFO - 已處理 731000 個項目
# 2025-03-13 08:07:10,637 - __main__ - INFO - 已處理 732000 個項目
# 2025-03-13 08:07:10,655 - __main__ - INFO - 已處理 733000 個項目
# 2025-03-13 08:07:10,677 - __main__ - INFO - 已處理 734000 個項目
# 2025-03-13 08:07:10,696 - __main__ - INFO - 已處理 735000 個項目
# 2025-03-13 08:07:10,714 - __main__ - INFO - 已處理 736000 個項目
# 2025-03-13 08:07:10,733 - __main__ - INFO - 已處理 737000 個項目
# 2025-03-13 08:07:10,753 - __main__ - INFO - 已處理 738000 個項目
# 2025-03-13 08:07:10,773 - __main__ - INFO - 已處理 739000 個項目
# 2025-03-13 08:07:10,792 - __main__ - INFO - 已處理 740000 個項目
# 2025-03-13 08:07:10,811 - __main__ - INFO - 已處理 741000 個項目
# 2025-03-13 08:07:10,832 - __main__ - INFO - 已處理 742000 個項目
# 2025-03-13 08:07:10,851 - __main__ - INFO - 已處理 743000 個項目
# 2025-03-13 08:07:10,869 - __main__ - INFO - 已處理 744000 個項目
# 2025-03-13 08:07:10,891 - __main__ - INFO - 已處理 745000 個項目
# 2025-03-13 08:07:10,910 - __main__ - INFO - 已處理 746000 個項目
# 2025-03-13 08:07:10,929 - __main__ - INFO - 已處理 747000 個項目
# 2025-03-13 08:07:10,948 - __main__ - INFO - 已處理 748000 個項目
# 2025-03-13 08:07:10,967 - __main__ - INFO - 已處理 749000 個項目
# 2025-03-13 08:07:10,985 - __main__ - INFO - 已處理 750000 個項目
# 2025-03-13 08:07:11,004 - __main__ - INFO - 已處理 751000 個項目
# 2025-03-13 08:07:11,023 - __main__ - INFO - 已處理 752000 個項目
# 2025-03-13 08:07:11,042 - __main__ - INFO - 已處理 753000 個項目
# 2025-03-13 08:07:11,061 - __main__ - INFO - 已處理 754000 個項目
# 2025-03-13 08:07:11,080 - __main__ - INFO - 已處理 755000 個項目
# 2025-03-13 08:07:11,099 - __main__ - INFO - 已處理 756000 個項目
# 2025-03-13 08:07:11,117 - __main__ - INFO - 已處理 757000 個項目
# 2025-03-13 08:07:11,137 - __main__ - INFO - 已處理 758000 個項目
# 2025-03-13 08:07:11,156 - __main__ - INFO - 已處理 759000 個項目
# 2025-03-13 08:07:11,175 - __main__ - INFO - 已處理 760000 個項目
# 2025-03-13 08:07:11,194 - __main__ - INFO - 已處理 761000 個項目
# 2025-03-13 08:07:11,214 - __main__ - INFO - 已處理 762000 個項目
# 2025-03-13 08:07:11,234 - __main__ - INFO - 已處理 763000 個項目
# 2025-03-13 08:07:11,253 - __main__ - INFO - 已處理 764000 個項目
# 2025-03-13 08:07:11,270 - __main__ - INFO - 已處理 765000 個項目
# 2025-03-13 08:07:11,290 - __main__ - INFO - 已處理 766000 個項目
# 2025-03-13 08:07:11,308 - __main__ - INFO - 已處理 767000 個項目
# 2025-03-13 08:07:11,326 - __main__ - INFO - 已處理 768000 個項目
# 2025-03-13 08:07:11,344 - __main__ - INFO - 已處理 769000 個項目
# 2025-03-13 08:07:11,362 - __main__ - INFO - 已處理 770000 個項目
# 2025-03-13 08:07:11,381 - __main__ - INFO - 已處理 771000 個項目
# 2025-03-13 08:07:11,399 - __main__ - INFO - 已處理 772000 個項目
# 2025-03-13 08:07:11,417 - __main__ - INFO - 已處理 773000 個項目
# 2025-03-13 08:07:11,435 - __main__ - INFO - 已處理 774000 個項目
# 2025-03-13 08:07:11,458 - __main__ - INFO - 已處理 775000 個項目
# 2025-03-13 08:07:11,477 - __main__ - INFO - 已處理 776000 個項目
# 2025-03-13 08:07:11,496 - __main__ - INFO - 已處理 777000 個項目
# 2025-03-13 08:07:11,515 - __main__ - INFO - 已處理 778000 個項目
# 2025-03-13 08:07:11,535 - __main__ - INFO - 已處理 779000 個項目
# 2025-03-13 08:07:11,555 - __main__ - INFO - 已處理 780000 個項目
# 2025-03-13 08:07:11,576 - __main__ - INFO - 已處理 781000 個項目
# 2025-03-13 08:07:11,597 - __main__ - INFO - 已處理 782000 個項目
# 2025-03-13 08:07:11,615 - __main__ - INFO - 已處理 783000 個項目
# 2025-03-13 08:07:11,637 - __main__ - INFO - 已處理 784000 個項目
# 2025-03-13 08:07:11,655 - __main__ - INFO - 已處理 785000 個項目
# 2025-03-13 08:07:11,673 - __main__ - INFO - 已處理 786000 個項目
# 2025-03-13 08:07:11,692 - __main__ - INFO - 已處理 787000 個項目
# 2025-03-13 08:07:11,711 - __main__ - INFO - 已處理 788000 個項目
# 2025-03-13 08:07:11,730 - __main__ - INFO - 已處理 789000 個項目
# 2025-03-13 08:07:11,748 - __main__ - INFO - 已處理 790000 個項目
# 2025-03-13 08:07:11,767 - __main__ - INFO - 已處理 791000 個項目
# 2025-03-13 08:07:11,786 - __main__ - INFO - 已處理 792000 個項目
# 2025-03-13 08:07:11,805 - __main__ - INFO - 已處理 793000 個項目
# 2025-03-13 08:07:11,824 - __main__ - INFO - 已處理 794000 個項目
# 2025-03-13 08:07:11,843 - __main__ - INFO - 已處理 795000 個項目
# 2025-03-13 08:07:11,862 - __main__ - INFO - 已處理 796000 個項目
# 2025-03-13 08:07:11,881 - __main__ - INFO - 已處理 797000 個項目
# 2025-03-13 08:07:11,899 - __main__ - INFO - 已處理 798000 個項目
# 2025-03-13 08:07:11,919 - __main__ - INFO - 已處理 799000 個項目
# 2025-03-13 08:07:11,938 - __main__ - INFO - 已處理 800000 個項目
# 2025-03-13 08:07:11,956 - __main__ - INFO - 已處理 801000 個項目
# 2025-03-13 08:07:11,977 - __main__ - INFO - 已處理 802000 個項目
# 2025-03-13 08:07:11,995 - __main__ - INFO - 已處理 803000 個項目
# 2025-03-13 08:07:12,013 - __main__ - INFO - 已處理 804000 個項目
# 2025-03-13 08:07:12,033 - __main__ - INFO - 已處理 805000 個項目
# 2025-03-13 08:07:12,052 - __main__ - INFO - 已處理 806000 個項目
# 2025-03-13 08:07:12,071 - __main__ - INFO - 已處理 807000 個項目
# 2025-03-13 08:07:12,092 - __main__ - INFO - 已處理 808000 個項目
# 2025-03-13 08:07:12,111 - __main__ - INFO - 已處理 809000 個項目
# 2025-03-13 08:07:12,130 - __main__ - INFO - 已處理 810000 個項目
# 2025-03-13 08:07:12,148 - __main__ - INFO - 已處理 811000 個項目
# 2025-03-13 08:07:12,167 - __main__ - INFO - 已處理 812000 個項目
# ...
# 2025-03-13 08:07:18,972 - __main__ - INFO - 已處理 1127000 個項目
# 2025-03-13 08:07:18,990 - __main__ - INFO - 已處理 1128000 個項目
# 2025-03-13 08:07:19,009 - __main__ - INFO - 已處理 1129000 個項目
# 2025-03-13 08:07:19,028 - __main__ - INFO - 已處理 1130000 個項目
# 2025-03-13 08:07:19,051 - __main__ - INFO - 已處理 1131000 個項目
# 2025-03-13 08:07:19,072 - __main__ - INFO - 已處理 1132000 個項目
# 2025-03-13 08:07:19,090 - __main__ - INFO - 已處理 1133000 個項目
# 2025-03-13 08:07:19,108 - __main__ - INFO - 已處理 1134000 個項目
# 2025-03-13 08:07:19,129 - __main__ - INFO - 已處理 1135000 個項目
# 2025-03-13 08:07:19,147 - __main__ - INFO - 已處理 1136000 個項目
# 2025-03-13 08:07:19,167 - __main__ - INFO - 已處理 1137000 個項目
# 2025-03-13 08:07:19,186 - __main__ - INFO - 已處理 1138000 個項目
# 2025-03-13 08:07:19,205 - __main__ - INFO - 已處理 1139000 個項目
# 2025-03-13 08:07:19,225 - __main__ - INFO - 已處理 1140000 個項目
# 2025-03-13 08:07:19,243 - __main__ - INFO - 已處理 1141000 個項目
# 2025-03-13 08:07:19,262 - __main__ - INFO - 已處理 1142000 個項目
# 2025-03-13 08:07:19,281 - __main__ - INFO - 已處理 1143000 個項目
# 2025-03-13 08:07:19,299 - __main__ - INFO - 已處理 1144000 個項目
# 2025-03-13 08:07:19,320 - __main__ - INFO - 已處理 1145000 個項目
# 2025-03-13 08:07:19,341 - __main__ - INFO - 已處理 1146000 個項目
# 2025-03-13 08:07:19,363 - __main__ - INFO - 已處理 1147000 個項目
# 2025-03-13 08:07:19,385 - __main__ - INFO - 已處理 1148000 個項目
# 2025-03-13 08:07:19,404 - __main__ - INFO - 已處理 1149000 個項目
# 2025-03-13 08:07:19,428 - __main__ - INFO - 已處理 1150000 個項目
# 2025-03-13 08:07:19,450 - __main__ - INFO - 已處理 1151000 個項目
# 2025-03-13 08:07:19,469 - __main__ - INFO - 已處理 1152000 個項目
# 2025-03-13 08:07:19,485 - __main__ - INFO - 已處理 1153000 個項目
# 2025-03-13 08:07:19,504 - __main__ - INFO - 已處理 1154000 個項目
# 2025-03-13 08:07:19,524 - __main__ - INFO - 已處理 1155000 個項目
# 2025-03-13 08:07:19,544 - __main__ - INFO - 已處理 1156000 個項目
# 2025-03-13 08:07:19,565 - __main__ - INFO - 已處理 1157000 個項目
# 2025-03-13 08:07:19,584 - __main__ - INFO - 已處理 1158000 個項目
# 2025-03-13 08:07:19,603 - __main__ - INFO - 已處理 1159000 個項目
# 2025-03-13 08:07:19,622 - __main__ - INFO - 已處理 1160000 個項目
# 2025-03-13 08:07:19,643 - __main__ - INFO - 已處理 1161000 個項目
# 2025-03-13 08:07:19,708 - __main__ - INFO - 已處理 1162000 個項目
# 2025-03-13 08:07:19,727 - __main__ - INFO - 已處理 1163000 個項目
# 2025-03-13 08:07:19,745 - __main__ - INFO - 已處理 1164000 個項目
# 2025-03-13 08:07:19,764 - __main__ - INFO - 已處理 1165000 個項目
# 2025-03-13 08:07:19,784 - __main__ - INFO - 已處理 1166000 個項目
# 2025-03-13 08:07:19,806 - __main__ - INFO - 已處理 1167000 個項目
# 2025-03-13 08:07:19,825 - __main__ - INFO - 已處理 1168000 個項目
# 2025-03-13 08:07:19,850 - __main__ - INFO - 已處理 1169000 個項目
# 2025-03-13 08:07:19,871 - __main__ - INFO - 已處理 1170000 個項目
# 2025-03-13 08:07:19,889 - __main__ - INFO - 已處理 1171000 個項目
# 2025-03-13 08:07:19,908 - __main__ - INFO - 已處理 1172000 個項目
# 2025-03-13 08:07:19,928 - __main__ - INFO - 已處理 1173000 個項目
# 2025-03-13 08:07:19,948 - __main__ - INFO - 已處理 1174000 個項目
# 2025-03-13 08:07:19,967 - __main__ - INFO - 已處理 1175000 個項目
# 2025-03-13 08:07:19,986 - __main__ - INFO - 已處理 1176000 個項目
# 2025-03-13 08:07:20,007 - __main__ - INFO - 已處理 1177000 個項目
# 2025-03-13 08:07:20,026 - __main__ - INFO - 已處理 1178000 個項目
# 2025-03-13 08:07:20,046 - __main__ - INFO - 已處理 1179000 個項目
# 2025-03-13 08:07:20,066 - __main__ - INFO - 已處理 1180000 個項目
# 2025-03-13 08:07:20,086 - __main__ - INFO - 已處理 1181000 個項目
# 2025-03-13 08:07:20,104 - __main__ - INFO - 已處理 1182000 個項目
# 2025-03-13 08:07:20,124 - __main__ - INFO - 已處理 1183000 個項目
# 2025-03-13 08:07:20,144 - __main__ - INFO - 已處理 1184000 個項目
# 2025-03-13 08:07:20,163 - __main__ - INFO - 已處理 1185000 個項目
# 2025-03-13 08:07:20,183 - __main__ - INFO - 已處理 1186000 個項目
# 2025-03-13 08:07:20,206 - __main__ - INFO - 已處理 1187000 個項目
# 2025-03-13 08:07:20,226 - __main__ - INFO - 已處理 1188000 個項目
# 2025-03-13 08:07:20,246 - __main__ - INFO - 已處理 1189000 個項目
# 2025-03-13 08:07:20,266 - __main__ - INFO - 已處理 1190000 個項目
# 2025-03-13 08:07:20,285 - __main__ - INFO - 已處理 1191000 個項目
# 2025-03-13 08:07:20,305 - __main__ - INFO - 已處理 1192000 個項目
# 2025-03-13 08:07:20,325 - __main__ - INFO - 已處理 1193000 個項目
# 2025-03-13 08:07:20,347 - __main__ - INFO - 已處理 1194000 個項目
# 2025-03-13 08:07:20,366 - __main__ - INFO - 已處理 1195000 個項目
# 2025-03-13 08:07:20,386 - __main__ - INFO - 已處理 1196000 個項目
# 2025-03-13 08:07:20,406 - __main__ - INFO - 已處理 1197000 個項目
# 2025-03-13 08:07:20,426 - __main__ - INFO - 已處理 1198000 個項目
# 2025-03-13 08:07:20,445 - __main__ - INFO - 已處理 1199000 個項目
# 2025-03-13 08:07:20,464 - __main__ - INFO - 已處理 1200000 個項目
# 2025-03-13 08:07:20,484 - __main__ - INFO - 已處理 1201000 個項目
# 2025-03-13 08:07:20,503 - __main__ - INFO - 已處理 1202000 個項目
# 2025-03-13 08:07:20,523 - __main__ - INFO - 已處理 1203000 個項目
# 2025-03-13 08:07:20,541 - __main__ - INFO - 已處理 1204000 個項目
# 2025-03-13 08:07:20,565 - __main__ - INFO - 已處理 1205000 個項目
# 2025-03-13 08:07:20,585 - __main__ - INFO - 已處理 1206000 個項目
# 2025-03-13 08:07:20,604 - __main__ - INFO - 已處理 1207000 個項目
# 2025-03-13 08:07:20,624 - __main__ - INFO - 已處理 1208000 個項目
# 2025-03-13 08:07:20,644 - __main__ - INFO - 已處理 1209000 個項目
# 2025-03-13 08:07:20,663 - __main__ - INFO - 已處理 1210000 個項目
# 2025-03-13 08:07:20,682 - __main__ - INFO - 已處理 1211000 個項目
# 2025-03-13 08:07:20,701 - __main__ - INFO - 已處理 1212000 個項目
# 2025-03-13 08:07:20,720 - __main__ - INFO - 已處理 1213000 個項目
# 2025-03-13 08:07:20,739 - __main__ - INFO - 已處理 1214000 個項目
# 2025-03-13 08:07:20,761 - __main__ - INFO - 已處理 1215000 個項目
# 2025-03-13 08:07:20,781 - __main__ - INFO - 已處理 1216000 個項目
# 2025-03-13 08:07:20,800 - __main__ - INFO - 已處理 1217000 個項目
# 2025-03-13 08:07:20,821 - __main__ - INFO - 已處理 1218000 個項目
# 2025-03-13 08:07:20,841 - __main__ - INFO - 已處理 1219000 個項目
# 2025-03-13 08:07:20,859 - __main__ - INFO - 已處理 1220000 個項目
# 2025-03-13 08:07:20,879 - __main__ - INFO - 已處理 1221000 個項目
# 2025-03-13 08:07:20,898 - __main__ - INFO - 已處理 1222000 個項目
# 2025-03-13 08:07:20,921 - __main__ - INFO - 已處理 1223000 個項目
# 2025-03-13 08:07:20,939 - __main__ - INFO - 已處理 1224000 個項目
# 2025-03-13 08:07:20,958 - __main__ - INFO - 已處理 1225000 個項目
# 2025-03-13 08:07:20,977 - __main__ - INFO - 已處理 1226000 個項目
# 2025-03-13 08:07:20,996 - __main__ - INFO - 已處理 1227000 個項目
# 2025-03-13 08:07:21,015 - __main__ - INFO - 已處理 1228000 個項目
# 2025-03-13 08:07:21,035 - __main__ - INFO - 已處理 1229000 個項目
# 2025-03-13 08:07:21,054 - __main__ - INFO - 已處理 1230000 個項目
# 2025-03-13 08:07:21,074 - __main__ - INFO - 已處理 1231000 個項目
# 2025-03-13 08:07:21,093 - __main__ - INFO - 已處理 1232000 個項目
# 2025-03-13 08:07:21,115 - __main__ - INFO - 已處理 1233000 個項目
# 2025-03-13 08:07:21,134 - __main__ - INFO - 已處理 1234000 個項目
# 2025-03-13 08:07:21,156 - __main__ - INFO - 已處理 1235000 個項目
# 2025-03-13 08:07:21,177 - __main__ - INFO - 已處理 1236000 個項目
# 2025-03-13 08:07:21,196 - __main__ - INFO - 已處理 1237000 個項目
# 2025-03-13 08:07:21,214 - __main__ - INFO - 已處理 1238000 個項目
# 2025-03-13 08:07:21,233 - __main__ - INFO - 已處理 1239000 個項目
# 2025-03-13 08:07:21,257 - __main__ - INFO - 已處理 1240000 個項目
# 2025-03-13 08:07:21,276 - __main__ - INFO - 已處理 1241000 個項目
# 2025-03-13 08:07:21,297 - __main__ - INFO - 已處理 1242000 個項目
# 2025-03-13 08:07:21,315 - __main__ - INFO - 已處理 1243000 個項目
# 2025-03-13 08:07:21,335 - __main__ - INFO - 已處理 1244000 個項目
# 2025-03-13 08:07:21,355 - __main__ - INFO - 已處理 1245000 個項目
# 2025-03-13 08:07:21,392 - __main__ - INFO - 已處理 1246000 個項目
# 2025-03-13 08:07:21,430 - __main__ - INFO - 已處理 1247000 個項目
# 2025-03-13 08:07:21,449 - __main__ - INFO - 已處理 1248000 個項目
# 2025-03-13 08:07:21,470 - __main__ - INFO - 已處理 1249000 個項目
# 2025-03-13 08:07:21,489 - __main__ - INFO - 已處理 1250000 個項目
# 2025-03-13 08:07:21,508 - __main__ - INFO - 已處理 1251000 個項目
# 2025-03-13 08:07:21,526 - __main__ - INFO - 已處理 1252000 個項目
# 2025-03-13 08:07:21,545 - __main__ - INFO - 已處理 1253000 個項目
# 2025-03-13 08:07:21,563 - __main__ - INFO - 已處理 1254000 個項目
# 2025-03-13 08:07:21,581 - __main__ - INFO - 已處理 1255000 個項目
# 2025-03-13 08:07:21,599 - __main__ - INFO - 已處理 1256000 個項目
# 2025-03-13 08:07:21,620 - __main__ - INFO - 已處理 1257000 個項目
# 2025-03-13 08:07:21,638 - __main__ - INFO - 已處理 1258000 個項目
# 2025-03-13 08:07:21,656 - __main__ - INFO - 已處理 1259000 個項目
# 2025-03-13 08:07:21,675 - __main__ - INFO - 已處理 1260000 個項目
# 2025-03-13 08:07:21,693 - __main__ - INFO - 已處理 1261000 個項目
# 2025-03-13 08:07:21,712 - __main__ - INFO - 已處理 1262000 個項目
# 2025-03-13 08:07:21,731 - __main__ - INFO - 已處理 1263000 個項目
# 2025-03-13 08:07:21,748 - __main__ - INFO - 已處理 1264000 個項目
# 2025-03-13 08:07:21,767 - __main__ - INFO - 已處理 1265000 個項目
# 2025-03-13 08:07:21,787 - __main__ - INFO - 已處理 1266000 個項目
# 2025-03-13 08:07:21,805 - __main__ - INFO - 已處理 1267000 個項目
# 2025-03-13 08:07:21,824 - __main__ - INFO - 已處理 1268000 個項目
# 2025-03-13 08:07:21,842 - __main__ - INFO - 已處理 1269000 個項目
# 2025-03-13 08:07:21,863 - __main__ - INFO - 已處理 1270000 個項目
# 2025-03-13 08:07:21,883 - __main__ - INFO - 已處理 1271000 個項目
# 2025-03-13 08:07:21,904 - __main__ - INFO - 已處理 1272000 個項目
# 2025-03-13 08:07:21,925 - __main__ - INFO - 已處理 1273000 個項目
# 2025-03-13 08:07:21,945 - __main__ - INFO - 已處理 1274000 個項目
# 2025-03-13 08:07:21,964 - __main__ - INFO - 已處理 1275000 個項目
# 2025-03-13 08:07:21,983 - __main__ - INFO - 已處理 1276000 個項目
# 2025-03-13 08:07:22,003 - __main__ - INFO - 已處理 1277000 個項目
# 2025-03-13 08:07:22,021 - __main__ - INFO - 已處理 1278000 個項目
# 2025-03-13 08:07:22,041 - __main__ - INFO - 已處理 1279000 個項目
# 2025-03-13 08:07:22,062 - __main__ - INFO - 已處理 1280000 個項目
# 2025-03-13 08:07:22,080 - __main__ - INFO - 已處理 1281000 個項目
# 2025-03-13 08:07:22,100 - __main__ - INFO - 已處理 1282000 個項目
# 2025-03-13 08:07:22,120 - __main__ - INFO - 已處理 1283000 個項目
# 2025-03-13 08:07:22,140 - __main__ - INFO - 已處理 1284000 個項目
# 2025-03-13 08:07:22,160 - __main__ - INFO - 已處理 1285000 個項目
# 2025-03-13 08:07:22,179 - __main__ - INFO - 已處理 1286000 個項目
# 2025-03-13 08:07:22,200 - __main__ - INFO - 已處理 1287000 個項目
# 2025-03-13 08:07:22,218 - __main__ - INFO - 已處理 1288000 個項目
# 2025-03-13 08:07:22,238 - __main__ - INFO - 已處理 1289000 個項目
# 2025-03-13 08:07:22,264 - __main__ - INFO - 已處理 1290000 個項目
# 2025-03-13 08:07:22,285 - __main__ - INFO - 已處理 1291000 個項目
# 2025-03-13 08:07:22,306 - __main__ - INFO - 已處理 1292000 個項目
# 2025-03-13 08:07:22,325 - __main__ - INFO - 已處理 1293000 個項目
# 2025-03-13 08:07:22,345 - __main__ - INFO - 已處理 1294000 個項目
# 2025-03-13 08:07:22,366 - __main__ - INFO - 已處理 1295000 個項目
# 2025-03-13 08:07:22,387 - __main__ - INFO - 已處理 1296000 個項目
# 2025-03-13 08:07:22,406 - __main__ - INFO - 已處理 1297000 個項目
# 2025-03-13 08:07:22,424 - __main__ - INFO - 已處理 1298000 個項目
# 2025-03-13 08:07:22,444 - __main__ - INFO - 已處理 1299000 個項目
# 2025-03-13 08:07:22,465 - __main__ - INFO - 已處理 1300000 個項目
# 2025-03-13 08:07:22,485 - __main__ - INFO - 已處理 1301000 個項目
# 2025-03-13 08:07:22,504 - __main__ - INFO - 已處理 1302000 個項目
# 2025-03-13 08:07:22,525 - __main__ - INFO - 已處理 1303000 個項目
# 2025-03-13 08:07:22,548 - __main__ - INFO - 已處理 1304000 個項目
# 2025-03-13 08:07:22,577 - __main__ - INFO - 已處理 1305000 個項目
# 2025-03-13 08:07:22,596 - __main__ - INFO - 已處理 1306000 個項目
# 2025-03-13 08:07:22,621 - __main__ - INFO - 已處理 1307000 個項目
# 2025-03-13 08:07:22,642 - __main__ - INFO - 已處理 1308000 個項目
# 2025-03-13 08:07:22,662 - __main__ - INFO - 已處理 1309000 個項目
# 2025-03-13 08:07:22,685 - __main__ - INFO - 已處理 1310000 個項目
# 2025-03-13 08:07:22,705 - __main__ - INFO - 已處理 1311000 個項目
# 2025-03-13 08:07:22,726 - __main__ - INFO - 已處理 1312000 個項目
# 2025-03-13 08:07:22,746 - __main__ - INFO - 已處理 1313000 個項目
# 2025-03-13 08:07:22,766 - __main__ - INFO - 已處理 1314000 個項目
# 2025-03-13 08:07:22,786 - __main__ - INFO - 已處理 1315000 個項目
# 2025-03-13 08:07:22,807 - __main__ - INFO - 已處理 1316000 個項目
# 2025-03-13 08:07:22,828 - __main__ - INFO - 已處理 1317000 個項目
# 2025-03-13 08:07:22,848 - __main__ - INFO - 已處理 1318000 個項目
# 2025-03-13 08:07:22,868 - __main__ - INFO - 已處理 1319000 個項目
# 2025-03-13 08:07:22,888 - __main__ - INFO - 已處理 1320000 個項目
# 2025-03-13 08:07:23,314 - __main__ - INFO - 已處理 1321000 個項目
# 2025-03-13 08:07:23,333 - __main__ - INFO - 已處理 1322000 個項目
# 2025-03-13 08:07:23,358 - __main__ - INFO - 已處理 1323000 個項目
# 2025-03-13 08:07:23,378 - __main__ - INFO - 已處理 1324000 個項目
# 2025-03-13 08:07:23,399 - __main__ - INFO - 已處理 1325000 個項目
# 2025-03-13 08:07:23,418 - __main__ - INFO - 已處理 1326000 個項目
# 2025-03-13 08:07:23,437 - __main__ - INFO - 已處理 1327000 個項目
# 2025-03-13 08:07:23,458 - __main__ - INFO - 已處理 1328000 個項目
# 2025-03-13 08:07:23,477 - __main__ - INFO - 已處理 1329000 個項目
# 2025-03-13 08:07:23,529 - __main__ - INFO - 已處理 1330000 個項目
# 2025-03-13 08:07:23,552 - __main__ - INFO - 已處理 1331000 個項目
# 2025-03-13 08:07:23,572 - __main__ - INFO - 已處理 1332000 個項目
# 2025-03-13 08:07:23,593 - __main__ - INFO - 已處理 1333000 個項目
# 2025-03-13 08:07:23,613 - __main__ - INFO - 已處理 1334000 個項目
# 2025-03-13 08:07:23,630 - __main__ - INFO - 已處理 1335000 個項目
# 2025-03-13 08:07:23,649 - __main__ - INFO - 已處理 1336000 個項目
# 2025-03-13 08:07:23,668 - __main__ - INFO - 已處理 1337000 個項目
# 2025-03-13 08:07:23,688 - __main__ - INFO - 已處理 1338000 個項目
# 2025-03-13 08:07:23,710 - __main__ - INFO - 已處理 1339000 個項目
# 2025-03-13 08:07:23,731 - __main__ - INFO - 已處理 1340000 個項目
# 2025-03-13 08:07:23,751 - __main__ - INFO - 已處理 1341000 個項目
# 2025-03-13 08:07:23,770 - __main__ - INFO - 已處理 1342000 個項目
# 2025-03-13 08:07:23,790 - __main__ - INFO - 已處理 1343000 個項目
# 2025-03-13 08:07:23,809 - __main__ - INFO - 已處理 1344000 個項目
# 2025-03-13 08:07:23,829 - __main__ - INFO - 已處理 1345000 個項目
# 2025-03-13 08:07:23,847 - __main__ - INFO - 已處理 1346000 個項目
# 2025-03-13 08:07:23,865 - __main__ - INFO - 已處理 1347000 個項目
# 2025-03-13 08:07:23,885 - __main__ - INFO - 已處理 1348000 個項目
# 2025-03-13 08:07:23,905 - __main__ - INFO - 已處理 1349000 個項目
# 2025-03-13 08:07:23,925 - __main__ - INFO - 已處理 1350000 個項目
# 2025-03-13 08:07:23,944 - __main__ - INFO - 已處理 1351000 個項目
# 2025-03-13 08:07:23,962 - __main__ - INFO - 已處理 1352000 個項目
# 2025-03-13 08:07:23,982 - __main__ - INFO - 已處理 1353000 個項目
# 2025-03-13 08:07:24,002 - __main__ - INFO - 已處理 1354000 個項目
# 2025-03-13 08:07:24,025 - __main__ - INFO - 已處理 1355000 個項目
# 2025-03-13 08:07:24,044 - __main__ - INFO - 已處理 1356000 個項目
# 2025-03-13 08:07:24,064 - __main__ - INFO - 已處理 1357000 個項目
# 2025-03-13 08:07:24,083 - __main__ - INFO - 已處理 1358000 個項目
# 2025-03-13 08:07:24,101 - __main__ - INFO - 已處理 1359000 個項目
# 2025-03-13 08:07:24,119 - __main__ - INFO - 已處理 1360000 個項目
# 2025-03-13 08:07:24,140 - __main__ - INFO - 已處理 1361000 個項目
# 2025-03-13 08:07:24,158 - __main__ - INFO - 已處理 1362000 個項目
# 2025-03-13 08:07:24,177 - __main__ - INFO - 已處理 1363000 個項目
# 2025-03-13 08:07:24,196 - __main__ - INFO - 已處理 1364000 個項目
# 2025-03-13 08:07:24,215 - __main__ - INFO - 已處理 1365000 個項目
# 2025-03-13 08:07:24,234 - __main__ - INFO - 已處理 1366000 個項目
# 2025-03-13 08:07:24,252 - __main__ - INFO - 已處理 1367000 個項目
# 2025-03-13 08:07:24,273 - __main__ - INFO - 已處理 1368000 個項目
# 2025-03-13 08:07:24,292 - __main__ - INFO - 已處理 1369000 個項目
# 2025-03-13 08:07:24,315 - __main__ - INFO - 已處理 1370000 個項目
# 2025-03-13 08:07:24,335 - __main__ - INFO - 已處理 1371000 個項目
# 2025-03-13 08:07:24,354 - __main__ - INFO - 已處理 1372000 個項目
# 2025-03-13 08:07:24,373 - __main__ - INFO - 已處理 1373000 個項目
# 2025-03-13 08:07:24,393 - __main__ - INFO - 已處理 1374000 個項目
# 2025-03-13 08:07:24,412 - __main__ - INFO - 已處理 1375000 個項目
# 2025-03-13 08:07:24,430 - __main__ - INFO - 已處理 1376000 個項目
# 2025-03-13 08:07:24,455 - __main__ - INFO - 已處理 1377000 個項目
# 2025-03-13 08:07:24,456 - __main__ - INFO - 已處理 1377010 個項目
# 2025-03-13 08:07:24,456 - __main__ - INFO - 分批處理完成，總共處理 1377010 個項目
# 2025-03-13 08:07:34,554 - __main__ - INFO - 已成功儲存 1377010 個項目至檔案: ../data/convert/official-cpe-dictionary_v2.3.json
# 2025-03-13 08:07:41,453 - __main__ - INFO - 已成功儲存 1377010 個項目至檔案: ../data/convert/official-cpe-dictionary_v2.3.csv
# 2025-03-13 08:07:41,542 - __main__ - INFO - 已成功儲存 22566 個廠商變體資訊至檔案: ../data/convert/vendor_variations.json
# 2025-03-13 08:07:41,550 - __main__ - INFO - 廠商變體分析結果: {
#   "total_vendors": 22566,
#   "vendors_with_variations": 25,
#   "percentage_with_variations": 0.11,
#   "max_variations": 2,
#   "max_variations_vendor": "alphaware_simple_e_commerce_system_project",
#   "max_variations_list": [
#     "alphaware_simple_e-commerce_system_project",
#     "alphaware_-_simple_e-commerce_system_project"
#   ]
# }
# 2025-03-13 08:07:41,551 - __main__ - INFO - 程式執行完成

# %% [markdown]
# ### Example of converted format
#
# #### JSON Format
#
# ```JSON
# {
#   "cpe22Uri": "cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~",
#   "cpe23Uri": "cpe:2.3:a:\\$0.99_kindle_books_project:\\$0.99_kindle_books:6:*:*:*:*:android:*:*",
#   "vendor": "\\$0.99_kindle_books_project",
#   "product": "\\$0.99_kindle_books",
#   "version": "6",
#   "title": "$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0",
#   "references": "Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)"
# },
# ```
#
# #### CSV Format
#
# ```CSV
# cpe22Uri,cpe23Uri,vendor,product,version,title,references
# cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~,cpe:2.3:a:\$0.99_kindle_books_project:\$0.99_kindle_books:6:*:*:*:*:android:*:*,\$0.99_kindle_books_project,\$0.99_kindle_books,6,$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0,Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)
# ```

# %% [markdown]
# ## Step 3: Create a vector database (using Chromadb as an example)
#
# To quickly retrieve the closest Common Platform Enumeration (CPE) data based on user input, we will utilize the similarity search capabilities of a vector database. Vector databases excel at transforming complex data (such as images, audio, etc.) into vector representations for mathematical operations. Given the variability of user input, the potential for different registration formats of vendor and product names within the CPE database, and the varying relevance of references included in CPE entries, we aim to leverage the similarity comparison capabilities of the vector database to effectively identify the desired CPE entries. Therefore, we need to import the National Vulnerability Database (NVD) CPE Directory List into Chromadb and convert it into vectors for subsequent similarity comparisons.
#
# > 為了能根據使用者輸入，快速取得最接近的通用平台列舉（CPE）資料，我們將利用向量資料庫的相似性搜尋功能。向量資料庫擅長將複雜資料（如圖像、聲音等）轉換為可進行數學運算的向量表示。由於使用者輸入的多樣性，以及廠商、產品名稱在 CPE 資料庫中可能存在不同形式的登記方式，加上 CPE 條目中包含的參考資料（References）有時相關、有時不相關，我們希望藉由向量資料庫的相似性比較能力，有效識別出期望的 CPE 條目。因此，我們需要將美國國家漏洞資料庫（NVD）的 CPE 目錄列表匯入 Chromadb，並將其轉換為向量，以便後續的相似性比對。
#
# ### Structure of the created to vector database
#
# ```Markdown
#           (Periodic or Manual)
# ┌───────────────────────────────────────┐
# │    NVD CPE Directory (ZIP/XML)        │
# └───────────────────────────────────────┘
#                │
#                ▼
#      CPE Directory Updater
#                │
#                ▼
#      CPE Parser & Transformer
#                │  (structured JSON)
#                ▼
#      Embedding Service (Huggingface)
#                │ (vector)
#                ▼
#   ┌────────────────────────────────────┐
#   │         Chromadb Vector DB         │
#   └────────────────────────────────────┘
# ```

# %%
import csv
import datetime
import json
import logging
import os
from dataclasses import dataclass
from functools import lru_cache
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple, Union

import chromadb
from chromadb.utils import embedding_functions


# 設定日誌
def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


# 設定日誌
setup_logging(logging.INFO, "../logs/cpe_database.log")
logger = logging.getLogger(__name__)


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class EmbeddingModelProvider:
    """提供不同的嵌入模型選項"""

    @staticmethod
    def get_default_embedding():
        """獲取預設的嵌入函數

        Returns:
            embedding_function: 預設的嵌入函數
        """
        return embedding_functions.DefaultEmbeddingFunction()


class CPEInputStandardizer:
    """CPE輸入標準化預處理器"""

    @staticmethod
    def standardize_text(text: Optional[str]) -> Optional[str]:
        """
        標準化文本:
        1. 轉換為小寫
        2. 替換標準化特殊字符
        3. 清理多餘空格

        Args:
            text: 要標準化的文本

        Returns:
            標準化後的文本，如果輸入為空則返回None
        """
        if not text:
            return None

        # 轉換為小寫
        text = text.lower().strip()

        # 替換特殊字符
        special_chars = [' ', '-', '.', '/', ':', '(', ')', '[', ']', '+', '&']
        for char in special_chars:
            text = text.replace(char, '_')

        # 合併連續底線
        while '__' in text:
            text = text.replace('__', '_')

        # 去除首尾底線
        text = text.strip('_')

        return text

    @staticmethod
    def standardize_version(version: Optional[str]) -> Optional[str]:
        """
        標準化版本號:
        1. 移除版本前綴
        2. 替換非標準分隔符
        3. 處理特殊版本格式
        4. 正規化數字部分（例如將001變為1）

        Args:
            version: 要標準化的版本號

        Returns:
            標準化後的版本號，如果輸入為空則返回None
        """
        if not version:
            return None

        # 去除空白
        version = version.strip()

        # 移除版本前綴 (v, ver, version等)
        prefixes = ['v', 'ver', 'version', 'release', 'rel']

        lower_version = version.lower()
        for prefix in prefixes:
            if lower_version.startswith(prefix):
                # 處理不同格式的前綴
                if len(version) > len(prefix):
                    if version[len(prefix)].isdigit():
                        # v1.0 格式
                        version = version[len(prefix):]
                    elif version[len(prefix)] in [' ', '.', '-', '_']:
                        # v 1.0, v.1.0, v-1.0 格式
                        version = version[len(prefix)+1:]

        # 清理版本號開頭的非數字字符
        while version and not version[0].isdigit():
            version = version[1:]

        # 如果清理後為空，返回None
        if not version:
            return None

        # 將常見的版本分隔符標準化為點
        for sep in ['-', '_', ' ']:
            version = version.replace(sep, '.')

        # 處理重複的分隔符
        while '..' in version:
            version = version.replace('..', '.')

        # 處理版本號的每個部分，移除無意義的前導零
        parts = version.split('.')
        normalized_parts = []
        for part in parts:
            if part.isdigit():
                # 移除前導零但保留單個零
                normalized_part = part.lstrip('0')
                normalized_part = normalized_part if normalized_part else '0'
                normalized_parts.append(normalized_part)
            else:
                normalized_parts.append(part)

        return '.'.join(normalized_parts)

    @staticmethod
    def standardize_input(vendor: Optional[str] = None,
                          product: Optional[str] = None,
                          version: Optional[str] = None) -> Tuple[Optional[str], Optional[str], Optional[str]]:
        """
        標準化處理用戶輸入的廠商、產品和版本

        Args:
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號

        Returns:
            標準化後的廠商、產品和版本
        """
        std_vendor = CPEInputStandardizer.standardize_text(vendor)
        std_product = CPEInputStandardizer.standardize_text(product)
        std_version = CPEInputStandardizer.standardize_version(version)

        return std_vendor, std_product, std_version

    @staticmethod
    def standardize_csv_row(row: Dict[str, str]) -> Dict[str, str]:
        """
        標準化CSV檔案中的一行

        Args:
            row: CSV行資料

        Returns:
            標準化後的行資料
        """
        vendor = row.get('vendor', '').strip() or None
        product = row.get('product', '').strip() or None
        version = row.get('version', '').strip() or None

        std_vendor, std_product, std_version = CPEInputStandardizer.standardize_input(
            vendor, product, version
        )

        # 建立新的標準化後的行
        standardized_row = row.copy()

        # 保存原始值
        standardized_row['original_vendor'] = vendor
        standardized_row['original_product'] = product
        standardized_row['original_version'] = version

        # 添加標準化值
        standardized_row['vendor'] = std_vendor
        standardized_row['product'] = std_product
        standardized_row['version'] = std_version

        return standardized_row


class StringMatcher:
    """字串相似度比對工具類"""

    @staticmethod
    @lru_cache(maxsize=1000)
    def levenshtein_distance(s1: str, s2: str) -> int:
        """計算兩個字符串之間的Levenshtein距離

        Args:
            s1: 第一個字串
            s2: 第二個字串

        Returns:
            Levenshtein距離
        """
        if len(s1) < len(s2):
            return StringMatcher.levenshtein_distance(s2, s1)

        if len(s2) == 0:
            return len(s1)

        previous_row = range(len(s2) + 1)
        for i, c1 in enumerate(s1):
            current_row = [i + 1]
            for j, c2 in enumerate(s2):
                insertions = previous_row[j + 1] + 1
                deletions = current_row[j] + 1
                substitutions = previous_row[j] + (c1 != c2)
                current_row.append(min(insertions, deletions, substitutions))
            previous_row = current_row

        return previous_row[-1]

    @staticmethod
    def calculate_similarity(s1: str, s2: str) -> float:
        """計算兩個字串的相似度

        Args:
            s1: 第一個字串
            s2: 第二個字串

        Returns:
            相似度分數，範圍為0到1，1表示完全相同
        """
        s1 = s1.lower().strip()
        s2 = s2.lower().strip()

        # 快速檢查
        if s1 == s2:
            return 1.0
        elif s1 in s2 or s2 in s1:
            return 0.8

        # 使用Levenshtein距離計算相似度
        distance = StringMatcher.levenshtein_distance(s1, s2)
        max_len = max(len(s1), len(s2))

        if max_len == 0:
            return 0.0

        return 1.0 - (distance / max_len)

    @staticmethod
    @lru_cache(maxsize=1000)
    def version_match(query_version: str, db_version: str) -> bool:
        """改進的版本號匹配邏輯

        Args:
            query_version: 查詢的版本號
            db_version: 資料庫中的版本號

        Returns:
            是否匹配
        """
        # 簡化版本號，移除不必要的零
        def normalize_version(v):
            if not v:
                return ""
            # 將版本號拆分為數字和非數字部分
            parts = []
            current = ""
            for c in v:
                if current and ((c.isdigit() and not current[-1].isdigit()) or
                                (not c.isdigit() and current[-1].isdigit())):
                    parts.append(current)
                    current = c
                else:
                    current += c
            if current:
                parts.append(current)

            # 對數字部分進行處理，移除前導零
            norm_parts = []
            for part in parts:
                if part.isdigit():
                    # 移除前導零但保留單個零
                    norm_part = part.lstrip('0')
                    norm_part = norm_part if norm_part else '0'
                    norm_parts.append(norm_part)
                else:
                    norm_parts.append(part)

            return "".join(norm_parts)

        norm_query = normalize_version(query_version)
        norm_db = normalize_version(db_version)

        # 先檢查完全匹配
        if norm_query == norm_db:
            return True

        # 再檢查部分匹配
        return norm_query in norm_db or norm_db in norm_query


class CPEDatabaseManager:
    """CPE資料庫管理器"""

    def __init__(self,
                 db_path: str = "../database/cpe_database",
                 use_gpu: bool = False,
                 embedding_model: str = "default"):
        """初始化 CPE 資料庫管理器

        Args:
            db_path: 資料庫存放路徑
            use_gpu: 是否使用 GPU. 預設為 False.
            embedding_model: 要使用的嵌入模型類型. 預設為 "default".
        """
        self.db_path = Path(db_path)
        self.db_path.mkdir(parents=True, exist_ok=True)

        self.client = None
        self.collection = None

        # 設定 GPU 使用選項
        self.use_gpu = use_gpu

        # 選擇嵌入模型
        self.setup_embedding_function(embedding_model)

        # 設定資料庫
        self.setup_database()

    def setup_embedding_function(self, embedding_model: str) -> None:
        """設定嵌入函數

        Args:
            embedding_model: 嵌入模型類型
        """
        self.embedding_function = EmbeddingModelProvider.get_default_embedding()
        embedding_description = "預設"

        logger.info(f"使用嵌入模型: {embedding_description}")

    def setup_database(self) -> None:
        """設定資料庫連接和集合"""
        try:
            self.client = chromadb.PersistentClient(path=str(self.db_path))

            # 使用設定的 embedding 函數建立集合
            self.collection = self.client.get_or_create_collection(
                name="cpe_dictionary",
                metadata={"description": "CPE Dictionary Collection"},
                embedding_function=self.embedding_function
            )
            logger.info(f"成功設定資料庫連接，儲存位置: {self.db_path}")
        except Exception as e:
            logger.error(f"設定資料庫時發生錯誤: {str(e)}")
            raise

    def load_cpe_data(self, file_path: Union[str, Path]) -> List[Dict[str, Any]]:
        """讀取並解析 CPE JSON 檔案

        Args:
            file_path: JSON 檔案路徑

        Returns:
            解析後的 CPE 資料
        """
        file_path = Path(file_path)
        if not file_path.exists():
            raise FileNotFoundError(f"找不到檔案: {file_path}")

        try:
            logger.info(f"開始讀取 CPE 資料: {file_path}")
            with open(file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
            logger.info(f"成功讀取 {len(data)} 筆 CPE 資料")
            return data
        except json.JSONDecodeError as e:
            logger.error(f"解析 JSON 檔案時發生錯誤: {str(e)}")
            raise
        except Exception as e:
            logger.error(f"讀取 CPE 資料時發生錯誤: {str(e)}")
            raise

    def prepare_search_text(self, item: Dict[str, Any]) -> str:
        """優化的搜尋文本準備函數，增加title的權重

        Args:
            item: CPE 項目資料

        Returns:
            用於向量搜尋的文字
        """
        # 提取基本資訊
        title = item.get('title', '').strip()
        vendor = item.get('vendor', '').strip()
        product = item.get('product', '').strip()
        version = item.get('version', '').strip()

        # 構建優化的搜尋文字
        # 將 title 作為最高優先級
        search_text = f"{title} {title} {title} {title} "  # 重複四次增加權重
        search_text += f"{vendor} {vendor} "  # 重複兩次增加權重
        search_text += f"{product} {product} "  # 重複兩次增加權重
        search_text += f"{version} "

        # 加入結構化資訊
        search_text += f"""
        Title: {title}
        Vendor: {vendor}
        Product: {product}
        Version: {version}
        """

        return search_text.strip()

    def prepare_documents(self, cpe_data: List[Dict[str, Any]]) -> Tuple[List[str], List[Dict[str, str]], List[str]]:
        """準備要導入到資料庫的文件資料

        Args:
            cpe_data: CPE 資料列表

        Returns:
            返回文件內容、中繼資料和ID的元組
        """
        documents = []
        metadatas = []
        ids = []

        for i, item in enumerate(cpe_data):
            try:
                # 取得 CPE 2.3 URI 作為唯一識別符
                cpe23uri = item.get('cpe23Uri', '')
                if not cpe23uri:
                    logger.warning(f"第 {i} 筆資料缺少 cpe23Uri，將略過")
                    continue

                # 使用 CPE 2.3 URI 作為 ID
                doc_id = cpe23uri

                # 製作優化的文件內容
                doc_content = self.prepare_search_text(item)

                # 準備豐富的中繼資料，方便後續檢索和過濾
                metadata = {
                    'vendor': item.get('vendor', ''),
                    'product': item.get('product', ''),
                    'version': item.get('version', ''),
                    'cpe22Uri': item.get('cpe22Uri', ''),
                    'cpe23Uri': cpe23uri,
                    'title': item.get('title', ''),
                    # 將 references 截斷以避免過長
                    'references': item.get('references', '')[:1000] if item.get('references') else ''
                }

                documents.append(doc_content)
                metadatas.append(metadata)
                ids.append(doc_id)

            except Exception as e:
                logger.warning(f"處理第 {i} 筆資料時發生錯誤: {str(e)}")
                continue

        return documents, metadatas, ids

    def import_data(self, file_path: Union[str, Path], batch_size: int = 1000,
                    reset_collection: bool = False) -> None:
        """導入 CPE 資料到資料庫

        Args:
            file_path: CPE JSON 檔案路徑
            batch_size: 批次處理大小. 預設為 1000.
            reset_collection: 是否重置集合. 預設為 False.
        """
        try:
            # 如果需要重置集合
            if reset_collection:
                self._reset_collection()

            # 讀取資料
            cpe_data = self.load_cpe_data(file_path)

            # 準備文件
            logger.info("準備文件資料...")
            documents, metadatas, ids = self.prepare_documents(cpe_data)
            logger.info(f"準備了 {len(documents)} 筆有效的 CPE 資料")

            # 批次處理
            total_items = len(documents)
            for i in range(0, total_items, batch_size):
                batch_end = min(i + batch_size, total_items)
                batch_docs = documents[i:batch_end]
                batch_meta = metadatas[i:batch_end]
                batch_ids = ids[i:batch_end]

                logger.info(f"正在導入批次 {i//batch_size + 1}/{(total_items-1)//batch_size + 1} " +
                            f"({i+1}-{batch_end}/{total_items})...")

                try:
                    # 使用 upsert 而非 add，以便處理重複的 CPE ID
                    self.collection.upsert(
                        documents=batch_docs,
                        metadatas=batch_meta,
                        ids=batch_ids
                    )
                    logger.info(f"已處理 {batch_end}/{total_items} 筆資料")
                except Exception as e:
                    logger.error(f"批次處理時發生錯誤: {str(e)}")
                    logger.error(f"問題批次範圍: {i+1}-{batch_end}")
                    # 繼續處理下一批，而不是中斷整個過程
                    continue

            logger.info(f"成功導入 CPE 資料，總計 {total_items} 筆")

        except Exception as e:
            logger.error(f"導入資料時發生錯誤: {str(e)}")
            raise

    def _reset_collection(self) -> None:
        """重置集合，處理不同版本的ChromaDB可能的差異"""
        logger.info("重置集合...")
        try:
            # 嘗試列出所有集合，然後刪除目標集合
            collection_names = [col for col in self.client.list_collections()]
            if "cpe_dictionary" in collection_names:
                self.client.delete_collection("cpe_dictionary")
            logger.info("成功刪除現有集合")
        except Exception as e:
            logger.warning(f"使用list_collections刪除集合時發生錯誤: {str(e)}")
            # 備用方法: 嘗試直接獲取然後刪除
            try:
                self.client.get_collection("cpe_dictionary")
                self.client.delete_collection("cpe_dictionary")
                logger.info("使用備用方法成功刪除現有集合")
            except Exception:
                # 如果集合不存在，忽略錯誤
                logger.info("集合不存在，將新建集合")
                pass

        # 創建新集合
        self.collection = self.client.create_collection(
            name="cpe_dictionary",
            metadata={"description": "CPE Dictionary Collection"},
            embedding_function=self.embedding_function
        )
        logger.info("集合已重置")

    def search(self,
               vendor: Optional[str] = None,
               product: Optional[str] = None,
               version: Optional[str] = None,
               n_results: int = 5) -> Dict[str, Any]:
        """優化的搜尋方法，使用多階段匹配邏輯，並加強title比對

        Args:
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號
            n_results: 返回結果數量

        Returns:
            搜尋結果
        """
        try:
            # 確保至少提供一個搜尋條件
            if not any([vendor, product, version]):
                raise ValueError("必須提供至少一個搜尋條件 (vendor, product, version)")

            # 構建搜尋關鍵字 - 增加一個模擬的title搜尋字串
            search_parts = []

            # 模擬可能的title格式
            simulated_title = []
            if vendor:
                simulated_title.append(vendor.strip())
            if product:
                simulated_title.append(product.strip())
            if simulated_title:
                search_parts.append(" ".join(simulated_title))

            # 加入原始的搜尋條件
            if vendor:
                search_parts.append(f"{vendor}")
            if product:
                search_parts.append(f"{product}")
            if version:
                search_parts.append(f"{version}")

            search_query = " ".join(search_parts)

            # 獲取初步結果
            original_results = self.collection.query(
                query_texts=[search_query],
                n_results=n_results * 3,  # 擴大搜尋範圍，後續會篩選
                include=['metadatas', 'distances']
            )

            # 重新排序和過濾結果
            sorted_results = self._process_search_results(
                original_results, vendor, product, version, n_results
            )

            return sorted_results

        except Exception as e:
            logger.error(f"搜尋時發生錯誤: {str(e)}")
            raise

    def _process_search_results(self, original_results, vendor, product, version, n_results):
        """處理搜尋結果，重新排序和過濾，加強對title的匹配考量

        Args:
            original_results: 原始搜尋結果
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號
            n_results: 返回結果數量

        Returns:
            處理後的搜尋結果
        """
        # 如果沒有得到任何結果，直接返回空結果
        if not original_results['metadatas'][0]:
            return {
                'original_results': original_results,
                'filtered_results': {
                    'ids': [[]],
                    'metadatas': [[]],
                    'distances': [[]]
                },
                'is_filtered': True
            }

        # 計算每個結果的綜合分數
        combined_scores = []

        # 權重設定
        title_weight = 0.5  # title匹配度的權重
        vendor_weight = 0.3  # 廠商匹配度的權重
        distance_weight = 0.2  # 原始距離的權重

        for i, meta in enumerate(original_results['metadatas'][0]):
            # 初始化分數
            title_score = 0.0
            vendor_score = 0.0

            # 原始距離分數
            distance = original_results['distances'][0][i]

            # 1. 計算title匹配度
            if vendor or product:
                db_title = meta['title'].lower()

                # 使用輸入構建可能的title片段
                search_fragments = []
                if vendor:
                    search_fragments.append(vendor.lower())
                if product:
                    search_fragments.append(product.lower())

                # 計算每個片段與title的相似度
                fragment_scores = []
                for fragment in search_fragments:
                    if fragment in db_title:
                        fragment_scores.append(0.9)  # 直接包含給予高分
                    else:
                        fragment_scores.append(
                            StringMatcher.calculate_similarity(fragment, db_title))

                # 取平均作為title分數
                if fragment_scores:
                    title_score = sum(fragment_scores) / len(fragment_scores)

            # 2. 計算廠商匹配度
            if vendor:
                db_vendor = meta['vendor'].lower()
                vendor_score = StringMatcher.calculate_similarity(
                    vendor.lower(), db_vendor)

            # 3. 計算版本匹配度
            version_match = 1.0
            if version and meta['version']:
                version_match = 1.0 if StringMatcher.version_match(
                    version, meta['version']) else 0.2

            # 計算綜合分數 (分數越低越好，與距離概念一致)
            combined_distance = (
                (1 - title_score) * title_weight +
                (1 - vendor_score) * vendor_weight +
                distance * distance_weight
            )

            # 如果版本不匹配，增加距離
            if version and not StringMatcher.version_match(version, meta['version']):
                combined_distance += 0.5

            combined_scores.append(combined_distance)

        # 根據綜合分數排序
        indices = sorted(range(len(combined_scores)),
                         key=lambda i: combined_scores[i])
        sorted_ids = [original_results['ids'][0][i] for i in indices]
        sorted_metadatas = [original_results['metadatas'][0][i]
                            for i in indices]
        sorted_distances = [combined_scores[i] for i in indices]

        # 提取前n_results個作為原始結果
        original_results = {
            'ids': [sorted_ids[:n_results]],
            'metadatas': [sorted_metadatas[:n_results]],
            'distances': [sorted_distances[:n_results]]
        }

        # 進行最終的精確過濾
        filtered_indices = []
        for i, metadata in enumerate(original_results['metadatas'][0]):
            # 先檢查title是否有匹配
            title_match = True
            if vendor or product:
                title_match = False
                title_lower = metadata['title'].lower()

                # 檢查vendor和product是否出現在title中
                if vendor and vendor.lower() in title_lower:
                    title_match = True
                if product and product.lower() in title_lower:
                    title_match = True

            # 再檢查具體欄位
            field_match = True
            if vendor and vendor.lower() not in metadata['vendor'].lower():
                field_match = False
            if product and product.lower() not in metadata['product'].lower():
                field_match = False
            if version and not StringMatcher.version_match(version, metadata['version']):
                field_match = False

            # title或欄位匹配時加入結果
            if title_match or field_match:
                filtered_indices.append(i)

        # 創建結果字典
        results = {
            'original_results': original_results,
            'filtered_results': None,
            'is_filtered': True
        }

        # 根據過濾後的索引重建結果
        if filtered_indices:
            filtered_results = {
                'ids': [[original_results['ids'][0][i] for i in filtered_indices]],
                'metadatas': [[original_results['metadatas'][0][i] for i in filtered_indices]],
                'distances': [[original_results['distances'][0][i] for i in filtered_indices]]
            }

            results['filtered_results'] = filtered_results
        else:
            # 如果過濾後沒有結果，設定空結果
            results['filtered_results'] = {
                'ids': [[]],
                'metadatas': [[]],
                'distances': [[]]
            }

        return results

    def get_collection_info(self) -> Dict[str, Any]:
        """獲取集合資訊

        Returns:
            集合資訊
        """
        try:
            # 獲取集合計數
            count = self.collection.count()

            # 判斷使用的嵌入模型類型
            try:
                # 嘗試檢查嵌入函數的類型
                if hasattr(embedding_functions, 'DefaultEmbeddingFunction') and \
                   isinstance(self.embedding_function, embedding_functions.DefaultEmbeddingFunction):
                    model_type = "Default"
                else:
                    # 嘗試使用不同的方式判斷
                    model_name = getattr(
                        self.embedding_function, '_model_name', None)
                    if model_name and 'huggingface' in str(model_name).lower():
                        model_type = "HuggingFace"
                    else:
                        model_type = "Default" if not self.use_gpu else "HuggingFace"
            except Exception as e:
                logger.warning(f"判斷嵌入模型類型時發生錯誤: {str(e)}")
                # 回退到基於 use_gpu 的簡單判斷
                model_type = "Default" if not self.use_gpu else "HuggingFace"

            # 獲取集合中繼資料
            collection_info = {
                "name": self.collection.name,
                "metadata": self.collection.metadata,
                "count": count,
                "embedding_model": model_type,
                "device": "GPU" if self.use_gpu else "CPU"
            }

            return collection_info
        except Exception as e:
            logger.error(f"獲取集合資訊時發生錯誤: {str(e)}")
            raise


class BatchSearcher:
    """批量搜尋處理器"""

    @staticmethod
    def batch_search_from_csv(db_manager: CPEDatabaseManager,
                              csv_file_path: str,
                              output_file_path: Optional[str] = None,
                              use_standardizer: bool = True) -> str:
        """優化的批量搜索功能，加入更好的結果篩選和相關性排序

        Args:
            db_manager: CPE資料庫管理器實例
            csv_file_path: 輸入CSV檔案路徑
            output_file_path: 輸出檔案路徑。如果為None，會自動生成檔名
            use_standardizer: 是否使用標準化預處理器。預設為True

        Returns:
            輸出檔案路徑
        """
        if not output_file_path:
            # 生成輸出檔名，包含時間戳記
            timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            output_file_path = f"search_results_{timestamp}.txt"

        # 統計搜尋資訊
        total_items = 0
        items_with_results = 0

        logger.info(f"開始從 {csv_file_path} 批次搜尋，結果將輸出到 {output_file_path}")
        logger.info(f"是否使用標準化預處理器: {use_standardizer}")

        try:
            with open(csv_file_path, 'r', encoding='utf-8') as csv_file, \
                    open(output_file_path, 'w', encoding='utf-8') as output_file:

                # 寫入檔案標頭
                BatchSearcher._write_header(
                    output_file, csv_file_path, use_standardizer)

                # 讀取CSV
                csv_reader = csv.DictReader(csv_file)

                # 檢查CSV是否有必要的欄位
                BatchSearcher._validate_csv_fields(csv_reader.fieldnames)

                # 處理每一行
                for i, row in enumerate(csv_reader, 1):
                    total_items += 1

                    # 獲取原始輸入
                    original_vendor = row.get('vendor', '').strip() or None
                    original_product = row.get('product', '').strip() or None
                    original_version = row.get('version', '').strip() or None

                    # 如果所有欄位都是空的，跳過這一行
                    if not any([original_vendor, original_product, original_version]):
                        logger.warning(f"第 {i} 行: 所有搜尋條件為空，跳過")
                        output_file.write(f"項目 {i}: 所有搜尋條件為空，跳過\n\n")
                        continue

                    # 處理輸入並進行搜尋
                    has_results = BatchSearcher._process_row(
                        i, db_manager, output_file,
                        original_vendor, original_product, original_version,
                        use_standardizer
                    )

                    if has_results:
                        items_with_results += 1

                # 寫入摘要
                BatchSearcher._write_summary(
                    output_file, total_items, items_with_results, use_standardizer
                )

            logger.info(
                f"批次搜尋完成，共處理 {total_items} 項，{items_with_results} 項有結果")
            return output_file_path

        except Exception as e:
            logger.error(f"批次搜尋過程中發生錯誤: {str(e)}")
            raise

    @staticmethod
    def _write_header(output_file, csv_file_path, use_standardizer):
        """寫入搜尋結果檔案的標頭"""
        if use_standardizer:
            output_file.write("CPE資料庫搜尋結果 - 批次處理 (含標準化預處理)\n")
        else:
            output_file.write("CPE資料庫搜尋結果 - 批次處理\n")

        output_file.write(f"輸入檔案: {csv_file_path}\n")
        output_file.write(
            f"處理時間: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        output_file.write(f"{'='*80}\n\n")

    @staticmethod
    def _validate_csv_fields(field_names):
        """驗證CSV欄位是否符合要求"""
        required_fields = ['vendor', 'product', 'version']
        missing_fields = [
            field for field in required_fields if field not in field_names]
        if missing_fields:
            raise ValueError(f"CSV檔案缺少必要欄位: {', '.join(missing_fields)}")

    @staticmethod
    def _process_row(row_num, db_manager, output_file,
                     original_vendor, original_product, original_version,
                     use_standardizer):
        """處理搜尋CSV的單行資料"""
        try:
            # 如果使用標準化預處理器，處理輸入
            if use_standardizer:
                vendor, product, version = CPEInputStandardizer.standardize_input(
                    original_vendor, original_product, original_version)

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {row_num}:\n")
                output_file.write(
                    f"  原始廠商: {original_vendor or '無'} -> 標準化: {vendor or '無'}\n")
                output_file.write(
                    f"  原始產品: {original_product or '無'} -> 標準化: {product or '無'}\n")
                output_file.write(
                    f"  原始版本: {original_version or '無'} -> 標準化: {version or '無'}\n\n")
            else:
                vendor = original_vendor
                product = original_product
                version = original_version

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {row_num}:\n")
                output_file.write(f"  廠商: {vendor or '無'}\n")
                output_file.write(f"  產品: {product or '無'}\n")
                output_file.write(f"  版本: {version or '無'}\n\n")

            # 搜尋
            results = db_manager.search(
                vendor=vendor, product=product, version=version)

            result_text = SearchResultFormatter.format_search_results(results)

            # 檢查是否有搜尋結果
            has_results = False
            filtered_results = results.get('filtered_results', {})
            if filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
                has_results = True

            # 寫入搜尋結果
            output_file.write(result_text)
            output_file.write(f"\n{'='*80}\n\n")

            # 記錄日誌
            if has_results:
                logger.info(
                    f"第 {row_num} 行: 搜尋成功，找到 {len(filtered_results['metadatas'][0])} 筆結果")
            else:
                logger.info(f"第 {row_num} 行: 搜尋成功，但沒有符合的結果")

            return has_results

        except Exception as e:
            logger.error(f"第 {row_num} 行: 搜尋時發生錯誤: {str(e)}")
            output_file.write(f"搜尋時發生錯誤: {str(e)}\n\n")
            output_file.write(f"{'='*80}\n\n")
            return False

    @staticmethod
    def _write_summary(output_file, total_items, items_with_results, use_standardizer):
        """寫入搜尋結果摘要"""
        output_file.write("批次搜尋摘要:\n")
        output_file.write(f"總項目數: {total_items}\n")
        output_file.write(f"有結果的項目數: {items_with_results}\n")
        output_file.write(f"無結果的項目數: {total_items - items_with_results}\n")
        if use_standardizer:
            output_file.write("使用標準化預處理: 是\n")
        else:
            output_file.write("使用標準化預處理: 否\n")


class SearchResultFormatter:
    """搜尋結果格式化工具類"""

    @staticmethod
    def format_search_results(results: Dict[str, Any]) -> str:
        """格式化搜尋結果為可讀的文字

        Args:
            results: 搜尋結果

        Returns:
            格式化的搜尋結果文字
        """
        if not results:
            return "未找到符合的結果"

        output = []

        # 處理原始結果
        original_results = results.get('original_results', {})
        if original_results and original_results.get('metadatas') and original_results['metadatas'][0]:
            output.append("\n=== 原始搜尋結果 ===")
            for i, (metadata, distance) in enumerate(zip(original_results['metadatas'][0],
                                                         original_results.get('distances', [[0] * len(original_results['metadatas'][0])])[0])):
                score = 1.0 - (distance / 2.0)  # 將距離轉換為可理解的分數

                output.append(f"\n原始結果 {i+1} (相似度: {score:.2f}):")
                output.append(f"完整名稱: {metadata['title']}")  # 先顯示title
                output.append(f"產品: {metadata['product']}")
                output.append(f"廠商: {metadata['vendor']}")
                output.append(f"版本: {metadata['version']}")
                output.append(f"CPE23: {metadata['cpe23Uri']}")

        # 處理過濾結果
        filtered_results = results.get('filtered_results', {})
        if results.get('is_filtered') and filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
            output.append("\n=== 過濾後的結果 ===")
            for i, (metadata, distance) in enumerate(zip(filtered_results['metadatas'][0],
                                                         filtered_results.get('distances', [[0] * len(filtered_results['metadatas'][0])])[0])):
                score = 1.0 - (distance / 2.0)

                output.append(f"\n過濾結果 {i+1} (相似度: {score:.2f}):")
                output.append(f"完整名稱: {metadata['title']}")  # 先顯示title
                output.append(f"產品: {metadata['product']}")
                output.append(f"廠商: {metadata['vendor']}")
                output.append(f"版本: {metadata['version']}")
                output.append(f"CPE23: {metadata['cpe23Uri']}")
        elif results.get('is_filtered') and (not filtered_results or not filtered_results.get('metadatas') or not filtered_results['metadatas'][0]):
            output.append("\n=== 過濾後的結果 ===")
            output.append("過濾後沒有符合條件的結果")

        return "\n".join(output)


def main():
    """主程式入口"""
    # 設定檔案路徑
    file_path = "../data/convert/official-cpe-dictionary_v2.3.json"

    try:
        use_gpu = False
        embedding_model = "default"
        logger.info("使用預設嵌入模型 (CPU)")

        # 初始化資料庫管理器
        db_manager = CPEDatabaseManager(
            use_gpu=use_gpu, embedding_model=embedding_model)

        # 顯示選單
        while True:
            print("\n=== CPE 資料庫管理工具 ===")
            print("1. 導入 CPE 資料")
            print("2. 查看集合資訊")
            print("3. 單次搜尋")
            print("4. 單次搜尋 (含標準化預處理)")
            print("5. 從CSV檔案批次搜尋")
            print("6. 從CSV檔案批次搜尋 (含標準化預處理)")
            print("0. 退出")

            choice = input("請選擇操作 (0-6): ").strip()

            if choice == "0":
                print("程式已結束。")
                break

            elif choice == "1":
                # 導入資料
                reset = input("是否要重置現有集合？(y/n): ").strip().lower() == 'y'
                db_manager.import_data(file_path, reset_collection=reset)

            elif choice == "2":
                # 顯示集合資訊
                collection_info = db_manager.get_collection_info()
                print("\n集合資訊:")
                print(f"名稱: {collection_info['name']}")
                print(f"項目數量: {collection_info['count']}")
                print(f"嵌入模型: {collection_info['embedding_model']}")
                print(f"使用裝置: {collection_info['device']}")

            elif choice == "3":
                # 單次搜尋
                main_single_search(db_manager, use_standardizer=False)

            elif choice == "4":
                # 單次搜尋(含標準化)
                main_single_search(db_manager, use_standardizer=True)

            elif choice == "5":
                # 批次搜尋
                main_batch_search(db_manager, use_standardizer=False)

            elif choice == "6":
                # 批次搜尋(含標準化)
                main_batch_search(db_manager, use_standardizer=True)

            else:
                print("無效的選擇，請重新輸入。")

    except Exception as e:
        logger.error(f"程式執行時發生錯誤: {str(e)}")
        print(f"錯誤: {str(e)}")
        raise


def main_single_search(db_manager, use_standardizer=False):
    """處理單次搜尋的主邏輯

    Args:
        db_manager: 資料庫管理器
        use_standardizer: 是否使用標準化處理
    """
    while True:
        print("\n請輸入搜尋條件 (直接按 Enter 跳過):")
        original_vendor = input("廠商名稱: ").strip() or None
        original_product = input("產品名稱: ").strip() or None
        original_version = input("版本號: ").strip() or None

        if not any([original_vendor, original_product, original_version]):
            print("至少需要提供一個搜尋條件")
            continue

        try:
            if use_standardizer:
                # 標準化處理
                vendor, product, version = CPEInputStandardizer.standardize_input(
                    original_vendor, original_product, original_version)

                # 顯示標準化結果
                print("\n標準化後的搜尋條件:")
                print(
                    f"原始廠商: {original_vendor or '無'} -> 標準化: {vendor or '無'}")
                print(
                    f"原始產品: {original_product or '無'} -> 標準化: {product or '無'}")
                print(
                    f"原始版本: {original_version or '無'} -> 標準化: {version or '無'}")

                # 詢問是否使用標準化結果
                use_std = input(
                    "\n是否使用標準化結果進行搜尋? (y/n, 預設為y): ").strip().lower() != 'n'

                if use_std:
                    # 使用標準化結果
                    results = db_manager.search(
                        vendor=vendor, product=product, version=version)
                    print("\n使用標準化條件搜尋結果:")
                else:
                    # 使用原始輸入
                    results = db_manager.search(
                        vendor=original_vendor, product=original_product, version=original_version)
                    print("\n使用原始條件搜尋結果:")
            else:
                # 不使用標準化，直接搜尋
                results = db_manager.search(
                    vendor=original_vendor, product=original_product, version=original_version)
                print("\n搜尋結果:")

            print(SearchResultFormatter.format_search_results(results))

            if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                break
        except Exception as e:
            print(f"搜尋過程中發生錯誤: {str(e)}")
            if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                break


def main_batch_search(db_manager, use_standardizer=False):
    """處理批次搜尋的主邏輯

    Args:
        db_manager: 資料庫管理器
        use_standardizer: 是否使用標準化處理
    """
    csv_file_path = input("請輸入CSV檔案路徑: ").strip()
    if not os.path.exists(csv_file_path):
        print(f"找不到檔案: {csv_file_path}")
        return

    try:
        output_path = BatchSearcher.batch_search_from_csv(
            db_manager, csv_file_path, use_standardizer=use_standardizer
        )
        print(f"\n批次搜尋完成! 結果已輸出至: {output_path}")
    except Exception as e:
        print(f"批次搜尋失敗: {str(e)}")


if __name__ == "__main__":
    main()
# Out:
# 2025-03-13 08:13:20,793 - __main__ - INFO - 使用預設嵌入模型 (CPU)
# 2025-03-13 08:13:20,795 - __main__ - INFO - 使用嵌入模型: 預設
# 2025-03-13 08:13:20,801 - __main__ - INFO - 成功設定資料庫連接，儲存位置: ../database/cpe_database
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 2025-03-13 08:13:36,182 - __main__ - INFO - 開始從 ./transform_data.csv 批次搜尋，結果將輸出到 search_results_20250313_081336.txt
# 2025-03-13 08:13:36,185 - __main__ - INFO - 是否使用標準化預處理器: True
# 2025-03-13 08:13:36,396 - __main__ - INFO - 第 1 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,462 - __main__ - INFO - 第 2 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,520 - __main__ - INFO - 第 3 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,603 - __main__ - INFO - 第 4 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,662 - __main__ - INFO - 第 5 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,735 - __main__ - INFO - 第 6 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,805 - __main__ - INFO - 第 7 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,877 - __main__ - INFO - 第 8 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:36,948 - __main__ - INFO - 第 9 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,026 - __main__ - INFO - 第 10 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,086 - __main__ - INFO - 第 11 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,149 - __main__ - INFO - 第 12 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,208 - __main__ - INFO - 第 13 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,275 - __main__ - INFO - 第 14 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,354 - __main__ - INFO - 第 15 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,417 - __main__ - INFO - 第 16 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,478 - __main__ - INFO - 第 17 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,541 - __main__ - INFO - 第 18 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,602 - __main__ - INFO - 第 19 行: 搜尋成功，找到 3 筆結果
# 2025-03-13 08:13:37,656 - __main__ - INFO - 第 20 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:37,716 - __main__ - INFO - 第 21 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:37,778 - __main__ - INFO - 第 22 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:37,853 - __main__ - INFO - 第 23 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:37,920 - __main__ - INFO - 第 24 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:37,998 - __main__ - INFO - 第 25 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,073 - __main__ - INFO - 第 26 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:38,134 - __main__ - INFO - 第 27 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,175 - __main__ - INFO - 第 28 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:38,244 - __main__ - INFO - 第 29 行: 搜尋成功，找到 2 筆結果
# 2025-03-13 08:13:38,303 - __main__ - INFO - 第 30 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,367 - __main__ - INFO - 第 31 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:38,443 - __main__ - INFO - 第 32 行: 搜尋成功，找到 1 筆結果
# 2025-03-13 08:13:38,511 - __main__ - INFO - 第 33 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,583 - __main__ - INFO - 第 34 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,647 - __main__ - INFO - 第 35 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:38,697 - __main__ - INFO - 第 36 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,761 - __main__ - INFO - 第 37 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:38,821 - __main__ - INFO - 第 38 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,882 - __main__ - INFO - 第 39 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:38,961 - __main__ - INFO - 第 40 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:39,027 - __main__ - INFO - 第 41 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:39,097 - __main__ - INFO - 第 42 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,164 - __main__ - INFO - 第 43 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,238 - __main__ - INFO - 第 44 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:39,308 - __main__ - INFO - 第 45 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,373 - __main__ - INFO - 第 46 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,436 - __main__ - INFO - 第 47 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,498 - __main__ - INFO - 第 48 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:39,561 - __main__ - INFO - 第 49 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:39,625 - __main__ - INFO - 第 50 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,682 - __main__ - INFO - 第 51 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:39,747 - __main__ - INFO - 第 52 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,825 - __main__ - INFO - 第 53 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,886 - __main__ - INFO - 第 54 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:39,940 - __main__ - INFO - 第 55 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:40,018 - __main__ - INFO - 第 56 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,097 - __main__ - INFO - 第 57 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:40,172 - __main__ - INFO - 第 58 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:40,240 - __main__ - INFO - 第 59 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,297 - __main__ - INFO - 第 60 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:40,381 - __main__ - INFO - 第 61 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,455 - __main__ - INFO - 第 62 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,511 - __main__ - INFO - 第 63 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,590 - __main__ - INFO - 第 64 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,651 - __main__ - INFO - 第 65 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,721 - __main__ - INFO - 第 66 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,789 - __main__ - INFO - 第 67 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,854 - __main__ - INFO - 第 68 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,908 - __main__ - INFO - 第 69 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:40,955 - __main__ - INFO - 第 70 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,041 - __main__ - INFO - 第 71 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,090 - __main__ - INFO - 第 72 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,154 - __main__ - INFO - 第 73 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,212 - __main__ - INFO - 第 74 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,269 - __main__ - INFO - 第 75 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,302 - __main__ - INFO - 第 76 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,359 - __main__ - INFO - 第 77 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,411 - __main__ - INFO - 第 78 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,477 - __main__ - INFO - 第 79 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:41,520 - __main__ - INFO - 第 80 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,583 - __main__ - INFO - 第 81 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:41,618 - __main__ - INFO - 第 82 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,677 - __main__ - INFO - 第 83 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,709 - __main__ - INFO - 第 84 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,777 - __main__ - INFO - 第 85 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,872 - __main__ - INFO - 第 86 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:41,940 - __main__ - INFO - 第 87 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,017 - __main__ - INFO - 第 88 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,070 - __main__ - INFO - 第 89 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:42,135 - __main__ - INFO - 第 90 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,198 - __main__ - INFO - 第 91 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,254 - __main__ - INFO - 第 92 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,310 - __main__ - INFO - 第 93 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,368 - __main__ - INFO - 第 94 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,446 - __main__ - INFO - 第 95 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,507 - __main__ - INFO - 第 96 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:42,578 - __main__ - INFO - 第 97 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,647 - __main__ - INFO - 第 98 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,722 - __main__ - INFO - 第 99 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,795 - __main__ - INFO - 第 100 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:42,857 - __main__ - INFO - 第 101 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:42,914 - __main__ - INFO - 第 102 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:42,969 - __main__ - INFO - 第 103 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:43,034 - __main__ - INFO - 第 104 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:43,105 - __main__ - INFO - 第 105 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:43,173 - __main__ - INFO - 第 106 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:43,238 - __main__ - INFO - 第 107 行: 搜尋成功，找到 4 筆結果
# 2025-03-13 08:13:43,290 - __main__ - INFO - 第 108 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,368 - __main__ - INFO - 第 109 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:43,426 - __main__ - INFO - 第 110 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,494 - __main__ - INFO - 第 111 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,573 - __main__ - INFO - 第 112 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:43,635 - __main__ - INFO - 第 113 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,706 - __main__ - INFO - 第 114 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:43,762 - __main__ - INFO - 第 115 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,815 - __main__ - INFO - 第 116 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,875 - __main__ - INFO - 第 117 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:43,959 - __main__ - INFO - 第 118 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,024 - __main__ - INFO - 第 119 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,103 - __main__ - INFO - 第 120 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,160 - __main__ - INFO - 第 121 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,219 - __main__ - INFO - 第 122 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,287 - __main__ - INFO - 第 123 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,355 - __main__ - INFO - 第 124 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,416 - __main__ - INFO - 第 125 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,491 - __main__ - INFO - 第 126 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,556 - __main__ - INFO - 第 127 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,619 - __main__ - INFO - 第 128 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,678 - __main__ - INFO - 第 129 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,747 - __main__ - INFO - 第 130 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,821 - __main__ - INFO - 第 131 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:44,893 - __main__ - INFO - 第 132 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:44,975 - __main__ - INFO - 第 133 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:45,037 - __main__ - INFO - 第 134 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:45,106 - __main__ - INFO - 第 135 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,152 - __main__ - INFO - 第 136 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,220 - __main__ - INFO - 第 137 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:45,292 - __main__ - INFO - 第 138 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,401 - __main__ - INFO - 第 139 行: 搜尋成功，找到 5 筆結果
# 2025-03-13 08:13:45,462 - __main__ - INFO - 第 140 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,515 - __main__ - INFO - 第 141 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,582 - __main__ - INFO - 第 142 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,650 - __main__ - INFO - 第 143 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,777 - __main__ - INFO - 第 144 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,847 - __main__ - INFO - 第 145 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,909 - __main__ - INFO - 第 146 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:45,977 - __main__ - INFO - 第 147 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,051 - __main__ - INFO - 第 148 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,122 - __main__ - INFO - 第 149 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,188 - __main__ - INFO - 第 150 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,246 - __main__ - INFO - 第 151 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,316 - __main__ - INFO - 第 152 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,374 - __main__ - INFO - 第 153 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,439 - __main__ - INFO - 第 154 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,507 - __main__ - INFO - 第 155 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,583 - __main__ - INFO - 第 156 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,641 - __main__ - INFO - 第 157 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,703 - __main__ - INFO - 第 158 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,757 - __main__ - INFO - 第 159 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,810 - __main__ - INFO - 第 160 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,870 - __main__ - INFO - 第 161 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:46,940 - __main__ - INFO - 第 162 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,000 - __main__ - INFO - 第 163 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,080 - __main__ - INFO - 第 164 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,142 - __main__ - INFO - 第 165 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,213 - __main__ - INFO - 第 166 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,275 - __main__ - INFO - 第 167 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,359 - __main__ - INFO - 第 168 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,429 - __main__ - INFO - 第 169 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,494 - __main__ - INFO - 第 170 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,567 - __main__ - INFO - 第 171 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,636 - __main__ - INFO - 第 172 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,699 - __main__ - INFO - 第 173 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,759 - __main__ - INFO - 第 174 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,820 - __main__ - INFO - 第 175 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,903 - __main__ - INFO - 第 176 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:47,968 - __main__ - INFO - 第 177 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,026 - __main__ - INFO - 第 178 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,104 - __main__ - INFO - 第 179 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,170 - __main__ - INFO - 第 180 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,234 - __main__ - INFO - 第 181 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,314 - __main__ - INFO - 第 182 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,380 - __main__ - INFO - 第 183 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,453 - __main__ - INFO - 第 184 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,536 - __main__ - INFO - 第 185 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,604 - __main__ - INFO - 第 186 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,669 - __main__ - INFO - 第 187 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,748 - __main__ - INFO - 第 188 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,810 - __main__ - INFO - 第 189 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,884 - __main__ - INFO - 第 190 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:48,947 - __main__ - INFO - 第 191 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,017 - __main__ - INFO - 第 192 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,081 - __main__ - INFO - 第 193 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,150 - __main__ - INFO - 第 194 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,205 - __main__ - INFO - 第 195 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,271 - __main__ - INFO - 第 196 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,321 - __main__ - INFO - 第 197 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,386 - __main__ - INFO - 第 198 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,455 - __main__ - INFO - 第 199 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,527 - __main__ - INFO - 第 200 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,602 - __main__ - INFO - 第 201 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,662 - __main__ - INFO - 第 202 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,717 - __main__ - INFO - 第 203 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,780 - __main__ - INFO - 第 204 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,844 - __main__ - INFO - 第 205 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,912 - __main__ - INFO - 第 206 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:49,973 - __main__ - INFO - 第 207 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,040 - __main__ - INFO - 第 208 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,107 - __main__ - INFO - 第 209 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,192 - __main__ - INFO - 第 210 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,278 - __main__ - INFO - 第 211 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,345 - __main__ - INFO - 第 212 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,405 - __main__ - INFO - 第 213 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,510 - __main__ - INFO - 第 214 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,560 - __main__ - INFO - 第 215 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,624 - __main__ - INFO - 第 216 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,698 - __main__ - INFO - 第 217 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,771 - __main__ - INFO - 第 218 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,847 - __main__ - INFO - 第 219 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,917 - __main__ - INFO - 第 220 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:50,994 - __main__ - INFO - 第 221 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,071 - __main__ - INFO - 第 222 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,139 - __main__ - INFO - 第 223 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,196 - __main__ - INFO - 第 224 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,274 - __main__ - INFO - 第 225 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,351 - __main__ - INFO - 第 226 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,431 - __main__ - INFO - 第 227 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,490 - __main__ - INFO - 第 228 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,575 - __main__ - INFO - 第 229 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,648 - __main__ - INFO - 第 230 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,720 - __main__ - INFO - 第 231 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,813 - __main__ - INFO - 第 232 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,907 - __main__ - INFO - 第 233 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:51,984 - __main__ - INFO - 第 234 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:52,047 - __main__ - INFO - 第 235 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:52,122 - __main__ - INFO - 第 236 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:52,201 - __main__ - INFO - 第 237 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:52,264 - __main__ - INFO - 第 238 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:52,323 - __main__ - INFO - 第 239 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 08:13:52,324 - __main__ - INFO - 批次搜尋完成，共處理 239 項，84 項有結果
# 批次搜尋完成! 結果已輸出至: search_results_20250313_081336.txt
#
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 程式已結束。
