# %% [markdown]
# # CPE Format Converter (POC) example Jupyter Notebook
#
# This is a proof of concept for a CPE Format Converter.
#
# ## Description
#
# Due to time constraints, the construction logic and thought process of this Proof of Concept (PoC) will be initially presented in this Jupyter Notebook. Further development and maintenance will continue to implement more comprehensive functionalities, such as automation and a Web User Interface.
#
# > 由於時間限制，此概念驗證（PoC）的建構邏輯與思路將以本 Jupyter Notebook 的形式初步呈現。後續將持續進行開發與維護，以實現自動化、Web 使用者介面等更完善的功能。
#
# ## Design
#
# This Proof of Concept (PoC) aims to provide users with a tool to search for vulnerabilities associated with specific products by inputting Vendor, Product, and Version information. The tool will interact with the National Vulnerability Database (NVD) Common Vulnerabilities and Exposures (CVE) database to retrieve relevant CVE vulnerability data. Since the NVD Vulnerability API (CVE API) uses Common Platform Enumeration (CPE) for searching, user input needs to be converted into CPE format. However, while the CPE format has a standardized specification, there is no standard conversion process, and it cannot be guaranteed that the converted CPE is included in the NVD. To address this issue, we will use the NVD's CPE Directory List as a foundation to convert user input and obtain or generate the correct CPE, subsequently using the NVD Vulnerability API to retrieve further vulnerability data.
#
# > 本概念驗證（PoC）旨在提供使用者一個工具，透過輸入廠商（Vendor）、產品（Product）和版本（Version）資訊，搜尋相關產品的漏洞（Vulnerability）。此工具將與美國國家漏洞資料庫（NVD）的通用漏洞披露（CVE）資料庫互動，取得相關的 CVE 漏洞資訊。由於 NVD 的漏洞應用程式介面（CVE API）使用通用平台列舉（CPE）進行搜尋，因此需要將使用者輸入轉換為 CPE 格式。然而，儘管 CPE 格式具有標準化的規範，卻缺乏標準的轉換流程，且無法確定轉換後的 CPE 是否已被 NVD 收錄。為解決此問題，我們將利用 NVD 提供的 CPE 目錄列表（CPE Directory List）作為基礎，進行使用者輸入的轉換，並取得或產生正確的 CPE，進而使用 NVD 的漏洞應用程式介面取得後續的漏洞資料。
#
# ## Usage
#
# We will leverage the interactive features of Jupyter Notebook to provide detailed explanations of the operational process through segmented code, allowing users to reproduce the same operational results by executing this notebook. Please follow the subsequent operational instructions and code comments for adjustments and execution.
#
# > 我們將利用 Jupyter Notebook 的互動式特性，以分段程式碼的方式詳細說明操作流程，並允許使用者透過執行本 Notebook 複現相同的操作結果。請依照後續的操作說明與程式碼註解進行調整與執行。

# %% [markdown]
# ## Step 1: Get Offical CPE Directory List
#
# Please manually download the CPE Directory List from the official National Vulnerability Database (NVD) website and place the file in the `data` directory of the project repository (Repo). If you have any questions about the operation, please refer to the README file in the `data` directory.
#
# > 請手動自美國國家漏洞資料庫（NVD）官方網站下載 CPE 目錄列表（CPE Directory List），並將檔案放置於專案儲存庫（Repo）的 `data` 目錄中。若對操作方式有疑問，請參閱 `data` 目錄中的 README 檔案。

# %% [markdown]
# ## Step 2: Decompression and Data Pre-processing
#
# The Common Platform Enumeration (CPE) list provided by the National Vulnerability Database (NVD) is in XML format. While detailed and comprehensive, its structure is not ideal for direct import into Chromadb for subsequent operations. Therefore, we will filter and organize the XML content of the CPE list and output it in Comma-Separated Values (CSV) format.
#
# (Converting to CSV format is a non-essential transitional step, primarily to facilitate the review of the organized XML data and accelerate data utilization and analysis.)
#
# The resulting structured CSV data (or Dataframe) will be processed and imported into Chromadb in the subsequent steps.
#
#
# > 由於美國國家漏洞資料庫（NVD）提供的通用平台列舉（CPE）列表為 XML 格式，其結構雖詳盡完整，但不利於直接匯入 Chromadb 進行後續操作。因此，我們將對 CPE 列表的 XML 內容進行篩選與整理，並轉換為逗號分隔值（CSV）格式輸出。
# >
# > （轉換為 CSV 格式為一非必要的過渡步驟，主要目的是為了方便檢視整理後的 XML 資料，以加速資料的使用與分析。）
# >
# > 轉換後的 CSV 結構化資料（或 Dataframe）將於後續步驟中進行計算並匯入 Chromadb。

# %%
from lxml import etree
import json
import csv
from typing import Dict, List, Iterator, Optional, Tuple
import logging
from pathlib import Path
import re
from dataclasses import dataclass, asdict
from contextlib import contextmanager


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class CPEParser:
    """CPE XML 字典的分析器，用於將 CPE 項目轉換為結構化資料"""

    # CPE 命名空間定義
    NAMESPACES = {
        'cpe-23': 'http://scap.nist.gov/schema/cpe-extension/2.3',
        'def': 'http://cpe.mitre.org/dictionary/2.0',
        'xml': 'http://www.w3.org/XML/1998/namespace'
    }

    def __init__(self, xml_file_path: str):
        """初始化 CPE 分析器

        Args:
            xml_file_path (str): XML 檔案路徑
        """
        self.xml_file_path = Path(xml_file_path)
        self.logger = logging.getLogger(__name__)

        if not self.xml_file_path.exists():
            raise FileNotFoundError(f"找不到 XML 檔案: {xml_file_path}")

    @staticmethod
    def parse_cpe23_uri(cpe23uri: str) -> Dict[str, str]:
        """分析 CPE 2.3 URI 並提取各個組件

        Args:
            cpe23uri (str): CPE 2.3 URI 字串 (例如: cpe:2.3:a:vendor:product:version:...)

        Returns:
            Dict[str, str]: 包含廠商、產品和版本資訊的字典
        """
        # CPE 2.3 格式: cpe:2.3:part:vendor:product:version:update:edition:language:sw_edition:target_sw:target_hw:other
        components = cpe23uri.split(':')

        if len(components) < 6:
            return {"vendor": "", "product": "", "version": ""}

        return {
            'vendor': components[3],
            'product': components[4],
            'version': components[5]
        }

    @contextmanager
    def _open_xml_context(self) -> Iterator:
        """建立用於迭代 XML 檔案中 CPE 項目的上下文管理器

        Yields:
            Iterator: 用於迭代 XML 檔案中 CPE 項目的迭代器
        """
        try:
            context = etree.iterparse(
                str(self.xml_file_path),
                events=('end',),
                tag=f'{{{self.NAMESPACES["def"]}}}cpe-item'
            )
            yield context
        except etree.ParseError as e:
            self.logger.error(f"XML 分析錯誤: {e}")
            raise
        except Exception as e:
            self.logger.error(f"處理 XML 時發生未預期的錯誤: {e}")
            raise

    def _extract_item_data(self, item: etree._Element) -> Optional[CPEItem]:
        """從 XML 元素中提取 CPE 項目資料

        Args:
            item (etree._Element): 包含 CPE 項目資料的 XML 元素

        Returns:
            Optional[CPEItem]: 如果成功提取則返回 CPEItem 物件，否則返回 None
        """
        try:
            # 取得 CPE 2.3 URI
            cpe23_item = item.find('.//cpe-23:cpe23-item', self.NAMESPACES)
            if cpe23_item is None:
                return None

            cpe23uri = cpe23_item.get('name', '')
            if not cpe23uri:
                return None

            # 分析 CPE 組件
            cpe_components = self.parse_cpe23_uri(cpe23uri)

            # 取得標題
            title_elem = item.find(
                './/def:title[@xml:lang="en-US"]', self.NAMESPACES)
            title = title_elem.text if title_elem is not None else ""

            # 取得參考資料
            references = self._extract_references(item)

            # 建立 CPE 項目物件
            return CPEItem(
                cpe22Uri=item.get('name', ''),
                cpe23Uri=cpe23uri,
                vendor=cpe_components['vendor'],
                product=cpe_components['product'],
                version=cpe_components['version'],
                title=title,
                references=references
            )
        except Exception as e:
            self.logger.warning(f"提取 CPE 項目時發生錯誤: {e}")
            return None

    def _extract_references(self, item: etree._Element) -> str:
        """從 XML 元素中提取參考資料

        Args:
            item (etree._Element): 包含參考資料的 XML 元素

        Returns:
            str: 格式化的參考資料字串
        """
        refs = item.findall('.//def:reference', self.NAMESPACES)
        ref_texts = []

        for ref in refs:
            href = ref.get('href', '')
            ref_text = ref.text or ''

            if href and ref_text:
                ref_texts.append(f"{ref_text} ({href})")
            elif href:
                ref_texts.append(href)
            elif ref_text:
                ref_texts.append(ref_text)

        return ' '.join(ref_texts)

    def _clear_element_memory(self, item: etree._Element) -> None:
        """清理 XML 元素佔用的記憶體

        Args:
            item (etree._Element): 要清理的 XML 元素
        """
        item.clear()
        # 清理前面的同層級元素以釋放記憶體
        while item.getprevious() is not None:
            del item.getparent()[0]

    def parse_xml(self) -> List[Dict]:
        """分析整個 CPE XML 檔案

        Returns:
            List[Dict]: 分析後的 CPE 資料列表
        """
        self.logger.info(f"開始分析 XML 檔案: {self.xml_file_path}")
        cpe_items = []

        with self._open_xml_context() as context:
            for event, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    cpe_items.append(asdict(cpe_item))

                self._clear_element_memory(item)

        self.logger.info(f"分析完成，共提取 {len(cpe_items)} 個 CPE 項目")
        return cpe_items

    def process_by_chunk(self, chunk_size: int = 1000) -> Iterator[List[Dict]]:
        """使用分批處理方式處理大型 XML 檔案

        Args:
            chunk_size (int, optional): 每批處理的項目數量. 預設為 1000.

        Yields:
            List[Dict]: 每批處理的 CPE 項目列表
        """
        self.logger.info(f"開始分批處理 XML 檔案 (每批 {chunk_size} 個項目)")
        items = []
        total_processed = 0

        with self._open_xml_context() as context:
            for event, item in context:
                cpe_item = self._extract_item_data(item)
                if cpe_item:
                    items.append(asdict(cpe_item))

                self._clear_element_memory(item)

                if len(items) >= chunk_size:
                    total_processed += len(items)
                    self.logger.debug(f"已處理 {total_processed} 個項目")
                    yield items
                    items = []

            if items:
                total_processed += len(items)
                self.logger.debug(f"已處理 {total_processed} 個項目")
                yield items

        self.logger.info(f"分批處理完成，總共處理 {total_processed} 個項目")

    def save_to_json(self, output_file: str, items: Optional[List[Dict]] = None) -> None:
        """將分析結果儲存為 JSON 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            cpe_items = items if items is not None else self.parse_xml()

            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(cpe_items, f, ensure_ascii=False, indent=2)

            self.logger.info(
                f"已成功儲存 {len(cpe_items)} 個項目至 JSON 檔案: {output_path}")

        except Exception as e:
            self.logger.error(f"儲存 JSON 檔案時發生錯誤: {e}")
            raise

    def save_to_csv(self, output_file: str, items: Optional[List[Dict]] = None) -> None:
        """將分析結果儲存為 CSV 格式

        Args:
            output_file (str): 輸出檔案路徑
            items (Optional[List[Dict]], optional): 要儲存的項目列表，如果為 None 則會分析 XML 檔案. 預設為 None.
        """
        output_path = Path(output_file)
        output_path.parent.mkdir(parents=True, exist_ok=True)

        try:
            cpe_items = items if items is not None else self.parse_xml()
            fieldnames = ['cpe22Uri', 'cpe23Uri', 'vendor', 'product',
                          'version', 'title', 'references']

            with open(output_path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(cpe_items)

            self.logger.info(
                f"已成功儲存 {len(cpe_items)} 個項目至 CSV 檔案: {output_path}")

        except Exception as e:
            self.logger.error(f"儲存 CSV 檔案時發生錯誤: {e}")
            raise


def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


def main():
    # 設定日誌
    log_file = "../logs/cpe_parser.log"
    setup_logging(log_level=logging.INFO, log_file=log_file)
    logger = logging.getLogger(__name__)

    # 設定檔案路徑
    input_file = "../data/official-cpe-dictionary_v2.3.xml"
    output_dir = Path("../data/convert")
    output_dir.mkdir(parents=True, exist_ok=True)

    output_json = output_dir / "official-cpe-dictionary_v2.3_v2.json"
    output_csv = output_dir / "official-cpe-dictionary_v2.3_v2.csv"

    try:
        logger.info(f"開始處理 CPE 字典檔案: {input_file}")
        parser = CPEParser(input_file)

        # 使用分批處理分析 XML 檔案並儲存結果
        all_items = []
        total_processed = 0

        for chunk in parser.process_by_chunk(chunk_size=1000):
            all_items.extend(chunk)
            total_processed += len(chunk)
            logger.info(f"已處理 {total_processed} 個項目")

        # 儲存為 JSON 和 CSV
        parser.save_to_json(str(output_json), all_items)
        parser.save_to_csv(str(output_csv), all_items)

        logger.info("程式執行完成")

    except FileNotFoundError as e:
        logger.error(f"找不到檔案: {e}")
    except Exception as e:
        logger.error(f"程式執行失敗: {e}", exc_info=True)


if __name__ == "__main__":
    main()
# Out:
# 2025-03-13 07:45:25,670 - __main__ - INFO - 開始處理 CPE 字典檔案: ../data/official-cpe-dictionary_v2.3.xml
# 2025-03-13 07:45:25,671 - __main__ - INFO - 開始分批處理 XML 檔案 (每批 1000 個項目)
# 2025-03-13 07:45:25,691 - __main__ - INFO - 已處理 1000 個項目
# 2025-03-13 07:45:25,709 - __main__ - INFO - 已處理 2000 個項目
# 2025-03-13 07:45:25,727 - __main__ - INFO - 已處理 3000 個項目
# 2025-03-13 07:45:25,746 - __main__ - INFO - 已處理 4000 個項目
# 2025-03-13 07:45:25,763 - __main__ - INFO - 已處理 5000 個項目
# 2025-03-13 07:45:25,779 - __main__ - INFO - 已處理 6000 個項目
# 2025-03-13 07:45:25,797 - __main__ - INFO - 已處理 7000 個項目
# 2025-03-13 07:45:25,815 - __main__ - INFO - 已處理 8000 個項目
# 2025-03-13 07:45:25,831 - __main__ - INFO - 已處理 9000 個項目
# 2025-03-13 07:45:25,848 - __main__ - INFO - 已處理 10000 個項目
# 2025-03-13 07:45:25,865 - __main__ - INFO - 已處理 11000 個項目
# 2025-03-13 07:45:25,882 - __main__ - INFO - 已處理 12000 個項目
# 2025-03-13 07:45:25,899 - __main__ - INFO - 已處理 13000 個項目
# 2025-03-13 07:45:25,916 - __main__ - INFO - 已處理 14000 個項目
# 2025-03-13 07:45:25,934 - __main__ - INFO - 已處理 15000 個項目
# 2025-03-13 07:45:25,951 - __main__ - INFO - 已處理 16000 個項目
# 2025-03-13 07:45:25,967 - __main__ - INFO - 已處理 17000 個項目
# 2025-03-13 07:45:25,984 - __main__ - INFO - 已處理 18000 個項目
# 2025-03-13 07:45:26,003 - __main__ - INFO - 已處理 19000 個項目
# 2025-03-13 07:45:26,020 - __main__ - INFO - 已處理 20000 個項目
# 2025-03-13 07:45:26,038 - __main__ - INFO - 已處理 21000 個項目
# 2025-03-13 07:45:26,056 - __main__ - INFO - 已處理 22000 個項目
# 2025-03-13 07:45:26,074 - __main__ - INFO - 已處理 23000 個項目
# 2025-03-13 07:45:26,091 - __main__ - INFO - 已處理 24000 個項目
# 2025-03-13 07:45:26,109 - __main__ - INFO - 已處理 25000 個項目
# 2025-03-13 07:45:26,125 - __main__ - INFO - 已處理 26000 個項目
# 2025-03-13 07:45:26,143 - __main__ - INFO - 已處理 27000 個項目
# 2025-03-13 07:45:26,161 - __main__ - INFO - 已處理 28000 個項目
# 2025-03-13 07:45:26,180 - __main__ - INFO - 已處理 29000 個項目
# 2025-03-13 07:45:26,198 - __main__ - INFO - 已處理 30000 個項目
# 2025-03-13 07:45:26,214 - __main__ - INFO - 已處理 31000 個項目
# 2025-03-13 07:45:26,231 - __main__ - INFO - 已處理 32000 個項目
# 2025-03-13 07:45:26,247 - __main__ - INFO - 已處理 33000 個項目
# 2025-03-13 07:45:26,265 - __main__ - INFO - 已處理 34000 個項目
# 2025-03-13 07:45:26,283 - __main__ - INFO - 已處理 35000 個項目
# 2025-03-13 07:45:26,299 - __main__ - INFO - 已處理 36000 個項目
# 2025-03-13 07:45:26,315 - __main__ - INFO - 已處理 37000 個項目
# 2025-03-13 07:45:26,331 - __main__ - INFO - 已處理 38000 個項目
# 2025-03-13 07:45:26,349 - __main__ - INFO - 已處理 39000 個項目
# 2025-03-13 07:45:26,365 - __main__ - INFO - 已處理 40000 個項目
# 2025-03-13 07:45:26,381 - __main__ - INFO - 已處理 41000 個項目
# 2025-03-13 07:45:26,397 - __main__ - INFO - 已處理 42000 個項目
# 2025-03-13 07:45:26,414 - __main__ - INFO - 已處理 43000 個項目
# 2025-03-13 07:45:26,432 - __main__ - INFO - 已處理 44000 個項目
# 2025-03-13 07:45:26,447 - __main__ - INFO - 已處理 45000 個項目
# 2025-03-13 07:45:26,464 - __main__ - INFO - 已處理 46000 個項目
# 2025-03-13 07:45:26,481 - __main__ - INFO - 已處理 47000 個項目
# 2025-03-13 07:45:26,497 - __main__ - INFO - 已處理 48000 個項目
# 2025-03-13 07:45:26,514 - __main__ - INFO - 已處理 49000 個項目
# 2025-03-13 07:45:26,530 - __main__ - INFO - 已處理 50000 個項目
# 2025-03-13 07:45:26,547 - __main__ - INFO - 已處理 51000 個項目
# 2025-03-13 07:45:26,565 - __main__ - INFO - 已處理 52000 個項目
# 2025-03-13 07:45:26,596 - __main__ - INFO - 已處理 53000 個項目
# 2025-03-13 07:45:26,613 - __main__ - INFO - 已處理 54000 個項目
# 2025-03-13 07:45:26,628 - __main__ - INFO - 已處理 55000 個項目
# 2025-03-13 07:45:26,643 - __main__ - INFO - 已處理 56000 個項目
# 2025-03-13 07:45:26,660 - __main__ - INFO - 已處理 57000 個項目
# 2025-03-13 07:45:26,678 - __main__ - INFO - 已處理 58000 個項目
# 2025-03-13 07:45:26,693 - __main__ - INFO - 已處理 59000 個項目
# 2025-03-13 07:45:26,709 - __main__ - INFO - 已處理 60000 個項目
# 2025-03-13 07:45:26,725 - __main__ - INFO - 已處理 61000 個項目
# 2025-03-13 07:45:26,741 - __main__ - INFO - 已處理 62000 個項目
# 2025-03-13 07:45:26,757 - __main__ - INFO - 已處理 63000 個項目
# 2025-03-13 07:45:26,773 - __main__ - INFO - 已處理 64000 個項目
# 2025-03-13 07:45:26,789 - __main__ - INFO - 已處理 65000 個項目
# 2025-03-13 07:45:26,804 - __main__ - INFO - 已處理 66000 個項目
# 2025-03-13 07:45:26,820 - __main__ - INFO - 已處理 67000 個項目
# 2025-03-13 07:45:26,836 - __main__ - INFO - 已處理 68000 個項目
# 2025-03-13 07:45:26,851 - __main__ - INFO - 已處理 69000 個項目
# 2025-03-13 07:45:26,867 - __main__ - INFO - 已處理 70000 個項目
# 2025-03-13 07:45:26,884 - __main__ - INFO - 已處理 71000 個項目
# 2025-03-13 07:45:26,901 - __main__ - INFO - 已處理 72000 個項目
# 2025-03-13 07:45:26,918 - __main__ - INFO - 已處理 73000 個項目
# 2025-03-13 07:45:26,934 - __main__ - INFO - 已處理 74000 個項目
# 2025-03-13 07:45:26,950 - __main__ - INFO - 已處理 75000 個項目
# 2025-03-13 07:45:26,965 - __main__ - INFO - 已處理 76000 個項目
# 2025-03-13 07:45:26,980 - __main__ - INFO - 已處理 77000 個項目
# 2025-03-13 07:45:26,994 - __main__ - INFO - 已處理 78000 個項目
# 2025-03-13 07:45:27,011 - __main__ - INFO - 已處理 79000 個項目
# 2025-03-13 07:45:27,026 - __main__ - INFO - 已處理 80000 個項目
# 2025-03-13 07:45:27,043 - __main__ - INFO - 已處理 81000 個項目
# 2025-03-13 07:45:27,059 - __main__ - INFO - 已處理 82000 個項目
# 2025-03-13 07:45:27,075 - __main__ - INFO - 已處理 83000 個項目
# 2025-03-13 07:45:27,093 - __main__ - INFO - 已處理 84000 個項目
# 2025-03-13 07:45:27,110 - __main__ - INFO - 已處理 85000 個項目
# 2025-03-13 07:45:27,125 - __main__ - INFO - 已處理 86000 個項目
# 2025-03-13 07:45:27,142 - __main__ - INFO - 已處理 87000 個項目
# 2025-03-13 07:45:27,158 - __main__ - INFO - 已處理 88000 個項目
# 2025-03-13 07:45:27,174 - __main__ - INFO - 已處理 89000 個項目
# 2025-03-13 07:45:27,190 - __main__ - INFO - 已處理 90000 個項目
# 2025-03-13 07:45:27,204 - __main__ - INFO - 已處理 91000 個項目
# 2025-03-13 07:45:27,221 - __main__ - INFO - 已處理 92000 個項目
# 2025-03-13 07:45:27,238 - __main__ - INFO - 已處理 93000 個項目
# 2025-03-13 07:45:27,254 - __main__ - INFO - 已處理 94000 個項目
# 2025-03-13 07:45:27,269 - __main__ - INFO - 已處理 95000 個項目
# 2025-03-13 07:45:27,285 - __main__ - INFO - 已處理 96000 個項目
# 2025-03-13 07:45:27,302 - __main__ - INFO - 已處理 97000 個項目
# 2025-03-13 07:45:27,319 - __main__ - INFO - 已處理 98000 個項目
# 2025-03-13 07:45:27,336 - __main__ - INFO - 已處理 99000 個項目
# 2025-03-13 07:45:27,351 - __main__ - INFO - 已處理 100000 個項目
# 2025-03-13 07:45:27,368 - __main__ - INFO - 已處理 101000 個項目
# 2025-03-13 07:45:27,384 - __main__ - INFO - 已處理 102000 個項目
# 2025-03-13 07:45:27,401 - __main__ - INFO - 已處理 103000 個項目
# 2025-03-13 07:45:27,416 - __main__ - INFO - 已處理 104000 個項目
# 2025-03-13 07:45:27,433 - __main__ - INFO - 已處理 105000 個項目
# 2025-03-13 07:45:27,449 - __main__ - INFO - 已處理 106000 個項目
# 2025-03-13 07:45:27,465 - __main__ - INFO - 已處理 107000 個項目
# 2025-03-13 07:45:27,483 - __main__ - INFO - 已處理 108000 個項目
# 2025-03-13 07:45:27,499 - __main__ - INFO - 已處理 109000 個項目
# 2025-03-13 07:45:27,516 - __main__ - INFO - 已處理 110000 個項目
# 2025-03-13 07:45:27,532 - __main__ - INFO - 已處理 111000 個項目
# 2025-03-13 07:45:27,552 - __main__ - INFO - 已處理 112000 個項目
# 2025-03-13 07:45:27,568 - __main__ - INFO - 已處理 113000 個項目
# 2025-03-13 07:45:27,585 - __main__ - INFO - 已處理 114000 個項目
# 2025-03-13 07:45:27,603 - __main__ - INFO - 已處理 115000 個項目
# 2025-03-13 07:45:27,619 - __main__ - INFO - 已處理 116000 個項目
# 2025-03-13 07:45:27,636 - __main__ - INFO - 已處理 117000 個項目
# 2025-03-13 07:45:27,652 - __main__ - INFO - 已處理 118000 個項目
# 2025-03-13 07:45:27,668 - __main__ - INFO - 已處理 119000 個項目
# 2025-03-13 07:45:27,685 - __main__ - INFO - 已處理 120000 個項目
# 2025-03-13 07:45:27,701 - __main__ - INFO - 已處理 121000 個項目
# 2025-03-13 07:45:27,716 - __main__ - INFO - 已處理 122000 個項目
# 2025-03-13 07:45:27,733 - __main__ - INFO - 已處理 123000 個項目
# 2025-03-13 07:45:27,750 - __main__ - INFO - 已處理 124000 個項目
# 2025-03-13 07:45:27,766 - __main__ - INFO - 已處理 125000 個項目
# 2025-03-13 07:45:27,783 - __main__ - INFO - 已處理 126000 個項目
# 2025-03-13 07:45:27,799 - __main__ - INFO - 已處理 127000 個項目
# 2025-03-13 07:45:27,816 - __main__ - INFO - 已處理 128000 個項目
# 2025-03-13 07:45:27,832 - __main__ - INFO - 已處理 129000 個項目
# 2025-03-13 07:45:27,849 - __main__ - INFO - 已處理 130000 個項目
# 2025-03-13 07:45:27,867 - __main__ - INFO - 已處理 131000 個項目
# 2025-03-13 07:45:27,885 - __main__ - INFO - 已處理 132000 個項目
# 2025-03-13 07:45:27,900 - __main__ - INFO - 已處理 133000 個項目
# 2025-03-13 07:45:27,915 - __main__ - INFO - 已處理 134000 個項目
# 2025-03-13 07:45:27,931 - __main__ - INFO - 已處理 135000 個項目
# 2025-03-13 07:45:27,948 - __main__ - INFO - 已處理 136000 個項目
# 2025-03-13 07:45:27,965 - __main__ - INFO - 已處理 137000 個項目
# 2025-03-13 07:45:27,981 - __main__ - INFO - 已處理 138000 個項目
# 2025-03-13 07:45:28,002 - __main__ - INFO - 已處理 139000 個項目
# 2025-03-13 07:45:28,019 - __main__ - INFO - 已處理 140000 個項目
# 2025-03-13 07:45:28,039 - __main__ - INFO - 已處理 141000 個項目
# 2025-03-13 07:45:28,057 - __main__ - INFO - 已處理 142000 個項目
# 2025-03-13 07:45:28,075 - __main__ - INFO - 已處理 143000 個項目
# 2025-03-13 07:45:28,094 - __main__ - INFO - 已處理 144000 個項目
# 2025-03-13 07:45:28,111 - __main__ - INFO - 已處理 145000 個項目
# 2025-03-13 07:45:28,127 - __main__ - INFO - 已處理 146000 個項目
# 2025-03-13 07:45:28,143 - __main__ - INFO - 已處理 147000 個項目
# 2025-03-13 07:45:28,160 - __main__ - INFO - 已處理 148000 個項目
# 2025-03-13 07:45:28,176 - __main__ - INFO - 已處理 149000 個項目
# 2025-03-13 07:45:28,193 - __main__ - INFO - 已處理 150000 個項目
# 2025-03-13 07:45:28,209 - __main__ - INFO - 已處理 151000 個項目
# 2025-03-13 07:45:28,226 - __main__ - INFO - 已處理 152000 個項目
# 2025-03-13 07:45:28,244 - __main__ - INFO - 已處理 153000 個項目
# 2025-03-13 07:45:28,263 - __main__ - INFO - 已處理 154000 個項目
# 2025-03-13 07:45:28,280 - __main__ - INFO - 已處理 155000 個項目
# 2025-03-13 07:45:28,335 - __main__ - INFO - 已處理 156000 個項目
# 2025-03-13 07:45:28,351 - __main__ - INFO - 已處理 157000 個項目
# 2025-03-13 07:45:28,368 - __main__ - INFO - 已處理 158000 個項目
# 2025-03-13 07:45:28,385 - __main__ - INFO - 已處理 159000 個項目
# 2025-03-13 07:45:28,403 - __main__ - INFO - 已處理 160000 個項目
# 2025-03-13 07:45:28,419 - __main__ - INFO - 已處理 161000 個項目
# 2025-03-13 07:45:28,435 - __main__ - INFO - 已處理 162000 個項目
# 2025-03-13 07:45:28,453 - __main__ - INFO - 已處理 163000 個項目
# 2025-03-13 07:45:28,468 - __main__ - INFO - 已處理 164000 個項目
# 2025-03-13 07:45:28,485 - __main__ - INFO - 已處理 165000 個項目
# 2025-03-13 07:45:28,503 - __main__ - INFO - 已處理 166000 個項目
# 2025-03-13 07:45:28,521 - __main__ - INFO - 已處理 167000 個項目
# 2025-03-13 07:45:28,539 - __main__ - INFO - 已處理 168000 個項目
# 2025-03-13 07:45:28,555 - __main__ - INFO - 已處理 169000 個項目
# 2025-03-13 07:45:28,573 - __main__ - INFO - 已處理 170000 個項目
# 2025-03-13 07:45:28,589 - __main__ - INFO - 已處理 171000 個項目
# 2025-03-13 07:45:28,606 - __main__ - INFO - 已處理 172000 個項目
# 2025-03-13 07:45:28,622 - __main__ - INFO - 已處理 173000 個項目
# 2025-03-13 07:45:28,641 - __main__ - INFO - 已處理 174000 個項目
# 2025-03-13 07:45:28,658 - __main__ - INFO - 已處理 175000 個項目
# 2025-03-13 07:45:28,676 - __main__ - INFO - 已處理 176000 個項目
# 2025-03-13 07:45:28,692 - __main__ - INFO - 已處理 177000 個項目
# 2025-03-13 07:45:28,709 - __main__ - INFO - 已處理 178000 個項目
# 2025-03-13 07:45:28,726 - __main__ - INFO - 已處理 179000 個項目
# 2025-03-13 07:45:28,744 - __main__ - INFO - 已處理 180000 個項目
# 2025-03-13 07:45:28,761 - __main__ - INFO - 已處理 181000 個項目
# 2025-03-13 07:45:28,778 - __main__ - INFO - 已處理 182000 個項目
# 2025-03-13 07:45:28,795 - __main__ - INFO - 已處理 183000 個項目
# 2025-03-13 07:45:28,810 - __main__ - INFO - 已處理 184000 個項目
# 2025-03-13 07:45:28,827 - __main__ - INFO - 已處理 185000 個項目
# 2025-03-13 07:45:28,844 - __main__ - INFO - 已處理 186000 個項目
# 2025-03-13 07:45:28,860 - __main__ - INFO - 已處理 187000 個項目
# 2025-03-13 07:45:28,876 - __main__ - INFO - 已處理 188000 個項目
# 2025-03-13 07:45:28,891 - __main__ - INFO - 已處理 189000 個項目
# 2025-03-13 07:45:28,906 - __main__ - INFO - 已處理 190000 個項目
# 2025-03-13 07:45:28,924 - __main__ - INFO - 已處理 191000 個項目
# 2025-03-13 07:45:28,942 - __main__ - INFO - 已處理 192000 個項目
# 2025-03-13 07:45:28,960 - __main__ - INFO - 已處理 193000 個項目
# 2025-03-13 07:45:28,979 - __main__ - INFO - 已處理 194000 個項目
# 2025-03-13 07:45:28,996 - __main__ - INFO - 已處理 195000 個項目
# 2025-03-13 07:45:29,013 - __main__ - INFO - 已處理 196000 個項目
# 2025-03-13 07:45:29,030 - __main__ - INFO - 已處理 197000 個項目
# 2025-03-13 07:45:29,046 - __main__ - INFO - 已處理 198000 個項目
# 2025-03-13 07:45:29,061 - __main__ - INFO - 已處理 199000 個項目
# 2025-03-13 07:45:29,078 - __main__ - INFO - 已處理 200000 個項目
# 2025-03-13 07:45:29,097 - __main__ - INFO - 已處理 201000 個項目
# 2025-03-13 07:45:29,138 - __main__ - INFO - 已處理 202000 個項目
# 2025-03-13 07:45:29,191 - __main__ - INFO - 已處理 203000 個項目
# 2025-03-13 07:45:29,236 - __main__ - INFO - 已處理 204000 個項目
# 2025-03-13 07:45:29,277 - __main__ - INFO - 已處理 205000 個項目
# 2025-03-13 07:45:29,309 - __main__ - INFO - 已處理 206000 個項目
# 2025-03-13 07:45:29,342 - __main__ - INFO - 已處理 207000 個項目
# 2025-03-13 07:45:29,368 - __main__ - INFO - 已處理 208000 個項目
# 2025-03-13 07:45:29,384 - __main__ - INFO - 已處理 209000 個項目
# 2025-03-13 07:45:29,400 - __main__ - INFO - 已處理 210000 個項目
# 2025-03-13 07:45:29,418 - __main__ - INFO - 已處理 211000 個項目
# 2025-03-13 07:45:29,476 - __main__ - INFO - 已處理 212000 個項目
# 2025-03-13 07:45:29,495 - __main__ - INFO - 已處理 213000 個項目
# 2025-03-13 07:45:29,512 - __main__ - INFO - 已處理 214000 個項目
# 2025-03-13 07:45:29,530 - __main__ - INFO - 已處理 215000 個項目
# 2025-03-13 07:45:29,547 - __main__ - INFO - 已處理 216000 個項目
# 2025-03-13 07:45:29,564 - __main__ - INFO - 已處理 217000 個項目
# 2025-03-13 07:45:29,581 - __main__ - INFO - 已處理 218000 個項目
# 2025-03-13 07:45:29,599 - __main__ - INFO - 已處理 219000 個項目
# 2025-03-13 07:45:29,615 - __main__ - INFO - 已處理 220000 個項目
# 2025-03-13 07:45:29,633 - __main__ - INFO - 已處理 221000 個項目
# 2025-03-13 07:45:29,650 - __main__ - INFO - 已處理 222000 個項目
# 2025-03-13 07:45:29,666 - __main__ - INFO - 已處理 223000 個項目
# 2025-03-13 07:45:29,683 - __main__ - INFO - 已處理 224000 個項目
# 2025-03-13 07:45:29,700 - __main__ - INFO - 已處理 225000 個項目
# 2025-03-13 07:45:29,716 - __main__ - INFO - 已處理 226000 個項目
# 2025-03-13 07:45:29,733 - __main__ - INFO - 已處理 227000 個項目
# 2025-03-13 07:45:29,750 - __main__ - INFO - 已處理 228000 個項目
# 2025-03-13 07:45:29,765 - __main__ - INFO - 已處理 229000 個項目
# 2025-03-13 07:45:29,783 - __main__ - INFO - 已處理 230000 個項目
# 2025-03-13 07:45:29,802 - __main__ - INFO - 已處理 231000 個項目
# 2025-03-13 07:45:29,820 - __main__ - INFO - 已處理 232000 個項目
# 2025-03-13 07:45:29,839 - __main__ - INFO - 已處理 233000 個項目
# 2025-03-13 07:45:29,857 - __main__ - INFO - 已處理 234000 個項目
# 2025-03-13 07:45:29,875 - __main__ - INFO - 已處理 235000 個項目
# 2025-03-13 07:45:29,892 - __main__ - INFO - 已處理 236000 個項目
# 2025-03-13 07:45:29,913 - __main__ - INFO - 已處理 237000 個項目
# 2025-03-13 07:45:29,976 - __main__ - INFO - 已處理 238000 個項目
# 2025-03-13 07:45:29,994 - __main__ - INFO - 已處理 239000 個項目
# 2025-03-13 07:45:30,011 - __main__ - INFO - 已處理 240000 個項目
# 2025-03-13 07:45:30,029 - __main__ - INFO - 已處理 241000 個項目
# 2025-03-13 07:45:30,047 - __main__ - INFO - 已處理 242000 個項目
# 2025-03-13 07:45:30,065 - __main__ - INFO - 已處理 243000 個項目
# 2025-03-13 07:45:30,085 - __main__ - INFO - 已處理 244000 個項目
# 2025-03-13 07:45:30,102 - __main__ - INFO - 已處理 245000 個項目
# 2025-03-13 07:45:30,120 - __main__ - INFO - 已處理 246000 個項目
# 2025-03-13 07:45:30,138 - __main__ - INFO - 已處理 247000 個項目
# 2025-03-13 07:45:30,157 - __main__ - INFO - 已處理 248000 個項目
# 2025-03-13 07:45:30,173 - __main__ - INFO - 已處理 249000 個項目
# 2025-03-13 07:45:30,192 - __main__ - INFO - 已處理 250000 個項目
# 2025-03-13 07:45:30,211 - __main__ - INFO - 已處理 251000 個項目
# 2025-03-13 07:45:30,229 - __main__ - INFO - 已處理 252000 個項目
# 2025-03-13 07:45:30,245 - __main__ - INFO - 已處理 253000 個項目
# 2025-03-13 07:45:30,262 - __main__ - INFO - 已處理 254000 個項目
# 2025-03-13 07:45:30,279 - __main__ - INFO - 已處理 255000 個項目
# 2025-03-13 07:45:30,296 - __main__ - INFO - 已處理 256000 個項目
# 2025-03-13 07:45:30,315 - __main__ - INFO - 已處理 257000 個項目
# 2025-03-13 07:45:30,333 - __main__ - INFO - 已處理 258000 個項目
# 2025-03-13 07:45:30,351 - __main__ - INFO - 已處理 259000 個項目
# 2025-03-13 07:45:30,368 - __main__ - INFO - 已處理 260000 個項目
# 2025-03-13 07:45:30,387 - __main__ - INFO - 已處理 261000 個項目
# 2025-03-13 07:45:30,405 - __main__ - INFO - 已處理 262000 個項目
# 2025-03-13 07:45:30,421 - __main__ - INFO - 已處理 263000 個項目
# 2025-03-13 07:45:30,438 - __main__ - INFO - 已處理 264000 個項目
# 2025-03-13 07:45:30,456 - __main__ - INFO - 已處理 265000 個項目
# 2025-03-13 07:45:30,473 - __main__ - INFO - 已處理 266000 個項目
# 2025-03-13 07:45:30,490 - __main__ - INFO - 已處理 267000 個項目
# 2025-03-13 07:45:30,508 - __main__ - INFO - 已處理 268000 個項目
# 2025-03-13 07:45:30,525 - __main__ - INFO - 已處理 269000 個項目
# 2025-03-13 07:45:30,546 - __main__ - INFO - 已處理 270000 個項目
# 2025-03-13 07:45:30,563 - __main__ - INFO - 已處理 271000 個項目
# 2025-03-13 07:45:30,581 - __main__ - INFO - 已處理 272000 個項目
# 2025-03-13 07:45:30,600 - __main__ - INFO - 已處理 273000 個項目
# 2025-03-13 07:45:30,619 - __main__ - INFO - 已處理 274000 個項目
# 2025-03-13 07:45:30,637 - __main__ - INFO - 已處理 275000 個項目
# 2025-03-13 07:45:30,655 - __main__ - INFO - 已處理 276000 個項目
# 2025-03-13 07:45:30,673 - __main__ - INFO - 已處理 277000 個項目
# 2025-03-13 07:45:30,690 - __main__ - INFO - 已處理 278000 個項目
# 2025-03-13 07:45:30,707 - __main__ - INFO - 已處理 279000 個項目
# 2025-03-13 07:45:30,724 - __main__ - INFO - 已處理 280000 個項目
# 2025-03-13 07:45:30,742 - __main__ - INFO - 已處理 281000 個項目
# 2025-03-13 07:45:30,759 - __main__ - INFO - 已處理 282000 個項目
# 2025-03-13 07:45:30,778 - __main__ - INFO - 已處理 283000 個項目
# 2025-03-13 07:45:30,798 - __main__ - INFO - 已處理 284000 個項目
# 2025-03-13 07:45:30,866 - __main__ - INFO - 已處理 285000 個項目
# 2025-03-13 07:45:30,886 - __main__ - INFO - 已處理 286000 個項目
# 2025-03-13 07:45:30,904 - __main__ - INFO - 已處理 287000 個項目
# 2025-03-13 07:45:30,921 - __main__ - INFO - 已處理 288000 個項目
# 2025-03-13 07:45:30,939 - __main__ - INFO - 已處理 289000 個項目
# 2025-03-13 07:45:30,956 - __main__ - INFO - 已處理 290000 個項目
# 2025-03-13 07:45:30,974 - __main__ - INFO - 已處理 291000 個項目
# 2025-03-13 07:45:30,991 - __main__ - INFO - 已處理 292000 個項目
# 2025-03-13 07:45:31,009 - __main__ - INFO - 已處理 293000 個項目
# 2025-03-13 07:45:31,026 - __main__ - INFO - 已處理 294000 個項目
# 2025-03-13 07:45:31,043 - __main__ - INFO - 已處理 295000 個項目
# 2025-03-13 07:45:31,060 - __main__ - INFO - 已處理 296000 個項目
# 2025-03-13 07:45:31,078 - __main__ - INFO - 已處理 297000 個項目
# 2025-03-13 07:45:31,095 - __main__ - INFO - 已處理 298000 個項目
# 2025-03-13 07:45:31,113 - __main__ - INFO - 已處理 299000 個項目
# 2025-03-13 07:45:31,131 - __main__ - INFO - 已處理 300000 個項目
# 2025-03-13 07:45:31,148 - __main__ - INFO - 已處理 301000 個項目
# 2025-03-13 07:45:31,166 - __main__ - INFO - 已處理 302000 個項目
# 2025-03-13 07:45:31,182 - __main__ - INFO - 已處理 303000 個項目
# 2025-03-13 07:45:31,200 - __main__ - INFO - 已處理 304000 個項目
# 2025-03-13 07:45:31,219 - __main__ - INFO - 已處理 305000 個項目
# 2025-03-13 07:45:31,238 - __main__ - INFO - 已處理 306000 個項目
# 2025-03-13 07:45:31,256 - __main__ - INFO - 已處理 307000 個項目
# 2025-03-13 07:45:31,273 - __main__ - INFO - 已處理 308000 個項目
# 2025-03-13 07:45:31,292 - __main__ - INFO - 已處理 309000 個項目
# 2025-03-13 07:45:31,309 - __main__ - INFO - 已處理 310000 個項目
# 2025-03-13 07:45:31,327 - __main__ - INFO - 已處理 311000 個項目
# 2025-03-13 07:45:31,346 - __main__ - INFO - 已處理 312000 個項目
# 2025-03-13 07:45:31,365 - __main__ - INFO - 已處理 313000 個項目
# 2025-03-13 07:45:31,383 - __main__ - INFO - 已處理 314000 個項目
# 2025-03-13 07:45:31,398 - __main__ - INFO - 已處理 315000 個項目
# 2025-03-13 07:45:31,416 - __main__ - INFO - 已處理 316000 個項目
# 2025-03-13 07:45:31,434 - __main__ - INFO - 已處理 317000 個項目
# 2025-03-13 07:45:31,453 - __main__ - INFO - 已處理 318000 個項目
# 2025-03-13 07:45:31,471 - __main__ - INFO - 已處理 319000 個項目
# 2025-03-13 07:45:31,488 - __main__ - INFO - 已處理 320000 個項目
# 2025-03-13 07:45:31,507 - __main__ - INFO - 已處理 321000 個項目
# 2025-03-13 07:45:31,523 - __main__ - INFO - 已處理 322000 個項目
# 2025-03-13 07:45:31,541 - __main__ - INFO - 已處理 323000 個項目
# 2025-03-13 07:45:31,558 - __main__ - INFO - 已處理 324000 個項目
# 2025-03-13 07:45:31,574 - __main__ - INFO - 已處理 325000 個項目
# 2025-03-13 07:45:31,592 - __main__ - INFO - 已處理 326000 個項目
# 2025-03-13 07:45:31,610 - __main__ - INFO - 已處理 327000 個項目
# 2025-03-13 07:45:31,626 - __main__ - INFO - 已處理 328000 個項目
# 2025-03-13 07:45:31,645 - __main__ - INFO - 已處理 329000 個項目
# 2025-03-13 07:45:31,662 - __main__ - INFO - 已處理 330000 個項目
# 2025-03-13 07:45:31,679 - __main__ - INFO - 已處理 331000 個項目
# 2025-03-13 07:45:31,698 - __main__ - INFO - 已處理 332000 個項目
# 2025-03-13 07:45:31,716 - __main__ - INFO - 已處理 333000 個項目
# 2025-03-13 07:45:31,736 - __main__ - INFO - 已處理 334000 個項目
# 2025-03-13 07:45:31,752 - __main__ - INFO - 已處理 335000 個項目
# 2025-03-13 07:45:31,807 - __main__ - INFO - 已處理 336000 個項目
# 2025-03-13 07:45:31,830 - __main__ - INFO - 已處理 337000 個項目
# 2025-03-13 07:45:31,851 - __main__ - INFO - 已處理 338000 個項目
# 2025-03-13 07:45:31,870 - __main__ - INFO - 已處理 339000 個項目
# 2025-03-13 07:45:31,893 - __main__ - INFO - 已處理 340000 個項目
# 2025-03-13 07:45:31,915 - __main__ - INFO - 已處理 341000 個項目
# 2025-03-13 07:45:31,932 - __main__ - INFO - 已處理 342000 個項目
# 2025-03-13 07:45:31,951 - __main__ - INFO - 已處理 343000 個項目
# 2025-03-13 07:45:31,967 - __main__ - INFO - 已處理 344000 個項目
# 2025-03-13 07:45:31,983 - __main__ - INFO - 已處理 345000 個項目
# 2025-03-13 07:45:31,999 - __main__ - INFO - 已處理 346000 個項目
# 2025-03-13 07:45:32,016 - __main__ - INFO - 已處理 347000 個項目
# 2025-03-13 07:45:32,034 - __main__ - INFO - 已處理 348000 個項目
# 2025-03-13 07:45:32,051 - __main__ - INFO - 已處理 349000 個項目
# 2025-03-13 07:45:32,068 - __main__ - INFO - 已處理 350000 個項目
# 2025-03-13 07:45:32,086 - __main__ - INFO - 已處理 351000 個項目
# 2025-03-13 07:45:32,104 - __main__ - INFO - 已處理 352000 個項目
# 2025-03-13 07:45:32,123 - __main__ - INFO - 已處理 353000 個項目
# 2025-03-13 07:45:32,141 - __main__ - INFO - 已處理 354000 個項目
# 2025-03-13 07:45:32,159 - __main__ - INFO - 已處理 355000 個項目
# 2025-03-13 07:45:32,176 - __main__ - INFO - 已處理 356000 個項目
# 2025-03-13 07:45:32,193 - __main__ - INFO - 已處理 357000 個項目
# 2025-03-13 07:45:32,209 - __main__ - INFO - 已處理 358000 個項目
# 2025-03-13 07:45:32,227 - __main__ - INFO - 已處理 359000 個項目
# 2025-03-13 07:45:32,244 - __main__ - INFO - 已處理 360000 個項目
# 2025-03-13 07:45:32,262 - __main__ - INFO - 已處理 361000 個項目
# 2025-03-13 07:45:32,278 - __main__ - INFO - 已處理 362000 個項目
# 2025-03-13 07:45:32,296 - __main__ - INFO - 已處理 363000 個項目
# 2025-03-13 07:45:32,314 - __main__ - INFO - 已處理 364000 個項目
# 2025-03-13 07:45:32,331 - __main__ - INFO - 已處理 365000 個項目
# 2025-03-13 07:45:32,349 - __main__ - INFO - 已處理 366000 個項目
# 2025-03-13 07:45:32,367 - __main__ - INFO - 已處理 367000 個項目
# 2025-03-13 07:45:32,384 - __main__ - INFO - 已處理 368000 個項目
# 2025-03-13 07:45:32,401 - __main__ - INFO - 已處理 369000 個項目
# 2025-03-13 07:45:32,419 - __main__ - INFO - 已處理 370000 個項目
# 2025-03-13 07:45:32,436 - __main__ - INFO - 已處理 371000 個項目
# 2025-03-13 07:45:32,453 - __main__ - INFO - 已處理 372000 個項目
# 2025-03-13 07:45:32,470 - __main__ - INFO - 已處理 373000 個項目
# 2025-03-13 07:45:32,487 - __main__ - INFO - 已處理 374000 個項目
# 2025-03-13 07:45:32,503 - __main__ - INFO - 已處理 375000 個項目
# 2025-03-13 07:45:32,524 - __main__ - INFO - 已處理 376000 個項目
# 2025-03-13 07:45:32,541 - __main__ - INFO - 已處理 377000 個項目
# 2025-03-13 07:45:32,559 - __main__ - INFO - 已處理 378000 個項目
# 2025-03-13 07:45:32,577 - __main__ - INFO - 已處理 379000 個項目
# 2025-03-13 07:45:32,594 - __main__ - INFO - 已處理 380000 個項目
# 2025-03-13 07:45:32,611 - __main__ - INFO - 已處理 381000 個項目
# 2025-03-13 07:45:32,630 - __main__ - INFO - 已處理 382000 個項目
# 2025-03-13 07:45:32,650 - __main__ - INFO - 已處理 383000 個項目
# 2025-03-13 07:45:32,669 - __main__ - INFO - 已處理 384000 個項目
# 2025-03-13 07:45:32,690 - __main__ - INFO - 已處理 385000 個項目
# 2025-03-13 07:45:32,711 - __main__ - INFO - 已處理 386000 個項目
# 2025-03-13 07:45:32,730 - __main__ - INFO - 已處理 387000 個項目
# 2025-03-13 07:45:32,752 - __main__ - INFO - 已處理 388000 個項目
# 2025-03-13 07:45:32,770 - __main__ - INFO - 已處理 389000 個項目
# 2025-03-13 07:45:32,790 - __main__ - INFO - 已處理 390000 個項目
# 2025-03-13 07:45:32,809 - __main__ - INFO - 已處理 391000 個項目
# 2025-03-13 07:45:32,830 - __main__ - INFO - 已處理 392000 個項目
# 2025-03-13 07:45:32,917 - __main__ - INFO - 已處理 393000 個項目
# 2025-03-13 07:45:32,944 - __main__ - INFO - 已處理 394000 個項目
# 2025-03-13 07:45:32,965 - __main__ - INFO - 已處理 395000 個項目
# 2025-03-13 07:45:32,987 - __main__ - INFO - 已處理 396000 個項目
# 2025-03-13 07:45:33,006 - __main__ - INFO - 已處理 397000 個項目
# 2025-03-13 07:45:33,024 - __main__ - INFO - 已處理 398000 個項目
# 2025-03-13 07:45:33,043 - __main__ - INFO - 已處理 399000 個項目
# 2025-03-13 07:45:33,062 - __main__ - INFO - 已處理 400000 個項目
# 2025-03-13 07:45:33,081 - __main__ - INFO - 已處理 401000 個項目
# 2025-03-13 07:45:33,100 - __main__ - INFO - 已處理 402000 個項目
# 2025-03-13 07:45:33,119 - __main__ - INFO - 已處理 403000 個項目
# 2025-03-13 07:45:33,141 - __main__ - INFO - 已處理 404000 個項目
# 2025-03-13 07:45:33,162 - __main__ - INFO - 已處理 405000 個項目
# 2025-03-13 07:45:33,180 - __main__ - INFO - 已處理 406000 個項目
# 2025-03-13 07:45:33,201 - __main__ - INFO - 已處理 407000 個項目
# 2025-03-13 07:45:33,223 - __main__ - INFO - 已處理 408000 個項目
# 2025-03-13 07:45:33,243 - __main__ - INFO - 已處理 409000 個項目
# 2025-03-13 07:45:33,264 - __main__ - INFO - 已處理 410000 個項目
# 2025-03-13 07:45:33,292 - __main__ - INFO - 已處理 411000 個項目
# 2025-03-13 07:45:33,311 - __main__ - INFO - 已處理 412000 個項目
# 2025-03-13 07:45:33,330 - __main__ - INFO - 已處理 413000 個項目
# 2025-03-13 07:45:33,348 - __main__ - INFO - 已處理 414000 個項目
# 2025-03-13 07:45:33,367 - __main__ - INFO - 已處理 415000 個項目
# 2025-03-13 07:45:33,387 - __main__ - INFO - 已處理 416000 個項目
# 2025-03-13 07:45:33,406 - __main__ - INFO - 已處理 417000 個項目
# 2025-03-13 07:45:33,427 - __main__ - INFO - 已處理 418000 個項目
# 2025-03-13 07:45:33,446 - __main__ - INFO - 已處理 419000 個項目
# 2025-03-13 07:45:33,467 - __main__ - INFO - 已處理 420000 個項目
# 2025-03-13 07:45:33,487 - __main__ - INFO - 已處理 421000 個項目
# 2025-03-13 07:45:33,507 - __main__ - INFO - 已處理 422000 個項目
# 2025-03-13 07:45:33,527 - __main__ - INFO - 已處理 423000 個項目
# 2025-03-13 07:45:33,547 - __main__ - INFO - 已處理 424000 個項目
# 2025-03-13 07:45:33,566 - __main__ - INFO - 已處理 425000 個項目
# 2025-03-13 07:45:33,583 - __main__ - INFO - 已處理 426000 個項目
# 2025-03-13 07:45:33,602 - __main__ - INFO - 已處理 427000 個項目
# 2025-03-13 07:45:33,622 - __main__ - INFO - 已處理 428000 個項目
# 2025-03-13 07:45:33,645 - __main__ - INFO - 已處理 429000 個項目
# 2025-03-13 07:45:33,664 - __main__ - INFO - 已處理 430000 個項目
# 2025-03-13 07:45:33,684 - __main__ - INFO - 已處理 431000 個項目
# 2025-03-13 07:45:33,702 - __main__ - INFO - 已處理 432000 個項目
# 2025-03-13 07:45:33,721 - __main__ - INFO - 已處理 433000 個項目
# 2025-03-13 07:45:33,740 - __main__ - INFO - 已處理 434000 個項目
# 2025-03-13 07:45:33,757 - __main__ - INFO - 已處理 435000 個項目
# 2025-03-13 07:45:33,773 - __main__ - INFO - 已處理 436000 個項目
# 2025-03-13 07:45:33,791 - __main__ - INFO - 已處理 437000 個項目
# 2025-03-13 07:45:33,812 - __main__ - INFO - 已處理 438000 個項目
# 2025-03-13 07:45:33,831 - __main__ - INFO - 已處理 439000 個項目
# 2025-03-13 07:45:33,851 - __main__ - INFO - 已處理 440000 個項目
# 2025-03-13 07:45:33,867 - __main__ - INFO - 已處理 441000 個項目
# 2025-03-13 07:45:33,884 - __main__ - INFO - 已處理 442000 個項目
# 2025-03-13 07:45:33,899 - __main__ - INFO - 已處理 443000 個項目
# 2025-03-13 07:45:33,916 - __main__ - INFO - 已處理 444000 個項目
# 2025-03-13 07:45:33,931 - __main__ - INFO - 已處理 445000 個項目
# 2025-03-13 07:45:33,948 - __main__ - INFO - 已處理 446000 個項目
# 2025-03-13 07:45:33,965 - __main__ - INFO - 已處理 447000 個項目
# 2025-03-13 07:45:33,982 - __main__ - INFO - 已處理 448000 個項目
# 2025-03-13 07:45:33,999 - __main__ - INFO - 已處理 449000 個項目
# 2025-03-13 07:45:34,016 - __main__ - INFO - 已處理 450000 個項目
# 2025-03-13 07:45:34,032 - __main__ - INFO - 已處理 451000 個項目
# 2025-03-13 07:45:34,048 - __main__ - INFO - 已處理 452000 個項目
# 2025-03-13 07:45:34,066 - __main__ - INFO - 已處理 453000 個項目
# 2025-03-13 07:45:34,082 - __main__ - INFO - 已處理 454000 個項目
# 2025-03-13 07:45:34,102 - __main__ - INFO - 已處理 455000 個項目
# 2025-03-13 07:45:34,120 - __main__ - INFO - 已處理 456000 個項目
# 2025-03-13 07:45:34,138 - __main__ - INFO - 已處理 457000 個項目
# 2025-03-13 07:45:34,157 - __main__ - INFO - 已處理 458000 個項目
# 2025-03-13 07:45:34,173 - __main__ - INFO - 已處理 459000 個項目
# 2025-03-13 07:45:34,193 - __main__ - INFO - 已處理 460000 個項目
# 2025-03-13 07:45:34,208 - __main__ - INFO - 已處理 461000 個項目
# 2025-03-13 07:45:34,223 - __main__ - INFO - 已處理 462000 個項目
# 2025-03-13 07:45:34,239 - __main__ - INFO - 已處理 463000 個項目
# 2025-03-13 07:45:34,257 - __main__ - INFO - 已處理 464000 個項目
# 2025-03-13 07:45:34,273 - __main__ - INFO - 已處理 465000 個項目
# 2025-03-13 07:45:34,290 - __main__ - INFO - 已處理 466000 個項目
# 2025-03-13 07:45:34,307 - __main__ - INFO - 已處理 467000 個項目
# 2025-03-13 07:45:34,325 - __main__ - INFO - 已處理 468000 個項目
# 2025-03-13 07:45:34,341 - __main__ - INFO - 已處理 469000 個項目
# 2025-03-13 07:45:34,358 - __main__ - INFO - 已處理 470000 個項目
# 2025-03-13 07:45:34,380 - __main__ - INFO - 已處理 471000 個項目
# 2025-03-13 07:45:34,398 - __main__ - INFO - 已處理 472000 個項目
# 2025-03-13 07:45:34,420 - __main__ - INFO - 已處理 473000 個項目
# 2025-03-13 07:45:34,439 - __main__ - INFO - 已處理 474000 個項目
# 2025-03-13 07:45:34,456 - __main__ - INFO - 已處理 475000 個項目
# 2025-03-13 07:45:34,474 - __main__ - INFO - 已處理 476000 個項目
# 2025-03-13 07:45:34,492 - __main__ - INFO - 已處理 477000 個項目
# 2025-03-13 07:45:34,509 - __main__ - INFO - 已處理 478000 個項目
# 2025-03-13 07:45:34,526 - __main__ - INFO - 已處理 479000 個項目
# 2025-03-13 07:45:34,545 - __main__ - INFO - 已處理 480000 個項目
# 2025-03-13 07:45:34,563 - __main__ - INFO - 已處理 481000 個項目
# 2025-03-13 07:45:34,580 - __main__ - INFO - 已處理 482000 個項目
# 2025-03-13 07:45:34,599 - __main__ - INFO - 已處理 483000 個項目
# 2025-03-13 07:45:34,616 - __main__ - INFO - 已處理 484000 個項目
# 2025-03-13 07:45:34,633 - __main__ - INFO - 已處理 485000 個項目
# 2025-03-13 07:45:34,650 - __main__ - INFO - 已處理 486000 個項目
# 2025-03-13 07:45:34,667 - __main__ - INFO - 已處理 487000 個項目
# 2025-03-13 07:45:34,684 - __main__ - INFO - 已處理 488000 個項目
# 2025-03-13 07:45:34,701 - __main__ - INFO - 已處理 489000 個項目
# 2025-03-13 07:45:34,719 - __main__ - INFO - 已處理 490000 個項目
# 2025-03-13 07:45:34,737 - __main__ - INFO - 已處理 491000 個項目
# 2025-03-13 07:45:34,755 - __main__ - INFO - 已處理 492000 個項目
# 2025-03-13 07:45:34,772 - __main__ - INFO - 已處理 493000 個項目
# 2025-03-13 07:45:34,790 - __main__ - INFO - 已處理 494000 個項目
# 2025-03-13 07:45:34,809 - __main__ - INFO - 已處理 495000 個項目
# 2025-03-13 07:45:34,828 - __main__ - INFO - 已處理 496000 個項目
# 2025-03-13 07:45:34,844 - __main__ - INFO - 已處理 497000 個項目
# 2025-03-13 07:45:34,868 - __main__ - INFO - 已處理 498000 個項目
# 2025-03-13 07:45:34,885 - __main__ - INFO - 已處理 499000 個項目
# 2025-03-13 07:45:34,903 - __main__ - INFO - 已處理 500000 個項目
# 2025-03-13 07:45:34,921 - __main__ - INFO - 已處理 501000 個項目
# 2025-03-13 07:45:34,939 - __main__ - INFO - 已處理 502000 個項目
# 2025-03-13 07:45:34,962 - __main__ - INFO - 已處理 503000 個項目
# 2025-03-13 07:45:35,017 - __main__ - INFO - 已處理 504000 個項目
# 2025-03-13 07:45:35,037 - __main__ - INFO - 已處理 505000 個項目
# 2025-03-13 07:45:35,054 - __main__ - INFO - 已處理 506000 個項目
# 2025-03-13 07:45:35,071 - __main__ - INFO - 已處理 507000 個項目
# 2025-03-13 07:45:35,089 - __main__ - INFO - 已處理 508000 個項目
# 2025-03-13 07:45:35,106 - __main__ - INFO - 已處理 509000 個項目
# 2025-03-13 07:45:35,123 - __main__ - INFO - 已處理 510000 個項目
# 2025-03-13 07:45:35,140 - __main__ - INFO - 已處理 511000 個項目
# 2025-03-13 07:45:35,157 - __main__ - INFO - 已處理 512000 個項目
# 2025-03-13 07:45:35,174 - __main__ - INFO - 已處理 513000 個項目
# 2025-03-13 07:45:35,190 - __main__ - INFO - 已處理 514000 個項目
# 2025-03-13 07:45:35,206 - __main__ - INFO - 已處理 515000 個項目
# 2025-03-13 07:45:35,223 - __main__ - INFO - 已處理 516000 個項目
# 2025-03-13 07:45:35,239 - __main__ - INFO - 已處理 517000 個項目
# 2025-03-13 07:45:35,255 - __main__ - INFO - 已處理 518000 個項目
# 2025-03-13 07:45:35,270 - __main__ - INFO - 已處理 519000 個項目
# 2025-03-13 07:45:35,286 - __main__ - INFO - 已處理 520000 個項目
# 2025-03-13 07:45:35,301 - __main__ - INFO - 已處理 521000 個項目
# 2025-03-13 07:45:35,317 - __main__ - INFO - 已處理 522000 個項目
# 2025-03-13 07:45:35,333 - __main__ - INFO - 已處理 523000 個項目
# 2025-03-13 07:45:35,348 - __main__ - INFO - 已處理 524000 個項目
# 2025-03-13 07:45:35,364 - __main__ - INFO - 已處理 525000 個項目
# 2025-03-13 07:45:35,380 - __main__ - INFO - 已處理 526000 個項目
# 2025-03-13 07:45:35,396 - __main__ - INFO - 已處理 527000 個項目
# 2025-03-13 07:45:35,412 - __main__ - INFO - 已處理 528000 個項目
# 2025-03-13 07:45:35,428 - __main__ - INFO - 已處理 529000 個項目
# 2025-03-13 07:45:35,444 - __main__ - INFO - 已處理 530000 個項目
# 2025-03-13 07:45:35,459 - __main__ - INFO - 已處理 531000 個項目
# 2025-03-13 07:45:35,475 - __main__ - INFO - 已處理 532000 個項目
# 2025-03-13 07:45:35,491 - __main__ - INFO - 已處理 533000 個項目
# 2025-03-13 07:45:35,508 - __main__ - INFO - 已處理 534000 個項目
# 2025-03-13 07:45:35,524 - __main__ - INFO - 已處理 535000 個項目
# 2025-03-13 07:45:35,541 - __main__ - INFO - 已處理 536000 個項目
# 2025-03-13 07:45:35,558 - __main__ - INFO - 已處理 537000 個項目
# 2025-03-13 07:45:35,573 - __main__ - INFO - 已處理 538000 個項目
# 2025-03-13 07:45:35,590 - __main__ - INFO - 已處理 539000 個項目
# 2025-03-13 07:45:35,606 - __main__ - INFO - 已處理 540000 個項目
# 2025-03-13 07:45:35,622 - __main__ - INFO - 已處理 541000 個項目
# 2025-03-13 07:45:35,638 - __main__ - INFO - 已處理 542000 個項目
# 2025-03-13 07:45:35,655 - __main__ - INFO - 已處理 543000 個項目
# 2025-03-13 07:45:35,671 - __main__ - INFO - 已處理 544000 個項目
# 2025-03-13 07:45:35,687 - __main__ - INFO - 已處理 545000 個項目
# 2025-03-13 07:45:35,703 - __main__ - INFO - 已處理 546000 個項目
# 2025-03-13 07:45:35,719 - __main__ - INFO - 已處理 547000 個項目
# 2025-03-13 07:45:35,734 - __main__ - INFO - 已處理 548000 個項目
# 2025-03-13 07:45:35,751 - __main__ - INFO - 已處理 549000 個項目
# 2025-03-13 07:45:35,767 - __main__ - INFO - 已處理 550000 個項目
# 2025-03-13 07:45:35,783 - __main__ - INFO - 已處理 551000 個項目
# 2025-03-13 07:45:35,798 - __main__ - INFO - 已處理 552000 個項目
# 2025-03-13 07:45:35,813 - __main__ - INFO - 已處理 553000 個項目
# 2025-03-13 07:45:35,829 - __main__ - INFO - 已處理 554000 個項目
# 2025-03-13 07:45:35,844 - __main__ - INFO - 已處理 555000 個項目
# 2025-03-13 07:45:35,860 - __main__ - INFO - 已處理 556000 個項目
# 2025-03-13 07:45:35,876 - __main__ - INFO - 已處理 557000 個項目
# 2025-03-13 07:45:35,893 - __main__ - INFO - 已處理 558000 個項目
# 2025-03-13 07:45:35,909 - __main__ - INFO - 已處理 559000 個項目
# 2025-03-13 07:45:35,925 - __main__ - INFO - 已處理 560000 個項目
# 2025-03-13 07:45:35,941 - __main__ - INFO - 已處理 561000 個項目
# 2025-03-13 07:45:35,956 - __main__ - INFO - 已處理 562000 個項目
# 2025-03-13 07:45:35,974 - __main__ - INFO - 已處理 563000 個項目
# 2025-03-13 07:45:35,990 - __main__ - INFO - 已處理 564000 個項目
# 2025-03-13 07:45:36,007 - __main__ - INFO - 已處理 565000 個項目
# 2025-03-13 07:45:36,024 - __main__ - INFO - 已處理 566000 個項目
# 2025-03-13 07:45:36,040 - __main__ - INFO - 已處理 567000 個項目
# 2025-03-13 07:45:36,056 - __main__ - INFO - 已處理 568000 個項目
# 2025-03-13 07:45:36,074 - __main__ - INFO - 已處理 569000 個項目
# 2025-03-13 07:45:36,090 - __main__ - INFO - 已處理 570000 個項目
# 2025-03-13 07:45:36,105 - __main__ - INFO - 已處理 571000 個項目
# 2025-03-13 07:45:36,121 - __main__ - INFO - 已處理 572000 個項目
# 2025-03-13 07:45:36,139 - __main__ - INFO - 已處理 573000 個項目
# 2025-03-13 07:45:36,155 - __main__ - INFO - 已處理 574000 個項目
# 2025-03-13 07:45:36,173 - __main__ - INFO - 已處理 575000 個項目
# 2025-03-13 07:45:36,190 - __main__ - INFO - 已處理 576000 個項目
# 2025-03-13 07:45:36,207 - __main__ - INFO - 已處理 577000 個項目
# 2025-03-13 07:45:36,224 - __main__ - INFO - 已處理 578000 個項目
# 2025-03-13 07:45:36,240 - __main__ - INFO - 已處理 579000 個項目
# 2025-03-13 07:45:36,256 - __main__ - INFO - 已處理 580000 個項目
# 2025-03-13 07:45:36,273 - __main__ - INFO - 已處理 581000 個項目
# 2025-03-13 07:45:36,289 - __main__ - INFO - 已處理 582000 個項目
# 2025-03-13 07:45:36,305 - __main__ - INFO - 已處理 583000 個項目
# 2025-03-13 07:45:36,321 - __main__ - INFO - 已處理 584000 個項目
# 2025-03-13 07:45:36,337 - __main__ - INFO - 已處理 585000 個項目
# 2025-03-13 07:45:36,354 - __main__ - INFO - 已處理 586000 個項目
# 2025-03-13 07:45:36,370 - __main__ - INFO - 已處理 587000 個項目
# 2025-03-13 07:45:36,387 - __main__ - INFO - 已處理 588000 個項目
# 2025-03-13 07:45:36,403 - __main__ - INFO - 已處理 589000 個項目
# 2025-03-13 07:45:36,420 - __main__ - INFO - 已處理 590000 個項目
# 2025-03-13 07:45:36,437 - __main__ - INFO - 已處理 591000 個項目
# 2025-03-13 07:45:36,453 - __main__ - INFO - 已處理 592000 個項目
# 2025-03-13 07:45:36,470 - __main__ - INFO - 已處理 593000 個項目
# 2025-03-13 07:45:36,486 - __main__ - INFO - 已處理 594000 個項目
# 2025-03-13 07:45:36,503 - __main__ - INFO - 已處理 595000 個項目
# 2025-03-13 07:45:36,520 - __main__ - INFO - 已處理 596000 個項目
# 2025-03-13 07:45:36,536 - __main__ - INFO - 已處理 597000 個項目
# 2025-03-13 07:45:36,553 - __main__ - INFO - 已處理 598000 個項目
# 2025-03-13 07:45:36,570 - __main__ - INFO - 已處理 599000 個項目
# 2025-03-13 07:45:36,585 - __main__ - INFO - 已處理 600000 個項目
# 2025-03-13 07:45:36,601 - __main__ - INFO - 已處理 601000 個項目
# 2025-03-13 07:45:36,619 - __main__ - INFO - 已處理 602000 個項目
# 2025-03-13 07:45:36,634 - __main__ - INFO - 已處理 603000 個項目
# 2025-03-13 07:45:36,651 - __main__ - INFO - 已處理 604000 個項目
# 2025-03-13 07:45:36,666 - __main__ - INFO - 已處理 605000 個項目
# 2025-03-13 07:45:36,683 - __main__ - INFO - 已處理 606000 個項目
# 2025-03-13 07:45:36,699 - __main__ - INFO - 已處理 607000 個項目
# 2025-03-13 07:45:36,714 - __main__ - INFO - 已處理 608000 個項目
# 2025-03-13 07:45:36,731 - __main__ - INFO - 已處理 609000 個項目
# 2025-03-13 07:45:36,747 - __main__ - INFO - 已處理 610000 個項目
# 2025-03-13 07:45:36,763 - __main__ - INFO - 已處理 611000 個項目
# 2025-03-13 07:45:36,779 - __main__ - INFO - 已處理 612000 個項目
# 2025-03-13 07:45:36,795 - __main__ - INFO - 已處理 613000 個項目
# 2025-03-13 07:45:36,810 - __main__ - INFO - 已處理 614000 個項目
# 2025-03-13 07:45:36,826 - __main__ - INFO - 已處理 615000 個項目
# 2025-03-13 07:45:36,846 - __main__ - INFO - 已處理 616000 個項目
# 2025-03-13 07:45:36,864 - __main__ - INFO - 已處理 617000 個項目
# 2025-03-13 07:45:36,879 - __main__ - INFO - 已處理 618000 個項目
# 2025-03-13 07:45:36,895 - __main__ - INFO - 已處理 619000 個項目
# 2025-03-13 07:45:36,912 - __main__ - INFO - 已處理 620000 個項目
# 2025-03-13 07:45:36,929 - __main__ - INFO - 已處理 621000 個項目
# 2025-03-13 07:45:36,945 - __main__ - INFO - 已處理 622000 個項目
# 2025-03-13 07:45:36,962 - __main__ - INFO - 已處理 623000 個項目
# 2025-03-13 07:45:36,977 - __main__ - INFO - 已處理 624000 個項目
# 2025-03-13 07:45:36,994 - __main__ - INFO - 已處理 625000 個項目
# 2025-03-13 07:45:37,010 - __main__ - INFO - 已處理 626000 個項目
# 2025-03-13 07:45:37,028 - __main__ - INFO - 已處理 627000 個項目
# 2025-03-13 07:45:37,043 - __main__ - INFO - 已處理 628000 個項目
# 2025-03-13 07:45:37,059 - __main__ - INFO - 已處理 629000 個項目
# 2025-03-13 07:45:37,076 - __main__ - INFO - 已處理 630000 個項目
# 2025-03-13 07:45:37,091 - __main__ - INFO - 已處理 631000 個項目
# 2025-03-13 07:45:37,109 - __main__ - INFO - 已處理 632000 個項目
# 2025-03-13 07:45:37,126 - __main__ - INFO - 已處理 633000 個項目
# 2025-03-13 07:45:37,144 - __main__ - INFO - 已處理 634000 個項目
# 2025-03-13 07:45:37,193 - __main__ - INFO - 已處理 635000 個項目
# 2025-03-13 07:45:37,212 - __main__ - INFO - 已處理 636000 個項目
# 2025-03-13 07:45:37,227 - __main__ - INFO - 已處理 637000 個項目
# 2025-03-13 07:45:37,243 - __main__ - INFO - 已處理 638000 個項目
# 2025-03-13 07:45:37,260 - __main__ - INFO - 已處理 639000 個項目
# 2025-03-13 07:45:37,277 - __main__ - INFO - 已處理 640000 個項目
# 2025-03-13 07:45:37,293 - __main__ - INFO - 已處理 641000 個項目
# 2025-03-13 07:45:37,309 - __main__ - INFO - 已處理 642000 個項目
# 2025-03-13 07:45:37,325 - __main__ - INFO - 已處理 643000 個項目
# 2025-03-13 07:45:37,340 - __main__ - INFO - 已處理 644000 個項目
# 2025-03-13 07:45:37,358 - __main__ - INFO - 已處理 645000 個項目
# 2025-03-13 07:45:37,375 - __main__ - INFO - 已處理 646000 個項目
# 2025-03-13 07:45:37,391 - __main__ - INFO - 已處理 647000 個項目
# 2025-03-13 07:45:37,409 - __main__ - INFO - 已處理 648000 個項目
# 2025-03-13 07:45:37,426 - __main__ - INFO - 已處理 649000 個項目
# 2025-03-13 07:45:37,442 - __main__ - INFO - 已處理 650000 個項目
# 2025-03-13 07:45:37,458 - __main__ - INFO - 已處理 651000 個項目
# 2025-03-13 07:45:37,475 - __main__ - INFO - 已處理 652000 個項目
# 2025-03-13 07:45:37,492 - __main__ - INFO - 已處理 653000 個項目
# 2025-03-13 07:45:37,508 - __main__ - INFO - 已處理 654000 個項目
# 2025-03-13 07:45:37,524 - __main__ - INFO - 已處理 655000 個項目
# 2025-03-13 07:45:37,541 - __main__ - INFO - 已處理 656000 個項目
# 2025-03-13 07:45:37,557 - __main__ - INFO - 已處理 657000 個項目
# 2025-03-13 07:45:37,574 - __main__ - INFO - 已處理 658000 個項目
# 2025-03-13 07:45:37,592 - __main__ - INFO - 已處理 659000 個項目
# 2025-03-13 07:45:37,611 - __main__ - INFO - 已處理 660000 個項目
# 2025-03-13 07:45:37,627 - __main__ - INFO - 已處理 661000 個項目
# 2025-03-13 07:45:37,644 - __main__ - INFO - 已處理 662000 個項目
# 2025-03-13 07:45:37,660 - __main__ - INFO - 已處理 663000 個項目
# 2025-03-13 07:45:37,677 - __main__ - INFO - 已處理 664000 個項目
# 2025-03-13 07:45:37,694 - __main__ - INFO - 已處理 665000 個項目
# 2025-03-13 07:45:37,711 - __main__ - INFO - 已處理 666000 個項目
# 2025-03-13 07:45:37,727 - __main__ - INFO - 已處理 667000 個項目
# 2025-03-13 07:45:37,744 - __main__ - INFO - 已處理 668000 個項目
# 2025-03-13 07:45:37,760 - __main__ - INFO - 已處理 669000 個項目
# 2025-03-13 07:45:37,776 - __main__ - INFO - 已處理 670000 個項目
# 2025-03-13 07:45:37,794 - __main__ - INFO - 已處理 671000 個項目
# 2025-03-13 07:45:37,812 - __main__ - INFO - 已處理 672000 個項目
# 2025-03-13 07:45:37,831 - __main__ - INFO - 已處理 673000 個項目
# 2025-03-13 07:45:37,848 - __main__ - INFO - 已處理 674000 個項目
# 2025-03-13 07:45:37,863 - __main__ - INFO - 已處理 675000 個項目
# 2025-03-13 07:45:37,879 - __main__ - INFO - 已處理 676000 個項目
# 2025-03-13 07:45:37,894 - __main__ - INFO - 已處理 677000 個項目
# 2025-03-13 07:45:37,910 - __main__ - INFO - 已處理 678000 個項目
# 2025-03-13 07:45:37,925 - __main__ - INFO - 已處理 679000 個項目
# 2025-03-13 07:45:37,941 - __main__ - INFO - 已處理 680000 個項目
# 2025-03-13 07:45:37,959 - __main__ - INFO - 已處理 681000 個項目
# 2025-03-13 07:45:37,975 - __main__ - INFO - 已處理 682000 個項目
# 2025-03-13 07:45:37,990 - __main__ - INFO - 已處理 683000 個項目
# 2025-03-13 07:45:38,009 - __main__ - INFO - 已處理 684000 個項目
# 2025-03-13 07:45:38,026 - __main__ - INFO - 已處理 685000 個項目
# 2025-03-13 07:45:38,042 - __main__ - INFO - 已處理 686000 個項目
# 2025-03-13 07:45:38,057 - __main__ - INFO - 已處理 687000 個項目
# 2025-03-13 07:45:38,073 - __main__ - INFO - 已處理 688000 個項目
# 2025-03-13 07:45:38,089 - __main__ - INFO - 已處理 689000 個項目
# 2025-03-13 07:45:38,105 - __main__ - INFO - 已處理 690000 個項目
# 2025-03-13 07:45:38,122 - __main__ - INFO - 已處理 691000 個項目
# 2025-03-13 07:45:38,138 - __main__ - INFO - 已處理 692000 個項目
# 2025-03-13 07:45:38,155 - __main__ - INFO - 已處理 693000 個項目
# 2025-03-13 07:45:38,171 - __main__ - INFO - 已處理 694000 個項目
# 2025-03-13 07:45:38,188 - __main__ - INFO - 已處理 695000 個項目
# 2025-03-13 07:45:38,205 - __main__ - INFO - 已處理 696000 個項目
# 2025-03-13 07:45:38,222 - __main__ - INFO - 已處理 697000 個項目
# 2025-03-13 07:45:38,239 - __main__ - INFO - 已處理 698000 個項目
# 2025-03-13 07:45:38,255 - __main__ - INFO - 已處理 699000 個項目
# 2025-03-13 07:45:38,271 - __main__ - INFO - 已處理 700000 個項目
# 2025-03-13 07:45:38,284 - __main__ - INFO - 已處理 701000 個項目
# 2025-03-13 07:45:38,300 - __main__ - INFO - 已處理 702000 個項目
# 2025-03-13 07:45:38,317 - __main__ - INFO - 已處理 703000 個項目
# 2025-03-13 07:45:38,332 - __main__ - INFO - 已處理 704000 個項目
# 2025-03-13 07:45:38,348 - __main__ - INFO - 已處理 705000 個項目
# 2025-03-13 07:45:38,365 - __main__ - INFO - 已處理 706000 個項目
# 2025-03-13 07:45:38,383 - __main__ - INFO - 已處理 707000 個項目
# 2025-03-13 07:45:38,401 - __main__ - INFO - 已處理 708000 個項目
# 2025-03-13 07:45:38,420 - __main__ - INFO - 已處理 709000 個項目
# 2025-03-13 07:45:38,437 - __main__ - INFO - 已處理 710000 個項目
# 2025-03-13 07:45:38,454 - __main__ - INFO - 已處理 711000 個項目
# 2025-03-13 07:45:38,471 - __main__ - INFO - 已處理 712000 個項目
# 2025-03-13 07:45:38,488 - __main__ - INFO - 已處理 713000 個項目
# 2025-03-13 07:45:38,508 - __main__ - INFO - 已處理 714000 個項目
# 2025-03-13 07:45:38,525 - __main__ - INFO - 已處理 715000 個項目
# 2025-03-13 07:45:38,542 - __main__ - INFO - 已處理 716000 個項目
# 2025-03-13 07:45:38,560 - __main__ - INFO - 已處理 717000 個項目
# 2025-03-13 07:45:38,579 - __main__ - INFO - 已處理 718000 個項目
# 2025-03-13 07:45:38,596 - __main__ - INFO - 已處理 719000 個項目
# 2025-03-13 07:45:38,613 - __main__ - INFO - 已處理 720000 個項目
# 2025-03-13 07:45:38,630 - __main__ - INFO - 已處理 721000 個項目
# 2025-03-13 07:45:38,646 - __main__ - INFO - 已處理 722000 個項目
# 2025-03-13 07:45:38,664 - __main__ - INFO - 已處理 723000 個項目
# 2025-03-13 07:45:38,680 - __main__ - INFO - 已處理 724000 個項目
# 2025-03-13 07:45:38,698 - __main__ - INFO - 已處理 725000 個項目
# 2025-03-13 07:45:38,716 - __main__ - INFO - 已處理 726000 個項目
# 2025-03-13 07:45:38,732 - __main__ - INFO - 已處理 727000 個項目
# 2025-03-13 07:45:38,749 - __main__ - INFO - 已處理 728000 個項目
# 2025-03-13 07:45:38,766 - __main__ - INFO - 已處理 729000 個項目
# 2025-03-13 07:45:38,782 - __main__ - INFO - 已處理 730000 個項目
# 2025-03-13 07:45:38,800 - __main__ - INFO - 已處理 731000 個項目
# 2025-03-13 07:45:38,817 - __main__ - INFO - 已處理 732000 個項目
# 2025-03-13 07:45:38,834 - __main__ - INFO - 已處理 733000 個項目
# 2025-03-13 07:45:38,853 - __main__ - INFO - 已處理 734000 個項目
# 2025-03-13 07:45:38,870 - __main__ - INFO - 已處理 735000 個項目
# 2025-03-13 07:45:38,886 - __main__ - INFO - 已處理 736000 個項目
# 2025-03-13 07:45:38,904 - __main__ - INFO - 已處理 737000 個項目
# 2025-03-13 07:45:38,922 - __main__ - INFO - 已處理 738000 個項目
# 2025-03-13 07:45:38,939 - __main__ - INFO - 已處理 739000 個項目
# 2025-03-13 07:45:38,956 - __main__ - INFO - 已處理 740000 個項目
# 2025-03-13 07:45:38,972 - __main__ - INFO - 已處理 741000 個項目
# 2025-03-13 07:45:38,991 - __main__ - INFO - 已處理 742000 個項目
# 2025-03-13 07:45:39,008 - __main__ - INFO - 已處理 743000 個項目
# 2025-03-13 07:45:39,026 - __main__ - INFO - 已處理 744000 個項目
# 2025-03-13 07:45:39,074 - __main__ - INFO - 已處理 745000 個項目
# 2025-03-13 07:45:39,096 - __main__ - INFO - 已處理 746000 個項目
# 2025-03-13 07:45:39,113 - __main__ - INFO - 已處理 747000 個項目
# 2025-03-13 07:45:39,130 - __main__ - INFO - 已處理 748000 個項目
# 2025-03-13 07:45:39,147 - __main__ - INFO - 已處理 749000 個項目
# 2025-03-13 07:45:39,164 - __main__ - INFO - 已處理 750000 個項目
# 2025-03-13 07:45:39,181 - __main__ - INFO - 已處理 751000 個項目
# 2025-03-13 07:45:39,199 - __main__ - INFO - 已處理 752000 個項目
# 2025-03-13 07:45:39,216 - __main__ - INFO - 已處理 753000 個項目
# 2025-03-13 07:45:39,233 - __main__ - INFO - 已處理 754000 個項目
# 2025-03-13 07:45:39,251 - __main__ - INFO - 已處理 755000 個項目
# 2025-03-13 07:45:39,268 - __main__ - INFO - 已處理 756000 個項目
# 2025-03-13 07:45:39,285 - __main__ - INFO - 已處理 757000 個項目
# 2025-03-13 07:45:39,301 - __main__ - INFO - 已處理 758000 個項目
# 2025-03-13 07:45:39,318 - __main__ - INFO - 已處理 759000 個項目
# 2025-03-13 07:45:39,336 - __main__ - INFO - 已處理 760000 個項目
# 2025-03-13 07:45:39,353 - __main__ - INFO - 已處理 761000 個項目
# 2025-03-13 07:45:39,370 - __main__ - INFO - 已處理 762000 個項目
# 2025-03-13 07:45:39,388 - __main__ - INFO - 已處理 763000 個項目
# 2025-03-13 07:45:39,404 - __main__ - INFO - 已處理 764000 個項目
# 2025-03-13 07:45:39,420 - __main__ - INFO - 已處理 765000 個項目
# 2025-03-13 07:45:39,438 - __main__ - INFO - 已處理 766000 個項目
# 2025-03-13 07:45:39,454 - __main__ - INFO - 已處理 767000 個項目
# 2025-03-13 07:45:39,470 - __main__ - INFO - 已處理 768000 個項目
# 2025-03-13 07:45:39,485 - __main__ - INFO - 已處理 769000 個項目
# 2025-03-13 07:45:39,501 - __main__ - INFO - 已處理 770000 個項目
# 2025-03-13 07:45:39,517 - __main__ - INFO - 已處理 771000 個項目
# 2025-03-13 07:45:39,532 - __main__ - INFO - 已處理 772000 個項目
# 2025-03-13 07:45:39,548 - __main__ - INFO - 已處理 773000 個項目
# 2025-03-13 07:45:39,563 - __main__ - INFO - 已處理 774000 個項目
# 2025-03-13 07:45:39,580 - __main__ - INFO - 已處理 775000 個項目
# 2025-03-13 07:45:39,596 - __main__ - INFO - 已處理 776000 個項目
# 2025-03-13 07:45:39,614 - __main__ - INFO - 已處理 777000 個項目
# 2025-03-13 07:45:39,629 - __main__ - INFO - 已處理 778000 個項目
# 2025-03-13 07:45:39,646 - __main__ - INFO - 已處理 779000 個項目
# 2025-03-13 07:45:39,662 - __main__ - INFO - 已處理 780000 個項目
# 2025-03-13 07:45:39,679 - __main__ - INFO - 已處理 781000 個項目
# 2025-03-13 07:45:39,695 - __main__ - INFO - 已處理 782000 個項目
# 2025-03-13 07:45:39,712 - __main__ - INFO - 已處理 783000 個項目
# 2025-03-13 07:45:39,729 - __main__ - INFO - 已處理 784000 個項目
# 2025-03-13 07:45:39,747 - __main__ - INFO - 已處理 785000 個項目
# 2025-03-13 07:45:39,762 - __main__ - INFO - 已處理 786000 個項目
# 2025-03-13 07:45:39,779 - __main__ - INFO - 已處理 787000 個項目
# 2025-03-13 07:45:39,795 - __main__ - INFO - 已處理 788000 個項目
# 2025-03-13 07:45:39,812 - __main__ - INFO - 已處理 789000 個項目
# 2025-03-13 07:45:39,828 - __main__ - INFO - 已處理 790000 個項目
# 2025-03-13 07:45:39,846 - __main__ - INFO - 已處理 791000 個項目
# 2025-03-13 07:45:39,866 - __main__ - INFO - 已處理 792000 個項目
# 2025-03-13 07:45:39,887 - __main__ - INFO - 已處理 793000 個項目
# 2025-03-13 07:45:39,907 - __main__ - INFO - 已處理 794000 個項目
# 2025-03-13 07:45:39,925 - __main__ - INFO - 已處理 795000 個項目
# 2025-03-13 07:45:39,943 - __main__ - INFO - 已處理 796000 個項目
# 2025-03-13 07:45:39,959 - __main__ - INFO - 已處理 797000 個項目
# 2025-03-13 07:45:39,975 - __main__ - INFO - 已處理 798000 個項目
# 2025-03-13 07:45:39,993 - __main__ - INFO - 已處理 799000 個項目
# 2025-03-13 07:45:40,012 - __main__ - INFO - 已處理 800000 個項目
# 2025-03-13 07:45:40,030 - __main__ - INFO - 已處理 801000 個項目
# 2025-03-13 07:45:40,047 - __main__ - INFO - 已處理 802000 個項目
# 2025-03-13 07:45:40,063 - __main__ - INFO - 已處理 803000 個項目
# 2025-03-13 07:45:40,080 - __main__ - INFO - 已處理 804000 個項目
# 2025-03-13 07:45:40,097 - __main__ - INFO - 已處理 805000 個項目
# 2025-03-13 07:45:40,116 - __main__ - INFO - 已處理 806000 個項目
# 2025-03-13 07:45:40,134 - __main__ - INFO - 已處理 807000 個項目
# 2025-03-13 07:45:40,152 - __main__ - INFO - 已處理 808000 個項目
# 2025-03-13 07:45:40,168 - __main__ - INFO - 已處理 809000 個項目
# 2025-03-13 07:45:40,184 - __main__ - INFO - 已處理 810000 個項目
# 2025-03-13 07:45:40,206 - __main__ - INFO - 已處理 811000 個項目
# 2025-03-13 07:45:40,223 - __main__ - INFO - 已處理 812000 個項目
# ...
# 2025-03-13 07:45:45,890 - __main__ - INFO - 已處理 1119000 個項目
# 2025-03-13 07:45:45,908 - __main__ - INFO - 已處理 1120000 個項目
# 2025-03-13 07:45:45,927 - __main__ - INFO - 已處理 1121000 個項目
# 2025-03-13 07:45:45,945 - __main__ - INFO - 已處理 1122000 個項目
# 2025-03-13 07:45:45,963 - __main__ - INFO - 已處理 1123000 個項目
# 2025-03-13 07:45:45,981 - __main__ - INFO - 已處理 1124000 個項目
# 2025-03-13 07:45:45,998 - __main__ - INFO - 已處理 1125000 個項目
# 2025-03-13 07:45:46,019 - __main__ - INFO - 已處理 1126000 個項目
# 2025-03-13 07:45:46,038 - __main__ - INFO - 已處理 1127000 個項目
# 2025-03-13 07:45:46,055 - __main__ - INFO - 已處理 1128000 個項目
# 2025-03-13 07:45:46,071 - __main__ - INFO - 已處理 1129000 個項目
# 2025-03-13 07:45:46,088 - __main__ - INFO - 已處理 1130000 個項目
# 2025-03-13 07:45:46,106 - __main__ - INFO - 已處理 1131000 個項目
# 2025-03-13 07:45:46,125 - __main__ - INFO - 已處理 1132000 個項目
# 2025-03-13 07:45:46,143 - __main__ - INFO - 已處理 1133000 個項目
# 2025-03-13 07:45:46,161 - __main__ - INFO - 已處理 1134000 個項目
# 2025-03-13 07:45:46,179 - __main__ - INFO - 已處理 1135000 個項目
# 2025-03-13 07:45:46,196 - __main__ - INFO - 已處理 1136000 個項目
# 2025-03-13 07:45:46,214 - __main__ - INFO - 已處理 1137000 個項目
# 2025-03-13 07:45:46,231 - __main__ - INFO - 已處理 1138000 個項目
# 2025-03-13 07:45:46,249 - __main__ - INFO - 已處理 1139000 個項目
# 2025-03-13 07:45:46,266 - __main__ - INFO - 已處理 1140000 個項目
# 2025-03-13 07:45:46,283 - __main__ - INFO - 已處理 1141000 個項目
# 2025-03-13 07:45:46,300 - __main__ - INFO - 已處理 1142000 個項目
# 2025-03-13 07:45:46,316 - __main__ - INFO - 已處理 1143000 個項目
# 2025-03-13 07:45:46,333 - __main__ - INFO - 已處理 1144000 個項目
# 2025-03-13 07:45:46,351 - __main__ - INFO - 已處理 1145000 個項目
# 2025-03-13 07:45:46,369 - __main__ - INFO - 已處理 1146000 個項目
# 2025-03-13 07:45:46,388 - __main__ - INFO - 已處理 1147000 個項目
# 2025-03-13 07:45:46,407 - __main__ - INFO - 已處理 1148000 個項目
# 2025-03-13 07:45:46,424 - __main__ - INFO - 已處理 1149000 個項目
# 2025-03-13 07:45:46,441 - __main__ - INFO - 已處理 1150000 個項目
# 2025-03-13 07:45:46,458 - __main__ - INFO - 已處理 1151000 個項目
# 2025-03-13 07:45:46,475 - __main__ - INFO - 已處理 1152000 個項目
# 2025-03-13 07:45:46,488 - __main__ - INFO - 已處理 1153000 個項目
# 2025-03-13 07:45:46,504 - __main__ - INFO - 已處理 1154000 個項目
# 2025-03-13 07:45:46,522 - __main__ - INFO - 已處理 1155000 個項目
# 2025-03-13 07:45:46,539 - __main__ - INFO - 已處理 1156000 個項目
# 2025-03-13 07:45:46,556 - __main__ - INFO - 已處理 1157000 個項目
# 2025-03-13 07:45:46,573 - __main__ - INFO - 已處理 1158000 個項目
# 2025-03-13 07:45:46,590 - __main__ - INFO - 已處理 1159000 個項目
# 2025-03-13 07:45:46,607 - __main__ - INFO - 已處理 1160000 個項目
# 2025-03-13 07:45:46,625 - __main__ - INFO - 已處理 1161000 個項目
# 2025-03-13 07:45:46,644 - __main__ - INFO - 已處理 1162000 個項目
# 2025-03-13 07:45:46,661 - __main__ - INFO - 已處理 1163000 個項目
# 2025-03-13 07:45:46,679 - __main__ - INFO - 已處理 1164000 個項目
# 2025-03-13 07:45:46,694 - __main__ - INFO - 已處理 1165000 個項目
# 2025-03-13 07:45:46,710 - __main__ - INFO - 已處理 1166000 個項目
# 2025-03-13 07:45:46,726 - __main__ - INFO - 已處理 1167000 個項目
# 2025-03-13 07:45:46,743 - __main__ - INFO - 已處理 1168000 個項目
# 2025-03-13 07:45:46,762 - __main__ - INFO - 已處理 1169000 個項目
# 2025-03-13 07:45:46,784 - __main__ - INFO - 已處理 1170000 個項目
# 2025-03-13 07:45:46,832 - __main__ - INFO - 已處理 1171000 個項目
# 2025-03-13 07:45:46,852 - __main__ - INFO - 已處理 1172000 個項目
# 2025-03-13 07:45:46,868 - __main__ - INFO - 已處理 1173000 個項目
# 2025-03-13 07:45:46,885 - __main__ - INFO - 已處理 1174000 個項目
# 2025-03-13 07:45:46,901 - __main__ - INFO - 已處理 1175000 個項目
# 2025-03-13 07:45:46,917 - __main__ - INFO - 已處理 1176000 個項目
# 2025-03-13 07:45:46,935 - __main__ - INFO - 已處理 1177000 個項目
# 2025-03-13 07:45:46,953 - __main__ - INFO - 已處理 1178000 個項目
# 2025-03-13 07:45:46,971 - __main__ - INFO - 已處理 1179000 個項目
# 2025-03-13 07:45:46,991 - __main__ - INFO - 已處理 1180000 個項目
# 2025-03-13 07:45:47,008 - __main__ - INFO - 已處理 1181000 個項目
# 2025-03-13 07:45:47,024 - __main__ - INFO - 已處理 1182000 個項目
# 2025-03-13 07:45:47,041 - __main__ - INFO - 已處理 1183000 個項目
# 2025-03-13 07:45:47,058 - __main__ - INFO - 已處理 1184000 個項目
# 2025-03-13 07:45:47,074 - __main__ - INFO - 已處理 1185000 個項目
# 2025-03-13 07:45:47,091 - __main__ - INFO - 已處理 1186000 個項目
# 2025-03-13 07:45:47,108 - __main__ - INFO - 已處理 1187000 個項目
# 2025-03-13 07:45:47,126 - __main__ - INFO - 已處理 1188000 個項目
# 2025-03-13 07:45:47,143 - __main__ - INFO - 已處理 1189000 個項目
# 2025-03-13 07:45:47,160 - __main__ - INFO - 已處理 1190000 個項目
# 2025-03-13 07:45:47,179 - __main__ - INFO - 已處理 1191000 個項目
# 2025-03-13 07:45:47,197 - __main__ - INFO - 已處理 1192000 個項目
# 2025-03-13 07:45:47,214 - __main__ - INFO - 已處理 1193000 個項目
# 2025-03-13 07:45:47,233 - __main__ - INFO - 已處理 1194000 個項目
# 2025-03-13 07:45:47,251 - __main__ - INFO - 已處理 1195000 個項目
# 2025-03-13 07:45:47,267 - __main__ - INFO - 已處理 1196000 個項目
# 2025-03-13 07:45:47,285 - __main__ - INFO - 已處理 1197000 個項目
# 2025-03-13 07:45:47,302 - __main__ - INFO - 已處理 1198000 個項目
# 2025-03-13 07:45:47,318 - __main__ - INFO - 已處理 1199000 個項目
# 2025-03-13 07:45:47,337 - __main__ - INFO - 已處理 1200000 個項目
# 2025-03-13 07:45:47,356 - __main__ - INFO - 已處理 1201000 個項目
# 2025-03-13 07:45:47,373 - __main__ - INFO - 已處理 1202000 個項目
# 2025-03-13 07:45:47,390 - __main__ - INFO - 已處理 1203000 個項目
# 2025-03-13 07:45:47,407 - __main__ - INFO - 已處理 1204000 個項目
# 2025-03-13 07:45:47,424 - __main__ - INFO - 已處理 1205000 個項目
# 2025-03-13 07:45:47,441 - __main__ - INFO - 已處理 1206000 個項目
# 2025-03-13 07:45:47,458 - __main__ - INFO - 已處理 1207000 個項目
# 2025-03-13 07:45:47,475 - __main__ - INFO - 已處理 1208000 個項目
# 2025-03-13 07:45:47,491 - __main__ - INFO - 已處理 1209000 個項目
# 2025-03-13 07:45:47,508 - __main__ - INFO - 已處理 1210000 個項目
# 2025-03-13 07:45:47,525 - __main__ - INFO - 已處理 1211000 個項目
# 2025-03-13 07:45:47,542 - __main__ - INFO - 已處理 1212000 個項目
# 2025-03-13 07:45:47,558 - __main__ - INFO - 已處理 1213000 個項目
# 2025-03-13 07:45:47,575 - __main__ - INFO - 已處理 1214000 個項目
# 2025-03-13 07:45:47,594 - __main__ - INFO - 已處理 1215000 個項目
# 2025-03-13 07:45:47,610 - __main__ - INFO - 已處理 1216000 個項目
# 2025-03-13 07:45:47,627 - __main__ - INFO - 已處理 1217000 個項目
# 2025-03-13 07:45:47,644 - __main__ - INFO - 已處理 1218000 個項目
# 2025-03-13 07:45:47,662 - __main__ - INFO - 已處理 1219000 個項目
# 2025-03-13 07:45:47,680 - __main__ - INFO - 已處理 1220000 個項目
# 2025-03-13 07:45:47,698 - __main__ - INFO - 已處理 1221000 個項目
# 2025-03-13 07:45:47,716 - __main__ - INFO - 已處理 1222000 個項目
# 2025-03-13 07:45:47,735 - __main__ - INFO - 已處理 1223000 個項目
# 2025-03-13 07:45:47,751 - __main__ - INFO - 已處理 1224000 個項目
# 2025-03-13 07:45:47,769 - __main__ - INFO - 已處理 1225000 個項目
# 2025-03-13 07:45:47,785 - __main__ - INFO - 已處理 1226000 個項目
# 2025-03-13 07:45:47,801 - __main__ - INFO - 已處理 1227000 個項目
# 2025-03-13 07:45:47,819 - __main__ - INFO - 已處理 1228000 個項目
# 2025-03-13 07:45:47,835 - __main__ - INFO - 已處理 1229000 個項目
# 2025-03-13 07:45:47,852 - __main__ - INFO - 已處理 1230000 個項目
# 2025-03-13 07:45:47,869 - __main__ - INFO - 已處理 1231000 個項目
# 2025-03-13 07:45:47,887 - __main__ - INFO - 已處理 1232000 個項目
# 2025-03-13 07:45:47,905 - __main__ - INFO - 已處理 1233000 個項目
# 2025-03-13 07:45:47,922 - __main__ - INFO - 已處理 1234000 個項目
# 2025-03-13 07:45:47,942 - __main__ - INFO - 已處理 1235000 個項目
# 2025-03-13 07:45:47,959 - __main__ - INFO - 已處理 1236000 個項目
# 2025-03-13 07:45:47,976 - __main__ - INFO - 已處理 1237000 個項目
# 2025-03-13 07:45:47,993 - __main__ - INFO - 已處理 1238000 個項目
# 2025-03-13 07:45:48,011 - __main__ - INFO - 已處理 1239000 個項目
# 2025-03-13 07:45:48,028 - __main__ - INFO - 已處理 1240000 個項目
# 2025-03-13 07:45:48,047 - __main__ - INFO - 已處理 1241000 個項目
# 2025-03-13 07:45:48,067 - __main__ - INFO - 已處理 1242000 個項目
# 2025-03-13 07:45:48,086 - __main__ - INFO - 已處理 1243000 個項目
# 2025-03-13 07:45:48,104 - __main__ - INFO - 已處理 1244000 個項目
# 2025-03-13 07:45:48,156 - __main__ - INFO - 已處理 1245000 個項目
# 2025-03-13 07:45:48,180 - __main__ - INFO - 已處理 1246000 個項目
# 2025-03-13 07:45:48,198 - __main__ - INFO - 已處理 1247000 個項目
# 2025-03-13 07:45:48,216 - __main__ - INFO - 已處理 1248000 個項目
# 2025-03-13 07:45:48,233 - __main__ - INFO - 已處理 1249000 個項目
# 2025-03-13 07:45:48,251 - __main__ - INFO - 已處理 1250000 個項目
# 2025-03-13 07:45:48,268 - __main__ - INFO - 已處理 1251000 個項目
# 2025-03-13 07:45:48,285 - __main__ - INFO - 已處理 1252000 個項目
# 2025-03-13 07:45:48,301 - __main__ - INFO - 已處理 1253000 個項目
# 2025-03-13 07:45:48,317 - __main__ - INFO - 已處理 1254000 個項目
# 2025-03-13 07:45:48,333 - __main__ - INFO - 已處理 1255000 個項目
# 2025-03-13 07:45:48,350 - __main__ - INFO - 已處理 1256000 個項目
# 2025-03-13 07:45:48,367 - __main__ - INFO - 已處理 1257000 個項目
# 2025-03-13 07:45:48,383 - __main__ - INFO - 已處理 1258000 個項目
# 2025-03-13 07:45:48,399 - __main__ - INFO - 已處理 1259000 個項目
# 2025-03-13 07:45:48,415 - __main__ - INFO - 已處理 1260000 個項目
# 2025-03-13 07:45:48,432 - __main__ - INFO - 已處理 1261000 個項目
# 2025-03-13 07:45:48,448 - __main__ - INFO - 已處理 1262000 個項目
# 2025-03-13 07:45:48,465 - __main__ - INFO - 已處理 1263000 個項目
# 2025-03-13 07:45:48,481 - __main__ - INFO - 已處理 1264000 個項目
# 2025-03-13 07:45:48,497 - __main__ - INFO - 已處理 1265000 個項目
# 2025-03-13 07:45:48,516 - __main__ - INFO - 已處理 1266000 個項目
# 2025-03-13 07:45:48,533 - __main__ - INFO - 已處理 1267000 個項目
# 2025-03-13 07:45:48,549 - __main__ - INFO - 已處理 1268000 個項目
# 2025-03-13 07:45:48,565 - __main__ - INFO - 已處理 1269000 個項目
# 2025-03-13 07:45:48,583 - __main__ - INFO - 已處理 1270000 個項目
# 2025-03-13 07:45:48,600 - __main__ - INFO - 已處理 1271000 個項目
# 2025-03-13 07:45:48,620 - __main__ - INFO - 已處理 1272000 個項目
# 2025-03-13 07:45:48,637 - __main__ - INFO - 已處理 1273000 個項目
# 2025-03-13 07:45:48,655 - __main__ - INFO - 已處理 1274000 個項目
# 2025-03-13 07:45:48,672 - __main__ - INFO - 已處理 1275000 個項目
# 2025-03-13 07:45:48,691 - __main__ - INFO - 已處理 1276000 個項目
# 2025-03-13 07:45:48,710 - __main__ - INFO - 已處理 1277000 個項目
# 2025-03-13 07:45:48,728 - __main__ - INFO - 已處理 1278000 個項目
# 2025-03-13 07:45:48,745 - __main__ - INFO - 已處理 1279000 個項目
# 2025-03-13 07:45:48,763 - __main__ - INFO - 已處理 1280000 個項目
# 2025-03-13 07:45:48,781 - __main__ - INFO - 已處理 1281000 個項目
# 2025-03-13 07:45:48,800 - __main__ - INFO - 已處理 1282000 個項目
# 2025-03-13 07:45:48,818 - __main__ - INFO - 已處理 1283000 個項目
# 2025-03-13 07:45:48,836 - __main__ - INFO - 已處理 1284000 個項目
# 2025-03-13 07:45:48,855 - __main__ - INFO - 已處理 1285000 個項目
# 2025-03-13 07:45:48,873 - __main__ - INFO - 已處理 1286000 個項目
# 2025-03-13 07:45:48,890 - __main__ - INFO - 已處理 1287000 個項目
# 2025-03-13 07:45:48,907 - __main__ - INFO - 已處理 1288000 個項目
# 2025-03-13 07:45:48,926 - __main__ - INFO - 已處理 1289000 個項目
# 2025-03-13 07:45:48,943 - __main__ - INFO - 已處理 1290000 個項目
# 2025-03-13 07:45:48,962 - __main__ - INFO - 已處理 1291000 個項目
# 2025-03-13 07:45:48,981 - __main__ - INFO - 已處理 1292000 個項目
# 2025-03-13 07:45:48,998 - __main__ - INFO - 已處理 1293000 個項目
# 2025-03-13 07:45:49,015 - __main__ - INFO - 已處理 1294000 個項目
# 2025-03-13 07:45:49,033 - __main__ - INFO - 已處理 1295000 個項目
# 2025-03-13 07:45:49,052 - __main__ - INFO - 已處理 1296000 個項目
# 2025-03-13 07:45:49,068 - __main__ - INFO - 已處理 1297000 個項目
# 2025-03-13 07:45:49,085 - __main__ - INFO - 已處理 1298000 個項目
# 2025-03-13 07:45:49,102 - __main__ - INFO - 已處理 1299000 個項目
# 2025-03-13 07:45:49,121 - __main__ - INFO - 已處理 1300000 個項目
# 2025-03-13 07:45:49,136 - __main__ - INFO - 已處理 1301000 個項目
# 2025-03-13 07:45:49,154 - __main__ - INFO - 已處理 1302000 個項目
# 2025-03-13 07:45:49,172 - __main__ - INFO - 已處理 1303000 個項目
# 2025-03-13 07:45:49,191 - __main__ - INFO - 已處理 1304000 個項目
# 2025-03-13 07:45:49,220 - __main__ - INFO - 已處理 1305000 個項目
# 2025-03-13 07:45:49,238 - __main__ - INFO - 已處理 1306000 個項目
# 2025-03-13 07:45:49,257 - __main__ - INFO - 已處理 1307000 個項目
# 2025-03-13 07:45:49,275 - __main__ - INFO - 已處理 1308000 個項目
# 2025-03-13 07:45:49,293 - __main__ - INFO - 已處理 1309000 個項目
# 2025-03-13 07:45:49,311 - __main__ - INFO - 已處理 1310000 個項目
# 2025-03-13 07:45:49,331 - __main__ - INFO - 已處理 1311000 個項目
# 2025-03-13 07:45:49,349 - __main__ - INFO - 已處理 1312000 個項目
# 2025-03-13 07:45:49,368 - __main__ - INFO - 已處理 1313000 個項目
# 2025-03-13 07:45:49,386 - __main__ - INFO - 已處理 1314000 個項目
# 2025-03-13 07:45:49,404 - __main__ - INFO - 已處理 1315000 個項目
# 2025-03-13 07:45:49,423 - __main__ - INFO - 已處理 1316000 個項目
# 2025-03-13 07:45:49,445 - __main__ - INFO - 已處理 1317000 個項目
# 2025-03-13 07:45:49,465 - __main__ - INFO - 已處理 1318000 個項目
# 2025-03-13 07:45:49,483 - __main__ - INFO - 已處理 1319000 個項目
# 2025-03-13 07:45:49,501 - __main__ - INFO - 已處理 1320000 個項目
# 2025-03-13 07:45:49,519 - __main__ - INFO - 已處理 1321000 個項目
# 2025-03-13 07:45:49,539 - __main__ - INFO - 已處理 1322000 個項目
# 2025-03-13 07:45:49,557 - __main__ - INFO - 已處理 1323000 個項目
# 2025-03-13 07:45:49,576 - __main__ - INFO - 已處理 1324000 個項目
# 2025-03-13 07:45:49,594 - __main__ - INFO - 已處理 1325000 個項目
# 2025-03-13 07:45:49,612 - __main__ - INFO - 已處理 1326000 個項目
# 2025-03-13 07:45:49,631 - __main__ - INFO - 已處理 1327000 個項目
# 2025-03-13 07:45:49,650 - __main__ - INFO - 已處理 1328000 個項目
# 2025-03-13 07:45:49,669 - __main__ - INFO - 已處理 1329000 個項目
# 2025-03-13 07:45:49,688 - __main__ - INFO - 已處理 1330000 個項目
# 2025-03-13 07:45:49,705 - __main__ - INFO - 已處理 1331000 個項目
# 2025-03-13 07:45:49,725 - __main__ - INFO - 已處理 1332000 個項目
# 2025-03-13 07:45:49,743 - __main__ - INFO - 已處理 1333000 個項目
# 2025-03-13 07:45:49,762 - __main__ - INFO - 已處理 1334000 個項目
# 2025-03-13 07:45:49,780 - __main__ - INFO - 已處理 1335000 個項目
# 2025-03-13 07:45:49,798 - __main__ - INFO - 已處理 1336000 個項目
# 2025-03-13 07:45:49,815 - __main__ - INFO - 已處理 1337000 個項目
# 2025-03-13 07:45:49,834 - __main__ - INFO - 已處理 1338000 個項目
# 2025-03-13 07:45:49,852 - __main__ - INFO - 已處理 1339000 個項目
# 2025-03-13 07:45:49,872 - __main__ - INFO - 已處理 1340000 個項目
# 2025-03-13 07:45:49,888 - __main__ - INFO - 已處理 1341000 個項目
# 2025-03-13 07:45:49,907 - __main__ - INFO - 已處理 1342000 個項目
# 2025-03-13 07:45:49,925 - __main__ - INFO - 已處理 1343000 個項目
# 2025-03-13 07:45:49,943 - __main__ - INFO - 已處理 1344000 個項目
# 2025-03-13 07:45:49,960 - __main__ - INFO - 已處理 1345000 個項目
# 2025-03-13 07:45:49,977 - __main__ - INFO - 已處理 1346000 個項目
# 2025-03-13 07:45:49,994 - __main__ - INFO - 已處理 1347000 個項目
# 2025-03-13 07:45:50,011 - __main__ - INFO - 已處理 1348000 個項目
# 2025-03-13 07:45:50,030 - __main__ - INFO - 已處理 1349000 個項目
# 2025-03-13 07:45:50,047 - __main__ - INFO - 已處理 1350000 個項目
# 2025-03-13 07:45:50,063 - __main__ - INFO - 已處理 1351000 個項目
# 2025-03-13 07:45:50,081 - __main__ - INFO - 已處理 1352000 個項目
# 2025-03-13 07:45:50,099 - __main__ - INFO - 已處理 1353000 個項目
# 2025-03-13 07:45:50,115 - __main__ - INFO - 已處理 1354000 個項目
# 2025-03-13 07:45:50,133 - __main__ - INFO - 已處理 1355000 個項目
# 2025-03-13 07:45:50,151 - __main__ - INFO - 已處理 1356000 個項目
# 2025-03-13 07:45:50,169 - __main__ - INFO - 已處理 1357000 個項目
# 2025-03-13 07:45:50,226 - __main__ - INFO - 已處理 1358000 個項目
# 2025-03-13 07:45:50,243 - __main__ - INFO - 已處理 1359000 個項目
# 2025-03-13 07:45:50,258 - __main__ - INFO - 已處理 1360000 個項目
# 2025-03-13 07:45:50,275 - __main__ - INFO - 已處理 1361000 個項目
# 2025-03-13 07:45:50,291 - __main__ - INFO - 已處理 1362000 個項目
# 2025-03-13 07:45:50,309 - __main__ - INFO - 已處理 1363000 個項目
# 2025-03-13 07:45:50,326 - __main__ - INFO - 已處理 1364000 個項目
# 2025-03-13 07:45:50,345 - __main__ - INFO - 已處理 1365000 個項目
# 2025-03-13 07:45:50,362 - __main__ - INFO - 已處理 1366000 個項目
# 2025-03-13 07:45:50,379 - __main__ - INFO - 已處理 1367000 個項目
# 2025-03-13 07:45:50,397 - __main__ - INFO - 已處理 1368000 個項目
# 2025-03-13 07:45:50,415 - __main__ - INFO - 已處理 1369000 個項目
# 2025-03-13 07:45:50,433 - __main__ - INFO - 已處理 1370000 個項目
# 2025-03-13 07:45:50,452 - __main__ - INFO - 已處理 1371000 個項目
# 2025-03-13 07:45:50,471 - __main__ - INFO - 已處理 1372000 個項目
# 2025-03-13 07:45:50,489 - __main__ - INFO - 已處理 1373000 個項目
# 2025-03-13 07:45:50,507 - __main__ - INFO - 已處理 1374000 個項目
# 2025-03-13 07:45:50,525 - __main__ - INFO - 已處理 1375000 個項目
# 2025-03-13 07:45:50,544 - __main__ - INFO - 已處理 1376000 個項目
# 2025-03-13 07:45:50,563 - __main__ - INFO - 已處理 1377000 個項目
# 2025-03-13 07:45:50,564 - __main__ - INFO - 已處理 1377010 個項目
# 2025-03-13 07:45:50,565 - __main__ - INFO - 分批處理完成，總共處理 1377010 個項目
# 2025-03-13 07:45:57,558 - __main__ - INFO - 已成功儲存 1377010 個項目至 JSON 檔案: ../data/convert/official-cpe-dictionary_v2.3_v2.json
# 2025-03-13 07:46:04,268 - __main__ - INFO - 已成功儲存 1377010 個項目至 CSV 檔案: ../data/convert/official-cpe-dictionary_v2.3_v2.csv
# 2025-03-13 07:46:04,269 - __main__ - INFO - 程式執行完成

# %% [markdown]
# ### Example of converted format
#
# #### JSON Format
#
# ```JSON
# {
#   "cpe22Uri": "cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~",
#   "cpe23Uri": "cpe:2.3:a:\\$0.99_kindle_books_project:\\$0.99_kindle_books:6:*:*:*:*:android:*:*",
#   "vendor": "\\$0.99_kindle_books_project",
#   "product": "\\$0.99_kindle_books",
#   "version": "6",
#   "title": "$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0",
#   "references": "Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)"
# },
# ```
#
# #### CSV Format
#
# ```CSV
# cpe22Uri,cpe23Uri,vendor,product,version,title,references
# cpe:/a:%240.99_kindle_books_project:%240.99_kindle_books:6::~~~android~~,cpe:2.3:a:\$0.99_kindle_books_project:\$0.99_kindle_books:6:*:*:*:*:android:*:*,\$0.99_kindle_books_project,\$0.99_kindle_books,6,$0.99 Kindle Books project $0.99 Kindle Books (aka com.kindle.books.for99) for android 6.0,Product information (https://play.google.com/store/apps/details?id=com.kindle.books.for99) Government Advisory (https://docs.google.com/spreadsheets/d/1t5GXwjw82SyunALVJb2w0zi3FoLRIkfGPc7AMjRF0r4/edit?pli=1#gid=1053404143)
# ```

# %% [markdown]
# ## Step 3: Create a vector database (using Chromadb as an example)
#
# To quickly retrieve the closest Common Platform Enumeration (CPE) data based on user input, we will utilize the similarity search capabilities of a vector database. Vector databases excel at transforming complex data (such as images, audio, etc.) into vector representations for mathematical operations. Given the variability of user input, the potential for different registration formats of vendor and product names within the CPE database, and the varying relevance of references included in CPE entries, we aim to leverage the similarity comparison capabilities of the vector database to effectively identify the desired CPE entries. Therefore, we need to import the National Vulnerability Database (NVD) CPE Directory List into Chromadb and convert it into vectors for subsequent similarity comparisons.
#
# > 為了能根據使用者輸入，快速取得最接近的通用平台列舉（CPE）資料，我們將利用向量資料庫的相似性搜尋功能。向量資料庫擅長將複雜資料（如圖像、聲音等）轉換為可進行數學運算的向量表示。由於使用者輸入的多樣性，以及廠商、產品名稱在 CPE 資料庫中可能存在不同形式的登記方式，加上 CPE 條目中包含的參考資料（References）有時相關、有時不相關，我們希望藉由向量資料庫的相似性比較能力，有效識別出期望的 CPE 條目。因此，我們需要將美國國家漏洞資料庫（NVD）的 CPE 目錄列表匯入 Chromadb，並將其轉換為向量，以便後續的相似性比對。
#
# ### Structure of the created to vector database
#
# ```Markdown
#           (Periodic or Manual)
# ┌───────────────────────────────────────┐
# │    NVD CPE Directory (ZIP/XML)        │
# └───────────────────────────────────────┘
#                │
#                ▼
#      CPE Directory Updater
#                │
#                ▼
#      CPE Parser & Transformer
#                │  (structured JSON)
#                ▼
#      Embedding Service (Huggingface)
#                │ (vector)
#                ▼
#   ┌────────────────────────────────────┐
#   │         Chromadb Vector DB         │
#   └────────────────────────────────────┘
# ```

# %%
import csv
import datetime
import json
import logging
import os
from dataclasses import dataclass
from functools import lru_cache
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple, Union

import chromadb
from chromadb.utils import embedding_functions


# 設定日誌
def setup_logging(log_level=logging.INFO, log_file=None):
    """設定日誌記錄

    Args:
        log_level (int, optional): 日誌等級. 預設為 logging.INFO.
        log_file (str, optional): 日誌檔案路徑，如果為 None 則只會輸出到控制台. 預設為 None.
    """
    log_format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'

    # 建立日誌處理器
    handlers = []
    handlers.append(logging.StreamHandler())  # 控制台輸出

    if log_file:
        log_dir = Path(log_file).parent
        log_dir.mkdir(parents=True, exist_ok=True)
        handlers.append(logging.FileHandler(
            log_file, encoding='utf-8'))  # 檔案輸出

    # 設定根日誌記錄器
    logging.basicConfig(
        level=log_level,
        format=log_format,
        handlers=handlers
    )


# 設定日誌
setup_logging(logging.INFO, "../logs/cpe_database.log")
logger = logging.getLogger(__name__)


@dataclass
class CPEItem:
    """代表單個 CPE 項目的資料結構"""
    cpe22Uri: str
    cpe23Uri: str
    vendor: str
    product: str
    version: str
    title: str
    references: str


class EmbeddingModelProvider:
    """提供不同的嵌入模型選項"""

    @staticmethod
    def get_default_embedding():
        """獲取預設的嵌入函數

        Returns:
            embedding_function: 預設的嵌入函數
        """
        return embedding_functions.DefaultEmbeddingFunction()


class CPEInputStandardizer:
    """CPE輸入標準化預處理器"""

    @staticmethod
    def standardize_text(text: Optional[str]) -> Optional[str]:
        """
        標準化文本:
        1. 轉換為小寫
        2. 替換標準化特殊字符
        3. 清理多餘空格

        Args:
            text: 要標準化的文本

        Returns:
            標準化後的文本，如果輸入為空則返回None
        """
        if not text:
            return None

        # 轉換為小寫
        text = text.lower().strip()

        # 替換特殊字符
        special_chars = [' ', '-', '.', '/', ':', '(', ')', '[', ']', '+', '&']
        for char in special_chars:
            text = text.replace(char, '_')

        # 合併連續底線
        while '__' in text:
            text = text.replace('__', '_')

        # 去除首尾底線
        text = text.strip('_')

        return text

    @staticmethod
    def standardize_version(version: Optional[str]) -> Optional[str]:
        """
        標準化版本號:
        1. 移除版本前綴
        2. 替換非標準分隔符
        3. 處理特殊版本格式
        4. 正規化數字部分（例如將001變為1）

        Args:
            version: 要標準化的版本號

        Returns:
            標準化後的版本號，如果輸入為空則返回None
        """
        if not version:
            return None

        # 去除空白
        version = version.strip()

        # 移除版本前綴 (v, ver, version等)
        prefixes = ['v', 'ver', 'version', 'release', 'rel']

        lower_version = version.lower()
        for prefix in prefixes:
            if lower_version.startswith(prefix):
                # 處理不同格式的前綴
                if len(version) > len(prefix):
                    if version[len(prefix)].isdigit():
                        # v1.0 格式
                        version = version[len(prefix):]
                    elif version[len(prefix)] in [' ', '.', '-', '_']:
                        # v 1.0, v.1.0, v-1.0 格式
                        version = version[len(prefix)+1:]

        # 清理版本號開頭的非數字字符
        while version and not version[0].isdigit():
            version = version[1:]

        # 如果清理後為空，返回None
        if not version:
            return None

        # 將常見的版本分隔符標準化為點
        for sep in ['-', '_', ' ']:
            version = version.replace(sep, '.')

        # 處理重複的分隔符
        while '..' in version:
            version = version.replace('..', '.')

        # 處理版本號的每個部分，移除無意義的前導零
        parts = version.split('.')
        normalized_parts = []
        for part in parts:
            if part.isdigit():
                # 移除前導零但保留單個零
                normalized_part = part.lstrip('0')
                normalized_part = normalized_part if normalized_part else '0'
                normalized_parts.append(normalized_part)
            else:
                normalized_parts.append(part)

        return '.'.join(normalized_parts)

    @staticmethod
    def standardize_input(vendor: Optional[str] = None,
                          product: Optional[str] = None,
                          version: Optional[str] = None) -> Tuple[Optional[str], Optional[str], Optional[str]]:
        """
        標準化處理用戶輸入的廠商、產品和版本

        Args:
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號

        Returns:
            標準化後的廠商、產品和版本
        """
        std_vendor = CPEInputStandardizer.standardize_text(vendor)
        std_product = CPEInputStandardizer.standardize_text(product)
        std_version = CPEInputStandardizer.standardize_version(version)

        return std_vendor, std_product, std_version

    @staticmethod
    def standardize_csv_row(row: Dict[str, str]) -> Dict[str, str]:
        """
        標準化CSV檔案中的一行

        Args:
            row: CSV行資料

        Returns:
            標準化後的行資料
        """
        vendor = row.get('vendor', '').strip() or None
        product = row.get('product', '').strip() or None
        version = row.get('version', '').strip() or None

        std_vendor, std_product, std_version = CPEInputStandardizer.standardize_input(
            vendor, product, version
        )

        # 建立新的標準化後的行
        standardized_row = row.copy()

        # 保存原始值
        standardized_row['original_vendor'] = vendor
        standardized_row['original_product'] = product
        standardized_row['original_version'] = version

        # 添加標準化值
        standardized_row['vendor'] = std_vendor
        standardized_row['product'] = std_product
        standardized_row['version'] = std_version

        return standardized_row


class StringMatcher:
    """字串相似度比對工具類"""

    @staticmethod
    @lru_cache(maxsize=1000)
    def levenshtein_distance(s1: str, s2: str) -> int:
        """計算兩個字符串之間的Levenshtein距離

        Args:
            s1: 第一個字串
            s2: 第二個字串

        Returns:
            Levenshtein距離
        """
        if len(s1) < len(s2):
            return StringMatcher.levenshtein_distance(s2, s1)

        if len(s2) == 0:
            return len(s1)

        previous_row = range(len(s2) + 1)
        for i, c1 in enumerate(s1):
            current_row = [i + 1]
            for j, c2 in enumerate(s2):
                insertions = previous_row[j + 1] + 1
                deletions = current_row[j] + 1
                substitutions = previous_row[j] + (c1 != c2)
                current_row.append(min(insertions, deletions, substitutions))
            previous_row = current_row

        return previous_row[-1]

    @staticmethod
    def calculate_similarity(s1: str, s2: str) -> float:
        """計算兩個字串的相似度

        Args:
            s1: 第一個字串
            s2: 第二個字串

        Returns:
            相似度分數，範圍為0到1，1表示完全相同
        """
        s1 = s1.lower().strip()
        s2 = s2.lower().strip()

        # 快速檢查
        if s1 == s2:
            return 1.0
        elif s1 in s2 or s2 in s1:
            return 0.8

        # 使用Levenshtein距離計算相似度
        distance = StringMatcher.levenshtein_distance(s1, s2)
        max_len = max(len(s1), len(s2))

        if max_len == 0:
            return 0.0

        return 1.0 - (distance / max_len)

    @staticmethod
    @lru_cache(maxsize=1000)
    def version_match(query_version: str, db_version: str) -> bool:
        """改進的版本號匹配邏輯

        Args:
            query_version: 查詢的版本號
            db_version: 資料庫中的版本號

        Returns:
            是否匹配
        """
        # 簡化版本號，移除不必要的零
        def normalize_version(v):
            if not v:
                return ""
            # 將版本號拆分為數字和非數字部分
            parts = []
            current = ""
            for c in v:
                if current and ((c.isdigit() and not current[-1].isdigit()) or
                                (not c.isdigit() and current[-1].isdigit())):
                    parts.append(current)
                    current = c
                else:
                    current += c
            if current:
                parts.append(current)

            # 對數字部分進行處理，移除前導零
            norm_parts = []
            for part in parts:
                if part.isdigit():
                    # 移除前導零但保留單個零
                    norm_part = part.lstrip('0')
                    norm_part = norm_part if norm_part else '0'
                    norm_parts.append(norm_part)
                else:
                    norm_parts.append(part)

            return "".join(norm_parts)

        norm_query = normalize_version(query_version)
        norm_db = normalize_version(db_version)

        # 先檢查完全匹配
        if norm_query == norm_db:
            return True

        # 再檢查部分匹配
        return norm_query in norm_db or norm_db in norm_query


class CPEDatabaseManager:
    """CPE資料庫管理器"""

    def __init__(self,
                 db_path: str = "../database/cpe_database",
                 use_gpu: bool = False,
                 embedding_model: str = "default"):
        """初始化 CPE 資料庫管理器

        Args:
            db_path: 資料庫存放路徑
            use_gpu: 是否使用 GPU. 預設為 False.
            embedding_model: 要使用的嵌入模型類型. 預設為 "default".
        """
        self.db_path = Path(db_path)
        self.db_path.mkdir(parents=True, exist_ok=True)

        self.client = None
        self.collection = None

        # 設定 GPU 使用選項
        self.use_gpu = use_gpu

        # 選擇嵌入模型
        self.setup_embedding_function(embedding_model)

        # 設定資料庫
        self.setup_database()

    def setup_embedding_function(self, embedding_model: str) -> None:
        """設定嵌入函數

        Args:
            embedding_model: 嵌入模型類型
        """
        self.embedding_function = EmbeddingModelProvider.get_default_embedding()
        embedding_description = "預設"

        logger.info(f"使用嵌入模型: {embedding_description}")

    def setup_database(self) -> None:
        """設定資料庫連接和集合"""
        try:
            self.client = chromadb.PersistentClient(path=str(self.db_path))

            # 使用設定的 embedding 函數建立集合
            self.collection = self.client.get_or_create_collection(
                name="cpe_dictionary",
                metadata={"description": "CPE Dictionary Collection"},
                embedding_function=self.embedding_function
            )
            logger.info(f"成功設定資料庫連接，儲存位置: {self.db_path}")
        except Exception as e:
            logger.error(f"設定資料庫時發生錯誤: {str(e)}")
            raise

    def load_cpe_data(self, file_path: Union[str, Path]) -> List[Dict[str, Any]]:
        """讀取並解析 CPE JSON 檔案

        Args:
            file_path: JSON 檔案路徑

        Returns:
            解析後的 CPE 資料
        """
        file_path = Path(file_path)
        if not file_path.exists():
            raise FileNotFoundError(f"找不到檔案: {file_path}")

        try:
            logger.info(f"開始讀取 CPE 資料: {file_path}")
            with open(file_path, "r", encoding="utf-8") as file:
                data = json.load(file)
            logger.info(f"成功讀取 {len(data)} 筆 CPE 資料")
            return data
        except json.JSONDecodeError as e:
            logger.error(f"解析 JSON 檔案時發生錯誤: {str(e)}")
            raise
        except Exception as e:
            logger.error(f"讀取 CPE 資料時發生錯誤: {str(e)}")
            raise

    def prepare_search_text(self, item: Dict[str, Any]) -> str:
        """優化的搜尋文本準備函數，減少重複內容的影響

        Args:
            item: CPE 項目資料

        Returns:
            用於向量搜尋的文字
        """
        # 提取基本資訊
        title = item.get('title', '').strip()
        vendor = item.get('vendor', '').strip()
        product = item.get('product', '').strip()
        version = item.get('version', '').strip()

        # 移除產品名稱中的廠商名稱，避免重複
        if vendor and product.lower().startswith(vendor.lower()):
            clean_product = product[len(vendor):].strip()
            # 如果刪除廠商名稱後只剩下標點符號等，則保留原始產品名稱
            if clean_product and not all(c in ' .,;:-_()[]' for c in clean_product):
                product = clean_product

        # 構建優化的搜尋文字
        # 將廠商權重提高
        search_text = f"{vendor} {vendor} {vendor} "  # 重複三次增加權重
        search_text += f"{product} {product} "        # 重複兩次增加權重
        search_text += f"{version} "
        search_text += f"{title} "

        # 加入結構化資訊
        search_text += f"""
        Title: {title}
        Vendor: {vendor}
        Product: {product}
        Version: {version}
        """

        return search_text.strip()

    def prepare_documents(self, cpe_data: List[Dict[str, Any]]) -> Tuple[List[str], List[Dict[str, str]], List[str]]:
        """準備要導入到資料庫的文件資料

        Args:
            cpe_data: CPE 資料列表

        Returns:
            返回文件內容、中繼資料和ID的元組
        """
        documents = []
        metadatas = []
        ids = []

        for i, item in enumerate(cpe_data):
            try:
                # 取得 CPE 2.3 URI 作為唯一識別符
                cpe23uri = item.get('cpe23Uri', '')
                if not cpe23uri:
                    logger.warning(f"第 {i} 筆資料缺少 cpe23Uri，將略過")
                    continue

                # 使用 CPE 2.3 URI 作為 ID
                doc_id = cpe23uri

                # 製作優化的文件內容
                doc_content = self.prepare_search_text(item)

                # 準備豐富的中繼資料，方便後續檢索和過濾
                metadata = {
                    'vendor': item.get('vendor', ''),
                    'product': item.get('product', ''),
                    'version': item.get('version', ''),
                    'cpe22Uri': item.get('cpe22Uri', ''),
                    'cpe23Uri': cpe23uri,
                    'title': item.get('title', ''),
                    # 將 references 截斷以避免過長
                    'references': item.get('references', '')[:1000] if item.get('references') else ''
                }

                documents.append(doc_content)
                metadatas.append(metadata)
                ids.append(doc_id)

            except Exception as e:
                logger.warning(f"處理第 {i} 筆資料時發生錯誤: {str(e)}")
                continue

        return documents, metadatas, ids

    def import_data(self, file_path: Union[str, Path], batch_size: int = 1000,
                    reset_collection: bool = False) -> None:
        """導入 CPE 資料到資料庫

        Args:
            file_path: CPE JSON 檔案路徑
            batch_size: 批次處理大小. 預設為 1000.
            reset_collection: 是否重置集合. 預設為 False.
        """
        try:
            # 如果需要重置集合
            if reset_collection:
                self._reset_collection()

            # 讀取資料
            cpe_data = self.load_cpe_data(file_path)

            # 準備文件
            logger.info("準備文件資料...")
            documents, metadatas, ids = self.prepare_documents(cpe_data)
            logger.info(f"準備了 {len(documents)} 筆有效的 CPE 資料")

            # 批次處理
            total_items = len(documents)
            for i in range(0, total_items, batch_size):
                batch_end = min(i + batch_size, total_items)
                batch_docs = documents[i:batch_end]
                batch_meta = metadatas[i:batch_end]
                batch_ids = ids[i:batch_end]

                logger.info(f"正在導入批次 {i//batch_size + 1}/{(total_items-1)//batch_size + 1} " +
                            f"({i+1}-{batch_end}/{total_items})...")

                try:
                    # 使用 upsert 而非 add，以便處理重複的 CPE ID
                    self.collection.upsert(
                        documents=batch_docs,
                        metadatas=batch_meta,
                        ids=batch_ids
                    )
                    logger.info(f"已處理 {batch_end}/{total_items} 筆資料")
                except Exception as e:
                    logger.error(f"批次處理時發生錯誤: {str(e)}")
                    logger.error(f"問題批次範圍: {i+1}-{batch_end}")
                    # 繼續處理下一批，而不是中斷整個過程
                    continue

            logger.info(f"成功導入 CPE 資料，總計 {total_items} 筆")

        except Exception as e:
            logger.error(f"導入資料時發生錯誤: {str(e)}")
            raise

    def _reset_collection(self) -> None:
        """重置集合，處理不同版本的ChromaDB可能的差異"""
        logger.info("重置集合...")
        try:
            # 嘗試列出所有集合，然後刪除目標集合
            collection_names = [col for col in self.client.list_collections()]
            if "cpe_dictionary" in collection_names:
                self.client.delete_collection("cpe_dictionary")
            logger.info("成功刪除現有集合")
        except Exception as e:
            logger.warning(f"使用list_collections刪除集合時發生錯誤: {str(e)}")
            # 備用方法: 嘗試直接獲取然後刪除
            try:
                self.client.get_collection("cpe_dictionary")
                self.client.delete_collection("cpe_dictionary")
                logger.info("使用備用方法成功刪除現有集合")
            except Exception:
                # 如果集合不存在，忽略錯誤
                logger.info("集合不存在，將新建集合")
                pass

        # 創建新集合
        self.collection = self.client.create_collection(
            name="cpe_dictionary",
            metadata={"description": "CPE Dictionary Collection"},
            embedding_function=self.embedding_function
        )
        logger.info("集合已重置")

    def search(self,
               vendor: Optional[str] = None,
               product: Optional[str] = None,
               version: Optional[str] = None,
               n_results: int = 5) -> Dict[str, Any]:
        """優化的搜尋方法，使用多階段匹配邏輯

        Args:
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號
            n_results: 返回結果數量

        Returns:
            搜尋結果
        """
        try:
            # 確保至少提供一個搜尋條件
            if not any([vendor, product, version]):
                raise ValueError("必須提供至少一個搜尋條件 (vendor, product, version)")

            # 構建搜尋關鍵字
            search_parts = []
            if vendor:
                search_parts.append(f"{vendor}")
            if product:
                search_parts.append(f"{product}")
            if version:
                search_parts.append(f"{version}")

            search_query = " ".join(search_parts)

            # 獲取初步結果
            original_results = self.collection.query(
                query_texts=[search_query],
                n_results=n_results * 3,  # 擴大搜尋範圍，後續會篩選
                include=['metadatas', 'distances']
            )

            # 重新排序和過濾結果
            sorted_results = self._process_search_results(
                original_results, vendor, product, version, n_results
            )

            return sorted_results

        except Exception as e:
            logger.error(f"搜尋時發生錯誤: {str(e)}")
            raise

    def _process_search_results(self, original_results, vendor, product, version, n_results):
        """處理搜尋結果，重新排序和過濾

        Args:
            original_results: 原始搜尋結果
            vendor: 廠商名稱
            product: 產品名稱
            version: 版本號
            n_results: 返回結果數量

        Returns:
            處理後的搜尋結果
        """
        # 加強對廠商名稱的匹配處理
        if vendor and original_results['metadatas'][0]:
            # 計算每個結果與輸入廠商名稱的相似度分數
            vendor_scores = []
            norm_vendor = vendor.lower()
            for meta in original_results['metadatas'][0]:
                db_vendor = meta['vendor'].lower()
                vendor_scores.append(
                    StringMatcher.calculate_similarity(norm_vendor, db_vendor))

            # 調整距離分數，廠商匹配度占50%權重
            adjusted_distances = []
            for i, dist in enumerate(original_results['distances'][0]):
                # 原始距離佔50%，廠商匹配度佔50%
                adjusted_dist = dist * 0.5 + (1 - vendor_scores[i]) * 0.5
                adjusted_distances.append(adjusted_dist)

            # 重新排序結果
            indices = sorted(range(len(adjusted_distances)),
                             key=lambda i: adjusted_distances[i])
            sorted_ids = [original_results['ids'][0][i] for i in indices]
            sorted_metadatas = [original_results['metadatas'][0][i]
                                for i in indices]
            sorted_distances = [adjusted_distances[i] for i in indices]

            # 取前n_results個結果
            original_results = {
                'ids': [sorted_ids[:n_results]],
                'metadatas': [sorted_metadatas[:n_results]],
                'distances': [sorted_distances[:n_results]]
            }

        # 進行最終的精確過濾
        filtered_indices = []
        for i, metadata in enumerate(original_results['metadatas'][0]):
            match = True
            if vendor and vendor.lower() not in metadata['vendor'].lower():
                match = False
            if product and product.lower() not in metadata['product'].lower():
                match = False
            if version and not StringMatcher.version_match(version, metadata['version']):
                match = False

            if match:
                filtered_indices.append(i)

        # 創建結果字典
        results = {
            'original_results': original_results,
            'filtered_results': None,
            'is_filtered': True
        }

        # 根據過濾後的索引重建結果
        if filtered_indices:
            filtered_results = {
                'ids': [[original_results['ids'][0][i] for i in filtered_indices]],
                'metadatas': [[original_results['metadatas'][0][i] for i in filtered_indices]],
                'distances': [[original_results['distances'][0][i] for i in filtered_indices]]
            }

            results['filtered_results'] = filtered_results
        else:
            # 如果過濾後沒有結果，設定空結果
            results['filtered_results'] = {
                'ids': [[]],
                'metadatas': [[]],
                'distances': [[]]
            }

        return results

    def get_collection_info(self) -> Dict[str, Any]:
        """獲取集合資訊

        Returns:
            集合資訊
        """
        try:
            # 獲取集合計數
            count = self.collection.count()

            # 判斷使用的嵌入模型類型
            try:
                # 嘗試檢查嵌入函數的類型
                if hasattr(embedding_functions, 'DefaultEmbeddingFunction') and \
                   isinstance(self.embedding_function, embedding_functions.DefaultEmbeddingFunction):
                    model_type = "Default"
                else:
                    # 嘗試使用不同的方式判斷
                    model_name = getattr(
                        self.embedding_function, '_model_name', None)
                    if model_name and 'huggingface' in str(model_name).lower():
                        model_type = "HuggingFace"
                    else:
                        model_type = "Default" if not self.use_gpu else "HuggingFace"
            except Exception as e:
                logger.warning(f"判斷嵌入模型類型時發生錯誤: {str(e)}")
                # 回退到基於 use_gpu 的簡單判斷
                model_type = "Default" if not self.use_gpu else "HuggingFace"

            # 獲取集合中繼資料
            collection_info = {
                "name": self.collection.name,
                "metadata": self.collection.metadata,
                "count": count,
                "embedding_model": model_type,
                "device": "GPU" if self.use_gpu else "CPU"
            }

            return collection_info
        except Exception as e:
            logger.error(f"獲取集合資訊時發生錯誤: {str(e)}")
            raise


class BatchSearcher:
    """批量搜尋處理器"""

    @staticmethod
    def batch_search_from_csv(db_manager: CPEDatabaseManager,
                              csv_file_path: str,
                              output_file_path: Optional[str] = None,
                              use_standardizer: bool = True) -> str:
        """優化的批量搜索功能，加入更好的結果篩選和相關性排序

        Args:
            db_manager: CPE資料庫管理器實例
            csv_file_path: 輸入CSV檔案路徑
            output_file_path: 輸出檔案路徑。如果為None，會自動生成檔名
            use_standardizer: 是否使用標準化預處理器。預設為True

        Returns:
            輸出檔案路徑
        """
        if not output_file_path:
            # 生成輸出檔名，包含時間戳記
            timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            output_file_path = f"search_results_{timestamp}.txt"

        # 統計搜尋資訊
        total_items = 0
        items_with_results = 0

        logger.info(f"開始從 {csv_file_path} 批次搜尋，結果將輸出到 {output_file_path}")
        logger.info(f"是否使用標準化預處理器: {use_standardizer}")

        try:
            with open(csv_file_path, 'r', encoding='utf-8') as csv_file, \
                    open(output_file_path, 'w', encoding='utf-8') as output_file:

                # 寫入檔案標頭
                BatchSearcher._write_header(
                    output_file, csv_file_path, use_standardizer)

                # 讀取CSV
                csv_reader = csv.DictReader(csv_file)

                # 檢查CSV是否有必要的欄位
                BatchSearcher._validate_csv_fields(csv_reader.fieldnames)

                # 處理每一行
                for i, row in enumerate(csv_reader, 1):
                    total_items += 1

                    # 獲取原始輸入
                    original_vendor = row.get('vendor', '').strip() or None
                    original_product = row.get('product', '').strip() or None
                    original_version = row.get('version', '').strip() or None

                    # 如果所有欄位都是空的，跳過這一行
                    if not any([original_vendor, original_product, original_version]):
                        logger.warning(f"第 {i} 行: 所有搜尋條件為空，跳過")
                        output_file.write(f"項目 {i}: 所有搜尋條件為空，跳過\n\n")
                        continue

                    # 處理輸入並進行搜尋
                    has_results = BatchSearcher._process_row(
                        i, db_manager, output_file,
                        original_vendor, original_product, original_version,
                        use_standardizer
                    )

                    if has_results:
                        items_with_results += 1

                # 寫入摘要
                BatchSearcher._write_summary(
                    output_file, total_items, items_with_results, use_standardizer
                )

            logger.info(
                f"批次搜尋完成，共處理 {total_items} 項，{items_with_results} 項有結果")
            return output_file_path

        except Exception as e:
            logger.error(f"批次搜尋過程中發生錯誤: {str(e)}")
            raise

    @staticmethod
    def _write_header(output_file, csv_file_path, use_standardizer):
        """寫入搜尋結果檔案的標頭"""
        if use_standardizer:
            output_file.write("CPE資料庫搜尋結果 - 批次處理 (含標準化預處理)\n")
        else:
            output_file.write("CPE資料庫搜尋結果 - 批次處理\n")

        output_file.write(f"輸入檔案: {csv_file_path}\n")
        output_file.write(
            f"處理時間: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        output_file.write(f"{'='*80}\n\n")

    @staticmethod
    def _validate_csv_fields(field_names):
        """驗證CSV欄位是否符合要求"""
        required_fields = ['vendor', 'product', 'version']
        missing_fields = [
            field for field in required_fields if field not in field_names]
        if missing_fields:
            raise ValueError(f"CSV檔案缺少必要欄位: {', '.join(missing_fields)}")

    @staticmethod
    def _process_row(row_num, db_manager, output_file,
                     original_vendor, original_product, original_version,
                     use_standardizer):
        """處理搜尋CSV的單行資料"""
        try:
            # 如果使用標準化預處理器，處理輸入
            if use_standardizer:
                vendor, product, version = CPEInputStandardizer.standardize_input(
                    original_vendor, original_product, original_version)

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {row_num}:\n")
                output_file.write(
                    f"  原始廠商: {original_vendor or '無'} -> 標準化: {vendor or '無'}\n")
                output_file.write(
                    f"  原始產品: {original_product or '無'} -> 標準化: {product or '無'}\n")
                output_file.write(
                    f"  原始版本: {original_version or '無'} -> 標準化: {version or '無'}\n\n")
            else:
                vendor = original_vendor
                product = original_product
                version = original_version

                # 寫入當前搜尋項目資訊
                output_file.write(f"項目 {row_num}:\n")
                output_file.write(f"  廠商: {vendor or '無'}\n")
                output_file.write(f"  產品: {product or '無'}\n")
                output_file.write(f"  版本: {version or '無'}\n\n")

            # 搜尋
            results = db_manager.search(
                vendor=vendor, product=product, version=version)

            result_text = SearchResultFormatter.format_search_results(results)

            # 檢查是否有搜尋結果
            has_results = False
            filtered_results = results.get('filtered_results', {})
            if filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
                has_results = True

            # 寫入搜尋結果
            output_file.write(result_text)
            output_file.write(f"\n{'='*80}\n\n")

            # 記錄日誌
            if has_results:
                logger.info(
                    f"第 {row_num} 行: 搜尋成功，找到 {len(filtered_results['metadatas'][0])} 筆結果")
            else:
                logger.info(f"第 {row_num} 行: 搜尋成功，但沒有符合的結果")

            return has_results

        except Exception as e:
            logger.error(f"第 {row_num} 行: 搜尋時發生錯誤: {str(e)}")
            output_file.write(f"搜尋時發生錯誤: {str(e)}\n\n")
            output_file.write(f"{'='*80}\n\n")
            return False

    @staticmethod
    def _write_summary(output_file, total_items, items_with_results, use_standardizer):
        """寫入搜尋結果摘要"""
        output_file.write("批次搜尋摘要:\n")
        output_file.write(f"總項目數: {total_items}\n")
        output_file.write(f"有結果的項目數: {items_with_results}\n")
        output_file.write(f"無結果的項目數: {total_items - items_with_results}\n")
        if use_standardizer:
            output_file.write("使用標準化預處理: 是\n")
        else:
            output_file.write("使用標準化預處理: 否\n")


class SearchResultFormatter:
    """搜尋結果格式化工具類"""

    @staticmethod
    def format_search_results(results: Dict[str, Any]) -> str:
        """格式化搜尋結果為可讀的文字

        Args:
            results: 搜尋結果

        Returns:
            格式化的搜尋結果文字
        """
        if not results:
            return "未找到符合的結果"

        output = []

        # 處理原始結果
        original_results = results.get('original_results', {})
        if original_results and original_results.get('metadatas') and original_results['metadatas'][0]:
            output.append("\n=== 原始搜尋結果 ===")
            for i, (metadata, distance) in enumerate(zip(original_results['metadatas'][0],
                                                         original_results.get('distances', [[0] * len(original_results['metadatas'][0])])[0])):
                score = 1.0 - (distance / 2.0)  # 將距離轉換為可理解的分數

                output.append(f"\n原始結果 {i+1} (相似度: {score:.2f}):")
                output.append(f"產品: {metadata['product']}")
                output.append(f"廠商: {metadata['vendor']}")
                output.append(f"版本: {metadata['version']}")
                output.append(f"CPE23: {metadata['cpe23Uri']}")

        # 處理過濾結果
        filtered_results = results.get('filtered_results', {})
        if results.get('is_filtered') and filtered_results and filtered_results.get('metadatas') and filtered_results['metadatas'][0]:
            output.append("\n=== 過濾後的結果 ===")
            for i, (metadata, distance) in enumerate(zip(filtered_results['metadatas'][0],
                                                         filtered_results.get('distances', [[0] * len(filtered_results['metadatas'][0])])[0])):
                score = 1.0 - (distance / 2.0)

                output.append(f"\n過濾結果 {i+1} (相似度: {score:.2f}):")
                output.append(f"產品: {metadata['product']}")
                output.append(f"廠商: {metadata['vendor']}")
                output.append(f"版本: {metadata['version']}")
                output.append(f"CPE23: {metadata['cpe23Uri']}")
        elif results.get('is_filtered') and (not filtered_results or not filtered_results.get('metadatas') or not filtered_results['metadatas'][0]):
            output.append("\n=== 過濾後的結果 ===")
            output.append("過濾後沒有符合條件的結果")

        return "\n".join(output)


def main():
    """主程式入口"""
    # 設定檔案路徑
    file_path = "../data/convert/official-cpe-dictionary_v2.3_v2.json"

    try:
        use_gpu = False
        embedding_model = "default"
        logger.info("使用預設嵌入模型 (CPU)")

        # 初始化資料庫管理器
        db_manager = CPEDatabaseManager(
            use_gpu=use_gpu, embedding_model=embedding_model)

        # 顯示選單
        while True:
            print("\n=== CPE 資料庫管理工具 ===")
            print("1. 導入 CPE 資料")
            print("2. 查看集合資訊")
            print("3. 單次搜尋")
            print("4. 單次搜尋 (含標準化預處理)")
            print("5. 從CSV檔案批次搜尋")
            print("6. 從CSV檔案批次搜尋 (含標準化預處理)")
            print("0. 退出")

            choice = input("請選擇操作 (0-6): ").strip()

            if choice == "0":
                print("程式已結束。")
                break

            elif choice == "1":
                # 導入資料
                reset = input("是否要重置現有集合？(y/n): ").strip().lower() == 'y'
                db_manager.import_data(file_path, reset_collection=reset)

            elif choice == "2":
                # 顯示集合資訊
                collection_info = db_manager.get_collection_info()
                print("\n集合資訊:")
                print(f"名稱: {collection_info['name']}")
                print(f"項目數量: {collection_info['count']}")
                print(f"嵌入模型: {collection_info['embedding_model']}")
                print(f"使用裝置: {collection_info['device']}")

            elif choice == "3":
                # 單次搜尋
                main_single_search(db_manager, use_standardizer=False)

            elif choice == "4":
                # 單次搜尋(含標準化)
                main_single_search(db_manager, use_standardizer=True)

            elif choice == "5":
                # 批次搜尋
                main_batch_search(db_manager, use_standardizer=False)

            elif choice == "6":
                # 批次搜尋(含標準化)
                main_batch_search(db_manager, use_standardizer=True)

            else:
                print("無效的選擇，請重新輸入。")

    except Exception as e:
        logger.error(f"程式執行時發生錯誤: {str(e)}")
        print(f"錯誤: {str(e)}")
        raise


def main_single_search(db_manager, use_standardizer=False):
    """處理單次搜尋的主邏輯

    Args:
        db_manager: 資料庫管理器
        use_standardizer: 是否使用標準化處理
    """
    while True:
        print("\n請輸入搜尋條件 (直接按 Enter 跳過):")
        original_vendor = input("廠商名稱: ").strip() or None
        original_product = input("產品名稱: ").strip() or None
        original_version = input("版本號: ").strip() or None

        if not any([original_vendor, original_product, original_version]):
            print("至少需要提供一個搜尋條件")
            continue

        try:
            if use_standardizer:
                # 標準化處理
                vendor, product, version = CPEInputStandardizer.standardize_input(
                    original_vendor, original_product, original_version)

                # 顯示標準化結果
                print("\n標準化後的搜尋條件:")
                print(
                    f"原始廠商: {original_vendor or '無'} -> 標準化: {vendor or '無'}")
                print(
                    f"原始產品: {original_product or '無'} -> 標準化: {product or '無'}")
                print(
                    f"原始版本: {original_version or '無'} -> 標準化: {version or '無'}")

                # 詢問是否使用標準化結果
                use_std = input(
                    "\n是否使用標準化結果進行搜尋? (y/n, 預設為y): ").strip().lower() != 'n'

                if use_std:
                    # 使用標準化結果
                    results = db_manager.search(
                        vendor=vendor, product=product, version=version)
                    print("\n使用標準化條件搜尋結果:")
                else:
                    # 使用原始輸入
                    results = db_manager.search(
                        vendor=original_vendor, product=original_product, version=original_version)
                    print("\n使用原始條件搜尋結果:")
            else:
                # 不使用標準化，直接搜尋
                results = db_manager.search(
                    vendor=original_vendor, product=original_product, version=original_version)
                print("\n搜尋結果:")

            print(SearchResultFormatter.format_search_results(results))

            if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                break
        except Exception as e:
            print(f"搜尋過程中發生錯誤: {str(e)}")
            if input("\n是否繼續搜尋？(y/n): ").strip().lower() != 'y':
                break


def main_batch_search(db_manager, use_standardizer=False):
    """處理批次搜尋的主邏輯

    Args:
        db_manager: 資料庫管理器
        use_standardizer: 是否使用標準化處理
    """
    csv_file_path = input("請輸入CSV檔案路徑: ").strip()
    if not os.path.exists(csv_file_path):
        print(f"找不到檔案: {csv_file_path}")
        return

    try:
        output_path = BatchSearcher.batch_search_from_csv(
            db_manager, csv_file_path, use_standardizer=use_standardizer
        )
        print(f"\n批次搜尋完成! 結果已輸出至: {output_path}")
    except Exception as e:
        print(f"批次搜尋失敗: {str(e)}")


if __name__ == "__main__":
    main()
# Out:
# 2025-03-13 07:46:04,872 - __main__ - INFO - 使用預設嵌入模型 (CPU)
# 2025-03-13 07:46:04,873 - __main__ - INFO - 使用嵌入模型: 預設
# 2025-03-13 07:46:04,914 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-03-13 07:46:05,000 - __main__ - INFO - 成功設定資料庫連接，儲存位置: ../database/cpe_database
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 2025-03-13 07:46:19,772 - __main__ - INFO - 開始從 ./transform_data.csv 批次搜尋，結果將輸出到 search_results_20250313_074619.txt
# 2025-03-13 07:46:19,775 - __main__ - INFO - 是否使用標準化預處理器: True
# 2025-03-13 07:46:22,400 - __main__ - INFO - 第 1 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,472 - __main__ - INFO - 第 2 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,524 - __main__ - INFO - 第 3 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,590 - __main__ - INFO - 第 4 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,663 - __main__ - INFO - 第 5 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,747 - __main__ - INFO - 第 6 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,822 - __main__ - INFO - 第 7 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,886 - __main__ - INFO - 第 8 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:22,958 - __main__ - INFO - 第 9 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,014 - __main__ - INFO - 第 10 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,076 - __main__ - INFO - 第 11 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,136 - __main__ - INFO - 第 12 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,200 - __main__ - INFO - 第 13 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,265 - __main__ - INFO - 第 14 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,323 - __main__ - INFO - 第 15 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,394 - __main__ - INFO - 第 16 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,472 - __main__ - INFO - 第 17 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,516 - __main__ - INFO - 第 18 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,572 - __main__ - INFO - 第 19 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,634 - __main__ - INFO - 第 20 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,699 - __main__ - INFO - 第 21 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,763 - __main__ - INFO - 第 22 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,813 - __main__ - INFO - 第 23 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,877 - __main__ - INFO - 第 24 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:23,937 - __main__ - INFO - 第 25 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,008 - __main__ - INFO - 第 26 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,064 - __main__ - INFO - 第 27 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,117 - __main__ - INFO - 第 28 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,167 - __main__ - INFO - 第 29 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,211 - __main__ - INFO - 第 30 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,250 - __main__ - INFO - 第 31 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,302 - __main__ - INFO - 第 32 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,361 - __main__ - INFO - 第 33 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,425 - __main__ - INFO - 第 34 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,494 - __main__ - INFO - 第 35 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,561 - __main__ - INFO - 第 36 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,616 - __main__ - INFO - 第 37 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,687 - __main__ - INFO - 第 38 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,773 - __main__ - INFO - 第 39 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,835 - __main__ - INFO - 第 40 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,900 - __main__ - INFO - 第 41 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:24,957 - __main__ - INFO - 第 42 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,025 - __main__ - INFO - 第 43 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,076 - __main__ - INFO - 第 44 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,137 - __main__ - INFO - 第 45 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,206 - __main__ - INFO - 第 46 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,267 - __main__ - INFO - 第 47 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,315 - __main__ - INFO - 第 48 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,395 - __main__ - INFO - 第 49 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,456 - __main__ - INFO - 第 50 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,521 - __main__ - INFO - 第 51 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,582 - __main__ - INFO - 第 52 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,646 - __main__ - INFO - 第 53 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,710 - __main__ - INFO - 第 54 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,763 - __main__ - INFO - 第 55 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,818 - __main__ - INFO - 第 56 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,873 - __main__ - INFO - 第 57 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:25,940 - __main__ - INFO - 第 58 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,029 - __main__ - INFO - 第 59 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,083 - __main__ - INFO - 第 60 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,138 - __main__ - INFO - 第 61 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,193 - __main__ - INFO - 第 62 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,247 - __main__ - INFO - 第 63 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,299 - __main__ - INFO - 第 64 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,366 - __main__ - INFO - 第 65 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,429 - __main__ - INFO - 第 66 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,491 - __main__ - INFO - 第 67 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,556 - __main__ - INFO - 第 68 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,620 - __main__ - INFO - 第 69 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,669 - __main__ - INFO - 第 70 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,748 - __main__ - INFO - 第 71 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,819 - __main__ - INFO - 第 72 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,867 - __main__ - INFO - 第 73 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,938 - __main__ - INFO - 第 74 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:26,999 - __main__ - INFO - 第 75 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,056 - __main__ - INFO - 第 76 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,128 - __main__ - INFO - 第 77 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,190 - __main__ - INFO - 第 78 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,246 - __main__ - INFO - 第 79 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,309 - __main__ - INFO - 第 80 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,386 - __main__ - INFO - 第 81 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,449 - __main__ - INFO - 第 82 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,507 - __main__ - INFO - 第 83 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,589 - __main__ - INFO - 第 84 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,711 - __main__ - INFO - 第 85 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,771 - __main__ - INFO - 第 86 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,875 - __main__ - INFO - 第 87 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:27,984 - __main__ - INFO - 第 88 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,069 - __main__ - INFO - 第 89 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,140 - __main__ - INFO - 第 90 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,213 - __main__ - INFO - 第 91 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,288 - __main__ - INFO - 第 92 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,366 - __main__ - INFO - 第 93 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,481 - __main__ - INFO - 第 94 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,554 - __main__ - INFO - 第 95 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,615 - __main__ - INFO - 第 96 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,683 - __main__ - INFO - 第 97 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,741 - __main__ - INFO - 第 98 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,798 - __main__ - INFO - 第 99 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,860 - __main__ - INFO - 第 100 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,902 - __main__ - INFO - 第 101 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:28,967 - __main__ - INFO - 第 102 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,016 - __main__ - INFO - 第 103 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,078 - __main__ - INFO - 第 104 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,144 - __main__ - INFO - 第 105 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,208 - __main__ - INFO - 第 106 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,263 - __main__ - INFO - 第 107 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,323 - __main__ - INFO - 第 108 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,384 - __main__ - INFO - 第 109 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,448 - __main__ - INFO - 第 110 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,509 - __main__ - INFO - 第 111 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,564 - __main__ - INFO - 第 112 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,612 - __main__ - INFO - 第 113 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,682 - __main__ - INFO - 第 114 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,746 - __main__ - INFO - 第 115 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,854 - __main__ - INFO - 第 116 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,922 - __main__ - INFO - 第 117 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:29,983 - __main__ - INFO - 第 118 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,031 - __main__ - INFO - 第 119 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,106 - __main__ - INFO - 第 120 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,177 - __main__ - INFO - 第 121 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,221 - __main__ - INFO - 第 122 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,285 - __main__ - INFO - 第 123 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,362 - __main__ - INFO - 第 124 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,420 - __main__ - INFO - 第 125 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,482 - __main__ - INFO - 第 126 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,535 - __main__ - INFO - 第 127 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,603 - __main__ - INFO - 第 128 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,667 - __main__ - INFO - 第 129 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,733 - __main__ - INFO - 第 130 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,794 - __main__ - INFO - 第 131 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,867 - __main__ - INFO - 第 132 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,934 - __main__ - INFO - 第 133 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:30,990 - __main__ - INFO - 第 134 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,063 - __main__ - INFO - 第 135 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,131 - __main__ - INFO - 第 136 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,199 - __main__ - INFO - 第 137 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,270 - __main__ - INFO - 第 138 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,327 - __main__ - INFO - 第 139 行: 搜尋成功，找到 1 筆結果
# 2025-03-13 07:46:31,393 - __main__ - INFO - 第 140 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,450 - __main__ - INFO - 第 141 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,512 - __main__ - INFO - 第 142 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,586 - __main__ - INFO - 第 143 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,642 - __main__ - INFO - 第 144 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,696 - __main__ - INFO - 第 145 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,757 - __main__ - INFO - 第 146 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,808 - __main__ - INFO - 第 147 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,868 - __main__ - INFO - 第 148 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,939 - __main__ - INFO - 第 149 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:31,984 - __main__ - INFO - 第 150 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,038 - __main__ - INFO - 第 151 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,087 - __main__ - INFO - 第 152 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,151 - __main__ - INFO - 第 153 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,211 - __main__ - INFO - 第 154 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,280 - __main__ - INFO - 第 155 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,333 - __main__ - INFO - 第 156 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,408 - __main__ - INFO - 第 157 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,484 - __main__ - INFO - 第 158 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,525 - __main__ - INFO - 第 159 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,601 - __main__ - INFO - 第 160 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,649 - __main__ - INFO - 第 161 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,707 - __main__ - INFO - 第 162 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,766 - __main__ - INFO - 第 163 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,817 - __main__ - INFO - 第 164 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,878 - __main__ - INFO - 第 165 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,940 - __main__ - INFO - 第 166 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:32,989 - __main__ - INFO - 第 167 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,038 - __main__ - INFO - 第 168 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,103 - __main__ - INFO - 第 169 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,160 - __main__ - INFO - 第 170 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,243 - __main__ - INFO - 第 171 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,318 - __main__ - INFO - 第 172 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,374 - __main__ - INFO - 第 173 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,436 - __main__ - INFO - 第 174 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,479 - __main__ - INFO - 第 175 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,545 - __main__ - INFO - 第 176 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,604 - __main__ - INFO - 第 177 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,686 - __main__ - INFO - 第 178 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,752 - __main__ - INFO - 第 179 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,841 - __main__ - INFO - 第 180 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,909 - __main__ - INFO - 第 181 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:33,957 - __main__ - INFO - 第 182 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,014 - __main__ - INFO - 第 183 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,078 - __main__ - INFO - 第 184 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,152 - __main__ - INFO - 第 185 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,216 - __main__ - INFO - 第 186 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,285 - __main__ - INFO - 第 187 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,332 - __main__ - INFO - 第 188 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,384 - __main__ - INFO - 第 189 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,440 - __main__ - INFO - 第 190 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,497 - __main__ - INFO - 第 191 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,542 - __main__ - INFO - 第 192 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,615 - __main__ - INFO - 第 193 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,671 - __main__ - INFO - 第 194 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,721 - __main__ - INFO - 第 195 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,781 - __main__ - INFO - 第 196 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,848 - __main__ - INFO - 第 197 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,908 - __main__ - INFO - 第 198 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:34,957 - __main__ - INFO - 第 199 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,020 - __main__ - INFO - 第 200 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,074 - __main__ - INFO - 第 201 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,127 - __main__ - INFO - 第 202 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,195 - __main__ - INFO - 第 203 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,250 - __main__ - INFO - 第 204 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,316 - __main__ - INFO - 第 205 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,382 - __main__ - INFO - 第 206 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,436 - __main__ - INFO - 第 207 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,496 - __main__ - INFO - 第 208 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,550 - __main__ - INFO - 第 209 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,617 - __main__ - INFO - 第 210 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,698 - __main__ - INFO - 第 211 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,759 - __main__ - INFO - 第 212 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,824 - __main__ - INFO - 第 213 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,883 - __main__ - INFO - 第 214 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:35,939 - __main__ - INFO - 第 215 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,004 - __main__ - INFO - 第 216 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,082 - __main__ - INFO - 第 217 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,143 - __main__ - INFO - 第 218 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,199 - __main__ - INFO - 第 219 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,256 - __main__ - INFO - 第 220 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,328 - __main__ - INFO - 第 221 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,387 - __main__ - INFO - 第 222 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,439 - __main__ - INFO - 第 223 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,492 - __main__ - INFO - 第 224 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,555 - __main__ - INFO - 第 225 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,616 - __main__ - INFO - 第 226 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,680 - __main__ - INFO - 第 227 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,745 - __main__ - INFO - 第 228 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,810 - __main__ - INFO - 第 229 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,870 - __main__ - INFO - 第 230 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,930 - __main__ - INFO - 第 231 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:36,990 - __main__ - INFO - 第 232 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,059 - __main__ - INFO - 第 233 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,117 - __main__ - INFO - 第 234 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,160 - __main__ - INFO - 第 235 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,216 - __main__ - INFO - 第 236 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,278 - __main__ - INFO - 第 237 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,340 - __main__ - INFO - 第 238 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,404 - __main__ - INFO - 第 239 行: 搜尋成功，但沒有符合的結果
# 2025-03-13 07:46:37,405 - __main__ - INFO - 批次搜尋完成，共處理 239 項，1 項有結果
# 批次搜尋完成! 結果已輸出至: search_results_20250313_074619.txt
#
# === CPE 資料庫管理工具 ===
# 1. 導入 CPE 資料
# 2. 查看集合資訊
# 3. 單次搜尋
# 4. 單次搜尋 (含標準化預處理)
# 5. 從CSV檔案批次搜尋
# 6. 從CSV檔案批次搜尋 (含標準化預處理)
# 0. 退出
# 程式已結束。
